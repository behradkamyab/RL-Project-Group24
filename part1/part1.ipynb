# %%
# %pip install -r ../requirements.txt
# Out:
# Requirement already satisfied: gymnasium in /Users/nioosha/work/project/RL-Project-Group24/.venv/lib/python3.13/site-packages (from -r ../requirements.txt (line 1)) (1.2.3)
# Requirement already satisfied: mujoco in /Users/nioosha/work/project/RL-Project-Group24/.venv/lib/python3.13/site-packages (from -r ../requirements.txt (line 2)) (3.8.1)
# Requirement already satisfied: stable-baselines3>=2.0.0 in /Users/nioosha/work/project/RL-Project-Group24/.venv/lib/python3.13/site-packages (from stable-baselines3[extra]>=2.0.0->-r ../requirements.txt (line 3)) (2.8.0)
# Requirement already satisfied: imageio in /Users/nioosha/work/project/RL-Project-Group24/.venv/lib/python3.13/site-packages (from -r ../requirements.txt (line 4)) (2.37.3)
# Requirement already satisfied: opencv-python<4 in /Users/nioosha/work/project/RL-Project-Group24/.venv/lib/python3.13/site-packages (from -r ../requirements.txt (line 5)) (3.4.18.65)
# Requirement already satisfied: numpy>=1.21.2 in /Users/nioosha/work/project/RL-Project-Group24/.venv/lib/python3.13/site-packages (from opencv-python<4->-r ../requirements.txt (line 5)) (2.4.5)
# Requirement already satisfied: cloudpickle>=1.2.0 in /Users/nioosha/work/project/RL-Project-Group24/.venv/lib/python3.13/site-packages (from gymnasium->-r ../requirements.txt (line 1)) (3.1.2)
# Requirement already satisfied: typing-extensions>=4.3.0 in /Users/nioosha/work/project/RL-Project-Group24/.venv/lib/python3.13/site-packages (from gymnasium->-r ../requirements.txt (line 1)) (4.15.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /Users/nioosha/work/project/RL-Project-Group24/.venv/lib/python3.13/site-packages (from gymnasium->-r ../requirements.txt (line 1)) (0.0.6)
# Requirement already satisfied: absl-py in /Users/nioosha/work/project/RL-Project-Group24/.venv/lib/python3.13/site-packages (from mujoco->-r ../requirements.txt (line 2)) (2.4.0)
# Requirement already satisfied: etils[epath] in /Users/nioosha/work/project/RL-Project-Group24/.venv/lib/python3.13/site-packages (from mujoco->-r ../requirements.txt (line 2)) (1.14.0)
# Requirement already satisfied: glfw in /Users/nioosha/work/project/RL-Project-Group24/.venv/lib/python3.13/site-packages (from mujoco->-r ../requirements.txt (line 2)) (2.10.0)
# Requirement already satisfied: pyopengl in /Users/nioosha/work/project/RL-Project-Group24/.venv/lib/python3.13/site-packages (from mujoco->-r ../requirements.txt (line 2)) (3.1.10)
# Requirement already satisfied: torch<3.0,>=2.3 in /Users/nioosha/work/project/RL-Project-Group24/.venv/lib/python3.13/site-packages (from stable-baselines3>=2.0.0->stable-baselines3[extra]>=2.0.0->-r ../requirements.txt (line 3)) (2.12.0)
# Requirement already satisfied: pandas in /Users/nioosha/work/project/RL-Project-Group24/.venv/lib/python3.13/site-packages (from stable-baselines3>=2.0.0->stable-baselines3[extra]>=2.0.0->-r ../requirements.txt (line 3)) (3.0.3)
# Requirement already satisfied: matplotlib in /Users/nioosha/work/project/RL-Project-Group24/.venv/lib/python3.13/site-packages (from stable-baselines3>=2.0.0->stable-baselines3[extra]>=2.0.0->-r ../requirements.txt (line 3)) (3.10.9)
# Requirement already satisfied: filelock in /Users/nioosha/work/project/RL-Project-Group24/.venv/lib/python3.13/site-packages (from torch<3.0,>=2.3->stable-baselines3>=2.0.0->stable-baselines3[extra]>=2.0.0->-r ../requirements.txt (line 3)) (3.29.0)
# Requirement already satisfied: setuptools<82 in /Users/nioosha/work/project/RL-Project-Group24/.venv/lib/python3.13/site-packages (from torch<3.0,>=2.3->stable-baselines3>=2.0.0->stable-baselines3[extra]>=2.0.0->-r ../requirements.txt (line 3)) (81.0.0)
# Requirement already satisfied: sympy>=1.13.3 in /Users/nioosha/work/project/RL-Project-Group24/.venv/lib/python3.13/site-packages (from torch<3.0,>=2.3->stable-baselines3>=2.0.0->stable-baselines3[extra]>=2.0.0->-r ../requirements.txt (line 3)) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /Users/nioosha/work/project/RL-Project-Group24/.venv/lib/python3.13/site-packages (from torch<3.0,>=2.3->stable-baselines3>=2.0.0->stable-baselines3[extra]>=2.0.0->-r ../requirements.txt (line 3)) (3.6.1)
# Requirement already satisfied: jinja2 in /Users/nioosha/work/project/RL-Project-Group24/.venv/lib/python3.13/site-packages (from torch<3.0,>=2.3->stable-baselines3>=2.0.0->stable-baselines3[extra]>=2.0.0->-r ../requirements.txt (line 3)) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /Users/nioosha/work/project/RL-Project-Group24/.venv/lib/python3.13/site-packages (from torch<3.0,>=2.3->stable-baselines3>=2.0.0->stable-baselines3[extra]>=2.0.0->-r ../requirements.txt (line 3)) (2026.4.0)
# Requirement already satisfied: pillow>=8.3.2 in /Users/nioosha/work/project/RL-Project-Group24/.venv/lib/python3.13/site-packages (from imageio->-r ../requirements.txt (line 4)) (12.2.0)
# Requirement already satisfied: pygame-ce in /Users/nioosha/work/project/RL-Project-Group24/.venv/lib/python3.13/site-packages (from stable-baselines3[extra]>=2.0.0->-r ../requirements.txt (line 3)) (2.5.7)
# Requirement already satisfied: tensorboard>=2.9.1 in /Users/nioosha/work/project/RL-Project-Group24/.venv/lib/python3.13/site-packages (from stable-baselines3[extra]>=2.0.0->-r ../requirements.txt (line 3)) (2.20.0)
# Requirement already satisfied: psutil in /Users/nioosha/work/project/RL-Project-Group24/.venv/lib/python3.13/site-packages (from stable-baselines3[extra]>=2.0.0->-r ../requirements.txt (line 3)) (7.2.2)
# Requirement already satisfied: tqdm in /Users/nioosha/work/project/RL-Project-Group24/.venv/lib/python3.13/site-packages (from stable-baselines3[extra]>=2.0.0->-r ../requirements.txt (line 3)) (4.67.3)
# Requirement already satisfied: rich in /Users/nioosha/work/project/RL-Project-Group24/.venv/lib/python3.13/site-packages (from stable-baselines3[extra]>=2.0.0->-r ../requirements.txt (line 3)) (15.0.0)
# Requirement already satisfied: ale-py>=0.9.0 in /Users/nioosha/work/project/RL-Project-Group24/.venv/lib/python3.13/site-packages (from stable-baselines3[extra]>=2.0.0->-r ../requirements.txt (line 3)) (0.11.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/nioosha/work/project/RL-Project-Group24/.venv/lib/python3.13/site-packages (from sympy>=1.13.3->torch<3.0,>=2.3->stable-baselines3>=2.0.0->stable-baselines3[extra]>=2.0.0->-r ../requirements.txt (line 3)) (1.3.0)
# Requirement already satisfied: grpcio>=1.48.2 in /Users/nioosha/work/project/RL-Project-Group24/.venv/lib/python3.13/site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0->-r ../requirements.txt (line 3)) (1.80.0)
# Requirement already satisfied: markdown>=2.6.8 in /Users/nioosha/work/project/RL-Project-Group24/.venv/lib/python3.13/site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0->-r ../requirements.txt (line 3)) (3.10.2)
# Requirement already satisfied: packaging in /Users/nioosha/work/project/RL-Project-Group24/.venv/lib/python3.13/site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0->-r ../requirements.txt (line 3)) (26.2)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in /Users/nioosha/work/project/RL-Project-Group24/.venv/lib/python3.13/site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0->-r ../requirements.txt (line 3)) (7.34.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /Users/nioosha/work/project/RL-Project-Group24/.venv/lib/python3.13/site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0->-r ../requirements.txt (line 3)) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /Users/nioosha/work/project/RL-Project-Group24/.venv/lib/python3.13/site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0->-r ../requirements.txt (line 3)) (3.1.8)
# Requirement already satisfied: markupsafe>=2.1.1 in /Users/nioosha/work/project/RL-Project-Group24/.venv/lib/python3.13/site-packages (from werkzeug>=1.0.1->tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0->-r ../requirements.txt (line 3)) (3.0.3)
# Requirement already satisfied: zipp in /Users/nioosha/work/project/RL-Project-Group24/.venv/lib/python3.13/site-packages (from etils[epath]->mujoco->-r ../requirements.txt (line 2)) (3.23.1)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/nioosha/work/project/RL-Project-Group24/.venv/lib/python3.13/site-packages (from matplotlib->stable-baselines3>=2.0.0->stable-baselines3[extra]>=2.0.0->-r ../requirements.txt (line 3)) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /Users/nioosha/work/project/RL-Project-Group24/.venv/lib/python3.13/site-packages (from matplotlib->stable-baselines3>=2.0.0->stable-baselines3[extra]>=2.0.0->-r ../requirements.txt (line 3)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/nioosha/work/project/RL-Project-Group24/.venv/lib/python3.13/site-packages (from matplotlib->stable-baselines3>=2.0.0->stable-baselines3[extra]>=2.0.0->-r ../requirements.txt (line 3)) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/nioosha/work/project/RL-Project-Group24/.venv/lib/python3.13/site-packages (from matplotlib->stable-baselines3>=2.0.0->stable-baselines3[extra]>=2.0.0->-r ../requirements.txt (line 3)) (1.5.0)
# Requirement already satisfied: pyparsing>=3 in /Users/nioosha/work/project/RL-Project-Group24/.venv/lib/python3.13/site-packages (from matplotlib->stable-baselines3>=2.0.0->stable-baselines3[extra]>=2.0.0->-r ../requirements.txt (line 3)) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/nioosha/work/project/RL-Project-Group24/.venv/lib/python3.13/site-packages (from matplotlib->stable-baselines3>=2.0.0->stable-baselines3[extra]>=2.0.0->-r ../requirements.txt (line 3)) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /Users/nioosha/work/project/RL-Project-Group24/.venv/lib/python3.13/site-packages (from python-dateutil>=2.7->matplotlib->stable-baselines3>=2.0.0->stable-baselines3[extra]>=2.0.0->-r ../requirements.txt (line 3)) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/nioosha/work/project/RL-Project-Group24/.venv/lib/python3.13/site-packages (from rich->stable-baselines3[extra]>=2.0.0->-r ../requirements.txt (line 3)) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/nioosha/work/project/RL-Project-Group24/.venv/lib/python3.13/site-packages (from rich->stable-baselines3[extra]>=2.0.0->-r ../requirements.txt (line 3)) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /Users/nioosha/work/project/RL-Project-Group24/.venv/lib/python3.13/site-packages (from markdown-it-py>=2.2.0->rich->stable-baselines3[extra]>=2.0.0->-r ../requirements.txt (line 3)) (0.1.2)
#
# [notice] A new release of pip is available: 26.1.1 -> 26.1.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
from train import main

history_none = main(baseline_mode='none', n_episodes=3000)
# Out:
# State space: Box(-inf, inf, (11,), float64)
# Action space: Box(-1.0, 1.0, (3,), float32)
# Episode    0  return=   10  avg(last 20)=   9.7
# Episode   20  return=    2  avg(last 20)=   8.7
# Episode   40  return=    6  avg(last 20)=  18.9
# Episode   60  return=    8  avg(last 20)=  21.4
# Episode   80  return=   25  avg(last 20)=  26.9
# Episode  100  return=   23  avg(last 20)=  23.0
# Episode  120  return=   35  avg(last 20)=  36.4
# Episode  140  return=  393  avg(last 20)= 160.6
# Episode  160  return=  178  avg(last 20)= 270.4
# Episode  180  return=  174  avg(last 20)= 138.9
# Episode  200  return=  175  avg(last 20)= 136.1
# Episode  220  return=  168  avg(last 20)= 220.4
# Episode  240  return=  461  avg(last 20)= 545.3
# Episode  260  return=  278  avg(last 20)= 363.6
# Episode  280  return=  189  avg(last 20)= 195.5
# Episode  300  return=  147  avg(last 20)= 159.3
# Episode  320  return=  112  avg(last 20)= 113.0
# Episode  340  return=  211  avg(last 20)= 186.5
# Episode  360  return=  202  avg(last 20)= 200.9
# Episode  380  return=  132  avg(last 20)= 185.2
# Episode  400  return=   74  avg(last 20)=  83.7
# Episode  420  return=   69  avg(last 20)=  71.8
# Episode  440  return=   68  avg(last 20)=  69.5
# Episode  460  return=   75  avg(last 20)=  71.1
# Episode  480  return=   82  avg(last 20)=  76.7
# Episode  500  return=   96  avg(last 20)=  86.8
# Episode  520  return=  121  avg(last 20)= 121.3
# Episode  540  return=   87  avg(last 20)= 109.1
# Episode  560  return=   84  avg(last 20)=  83.9
# Episode  580  return=   87  avg(last 20)=  89.5
# Episode  600  return=  161  avg(last 20)= 123.9
# Episode  620  return=  197  avg(last 20)= 184.4
# Episode  640  return=  211  avg(last 20)= 208.1
# Episode  660  return=  187  avg(last 20)= 201.0
# Episode  680  return=  187  avg(last 20)= 187.9
# Episode  700  return=  184  avg(last 20)= 185.6
# Episode  720  return=  194  avg(last 20)= 189.5
# Episode  740  return=  199  avg(last 20)= 197.6
# Episode  760  return=  206  avg(last 20)= 202.6
# Episode  780  return=  206  avg(last 20)= 206.7
# Episode  800  return=  210  avg(last 20)= 207.5
# Episode  820  return=  207  avg(last 20)= 208.8
# Episode  840  return=  208  avg(last 20)= 207.7
# Episode  860  return=  205  avg(last 20)= 206.5
# Episode  880  return=  206  avg(last 20)= 193.8
# Episode  900  return=  210  avg(last 20)= 215.6
# Episode  920  return=  212  avg(last 20)= 213.1
# Episode  940  return=  218  avg(last 20)= 215.7
# Episode  960  return=  216  avg(last 20)= 217.8
# Episode  980  return=  220  avg(last 20)= 216.5
# Episode 1000  return=  211  avg(last 20)= 213.1
# Episode 1020  return=  226  avg(last 20)= 216.9
# Episode 1040  return=  218  avg(last 20)= 225.4
# Episode 1060  return=  226  avg(last 20)= 225.6
# Episode 1080  return=  247  avg(last 20)= 238.3
# Episode 1100  return=  210  avg(last 20)= 232.3
# Episode 1120  return=  230  avg(last 20)= 231.4
# Episode 1140  return=  236  avg(last 20)= 237.6
# Episode 1160  return=  217  avg(last 20)= 224.2
# Episode 1180  return=  211  avg(last 20)= 214.1
# Episode 1200  return=  215  avg(last 20)= 210.7
# Episode 1220  return=  211  avg(last 20)= 210.8
# Episode 1240  return=  212  avg(last 20)= 210.4
# Episode 1260  return=  209  avg(last 20)= 207.4
# Episode 1280  return=  207  avg(last 20)= 209.4
# Episode 1300  return=  223  avg(last 20)= 210.8
# Episode 1320  return=  217  avg(last 20)= 217.4
# Episode 1340  return=  220  avg(last 20)= 209.4
# Episode 1360  return=  221  avg(last 20)= 215.8
# Episode 1380  return=  232  avg(last 20)= 209.6
# Episode 1400  return=  251  avg(last 20)= 208.6
# Episode 1420  return=  202  avg(last 20)= 207.1
# Episode 1440  return=  301  avg(last 20)= 242.9
# Episode 1460  return=  305  avg(last 20)= 275.0
# Episode 1480  return=  128  avg(last 20)= 238.5
# Episode 1500  return=  144  avg(last 20)= 200.3
# Episode 1520  return=   73  avg(last 20)= 117.4
# Episode 1540  return=   75  avg(last 20)= 108.3
# Episode 1560  return=   58  avg(last 20)=  88.9
# Episode 1580  return=  185  avg(last 20)= 117.6
# Episode 1600  return=   74  avg(last 20)= 123.7
# Episode 1620  return=   39  avg(last 20)=  53.8
# Episode 1640  return=   40  avg(last 20)=  40.0
# Episode 1660  return=   38  avg(last 20)=  36.8
# Episode 1680  return=   39  avg(last 20)=  37.3
# Episode 1700  return=   35  avg(last 20)=  35.3
# Episode 1720  return=   36  avg(last 20)=  34.0
# Episode 1740  return=   28  avg(last 20)=  31.1
# Episode 1760  return=   28  avg(last 20)=  28.6
# Episode 1780  return=   26  avg(last 20)=  27.7
# Episode 1800  return=   26  avg(last 20)=  27.2
# Episode 1820  return=   26  avg(last 20)=  27.2
# Episode 1840  return=   27  avg(last 20)=  26.5
# Episode 1860  return=   26  avg(last 20)=  26.2
# Episode 1880  return=   26  avg(last 20)=  26.0
# Episode 1900  return=   27  avg(last 20)=  26.1
# Episode 1920  return=   26  avg(last 20)=  26.1
# Episode 1940  return=   26  avg(last 20)=  25.9
# Episode 1960  return=   27  avg(last 20)=  26.3
# Episode 1980  return=   25  avg(last 20)=  26.5
# Episode 2000  return=   26  avg(last 20)=  26.3
# Episode 2020  return=   26  avg(last 20)=  25.7
# Episode 2040  return=   26  avg(last 20)=  26.0
# Episode 2060  return=   26  avg(last 20)=  26.2
# Episode 2080  return=   26  avg(last 20)=  26.6
# Episode 2100  return=   27  avg(last 20)=  26.7
# Episode 2120  return=   26  avg(last 20)=  27.1
# Episode 2140  return=   27  avg(last 20)=  27.1
# Episode 2160  return=   28  avg(last 20)=  27.5
# Episode 2180  return=   27  avg(last 20)=  26.7
# Episode 2200  return=   28  avg(last 20)=  27.0
# Episode 2220  return=   28  avg(last 20)=  27.3
# Episode 2240  return=   27  avg(last 20)=  27.1
# Episode 2260  return=   29  avg(last 20)=  27.9
# Episode 2280  return=   28  avg(last 20)=  27.5
# Episode 2300  return=   29  avg(last 20)=  27.4
# Episode 2320  return=   30  avg(last 20)=  28.8
# Episode 2340  return=   33  avg(last 20)=  29.6
# Episode 2360  return=   27  avg(last 20)=  30.2
# Episode 2380  return=   28  avg(last 20)=  28.3
# Episode 2400  return=   32  avg(last 20)=  28.5
# Episode 2420  return=   31  avg(last 20)=  30.6
# Episode 2440  return=   29  avg(last 20)=  29.0
# Episode 2460  return=   29  avg(last 20)=  28.6
# Episode 2480  return=   27  avg(last 20)=  27.1
# Episode 2500  return=   28  avg(last 20)=  27.5
# Episode 2520  return=   27  avg(last 20)=  29.1
# Episode 2540  return=   37  avg(last 20)=  30.3
# Episode 2560  return=   36  avg(last 20)=  33.9
# Episode 2580  return=   35  avg(last 20)=  39.6
# Episode 2600  return=   41  avg(last 20)=  39.1
# Episode 2620  return=   34  avg(last 20)=  40.3
# Episode 2640  return=   33  avg(last 20)=  37.7
# Episode 2660  return=   32  avg(last 20)=  38.7
# Episode 2680  return=   41  avg(last 20)=  43.5
# Episode 2700  return=   48  avg(last 20)=  47.0
# Episode 2720  return=   55  avg(last 20)=  47.6
# Episode 2740  return=   81  avg(last 20)=  49.6
# Episode 2760  return=   63  avg(last 20)=  62.2
# Episode 2780  return=   54  avg(last 20)=  59.3
# Episode 2800  return=   69  avg(last 20)=  56.8
# Episode 2820  return=   30  avg(last 20)=  50.2
# Episode 2840  return=   68  avg(last 20)=  42.9
# Episode 2860  return=   42  avg(last 20)=  37.0
# Episode 2880  return=   57  avg(last 20)=  39.2
# Episode 2900  return=   54  avg(last 20)=  49.2
# Episode 2920  return=   24  avg(last 20)=  55.2
# Episode 2940  return=   60  avg(last 20)=  60.0
# Episode 2960  return=   27  avg(last 20)=  59.8
# Episode 2980  return=   49  avg(last 20)=  53.6
# Saved model_none.pt and history_none.pkl and time_none.pkl

# %%
history_const_0   = main(baseline_mode='constant', baseline_value=0, n_episodes=3000)
history_const_20  = main(baseline_mode='constant', baseline_value=20, n_episodes=3000)
history_const_100 = main(baseline_mode='constant', baseline_value=100, n_episodes=3000)
# Out:
# State space: Box(-inf, inf, (11,), float64)
# Action space: Box(-1.0, 1.0, (3,), float32)
# Episode    0  return=   10  avg(last 20)=   9.7
# Episode   20  return=    2  avg(last 20)=   8.7
# Episode   40  return=    6  avg(last 20)=  18.9
# Episode   60  return=    8  avg(last 20)=  21.4
# Episode   80  return=   25  avg(last 20)=  26.9
# Episode  100  return=   23  avg(last 20)=  23.0
# Episode  120  return=   35  avg(last 20)=  36.4
# Episode  140  return=  393  avg(last 20)= 160.6
# Episode  160  return=  178  avg(last 20)= 270.4
# Episode  180  return=  174  avg(last 20)= 138.9
# Episode  200  return=  175  avg(last 20)= 136.1
# Episode  220  return=  168  avg(last 20)= 220.4
# Episode  240  return=  461  avg(last 20)= 545.3
# Episode  260  return=  278  avg(last 20)= 363.6
# Episode  280  return=  189  avg(last 20)= 195.5
# Episode  300  return=  147  avg(last 20)= 159.3
# Episode  320  return=  112  avg(last 20)= 113.0
# Episode  340  return=  211  avg(last 20)= 186.5
# Episode  360  return=  202  avg(last 20)= 200.9
# Episode  380  return=  132  avg(last 20)= 185.2
# Episode  400  return=   74  avg(last 20)=  83.7
# Episode  420  return=   69  avg(last 20)=  71.8
# Episode  440  return=   68  avg(last 20)=  69.5
# Episode  460  return=   75  avg(last 20)=  71.1
# Episode  480  return=   82  avg(last 20)=  76.7
# Episode  500  return=   96  avg(last 20)=  86.8
# Episode  520  return=  121  avg(last 20)= 121.3
# Episode  540  return=   87  avg(last 20)= 109.1
# Episode  560  return=   84  avg(last 20)=  83.9
# Episode  580  return=   87  avg(last 20)=  89.5
# Episode  600  return=  161  avg(last 20)= 123.9
# Episode  620  return=  197  avg(last 20)= 184.4
# Episode  640  return=  211  avg(last 20)= 208.1
# Episode  660  return=  187  avg(last 20)= 201.0
# Episode  680  return=  187  avg(last 20)= 187.9
# Episode  700  return=  184  avg(last 20)= 185.6
# Episode  720  return=  194  avg(last 20)= 189.5
# Episode  740  return=  199  avg(last 20)= 197.6
# Episode  760  return=  206  avg(last 20)= 202.6
# Episode  780  return=  206  avg(last 20)= 206.7
# Episode  800  return=  210  avg(last 20)= 207.5
# Episode  820  return=  207  avg(last 20)= 208.8
# Episode  840  return=  208  avg(last 20)= 207.7
# Episode  860  return=  205  avg(last 20)= 206.5
# Episode  880  return=  206  avg(last 20)= 193.8
# Episode  900  return=  210  avg(last 20)= 215.6
# Episode  920  return=  212  avg(last 20)= 213.1
# Episode  940  return=  218  avg(last 20)= 215.7
# Episode  960  return=  216  avg(last 20)= 217.8
# Episode  980  return=  220  avg(last 20)= 216.5
# Episode 1000  return=  211  avg(last 20)= 213.1
# Episode 1020  return=  226  avg(last 20)= 216.9
# Episode 1040  return=  218  avg(last 20)= 225.4
# Episode 1060  return=  226  avg(last 20)= 225.6
# Episode 1080  return=  247  avg(last 20)= 238.3
# Episode 1100  return=  210  avg(last 20)= 232.3
# Episode 1120  return=  230  avg(last 20)= 231.4
# Episode 1140  return=  236  avg(last 20)= 237.6
# Episode 1160  return=  217  avg(last 20)= 224.2
# Episode 1180  return=  211  avg(last 20)= 214.1
# Episode 1200  return=  215  avg(last 20)= 210.7
# Episode 1220  return=  211  avg(last 20)= 210.8
# Episode 1240  return=  212  avg(last 20)= 210.4
# Episode 1260  return=  209  avg(last 20)= 207.4
# Episode 1280  return=  207  avg(last 20)= 209.4
# Episode 1300  return=  223  avg(last 20)= 210.8
# Episode 1320  return=  217  avg(last 20)= 217.4
# Episode 1340  return=  220  avg(last 20)= 209.4
# Episode 1360  return=  221  avg(last 20)= 215.8
# Episode 1380  return=  232  avg(last 20)= 209.6
# Episode 1400  return=  251  avg(last 20)= 208.6
# Episode 1420  return=  202  avg(last 20)= 207.1
# Episode 1440  return=  301  avg(last 20)= 242.9
# Episode 1460  return=  305  avg(last 20)= 275.0
# Episode 1480  return=  128  avg(last 20)= 238.5
# Episode 1500  return=  144  avg(last 20)= 200.3
# Episode 1520  return=   73  avg(last 20)= 117.4
# Episode 1540  return=   75  avg(last 20)= 108.3
# Episode 1560  return=   58  avg(last 20)=  88.9
# Episode 1580  return=  185  avg(last 20)= 117.6
# Episode 1600  return=   74  avg(last 20)= 123.7
# Episode 1620  return=   39  avg(last 20)=  53.8
# Episode 1640  return=   40  avg(last 20)=  40.0
# Episode 1660  return=   38  avg(last 20)=  36.8
# Episode 1680  return=   39  avg(last 20)=  37.3
# Episode 1700  return=   35  avg(last 20)=  35.3
# Episode 1720  return=   36  avg(last 20)=  34.0
# Episode 1740  return=   28  avg(last 20)=  31.1
# Episode 1760  return=   28  avg(last 20)=  28.6
# Episode 1780  return=   26  avg(last 20)=  27.7
# Episode 1800  return=   26  avg(last 20)=  27.2
# Episode 1820  return=   26  avg(last 20)=  27.2
# Episode 1840  return=   27  avg(last 20)=  26.5
# Episode 1860  return=   26  avg(last 20)=  26.2
# Episode 1880  return=   26  avg(last 20)=  26.0
# Episode 1900  return=   27  avg(last 20)=  26.1
# Episode 1920  return=   26  avg(last 20)=  26.1
# Episode 1940  return=   26  avg(last 20)=  25.9
# Episode 1960  return=   27  avg(last 20)=  26.3
# Episode 1980  return=   25  avg(last 20)=  26.5
# Episode 2000  return=   26  avg(last 20)=  26.3
# Episode 2020  return=   26  avg(last 20)=  25.7
# Episode 2040  return=   26  avg(last 20)=  26.0
# Episode 2060  return=   26  avg(last 20)=  26.2
# Episode 2080  return=   26  avg(last 20)=  26.6
# Episode 2100  return=   27  avg(last 20)=  26.7
# Episode 2120  return=   26  avg(last 20)=  27.1
# Episode 2140  return=   27  avg(last 20)=  27.1
# Episode 2160  return=   28  avg(last 20)=  27.5
# Episode 2180  return=   27  avg(last 20)=  26.7
# Episode 2200  return=   28  avg(last 20)=  27.0
# Episode 2220  return=   28  avg(last 20)=  27.3
# Episode 2240  return=   27  avg(last 20)=  27.1
# Episode 2260  return=   29  avg(last 20)=  27.9
# Episode 2280  return=   28  avg(last 20)=  27.5
# Episode 2300  return=   29  avg(last 20)=  27.4
# Episode 2320  return=   30  avg(last 20)=  28.8
# Episode 2340  return=   33  avg(last 20)=  29.6
# Episode 2360  return=   27  avg(last 20)=  30.2
# Episode 2380  return=   28  avg(last 20)=  28.3
# Episode 2400  return=   32  avg(last 20)=  28.5
# Episode 2420  return=   31  avg(last 20)=  30.6
# Episode 2440  return=   29  avg(last 20)=  29.0
# Episode 2460  return=   29  avg(last 20)=  28.6
# Episode 2480  return=   27  avg(last 20)=  27.1
# Episode 2500  return=   28  avg(last 20)=  27.5
# Episode 2520  return=   27  avg(last 20)=  29.1
# Episode 2540  return=   37  avg(last 20)=  30.3
# Episode 2560  return=   36  avg(last 20)=  33.9
# Episode 2580  return=   35  avg(last 20)=  39.6
# Episode 2600  return=   41  avg(last 20)=  39.1
# Episode 2620  return=   34  avg(last 20)=  40.3
# Episode 2640  return=   33  avg(last 20)=  37.7
# Episode 2660  return=   32  avg(last 20)=  38.7
# Episode 2680  return=   41  avg(last 20)=  43.5
# Episode 2700  return=   48  avg(last 20)=  47.0
# Episode 2720  return=   55  avg(last 20)=  47.6
# Episode 2740  return=   81  avg(last 20)=  49.6
# Episode 2760  return=   63  avg(last 20)=  62.2
# Episode 2780  return=   54  avg(last 20)=  59.3
# Episode 2800  return=   69  avg(last 20)=  56.8
# Episode 2820  return=   30  avg(last 20)=  50.2
# Episode 2840  return=   68  avg(last 20)=  42.9
# Episode 2860  return=   42  avg(last 20)=  37.0
# Episode 2880  return=   57  avg(last 20)=  39.2
# Episode 2900  return=   54  avg(last 20)=  49.2
# Episode 2920  return=   24  avg(last 20)=  55.2
# Episode 2940  return=   60  avg(last 20)=  60.0
# Episode 2960  return=   27  avg(last 20)=  59.8
# Episode 2980  return=   49  avg(last 20)=  53.6
# Saved model_constant_b0.pt and history_constant_b0.pkl and time_constant_b0.pkl
# State space: Box(-inf, inf, (11,), float64)
# Action space: Box(-1.0, 1.0, (3,), float32)
# Episode    0  return=   10  avg(last 20)=   9.7
# Episode   20  return=    7  avg(last 20)=  20.9
# Episode   40  return=   51  avg(last 20)=  36.6
# Episode   60  return=   56  avg(last 20)=  59.4
# Episode   80  return=   65  avg(last 20)=  89.0
# Episode  100  return=  362  avg(last 20)= 156.7
# Episode  120  return=   72  avg(last 20)= 204.3
# Episode  140  return=  188  avg(last 20)= 146.0
# Episode  160  return=  117  avg(last 20)= 175.3
# Episode  180  return=  183  avg(last 20)= 173.6
# Episode  200  return=  195  avg(last 20)= 193.2
# Episode  220  return=  158  avg(last 20)= 142.6
# Episode  240  return=  155  avg(last 20)= 153.9
# Episode  260  return=  197  avg(last 20)= 174.9
# Episode  280  return=  203  avg(last 20)= 202.4
# Episode  300  return=  211  avg(last 20)= 200.1
# Episode  320  return=  232  avg(last 20)= 190.0
# Episode  340  return=  199  avg(last 20)= 170.6
# Episode  360  return=  234  avg(last 20)= 218.4
# Episode  380  return=  255  avg(last 20)= 248.7
# Episode  400  return=  227  avg(last 20)= 229.6
# Episode  420  return=  153  avg(last 20)= 196.7
# Episode  440  return=  210  avg(last 20)= 182.7
# Episode  460  return=  190  avg(last 20)= 199.2
# Episode  480  return=  146  avg(last 20)= 191.0
# Episode  500  return=  208  avg(last 20)= 195.7
# Episode  520  return=  218  avg(last 20)= 219.9
# Episode  540  return=  167  avg(last 20)= 173.2
# Episode  560  return=  207  avg(last 20)= 181.8
# Episode  580  return=  204  avg(last 20)= 206.4
# Episode  600  return=  133  avg(last 20)= 137.6
# Episode  620  return=  193  avg(last 20)= 186.2
# Episode  640  return=  195  avg(last 20)= 191.6
# Episode  660  return=  172  avg(last 20)= 179.2
# Episode  680  return=  172  avg(last 20)= 167.4
# Episode  700  return=  169  avg(last 20)= 166.5
# Episode  720  return=  182  avg(last 20)= 181.2
# Episode  740  return=  172  avg(last 20)= 179.1
# Episode  760  return=  177  avg(last 20)= 173.5
# Episode  780  return=  178  avg(last 20)= 175.7
# Episode  800  return=  167  avg(last 20)= 171.0
# Episode  820  return=  168  avg(last 20)= 169.0
# Episode  840  return=  177  avg(last 20)= 172.7
# Episode  860  return=  183  avg(last 20)= 179.3
# Episode  880  return=  184  avg(last 20)= 189.3
# Episode  900  return=  161  avg(last 20)= 189.8
# Episode  920  return=  163  avg(last 20)= 137.9
# Episode  940  return=   56  avg(last 20)= 128.3
# Episode  960  return=   59  avg(last 20)=  93.1
# Episode  980  return=   68  avg(last 20)=  67.6
# Episode 1000  return=   64  avg(last 20)=  66.1
# Episode 1020  return=   62  avg(last 20)=  62.7
# Episode 1040  return=   65  avg(last 20)=  64.3
# Episode 1060  return=   68  avg(last 20)=  69.3
# Episode 1080  return=   68  avg(last 20)=  70.2
# Episode 1100  return=   80  avg(last 20)=  71.6
# Episode 1120  return=   79  avg(last 20)=  77.0
# Episode 1140  return=   84  avg(last 20)=  85.0
# Episode 1160  return=   78  avg(last 20)=  84.1
# Episode 1180  return=   85  avg(last 20)=  87.5
# Episode 1200  return=  110  avg(last 20)= 111.7
# Episode 1220  return=  251  avg(last 20)= 187.9
# Episode 1240  return=  245  avg(last 20)= 229.3
# Episode 1260  return=  252  avg(last 20)= 244.6
# Episode 1280  return=  254  avg(last 20)= 240.6
# Episode 1300  return=  229  avg(last 20)= 199.6
# Episode 1320  return=  225  avg(last 20)= 230.7
# Episode 1340  return=  218  avg(last 20)= 225.3
# Episode 1360  return=  209  avg(last 20)= 223.3
# Episode 1380  return=  217  avg(last 20)= 202.8
# Episode 1400  return=  217  avg(last 20)= 204.6
# Episode 1420  return=  218  avg(last 20)= 220.1
# Episode 1440  return=  222  avg(last 20)= 212.1
# Episode 1460  return=  165  avg(last 20)= 209.1
# Episode 1480  return=  198  avg(last 20)= 178.8
# Episode 1500  return=  214  avg(last 20)= 187.2
# Episode 1520  return=  225  avg(last 20)= 206.7
# Episode 1540  return=  232  avg(last 20)= 226.6
# Episode 1560  return=  246  avg(last 20)= 222.7
# Episode 1580  return=  266  avg(last 20)= 201.4
# Episode 1600  return=   65  avg(last 20)= 149.1
# Episode 1620  return=   73  avg(last 20)= 102.6
# Episode 1640  return=   57  avg(last 20)=  51.2
# Episode 1660  return=   95  avg(last 20)=  82.2
# Episode 1680  return=   40  avg(last 20)=  68.6
# Episode 1700  return=   59  avg(last 20)=  54.2
# Episode 1720  return=   70  avg(last 20)=  65.9
# Episode 1740  return=  144  avg(last 20)= 121.7
# Episode 1760  return=  112  avg(last 20)= 101.9
# Episode 1780  return=  104  avg(last 20)= 101.2
# Episode 1800  return=   92  avg(last 20)=  94.4
# Episode 1820  return=   84  avg(last 20)=  87.1
# Episode 1840  return=  117  avg(last 20)= 106.2
# Episode 1860  return=  216  avg(last 20)= 184.4
# Episode 1880  return=  220  avg(last 20)= 220.0
# Episode 1900  return=  217  avg(last 20)= 222.4
# Episode 1920  return=  220  avg(last 20)= 222.3
# Episode 1940  return=  185  avg(last 20)= 194.3
# Episode 1960  return=  173  avg(last 20)= 184.6
# Episode 1980  return=  162  avg(last 20)= 155.9
# Episode 2000  return=  149  avg(last 20)= 148.3
# Episode 2020  return=  135  avg(last 20)= 132.3
# Episode 2040  return=  121  avg(last 20)= 137.1
# Episode 2060  return=   86  avg(last 20)= 105.0
# Episode 2080  return=   74  avg(last 20)= 107.3
# Episode 2100  return=   59  avg(last 20)=  91.1
# Episode 2120  return=   50  avg(last 20)=  65.8
# Episode 2140  return=   66  avg(last 20)=  63.0
# Episode 2160  return=   66  avg(last 20)=  65.1
# Episode 2180  return=   68  avg(last 20)=  70.9
# Episode 2200  return=   55  avg(last 20)=  61.2
# Episode 2220  return=   68  avg(last 20)=  58.3
# Episode 2240  return=   91  avg(last 20)=  71.4
# Episode 2260  return=   96  avg(last 20)=  85.6
# Episode 2280  return=  117  avg(last 20)= 111.4
# Episode 2300  return=  161  avg(last 20)= 128.9
# Episode 2320  return=  188  avg(last 20)= 176.9
# Episode 2340  return=  186  avg(last 20)= 193.6
# Episode 2360  return=  213  avg(last 20)= 172.1
# Episode 2380  return=  146  avg(last 20)= 162.9
# Episode 2400  return=  126  avg(last 20)= 126.0
# Episode 2420  return=   55  avg(last 20)=  96.1
# Episode 2440  return=   99  avg(last 20)=  75.8
# Episode 2460  return=   94  avg(last 20)=  77.9
# Episode 2480  return=   71  avg(last 20)=  83.0
# Episode 2500  return=   74  avg(last 20)=  78.1
# Episode 2520  return=   61  avg(last 20)=  66.3
# Episode 2540  return=   60  avg(last 20)=  60.5
# Episode 2560  return=   59  avg(last 20)=  54.5
# Episode 2580  return=   29  avg(last 20)=  39.9
# Episode 2600  return=   37  avg(last 20)=  31.9
# Episode 2620  return=   53  avg(last 20)=  43.9
# Episode 2640  return=   58  avg(last 20)=  53.6
# Episode 2660  return=   70  avg(last 20)=  62.8
# Episode 2680  return=   67  avg(last 20)=  64.3
# Episode 2700  return=   78  avg(last 20)=  71.3
# Episode 2720  return=   89  avg(last 20)=  68.0
# Episode 2740  return=   87  avg(last 20)=  79.9
# Episode 2760  return=   84  avg(last 20)=  76.7
# Episode 2780  return=   77  avg(last 20)=  67.1
# Episode 2800  return=   85  avg(last 20)=  77.1
# Episode 2820  return=   95  avg(last 20)=  83.4
# Episode 2840  return=   95  avg(last 20)=  90.4
# Episode 2860  return=   97  avg(last 20)= 101.1
# Episode 2880  return=   95  avg(last 20)=  99.4
# Episode 2900  return=   96  avg(last 20)= 102.9
# Episode 2920  return=  116  avg(last 20)= 104.2
# Episode 2940  return=  108  avg(last 20)= 108.8
# Episode 2960  return=   92  avg(last 20)= 100.4
# Episode 2980  return=  100  avg(last 20)=  99.9
# Saved model_constant_b20.pt and history_constant_b20.pkl and time_constant_b20.pkl
# State space: Box(-inf, inf, (11,), float64)
# Action space: Box(-1.0, 1.0, (3,), float32)
# Episode    0  return=   10  avg(last 20)=   9.7
# Episode   20  return=   43  avg(last 20)=  16.1
# Episode   40  return=   11  avg(last 20)=  12.2
# Episode   60  return=    7  avg(last 20)=  14.2
# Episode   80  return=   49  avg(last 20)=  30.1
# Episode  100  return=   57  avg(last 20)=  45.6
# Episode  120  return=  116  avg(last 20)=  48.4
# Episode  140  return=   67  avg(last 20)=  52.0
# Episode  160  return=   71  avg(last 20)=  69.9
# Episode  180  return=   50  avg(last 20)=  93.4
# Episode  200  return=  165  avg(last 20)=  95.2
# Episode  220  return=    7  avg(last 20)=  57.6
# Episode  240  return=  144  avg(last 20)=  88.0
# Episode  260  return=   98  avg(last 20)=  97.7
# Episode  280  return=  118  avg(last 20)= 100.5
# Episode  300  return=   25  avg(last 20)=  97.4
# Episode  320  return=   45  avg(last 20)=  70.7
# Episode  340  return=    1  avg(last 20)=  72.5
# Episode  360  return=   99  avg(last 20)=  67.8
# Episode  380  return=   72  avg(last 20)=  90.8
# Episode  400  return=   38  avg(last 20)=  97.6
# Episode  420  return=  106  avg(last 20)=  76.5
# Episode  440  return=  115  avg(last 20)= 109.3
# Episode  460  return=  316  avg(last 20)= 153.4
# Episode  480  return=    4  avg(last 20)= 145.9
# Episode  500  return=  174  avg(last 20)= 201.4
# Episode  520  return=  168  avg(last 20)= 172.1
# Episode  540  return=  121  avg(last 20)= 165.1
# Episode  560  return=   80  avg(last 20)= 117.7
# Episode  580  return=  262  avg(last 20)= 146.0
# Episode  600  return=  113  avg(last 20)= 139.9
# Episode  620  return=   93  avg(last 20)= 146.9
# Episode  640  return=   87  avg(last 20)=  56.8
# Episode  660  return=   69  avg(last 20)=  58.8
# Episode  680  return=   50  avg(last 20)=  43.8
# Episode  700  return=   46  avg(last 20)=  36.3
# Episode  720  return=   43  avg(last 20)=  39.5
# Episode  740  return=   46  avg(last 20)=  38.2
# Episode  760  return=   66  avg(last 20)=  53.6
# Episode  780  return=   99  avg(last 20)= 127.7
# Episode  800  return=  253  avg(last 20)= 173.2
# Episode  820  return=  204  avg(last 20)= 173.8
# Episode  840  return=  125  avg(last 20)= 190.3
# Episode  860  return=  164  avg(last 20)= 164.0
# Episode  880  return=  157  avg(last 20)= 179.1
# Episode  900  return=  314  avg(last 20)= 178.4
# Episode  920  return=  242  avg(last 20)= 103.4
# Episode  940  return=  314  avg(last 20)= 239.7
# Episode  960  return=  280  avg(last 20)= 206.6
# Episode  980  return=  108  avg(last 20)= 173.6
# Episode 1000  return=  189  avg(last 20)= 125.3
# Episode 1020  return=  243  avg(last 20)= 232.7
# Episode 1040  return=  276  avg(last 20)= 276.2
# Episode 1060  return=  179  avg(last 20)= 257.3
# Episode 1080  return=  167  avg(last 20)= 212.1
# Episode 1100  return=  159  avg(last 20)= 184.7
# Episode 1120  return=  149  avg(last 20)= 150.5
# Episode 1140  return=  142  avg(last 20)= 143.8
# Episode 1160  return=  149  avg(last 20)= 129.8
# Episode 1180  return=  158  avg(last 20)= 145.6
# Episode 1200  return=  191  avg(last 20)= 150.4
# Episode 1220  return=  158  avg(last 20)= 165.3
# Episode 1240  return=  215  avg(last 20)= 244.9
# Episode 1260  return=  113  avg(last 20)= 206.8
# Episode 1280  return=  167  avg(last 20)= 201.5
# Episode 1300  return=  198  avg(last 20)= 215.8
# Episode 1320  return=  269  avg(last 20)= 192.2
# Episode 1340  return=  408  avg(last 20)= 256.4
# Episode 1360  return=  279  avg(last 20)= 239.5
# Episode 1380  return=  336  avg(last 20)= 249.0
# Episode 1400  return=  222  avg(last 20)= 244.4
# Episode 1420  return=  346  avg(last 20)= 221.6
# Episode 1440  return=  296  avg(last 20)= 287.8
# Episode 1460  return=  243  avg(last 20)= 217.6
# Episode 1480  return=  167  avg(last 20)= 174.0
# Episode 1500  return=  177  avg(last 20)= 175.1
# Episode 1520  return=  244  avg(last 20)= 177.6
# Episode 1540  return=  307  avg(last 20)= 307.5
# Episode 1560  return=  367  avg(last 20)= 283.2
# Episode 1580  return=  177  avg(last 20)= 205.8
# Episode 1600  return=  291  avg(last 20)= 195.2
# Episode 1620  return=  176  avg(last 20)= 239.8
# Episode 1640  return=  199  avg(last 20)= 200.5
# Episode 1660  return=  265  avg(last 20)= 196.1
# Episode 1680  return=  267  avg(last 20)= 232.1
# Episode 1700  return=  223  avg(last 20)= 232.8
# Episode 1720  return=  234  avg(last 20)= 206.5
# Episode 1740  return=  182  avg(last 20)= 200.2
# Episode 1760  return=  177  avg(last 20)= 195.6
# Episode 1780  return=  280  avg(last 20)= 223.8
# Episode 1800  return=  167  avg(last 20)= 195.6
# Episode 1820  return=  342  avg(last 20)= 253.6
# Episode 1840  return=  228  avg(last 20)= 260.0
# Episode 1860  return=  113  avg(last 20)= 226.5
# Episode 1880  return=  282  avg(last 20)= 227.3
# Episode 1900  return=   91  avg(last 20)= 234.2
# Episode 1920  return=  312  avg(last 20)= 259.3
# Episode 1940  return=  256  avg(last 20)= 321.5
# Episode 1960  return=   95  avg(last 20)= 206.1
# Episode 1980  return=   92  avg(last 20)=  89.6
# Episode 2000  return=   97  avg(last 20)=  90.9
# Episode 2020  return=   99  avg(last 20)= 130.5
# Episode 2040  return=   58  avg(last 20)= 104.3
# Episode 2060  return=   77  avg(last 20)=  79.0
# Episode 2080  return=   99  avg(last 20)=  85.3
# Episode 2100  return=   57  avg(last 20)=  78.2
# Episode 2120  return=   67  avg(last 20)=  57.2
# Episode 2140  return=   53  avg(last 20)=  59.9
# Episode 2160  return=   66  avg(last 20)=  60.0
# Episode 2180  return=   82  avg(last 20)=  78.4
# Episode 2200  return=   96  avg(last 20)=  84.5
# Episode 2220  return=   94  avg(last 20)=  89.5
# Episode 2240  return=   64  avg(last 20)=  89.7
# Episode 2260  return=   61  avg(last 20)=  64.7
# Episode 2280  return=   50  avg(last 20)=  59.3
# Episode 2300  return=   90  avg(last 20)=  71.0
# Episode 2320  return=   87  avg(last 20)=  86.4
# Episode 2340  return=   49  avg(last 20)=  59.7
# Episode 2360  return=   52  avg(last 20)=  48.3
# Episode 2380  return=   47  avg(last 20)=  51.6
# Episode 2400  return=   52  avg(last 20)=  50.0
# Episode 2420  return=   61  avg(last 20)=  58.3
# Episode 2440  return=   91  avg(last 20)=  82.4
# Episode 2460  return=   92  avg(last 20)=  96.2
# Episode 2480  return=   61  avg(last 20)=  78.0
# Episode 2500  return=  104  avg(last 20)=  85.8
# Episode 2520  return=  121  avg(last 20)= 119.3
# Episode 2540  return=  145  avg(last 20)= 135.7
# Episode 2560  return=  134  avg(last 20)= 133.3
# Episode 2580  return=  154  avg(last 20)= 143.9
# Episode 2600  return=  135  avg(last 20)= 136.5
# Episode 2620  return=  162  avg(last 20)= 145.0
# Episode 2640  return=  128  avg(last 20)= 154.1
# Episode 2660  return=  154  avg(last 20)= 127.2
# Episode 2680  return=  156  avg(last 20)= 157.6
# Episode 2700  return=   92  avg(last 20)= 145.6
# Episode 2720  return=  112  avg(last 20)= 119.3
# Episode 2740  return=  111  avg(last 20)= 145.1
# Episode 2760  return=  138  avg(last 20)= 121.2
# Episode 2780  return=  162  avg(last 20)= 140.3
# Episode 2800  return=  114  avg(last 20)= 145.9
# Episode 2820  return=   93  avg(last 20)=  91.3
# Episode 2840  return=   67  avg(last 20)=  85.1
# Episode 2860  return=   67  avg(last 20)=  65.0
# Episode 2880  return=   45  avg(last 20)=  65.1
# Episode 2900  return=   45  avg(last 20)=  42.4
# Episode 2920  return=   48  avg(last 20)=  45.7
# Episode 2940  return=   48  avg(last 20)=  45.3
# Episode 2960  return=   46  avg(last 20)=  46.0
# Episode 2980  return=   41  avg(last 20)=  43.2
# Saved model_constant_b100.pt and history_constant_b100.pkl and time_constant_b100.pkl

# %%
history_ema_005   = main(baseline_mode='ema', baseline_alpha=0.05, n_episodes=3000)
history_ema_0005  = main(baseline_mode='ema', baseline_alpha=0.0005, n_episodes=3000)
history_ema_05    = main(baseline_mode='ema', baseline_alpha=0.5, n_episodes=3000)
# Out:
# State space: Box(-inf, inf, (11,), float64)
# Action space: Box(-1.0, 1.0, (3,), float32)
# Episode    0  return=   10  avg(last 20)=   9.7
# Episode   20  return=    7  avg(last 20)=   8.9
# Episode   40  return=   48  avg(last 20)=  17.3
# Episode   60  return=   47  avg(last 20)=  23.6
# Episode   80  return=  146  avg(last 20)=  53.7
# Episode  100  return=  105  avg(last 20)= 146.5
# Episode  120  return=  347  avg(last 20)= 213.8
# Episode  140  return=  585  avg(last 20)= 432.0
# Episode  160  return=  287  avg(last 20)= 339.3
# Episode  180  return=  319  avg(last 20)= 231.2
# Episode  200  return=  492  avg(last 20)= 391.3
# Episode  220  return=  339  avg(last 20)= 504.8
# Episode  240  return=  381  avg(last 20)= 352.7
# Episode  260  return=  425  avg(last 20)= 435.6
# Episode  280  return=  584  avg(last 20)= 537.7
# Episode  300  return=  468  avg(last 20)= 438.9
# Episode  320  return=  579  avg(last 20)= 529.3
# Episode  340  return=  400  avg(last 20)= 475.4
# Episode  360  return=  382  avg(last 20)= 355.3
# Episode  380  return=  272  avg(last 20)= 269.7
# Episode  400  return=  177  avg(last 20)= 355.0
# Episode  420  return=  459  avg(last 20)= 477.6
# Episode  440  return=  437  avg(last 20)= 459.3
# Episode  460  return=  392  avg(last 20)= 385.4
# Episode  480  return=  382  avg(last 20)= 310.6
# Episode  500  return=  277  avg(last 20)= 383.7
# Episode  520  return=  492  avg(last 20)= 402.8
# Episode  540  return=  343  avg(last 20)= 274.3
# Episode  560  return=  269  avg(last 20)= 261.9
# Episode  580  return=  240  avg(last 20)= 263.7
# Episode  600  return=  279  avg(last 20)= 298.5
# Episode  620  return=  300  avg(last 20)= 298.3
# Episode  640  return=  295  avg(last 20)= 314.3
# Episode  660  return=  297  avg(last 20)= 307.2
# Episode  680  return=  271  avg(last 20)= 285.6
# Episode  700  return=   96  avg(last 20)= 204.4
# Episode  720  return=  244  avg(last 20)= 235.2
# Episode  740  return=  234  avg(last 20)= 235.5
# Episode  760  return=  248  avg(last 20)= 223.3
# Episode  780  return=  225  avg(last 20)= 203.2
# Episode  800  return=  152  avg(last 20)= 201.8
# Episode  820  return=   61  avg(last 20)= 125.5
# Episode  840  return=  216  avg(last 20)= 153.1
# Episode  860  return=  374  avg(last 20)= 334.7
# Episode  880  return=  433  avg(last 20)= 338.7
# Episode  900  return=  395  avg(last 20)= 420.6
# Episode  920  return=  418  avg(last 20)= 413.3
# Episode  940  return=  427  avg(last 20)= 439.7
# Episode  960  return=  414  avg(last 20)= 411.9
# Episode  980  return=  394  avg(last 20)= 385.7
# Episode 1000  return=  379  avg(last 20)= 385.3
# Episode 1020  return=  401  avg(last 20)= 388.3
# Episode 1040  return=  382  avg(last 20)= 372.5
# Episode 1060  return=  274  avg(last 20)= 322.1
# Episode 1080  return=  274  avg(last 20)= 263.9
# Episode 1100  return=  270  avg(last 20)= 253.7
# Episode 1120  return=  223  avg(last 20)= 261.8
# Episode 1140  return=  132  avg(last 20)= 209.7
# Episode 1160  return=  350  avg(last 20)= 323.2
# Episode 1180  return=  379  avg(last 20)= 344.5
# Episode 1200  return=  363  avg(last 20)= 337.4
# Episode 1220  return=  379  avg(last 20)= 365.2
# Episode 1240  return=  375  avg(last 20)= 348.6
# Episode 1260  return=  366  avg(last 20)= 363.2
# Episode 1280  return=  359  avg(last 20)= 351.6
# Episode 1300  return=  361  avg(last 20)= 370.3
# Episode 1320  return=  386  avg(last 20)= 360.2
# Episode 1340  return=  222  avg(last 20)= 353.7
# Episode 1360  return=  320  avg(last 20)= 325.8
# Episode 1380  return=  284  avg(last 20)= 294.7
# Episode 1400  return=  292  avg(last 20)= 274.1
# Episode 1420  return=  300  avg(last 20)= 300.3
# Episode 1440  return=  318  avg(last 20)= 279.2
# Episode 1460  return=  307  avg(last 20)= 307.6
# Episode 1480  return=  341  avg(last 20)= 328.3
# Episode 1500  return=  393  avg(last 20)= 325.9
# Episode 1520  return=  338  avg(last 20)= 358.0
# Episode 1540  return=  508  avg(last 20)= 418.4
# Episode 1560  return=  534  avg(last 20)= 563.3
# Episode 1580  return=  535  avg(last 20)= 535.2
# Episode 1600  return=  486  avg(last 20)= 482.1
# Episode 1620  return=  539  avg(last 20)= 472.7
# Episode 1640  return=  474  avg(last 20)= 501.1
# Episode 1660  return=  412  avg(last 20)= 445.2
# Episode 1680  return=  327  avg(last 20)= 406.4
# Episode 1700  return=  387  avg(last 20)= 409.6
# Episode 1720  return=  466  avg(last 20)= 348.7
# Episode 1740  return=  430  avg(last 20)= 444.2
# Episode 1760  return=  453  avg(last 20)= 451.8
# Episode 1780  return=  452  avg(last 20)= 394.6
# Episode 1800  return=  399  avg(last 20)= 417.7
# Episode 1820  return=  339  avg(last 20)= 368.9
# Episode 1840  return=  157  avg(last 20)= 353.9
# Episode 1860  return=  372  avg(last 20)= 306.4
# Episode 1880  return=  250  avg(last 20)= 340.9
# Episode 1900  return=  365  avg(last 20)= 352.3
# Episode 1920  return=  351  avg(last 20)= 338.1
# Episode 1940  return=  386  avg(last 20)= 339.7
# Episode 1960  return=  407  avg(last 20)= 355.5
# Episode 1980  return=  367  avg(last 20)= 365.4
# Episode 2000  return=  378  avg(last 20)= 360.2
# Episode 2020  return=  392  avg(last 20)= 330.0
# Episode 2040  return=  351  avg(last 20)= 378.6
# Episode 2060  return=  349  avg(last 20)= 359.8
# Episode 2080  return=  316  avg(last 20)= 341.1
# Episode 2100  return=  343  avg(last 20)= 377.5
# Episode 2120  return=  332  avg(last 20)= 343.8
# Episode 2140  return=  350  avg(last 20)= 305.8
# Episode 2160  return=  203  avg(last 20)= 271.7
# Episode 2180  return=  326  avg(last 20)= 333.7
# Episode 2200  return=  449  avg(last 20)= 388.6
# Episode 2220  return=  348  avg(last 20)= 366.8
# Episode 2240  return=  401  avg(last 20)= 349.3
# Episode 2260  return=  441  avg(last 20)= 346.7
# Episode 2280  return=  405  avg(last 20)= 391.4
# Episode 2300  return=  428  avg(last 20)= 383.8
# Episode 2320  return=  291  avg(last 20)= 378.4
# Episode 2340  return=  310  avg(last 20)= 472.1
# Episode 2360  return=  299  avg(last 20)= 400.3
# Episode 2380  return=  410  avg(last 20)= 409.0
# Episode 2400  return=  390  avg(last 20)= 414.9
# Episode 2420  return=  591  avg(last 20)= 277.3
# Episode 2440  return=  517  avg(last 20)= 368.9
# Episode 2460  return=  441  avg(last 20)= 377.1
# Episode 2480  return=  425  avg(last 20)= 458.0
# Episode 2500  return=  511  avg(last 20)= 468.5
# Episode 2520  return=  305  avg(last 20)= 416.1
# Episode 2540  return=  594  avg(last 20)= 420.9
# Episode 2560  return=  514  avg(last 20)= 495.5
# Episode 2580  return=  490  avg(last 20)= 527.1
# Episode 2600  return=  313  avg(last 20)= 450.4
# Episode 2620  return=  520  avg(last 20)= 419.4
# Episode 2640  return=  398  avg(last 20)= 369.3
# Episode 2660  return=  419  avg(last 20)= 343.7
# Episode 2680  return=  499  avg(last 20)= 358.1
# Episode 2700  return=  152  avg(last 20)= 305.6
# Episode 2720  return=  117  avg(last 20)= 299.3
# Episode 2740  return=   17  avg(last 20)=  64.7
# Episode 2760  return=   51  avg(last 20)=  56.9
# Episode 2780  return=  428  avg(last 20)= 170.6
# Episode 2800  return=  211  avg(last 20)= 189.2
# Episode 2820  return=  219  avg(last 20)= 288.0
# Episode 2840  return=  261  avg(last 20)= 364.9
# Episode 2860  return=  272  avg(last 20)= 328.7
# Episode 2880  return=  122  avg(last 20)= 329.4
# Episode 2900  return=  269  avg(last 20)= 275.4
# Episode 2920  return=  398  avg(last 20)= 299.4
# Episode 2940  return=  348  avg(last 20)= 368.6
# Episode 2960  return=  287  avg(last 20)= 339.1
# Episode 2980  return=  480  avg(last 20)= 336.4
# Saved model_ema_a0.0500.pt and history_ema_a0.0500.pkl and time_ema_a0.0500.pkl
# State space: Box(-inf, inf, (11,), float64)
# Action space: Box(-1.0, 1.0, (3,), float32)
# Episode    0  return=   10  avg(last 20)=   9.7
# Episode   20  return=    2  avg(last 20)=   8.7
# Episode   40  return=    7  avg(last 20)=  20.1
# Episode   60  return=   39  avg(last 20)=  40.6
# Episode   80  return=   17  avg(last 20)=  20.3
# Episode  100  return=   15  avg(last 20)=  13.4
# Episode  120  return=   20  avg(last 20)=  20.9
# Episode  140  return=   40  avg(last 20)=  40.3
# Episode  160  return=  215  avg(last 20)= 138.2
# Episode  180  return=  227  avg(last 20)= 219.3
# Episode  200  return=   66  avg(last 20)= 134.9
# Episode  220  return=   43  avg(last 20)=  87.4
# Episode  240  return=  314  avg(last 20)= 142.4
# Episode  260  return=   72  avg(last 20)= 103.8
# Episode  280  return=  249  avg(last 20)= 189.6
# Episode  300  return=  228  avg(last 20)= 196.3
# Episode  320  return=  238  avg(last 20)= 113.4
# Episode  340  return=   57  avg(last 20)= 167.4
# Episode  360  return=  308  avg(last 20)= 309.1
# Episode  380  return=  219  avg(last 20)= 279.7
# Episode  400  return=  182  avg(last 20)= 210.2
# Episode  420  return=  180  avg(last 20)= 175.9
# Episode  440  return=  148  avg(last 20)= 161.2
# Episode  460  return=  110  avg(last 20)= 130.8
# Episode  480  return=   97  avg(last 20)= 100.5
# Episode  500  return=   74  avg(last 20)=  84.3
# Episode  520  return=   71  avg(last 20)=  73.1
# Episode  540  return=  108  avg(last 20)=  87.8
# Episode  560  return=  119  avg(last 20)= 108.2
# Episode  580  return=  136  avg(last 20)= 129.6
# Episode  600  return=  134  avg(last 20)= 150.3
# Episode  620  return=  114  avg(last 20)= 141.0
# Episode  640  return=   69  avg(last 20)=  87.0
# Episode  660  return=   61  avg(last 20)=  69.1
# Episode  680  return=   85  avg(last 20)=  76.7
# Episode  700  return=  133  avg(last 20)= 109.0
# Episode  720  return=  173  avg(last 20)= 160.1
# Episode  740  return=  171  avg(last 20)= 171.3
# Episode  760  return=  174  avg(last 20)= 172.9
# Episode  780  return=  141  avg(last 20)= 150.4
# Episode  800  return=  171  avg(last 20)= 158.7
# Episode  820  return=  175  avg(last 20)= 175.0
# Episode  840  return=  171  avg(last 20)= 175.4
# Episode  860  return=  171  avg(last 20)= 161.5
# Episode  880  return=  167  avg(last 20)= 167.2
# Episode  900  return=  169  avg(last 20)= 165.3
# Episode  920  return=  167  avg(last 20)= 167.8
# Episode  940  return=  114  avg(last 20)= 158.5
# Episode  960  return=  112  avg(last 20)= 114.8
# Episode  980  return=  171  avg(last 20)= 161.9
# Episode 1000  return=  172  avg(last 20)= 171.8
# Episode 1020  return=  172  avg(last 20)= 172.7
# Episode 1040  return=  173  avg(last 20)= 172.5
# Episode 1060  return=  170  avg(last 20)= 173.0
# Episode 1080  return=  167  avg(last 20)= 155.5
# Episode 1100  return=  171  avg(last 20)= 164.8
# Episode 1120  return=  172  avg(last 20)= 171.9
# Episode 1140  return=  172  avg(last 20)= 172.0
# Episode 1160  return=  175  avg(last 20)= 173.7
# Episode 1180  return=  144  avg(last 20)= 162.1
# Episode 1200  return=  126  avg(last 20)= 133.0
# Episode 1220  return=  164  avg(last 20)= 143.1
# Episode 1240  return=  187  avg(last 20)= 182.4
# Episode 1260  return=  187  avg(last 20)= 187.4
# Episode 1280  return=  174  avg(last 20)= 177.7
# Episode 1300  return=  175  avg(last 20)= 176.1
# Episode 1320  return=  179  avg(last 20)= 181.3
# Episode 1340  return=  174  avg(last 20)= 179.0
# Episode 1360  return=  172  avg(last 20)= 175.0
# Episode 1380  return=  172  avg(last 20)= 174.4
# Episode 1400  return=  186  avg(last 20)= 176.2
# Episode 1420  return=  175  avg(last 20)= 180.1
# Episode 1440  return=  179  avg(last 20)= 179.8
# Episode 1460  return=  151  avg(last 20)= 174.6
# Episode 1480  return=  142  avg(last 20)= 147.5
# Episode 1500  return=  186  avg(last 20)= 159.3
# Episode 1520  return=  177  avg(last 20)= 180.0
# Episode 1540  return=  186  avg(last 20)= 181.4
# Episode 1560  return=  179  avg(last 20)= 179.3
# Episode 1580  return=  144  avg(last 20)= 153.7
# Episode 1600  return=  120  avg(last 20)= 111.1
# Episode 1620  return=  153  avg(last 20)= 145.4
# Episode 1640  return=  178  avg(last 20)= 165.8
# Episode 1660  return=  176  avg(last 20)= 174.4
# Episode 1680  return=  136  avg(last 20)= 159.8
# Episode 1700  return=  186  avg(last 20)= 170.2
# Episode 1720  return=  181  avg(last 20)= 181.7
# Episode 1740  return=  190  avg(last 20)= 183.8
# Episode 1760  return=  189  avg(last 20)= 185.3
# Episode 1780  return=  184  avg(last 20)= 184.6
# Episode 1800  return=  177  avg(last 20)= 185.0
# Episode 1820  return=  191  avg(last 20)= 188.0
# Episode 1840  return=  186  avg(last 20)= 171.4
# Episode 1860  return=  193  avg(last 20)= 185.1
# Episode 1880  return=  199  avg(last 20)= 199.1
# Episode 1900  return=  206  avg(last 20)= 203.5
# Episode 1920  return=  174  avg(last 20)= 197.3
# Episode 1940  return=  147  avg(last 20)= 154.5
# Episode 1960  return=  210  avg(last 20)= 178.7
# Episode 1980  return=  199  avg(last 20)= 204.9
# Episode 2000  return=  194  avg(last 20)= 201.8
# Episode 2020  return=  199  avg(last 20)= 169.7
# Episode 2040  return=  187  avg(last 20)= 190.7
# Episode 2060  return=  196  avg(last 20)= 179.6
# Episode 2080  return=  204  avg(last 20)= 201.4
# Episode 2100  return=  199  avg(last 20)= 199.9
# Episode 2120  return=  198  avg(last 20)= 195.9
# Episode 2140  return=  210  avg(last 20)= 207.3
# Episode 2160  return=   66  avg(last 20)= 167.2
# Episode 2180  return=   16  avg(last 20)=  29.0
# Episode 2200  return=   15  avg(last 20)=  20.8
# Episode 2220  return=   24  avg(last 20)=  16.2
# Episode 2240  return=   54  avg(last 20)=  30.5
# Episode 2260  return=   85  avg(last 20)=  50.6
# Episode 2280  return=  204  avg(last 20)= 173.4
# Episode 2300  return=  189  avg(last 20)= 198.4
# Episode 2320  return=  144  avg(last 20)= 169.8
# Episode 2340  return=  166  avg(last 20)= 163.2
# Episode 2360  return=  184  avg(last 20)= 188.6
# Episode 2380  return=  186  avg(last 20)= 180.3
# Episode 2400  return=  172  avg(last 20)= 181.3
# Episode 2420  return=  187  avg(last 20)= 177.8
# Episode 2440  return=  198  avg(last 20)= 187.1
# Episode 2460  return=  176  avg(last 20)= 185.5
# Episode 2480  return=  185  avg(last 20)= 182.0
# Episode 2500  return=  176  avg(last 20)= 178.3
# Episode 2520  return=  196  avg(last 20)= 185.6
# Episode 2540  return=  203  avg(last 20)= 199.7
# Episode 2560  return=  209  avg(last 20)= 203.6
# Episode 2580  return=  197  avg(last 20)= 184.3
# Episode 2600  return=  163  avg(last 20)= 175.2
# Episode 2620  return=  169  avg(last 20)= 159.9
# Episode 2640  return=  175  avg(last 20)= 168.8
# Episode 2660  return=  173  avg(last 20)= 177.7
# Episode 2680  return=  164  avg(last 20)= 168.1
# Episode 2700  return=  152  avg(last 20)= 155.2
# Episode 2720  return=  208  avg(last 20)= 185.0
# Episode 2740  return=  185  avg(last 20)= 197.6
# Episode 2760  return=  195  avg(last 20)= 194.7
# Episode 2780  return=  205  avg(last 20)= 196.1
# Episode 2800  return=  204  avg(last 20)= 199.3
# Episode 2820  return=  199  avg(last 20)= 201.7
# Episode 2840  return=  198  avg(last 20)= 199.7
# Episode 2860  return=  199  avg(last 20)= 201.3
# Episode 2880  return=  205  avg(last 20)= 201.1
# Episode 2900  return=  181  avg(last 20)= 203.1
# Episode 2920  return=  210  avg(last 20)= 205.1
# Episode 2940  return=  194  avg(last 20)= 209.5
# Episode 2960  return=  211  avg(last 20)= 201.4
# Episode 2980  return=  181  avg(last 20)= 198.6
# Saved model_ema_a0.0005.pt and history_ema_a0.0005.pkl and time_ema_a0.0005.pkl
# State space: Box(-inf, inf, (11,), float64)
# Action space: Box(-1.0, 1.0, (3,), float32)
# Episode    0  return=   10  avg(last 20)=   9.7
# Episode   20  return=    0  avg(last 20)=   3.6
# Episode   40  return=   46  avg(last 20)=  10.1
# Episode   60  return=   58  avg(last 20)=  27.3
# Episode   80  return=  219  avg(last 20)= 107.6
# Episode  100  return=  187  avg(last 20)= 220.7
# Episode  120  return=  252  avg(last 20)= 227.2
# Episode  140  return=  136  avg(last 20)= 211.3
# Episode  160  return=  125  avg(last 20)= 172.3
# Episode  180  return=  215  avg(last 20)= 191.2
# Episode  200  return=  210  avg(last 20)= 213.0
# Episode  220  return=  198  avg(last 20)= 194.2
# Episode  240  return=  185  avg(last 20)= 198.1
# Episode  260  return=  212  avg(last 20)= 201.0
# Episode  280  return=  200  avg(last 20)= 202.8
# Episode  300  return=  200  avg(last 20)= 197.4
# Episode  320  return=  180  avg(last 20)= 190.1
# Episode  340  return=  171  avg(last 20)= 174.7
# Episode  360  return=  205  avg(last 20)= 195.2
# Episode  380  return=  180  avg(last 20)= 188.5
# Episode  400  return=   80  avg(last 20)= 114.8
# Episode  420  return=  100  avg(last 20)=  76.2
# Episode  440  return=  167  avg(last 20)= 123.5
# Episode  460  return=  169  avg(last 20)= 169.7
# Episode  480  return=  133  avg(last 20)= 163.7
# Episode  500  return=   90  avg(last 20)= 128.1
# Episode  520  return=  361  avg(last 20)= 178.0
# Episode  540  return=  231  avg(last 20)= 304.7
# Episode  560  return=   73  avg(last 20)= 167.4
# Episode  580  return=   21  avg(last 20)=  64.8
# Episode  600  return=   64  avg(last 20)=  62.8
# Episode  620  return=  121  avg(last 20)= 145.7
# Episode  640  return=  261  avg(last 20)= 340.7
# Episode  660  return=  301  avg(last 20)= 300.6
# Episode  680  return=  287  avg(last 20)= 264.3
# Episode  700  return=  329  avg(last 20)= 212.0
# Episode  720  return=  327  avg(last 20)= 275.7
# Episode  740  return=   53  avg(last 20)= 251.6
# Episode  760  return=  237  avg(last 20)= 249.3
# Episode  780  return=  164  avg(last 20)= 333.6
# Episode  800  return=  550  avg(last 20)= 345.4
# Episode  820  return=  439  avg(last 20)= 432.9
# Episode  840  return=  362  avg(last 20)= 463.3
# Episode  860  return=  366  avg(last 20)= 539.4
# Episode  880  return=  368  avg(last 20)= 420.9
# Episode  900  return=  346  avg(last 20)= 318.4
# Episode  920  return=  419  avg(last 20)= 411.8
# Episode  940  return=  398  avg(last 20)= 418.3
# Episode  960  return= 1108  avg(last 20)= 400.4
# Episode  980  return=  129  avg(last 20)= 442.9
# Episode 1000  return=  132  avg(last 20)= 169.7
# Episode 1020  return=  414  avg(last 20)= 374.8
# Episode 1040  return=  656  avg(last 20)= 435.2
# Episode 1060  return=  638  avg(last 20)= 431.3
# Episode 1080  return=  628  avg(last 20)= 436.1
# Episode 1100  return=  397  avg(last 20)= 455.0
# Episode 1120  return=  696  avg(last 20)= 522.2
# Episode 1140  return=  188  avg(last 20)= 370.9
# Episode 1160  return=  108  avg(last 20)= 145.2
# Episode 1180  return=  205  avg(last 20)= 151.6
# Episode 1200  return=  179  avg(last 20)= 184.2
# Episode 1220  return=  511  avg(last 20)= 201.9
# Episode 1240  return=  384  avg(last 20)= 229.3
# Episode 1260  return=  580  avg(last 20)= 442.8
# Episode 1280  return=  271  avg(last 20)= 431.6
# Episode 1300  return=  498  avg(last 20)= 385.5
# Episode 1320  return=  391  avg(last 20)= 405.4
# Episode 1340  return=  285  avg(last 20)= 311.3
# Episode 1360  return=  197  avg(last 20)= 388.8
# Episode 1380  return=  239  avg(last 20)= 384.6
# Episode 1400  return=  286  avg(last 20)= 344.8
# Episode 1420  return=  609  avg(last 20)= 577.8
# Episode 1440  return=  417  avg(last 20)= 550.0
# Episode 1460  return=  670  avg(last 20)= 591.5
# Episode 1480  return=  342  avg(last 20)= 453.9
# Episode 1500  return=  394  avg(last 20)= 364.6
# Episode 1520  return=  482  avg(last 20)= 346.3
# Episode 1540  return=  601  avg(last 20)= 464.3
# Episode 1560  return=  636  avg(last 20)= 571.3
# Episode 1580  return=  515  avg(last 20)= 381.4
# Episode 1600  return=  577  avg(last 20)= 559.0
# Episode 1620  return=  558  avg(last 20)= 560.1
# Episode 1640  return=  616  avg(last 20)= 542.0
# Episode 1660  return=  414  avg(last 20)= 529.7
# Episode 1680  return=  616  avg(last 20)= 484.9
# Episode 1700  return=  464  avg(last 20)= 549.8
# Episode 1720  return=  411  avg(last 20)= 491.3
# Episode 1740  return=  459  avg(last 20)= 442.7
# Episode 1760  return=  487  avg(last 20)= 463.0
# Episode 1780  return=  289  avg(last 20)= 431.8
# Episode 1800  return=  651  avg(last 20)= 446.1
# Episode 1820  return=  204  avg(last 20)= 580.0
# Episode 1840  return=  384  avg(last 20)= 521.4
# Episode 1860  return=  371  avg(last 20)= 436.9
# Episode 1880  return=  244  avg(last 20)= 465.3
# Episode 1900  return=  427  avg(last 20)= 410.2
# Episode 1920  return=  468  avg(last 20)= 414.2
# Episode 1940  return=  421  avg(last 20)= 422.3
# Episode 1960  return=   -1  avg(last 20)= 402.5
# Episode 1980  return=  509  avg(last 20)= 484.9
# Episode 2000  return=  538  avg(last 20)= 415.0
# Episode 2020  return=  283  avg(last 20)= 364.2
# Episode 2040  return=  330  avg(last 20)= 381.8
# Episode 2060  return=  481  avg(last 20)= 293.8
# Episode 2080  return=  263  avg(last 20)= 398.0
# Episode 2100  return=  360  avg(last 20)= 429.0
# Episode 2120  return=  381  avg(last 20)= 421.6
# Episode 2140  return=  511  avg(last 20)= 499.1
# Episode 2160  return=  260  avg(last 20)= 439.0
# Episode 2180  return=  592  avg(last 20)= 382.2
# Episode 2200  return=  386  avg(last 20)= 446.4
# Episode 2220  return=  463  avg(last 20)= 479.0
# Episode 2240  return=  446  avg(last 20)= 450.0
# Episode 2260  return=  499  avg(last 20)= 414.5
# Episode 2280  return=  328  avg(last 20)= 304.4
# Episode 2300  return=  363  avg(last 20)= 372.2
# Episode 2320  return=  336  avg(last 20)= 369.6
# Episode 2340  return=  100  avg(last 20)= 297.0
# Episode 2360  return=  271  avg(last 20)= 312.6
# Episode 2380  return=  341  avg(last 20)= 403.5
# Episode 2400  return=  458  avg(last 20)= 424.6
# Episode 2420  return=  491  avg(last 20)= 437.7
# Episode 2440  return=  576  avg(last 20)= 457.6
# Episode 2460  return=  221  avg(last 20)= 307.4
# Episode 2480  return=  132  avg(last 20)= 199.0
# Episode 2500  return=  515  avg(last 20)= 196.6
# Episode 2520  return=  190  avg(last 20)= 220.9
# Episode 2540  return=  258  avg(last 20)= 218.5
# Episode 2560  return=  217  avg(last 20)= 248.0
# Episode 2580  return=  241  avg(last 20)= 295.6
# Episode 2600  return=  264  avg(last 20)= 305.7
# Episode 2620  return=  379  avg(last 20)= 552.5
# Episode 2640  return=  379  avg(last 20)= 496.1
# Episode 2660  return=  782  avg(last 20)= 500.0
# Episode 2680  return=  397  avg(last 20)= 380.4
# Episode 2700  return=  367  avg(last 20)= 401.4
# Episode 2720  return=  505  avg(last 20)= 423.0
# Episode 2740  return=  320  avg(last 20)= 405.3
# Episode 2760  return=  502  avg(last 20)= 461.9
# Episode 2780  return=  162  avg(last 20)= 435.4
# Episode 2800  return=  476  avg(last 20)= 479.8
# Episode 2820  return=  515  avg(last 20)= 491.7
# Episode 2840  return=  497  avg(last 20)= 469.8
# Episode 2860  return=  394  avg(last 20)= 475.4
# Episode 2880  return=  423  avg(last 20)= 469.0
# Episode 2900  return=  553  avg(last 20)= 501.4
# Episode 2920  return=  499  avg(last 20)= 478.4
# Episode 2940  return=  558  avg(last 20)= 442.0
# Episode 2960  return=  470  avg(last 20)= 495.7
# Episode 2980  return=  397  avg(last 20)= 468.8
# Saved model_ema_a0.5000.pt and history_ema_a0.5000.pkl and time_ema_a0.5000.pkl

# %%
history_ema_005   = main(baseline_mode='ema', baseline_alpha=0.05, n_episodes=3000, baseline_value=100)
history_ema_0005  = main(baseline_mode='ema', baseline_alpha=0.0005, n_episodes=3000, baseline_value=100)
history_ema_05    = main(baseline_mode='ema', baseline_alpha=0.5, n_episodes=3000, baseline_value=100)
# Out:
# State space: Box(-inf, inf, (11,), float64)
# Action space: Box(-1.0, 1.0, (3,), float32)
# Episode    0  return=   10  avg(last 20)=   9.7
# Episode   20  return=   60  avg(last 20)=  17.2
# Episode   40  return=    6  avg(last 20)=  28.1
# Episode   60  return=   85  avg(last 20)=  46.2
# Episode   80  return=  131  avg(last 20)=  78.4
# Episode  100  return=  214  avg(last 20)= 164.1
# Episode  120  return=  124  avg(last 20)= 178.9
# Episode  140  return=  200  avg(last 20)= 177.2
# Episode  160  return=  207  avg(last 20)= 200.9
# Episode  180  return=  186  avg(last 20)= 196.3
# Episode  200  return=  130  avg(last 20)= 161.1
# Episode  220  return=  135  avg(last 20)= 126.3
# Episode  240  return=  155  avg(last 20)= 142.7
# Episode  260  return=  203  avg(last 20)= 185.3
# Episode  280  return=  233  avg(last 20)= 197.3
# Episode  300  return=  363  avg(last 20)= 280.5
# Episode  320  return=  277  avg(last 20)= 236.8
# Episode  340  return=  268  avg(last 20)= 288.7
# Episode  360  return=  219  avg(last 20)= 231.8
# Episode  380  return=   85  avg(last 20)= 188.2
# Episode  400  return=  258  avg(last 20)= 216.4
# Episode  420  return=  309  avg(last 20)= 278.4
# Episode  440  return=  341  avg(last 20)= 395.2
# Episode  460  return=  377  avg(last 20)= 508.5
# Episode  480  return=  339  avg(last 20)= 429.7
# Episode  500  return=  388  avg(last 20)= 381.0
# Episode  520  return=  337  avg(last 20)= 345.1
# Episode  540  return=  321  avg(last 20)= 313.4
# Episode  560  return=  138  avg(last 20)= 271.8
# Episode  580  return=  347  avg(last 20)= 303.9
# Episode  600  return=  385  avg(last 20)= 355.6
# Episode  620  return=  328  avg(last 20)= 323.2
# Episode  640  return=  413  avg(last 20)= 337.3
# Episode  660  return=  476  avg(last 20)= 443.7
# Episode  680  return=  418  avg(last 20)= 399.7
# Episode  700  return=  684  avg(last 20)= 525.7
# Episode  720  return=  798  avg(last 20)= 692.5
# Episode  740  return=  417  avg(last 20)= 555.4
# Episode  760  return=  495  avg(last 20)= 469.3
# Episode  780  return=  457  avg(last 20)= 473.6
# Episode  800  return=  665  avg(last 20)= 522.6
# Episode  820  return=  598  avg(last 20)= 580.2
# Episode  840  return=  461  avg(last 20)= 527.3
# Episode  860  return=  374  avg(last 20)= 382.4
# Episode  880  return=  382  avg(last 20)= 380.1
# Episode  900  return=  342  avg(last 20)= 313.3
# Episode  920  return=  410  avg(last 20)= 376.5
# Episode  940  return=  450  avg(last 20)= 390.0
# Episode  960  return=  488  avg(last 20)= 437.5
# Episode  980  return=  547  avg(last 20)= 496.2
# Episode 1000  return=  656  avg(last 20)= 574.8
# Episode 1020  return=  950  avg(last 20)= 626.5
# Episode 1040  return=  187  avg(last 20)= 630.4
# Episode 1060  return=  718  avg(last 20)= 641.3
# Episode 1080  return=  655  avg(last 20)= 702.8
# Episode 1100  return=  463  avg(last 20)= 593.5
# Episode 1120  return=  497  avg(last 20)= 487.1
# Episode 1140  return=  492  avg(last 20)= 485.4
# Episode 1160  return=  453  avg(last 20)= 450.4
# Episode 1180  return=  440  avg(last 20)= 388.3
# Episode 1200  return=  401  avg(last 20)= 408.6
# Episode 1220  return=  393  avg(last 20)= 410.9
# Episode 1240  return=  422  avg(last 20)= 411.9
# Episode 1260  return=  409  avg(last 20)= 409.4
# Episode 1280  return=  412  avg(last 20)= 338.0
# Episode 1300  return=  306  avg(last 20)= 342.7
# Episode 1320  return=  253  avg(last 20)= 331.1
# Episode 1340  return=   25  avg(last 20)=  95.9
# Episode 1360  return=   70  avg(last 20)=  76.2
# Episode 1380  return=   58  avg(last 20)=  61.2
# Episode 1400  return=   76  avg(last 20)= 119.1
# Episode 1420  return=  387  avg(last 20)= 228.4
# Episode 1440  return=  447  avg(last 20)= 408.3
# Episode 1460  return=  427  avg(last 20)= 431.0
# Episode 1480  return=  428  avg(last 20)= 376.4
# Episode 1500  return=  471  avg(last 20)= 447.9
# Episode 1520  return=  431  avg(last 20)= 445.0
# Episode 1540  return=  355  avg(last 20)= 404.4
# Episode 1560  return=  374  avg(last 20)= 359.6
# Episode 1580  return=  373  avg(last 20)= 379.5
# Episode 1600  return=  324  avg(last 20)= 313.8
# Episode 1620  return=  328  avg(last 20)= 320.7
# Episode 1640  return=  342  avg(last 20)= 331.4
# Episode 1660  return=  364  avg(last 20)= 346.0
# Episode 1680  return=  332  avg(last 20)= 323.3
# Episode 1700  return=  374  avg(last 20)= 364.6
# Episode 1720  return=  374  avg(last 20)= 343.1
# Episode 1740  return=  290  avg(last 20)= 297.0
# Episode 1760  return=  306  avg(last 20)= 326.0
# Episode 1780  return=  355  avg(last 20)= 341.1
# Episode 1800  return=  369  avg(last 20)= 346.3
# Episode 1820  return=  181  avg(last 20)= 237.0
# Episode 1840  return=  582  avg(last 20)= 282.1
# Episode 1860  return=  423  avg(last 20)= 375.9
# Episode 1880  return=  113  avg(last 20)= 241.1
# Episode 1900  return=  313  avg(last 20)= 125.4
# Episode 1920  return=  490  avg(last 20)= 253.3
# Episode 1940  return=  152  avg(last 20)= 316.0
# Episode 1960  return=  483  avg(last 20)= 397.0
# Episode 1980  return=  435  avg(last 20)= 398.5
# Episode 2000  return=  314  avg(last 20)= 380.7
# Episode 2020  return=  443  avg(last 20)= 418.8
# Episode 2040  return=  426  avg(last 20)= 403.3
# Episode 2060  return=  365  avg(last 20)= 366.7
# Episode 2080  return=  505  avg(last 20)= 383.7
# Episode 2100  return=  594  avg(last 20)= 500.8
# Episode 2120  return=  370  avg(last 20)= 470.0
# Episode 2140  return=  607  avg(last 20)= 402.7
# Episode 2160  return=  358  avg(last 20)= 447.5
# Episode 2180  return=  364  avg(last 20)= 359.0
# Episode 2200  return=  729  avg(last 20)= 245.6
# Episode 2220  return=  404  avg(last 20)= 516.3
# Episode 2240  return=  370  avg(last 20)= 466.1
# Episode 2260  return=  488  avg(last 20)= 372.0
# Episode 2280  return=  130  avg(last 20)= 206.7
# Episode 2300  return=  263  avg(last 20)= 207.9
# Episode 2320  return=  549  avg(last 20)= 339.9
# Episode 2340  return=   90  avg(last 20)= 326.3
# Episode 2360  return=  205  avg(last 20)= 191.9
# Episode 2380  return=  574  avg(last 20)= 453.3
# Episode 2400  return=  540  avg(last 20)= 477.7
# Episode 2420  return=  617  avg(last 20)= 543.7
# Episode 2440  return=  500  avg(last 20)= 511.2
# Episode 2460  return=  579  avg(last 20)= 520.4
# Episode 2480  return=  610  avg(last 20)= 501.7
# Episode 2500  return=  584  avg(last 20)= 448.8
# Episode 2520  return=  354  avg(last 20)= 456.5
# Episode 2540  return=  243  avg(last 20)= 506.2
# Episode 2560  return=  308  avg(last 20)= 496.4
# Episode 2580  return=  594  avg(last 20)= 536.6
# Episode 2600  return=  251  avg(last 20)= 507.4
# Episode 2620  return=  598  avg(last 20)= 573.8
# Episode 2640  return=  481  avg(last 20)= 468.4
# Episode 2660  return=  613  avg(last 20)= 550.1
# Episode 2680  return=  659  avg(last 20)= 558.9
# Episode 2700  return=  598  avg(last 20)= 647.9
# Episode 2720  return=  548  avg(last 20)= 568.8
# Episode 2740  return=  580  avg(last 20)= 574.3
# Episode 2760  return=  398  avg(last 20)= 572.9
# Episode 2780  return= 1057  avg(last 20)= 625.1
# Episode 2800  return=  791  avg(last 20)= 616.4
# Episode 2820  return=  397  avg(last 20)= 408.3
# Episode 2840  return=  293  avg(last 20)= 357.5
# Episode 2860  return=  320  avg(last 20)= 285.0
# Episode 2880  return=  541  avg(last 20)= 332.8
# Episode 2900  return=  352  avg(last 20)= 325.4
# Episode 2920  return=  530  avg(last 20)= 542.3
# Episode 2940  return=  234  avg(last 20)= 512.5
# Episode 2960  return=  268  avg(last 20)= 497.3
# Episode 2980  return=  622  avg(last 20)= 538.7
# Saved model_ema_a0.0500.pt and history_ema_a0.0500.pkl and time_ema_a0.0500.pkl
# State space: Box(-inf, inf, (11,), float64)
# Action space: Box(-1.0, 1.0, (3,), float32)
# Episode    0  return=   10  avg(last 20)=   9.7
# Episode   20  return=   43  avg(last 20)=  16.1
# Episode   40  return=   11  avg(last 20)=  12.3
# Episode   60  return=   11  avg(last 20)=  16.6
# Episode   80  return=   19  avg(last 20)=  27.9
# Episode  100  return=   42  avg(last 20)=  46.7
# Episode  120  return=   48  avg(last 20)=  53.5
# Episode  140  return=   42  avg(last 20)=  49.5
# Episode  160  return=   44  avg(last 20)=  48.0
# Episode  180  return=   48  avg(last 20)=  42.4
# Episode  200  return=   43  avg(last 20)=  42.3
# Episode  220  return=   43  avg(last 20)=  36.0
# Episode  240  return=   46  avg(last 20)=  35.2
# Episode  260  return=   48  avg(last 20)=  41.3
# Episode  280  return=   45  avg(last 20)=  43.0
# Episode  300  return=   41  avg(last 20)=  44.3
# Episode  320  return=   43  avg(last 20)=  40.7
# Episode  340  return=   43  avg(last 20)=  39.6
# Episode  360  return=   48  avg(last 20)=  44.3
# Episode  380  return=   60  avg(last 20)=  50.3
# Episode  400  return=   55  avg(last 20)=  53.6
# Episode  420  return=   51  avg(last 20)=  58.9
# Episode  440  return=   70  avg(last 20)=  66.6
# Episode  460  return=   51  avg(last 20)=  59.9
# Episode  480  return=   54  avg(last 20)=  55.7
# Episode  500  return=   57  avg(last 20)=  56.1
# Episode  520  return=   60  avg(last 20)=  60.7
# Episode  540  return=   50  avg(last 20)=  60.5
# Episode  560  return=   61  avg(last 20)=  62.3
# Episode  580  return=   57  avg(last 20)=  61.7
# Episode  600  return=   53  avg(last 20)=  57.9
# Episode  620  return=   53  avg(last 20)=  53.3
# Episode  640  return=   50  avg(last 20)=  48.5
# Episode  660  return=   43  avg(last 20)=  47.5
# Episode  680  return=   52  avg(last 20)=  49.4
# Episode  700  return=   55  avg(last 20)=  55.8
# Episode  720  return=   67  avg(last 20)=  54.7
# Episode  740  return=   52  avg(last 20)=  54.3
# Episode  760  return=   63  avg(last 20)=  57.4
# Episode  780  return=   61  avg(last 20)=  60.5
# Episode  800  return=   57  avg(last 20)=  58.8
# Episode  820  return=   60  avg(last 20)=  58.6
# Episode  840  return=   63  avg(last 20)=  57.8
# Episode  860  return=   63  avg(last 20)=  58.5
# Episode  880  return=   50  avg(last 20)=  51.8
# Episode  900  return=   50  avg(last 20)=  49.8
# Episode  920  return=   56  avg(last 20)=  51.3
# Episode  940  return=   57  avg(last 20)=  55.2
# Episode  960  return=   55  avg(last 20)=  57.5
# Episode  980  return=   48  avg(last 20)=  42.5
# Episode 1000  return=   62  avg(last 20)=  51.0
# Episode 1020  return=   68  avg(last 20)=  56.4
# Episode 1040  return=   28  avg(last 20)=  43.7
# Episode 1060  return=   48  avg(last 20)=  42.1
# Episode 1080  return=   60  avg(last 20)=  50.1
# Episode 1100  return=   29  avg(last 20)=  55.1
# Episode 1120  return=   65  avg(last 20)=  57.7
# Episode 1140  return=  115  avg(last 20)=  90.3
# Episode 1160  return=   93  avg(last 20)=  87.5
# Episode 1180  return=  100  avg(last 20)=  81.2
# Episode 1200  return=   79  avg(last 20)=  77.7
# Episode 1220  return=   86  avg(last 20)=  89.8
# Episode 1240  return=   99  avg(last 20)= 118.1
# Episode 1260  return=  127  avg(last 20)= 109.0
# Episode 1280  return=  121  avg(last 20)= 120.7
# Episode 1300  return=  148  avg(last 20)= 174.5
# Episode 1320  return=  296  avg(last 20)= 224.6
# Episode 1340  return=  439  avg(last 20)= 393.6
# Episode 1360  return=  152  avg(last 20)= 291.9
# Episode 1380  return=  499  avg(last 20)= 236.7
# Episode 1400  return=  472  avg(last 20)= 358.1
# Episode 1420  return=  428  avg(last 20)= 388.8
# Episode 1440  return=  401  avg(last 20)= 342.1
# Episode 1460  return=  390  avg(last 20)= 379.0
# Episode 1480  return=  816  avg(last 20)= 616.4
# Episode 1500  return= 1045  avg(last 20)= 917.6
# Episode 1520  return= 1009  avg(last 20)= 853.8
# Episode 1540  return=  326  avg(last 20)= 529.5
# Episode 1560  return=  303  avg(last 20)= 744.0
# Episode 1580  return=  384  avg(last 20)= 821.2
# Episode 1600  return=  987  avg(last 20)= 973.4
# Episode 1620  return= 1029  avg(last 20)= 905.1
# Episode 1640  return= 1030  avg(last 20)= 939.7
# Episode 1660  return= 1002  avg(last 20)= 941.3
# Episode 1680  return=  393  avg(last 20)= 755.8
# Episode 1700  return=  588  avg(last 20)= 544.5
# Episode 1720  return=  995  avg(last 20)= 784.7
# Episode 1740  return= 1001  avg(last 20)= 926.6
# Episode 1760  return=  994  avg(last 20)= 980.4
# Episode 1780  return=  999  avg(last 20)= 987.3
# Episode 1800  return= 1013  avg(last 20)=1002.7
# Episode 1820  return=  251  avg(last 20)= 483.3
# Episode 1840  return=  442  avg(last 20)= 273.9
# Episode 1860  return= 1013  avg(last 20)= 985.7
# Episode 1880  return= 1027  avg(last 20)=1018.9
# Episode 1900  return= 1020  avg(last 20)= 862.1
# Episode 1920  return= 1026  avg(last 20)=1020.2
# Episode 1940  return= 1019  avg(last 20)=1023.7
# Episode 1960  return= 1036  avg(last 20)= 982.4
# Episode 1980  return= 1043  avg(last 20)= 749.4
# Episode 2000  return= 1033  avg(last 20)= 618.8
# Episode 2020  return=  378  avg(last 20)= 651.1
# Episode 2040  return= 1038  avg(last 20)= 630.9
# Episode 2060  return= 1047  avg(last 20)=1001.8
# Episode 2080  return= 1062  avg(last 20)= 952.7
# Episode 2100  return= 1049  avg(last 20)= 994.2
# Episode 2120  return=  692  avg(last 20)= 924.3
# Episode 2140  return= 1037  avg(last 20)= 917.7
# Episode 2160  return= 1054  avg(last 20)= 753.3
# Episode 2180  return= 1042  avg(last 20)= 998.3
# Episode 2200  return= 1021  avg(last 20)=1030.2
# Episode 2220  return= 1024  avg(last 20)=1025.6
# Episode 2240  return= 1040  avg(last 20)=1031.1
# Episode 2260  return= 1037  avg(last 20)=1036.2
# Episode 2280  return= 1044  avg(last 20)= 956.8
# Episode 2300  return= 1058  avg(last 20)=1048.6
# Episode 2320  return= 1057  avg(last 20)=1005.6
# Episode 2340  return= 1054  avg(last 20)=1057.8
# Episode 2360  return=  423  avg(last 20)= 940.3
# Episode 2380  return= 1024  avg(last 20)= 863.0
# Episode 2400  return= 1043  avg(last 20)=1034.7
# Episode 2420  return= 1055  avg(last 20)=1051.9
# Episode 2440  return=  854  avg(last 20)=1051.0
# Episode 2460  return= 1053  avg(last 20)= 920.2
# Episode 2480  return= 1044  avg(last 20)= 932.9
# Episode 2500  return= 1039  avg(last 20)= 988.7
# Episode 2520  return= 1041  avg(last 20)=1037.2
# Episode 2540  return= 1033  avg(last 20)= 989.8
# Episode 2560  return= 1017  avg(last 20)=1029.8
# Episode 2580  return= 1014  avg(last 20)= 967.2
# Episode 2600  return= 1029  avg(last 20)=1022.4
# Episode 2620  return= 1015  avg(last 20)=1024.1
# Episode 2640  return= 1025  avg(last 20)=1026.7
# Episode 2660  return= 1036  avg(last 20)=1034.2
# Episode 2680  return= 1032  avg(last 20)=1031.7
# Episode 2700  return= 1018  avg(last 20)=1028.3
# Episode 2720  return= 1033  avg(last 20)=1024.2
# Episode 2740  return=  678  avg(last 20)= 944.1
# Episode 2760  return= 1019  avg(last 20)= 943.2
# Episode 2780  return= 1019  avg(last 20)=1016.4
# Episode 2800  return= 1016  avg(last 20)=1020.7
# Episode 2820  return=  560  avg(last 20)= 996.7
# Episode 2840  return= 1015  avg(last 20)= 887.3
# Episode 2860  return= 1027  avg(last 20)= 906.6
# Episode 2880  return= 1027  avg(last 20)= 984.8
# Episode 2900  return= 1032  avg(last 20)=1030.4
# Episode 2920  return= 1035  avg(last 20)=1032.6
# Episode 2940  return= 1042  avg(last 20)=1040.5
# Episode 2960  return= 1053  avg(last 20)= 986.6
# Episode 2980  return= 1054  avg(last 20)= 772.6
# Saved model_ema_a0.0005.pt and history_ema_a0.0005.pkl and time_ema_a0.0005.pkl
# State space: Box(-inf, inf, (11,), float64)
# Action space: Box(-1.0, 1.0, (3,), float32)
# Episode    0  return=   10  avg(last 20)=   9.7
# Episode   20  return=    8  avg(last 20)=  14.3
# Episode   40  return=   30  avg(last 20)=  22.5
# Episode   60  return=   55  avg(last 20)=  31.7
# Episode   80  return=  300  avg(last 20)=  86.0
# Episode  100  return=    2  avg(last 20)= 125.7
# Episode  120  return=  176  avg(last 20)= 132.0
# Episode  140  return=  163  avg(last 20)= 168.0
# Episode  160  return=  138  avg(last 20)= 130.9
# Episode  180  return=   27  avg(last 20)= 155.9
# Episode  200  return=  213  avg(last 20)= 197.3
# Episode  220  return=  212  avg(last 20)= 168.0
# Episode  240  return=  215  avg(last 20)= 195.0
# Episode  260  return=  147  avg(last 20)= 158.1
# Episode  280  return=  210  avg(last 20)= 173.9
# Episode  300  return=  142  avg(last 20)= 191.1
# Episode  320  return=  238  avg(last 20)= 113.2
# Episode  340  return=  218  avg(last 20)= 204.6
# Episode  360  return=  206  avg(last 20)= 217.5
# Episode  380  return=  198  avg(last 20)= 195.1
# Episode  400  return=  361  avg(last 20)= 217.6
# Episode  420  return=  219  avg(last 20)= 222.0
# Episode  440  return=  270  avg(last 20)= 282.0
# Episode  460  return=  263  avg(last 20)= 375.2
# Episode  480  return=  177  avg(last 20)= 362.6
# Episode  500  return=   56  avg(last 20)= 248.0
# Episode  520  return=  334  avg(last 20)= 293.0
# Episode  540  return=  280  avg(last 20)= 371.8
# Episode  560  return=  314  avg(last 20)= 389.2
# Episode  580  return=  649  avg(last 20)= 312.0
# Episode  600  return=  304  avg(last 20)= 299.2
# Episode  620  return=  251  avg(last 20)= 325.4
# Episode  640  return=  139  avg(last 20)= 316.7
# Episode  660  return=  522  avg(last 20)= 357.3
# Episode  680  return=  139  avg(last 20)= 412.5
# Episode  700  return=  836  avg(last 20)= 405.0
# Episode  720  return=  206  avg(last 20)= 335.8
# Episode  740  return=  327  avg(last 20)= 414.1
# Episode  760  return=  381  avg(last 20)= 351.3
# Episode  780  return=  248  avg(last 20)= 314.9
# Episode  800  return=  227  avg(last 20)= 212.5
# Episode  820  return=  663  avg(last 20)= 316.4
# Episode  840  return=  338  avg(last 20)= 435.9
# Episode  860  return=  266  avg(last 20)= 357.3
# Episode  880  return=  269  avg(last 20)= 422.3
# Episode  900  return=  257  avg(last 20)= 414.7
# Episode  920  return=  316  avg(last 20)= 418.1
# Episode  940  return=  131  avg(last 20)= 312.1
# Episode  960  return=  361  avg(last 20)= 303.6
# Episode  980  return=  276  avg(last 20)= 411.6
# Episode 1000  return=  221  avg(last 20)= 343.7
# Episode 1020  return=  305  avg(last 20)= 363.2
# Episode 1040  return=  276  avg(last 20)= 330.2
# Episode 1060  return=  476  avg(last 20)= 352.2
# Episode 1080  return=  313  avg(last 20)= 371.1
# Episode 1100  return=  383  avg(last 20)= 365.5
# Episode 1120  return=  247  avg(last 20)= 285.3
# Episode 1140  return=  270  avg(last 20)= 320.3
# Episode 1160  return=  166  avg(last 20)= 317.4
# Episode 1180  return=  218  avg(last 20)= 314.2
# Episode 1200  return=  359  avg(last 20)= 332.9
# Episode 1220  return=   98  avg(last 20)= 343.8
# Episode 1240  return=  485  avg(last 20)= 310.2
# Episode 1260  return=  366  avg(last 20)= 375.3
# Episode 1280  return=  268  avg(last 20)= 430.2
# Episode 1300  return=  221  avg(last 20)= 454.2
# Episode 1320  return=  241  avg(last 20)= 339.3
# Episode 1340  return=  336  avg(last 20)= 471.3
# Episode 1360  return=  428  avg(last 20)= 367.6
# Episode 1380  return=  365  avg(last 20)= 397.4
# Episode 1400  return=  336  avg(last 20)= 357.8
# Episode 1420  return=  368  avg(last 20)= 402.4
# Episode 1440  return=  353  avg(last 20)= 382.8
# Episode 1460  return=  548  avg(last 20)= 420.2
# Episode 1480  return=  482  avg(last 20)= 484.5
# Episode 1500  return=  441  avg(last 20)= 482.0
# Episode 1520  return=  360  avg(last 20)= 459.4
# Episode 1540  return=  573  avg(last 20)= 512.7
# Episode 1560  return=  492  avg(last 20)= 530.1
# Episode 1580  return=  446  avg(last 20)= 376.6
# Episode 1600  return=  617  avg(last 20)= 438.5
# Episode 1620  return=  378  avg(last 20)= 344.4
# Episode 1640  return=  306  avg(last 20)= 382.2
# Episode 1660  return=  293  avg(last 20)= 325.2
# Episode 1680  return=  499  avg(last 20)= 404.4
# Episode 1700  return=  740  avg(last 20)= 411.6
# Episode 1720  return=  605  avg(last 20)= 406.8
# Episode 1740  return=  458  avg(last 20)= 401.2
# Episode 1760  return=  505  avg(last 20)= 386.9
# Episode 1780  return=   68  avg(last 20)= 193.4
# Episode 1800  return=   73  avg(last 20)=  68.6
# Episode 1820  return=   93  avg(last 20)=  62.8
# Episode 1840  return=  125  avg(last 20)= 109.6
# Episode 1860  return=  202  avg(last 20)= 179.8
# Episode 1880  return=  558  avg(last 20)= 356.4
# Episode 1900  return=  677  avg(last 20)= 434.5
# Episode 1920  return=  421  avg(last 20)= 425.6
# Episode 1940  return=  210  avg(last 20)= 329.1
# Episode 1960  return=  150  avg(last 20)= 211.5
# Episode 1980  return=  200  avg(last 20)= 131.5
# Episode 2000  return=  219  avg(last 20)= 148.6
# Episode 2020  return=  114  avg(last 20)= 127.3
# Episode 2040  return=  137  avg(last 20)= 135.2
# Episode 2060  return=   70  avg(last 20)=  99.6
# Episode 2080  return=  158  avg(last 20)= 101.8
# Episode 2100  return=   81  avg(last 20)= 114.8
# Episode 2120  return=  221  avg(last 20)= 133.3
# Episode 2140  return=  259  avg(last 20)= 174.4
# Episode 2160  return=  150  avg(last 20)= 315.2
# Episode 2180  return=  227  avg(last 20)= 310.8
# Episode 2200  return=  209  avg(last 20)= 233.5
# Episode 2220  return=  201  avg(last 20)= 229.2
# Episode 2240  return=  256  avg(last 20)= 345.8
# Episode 2260  return=  256  avg(last 20)= 299.2
# Episode 2280  return=  253  avg(last 20)= 362.8
# Episode 2300  return=  376  avg(last 20)= 423.5
# Episode 2320  return=  511  avg(last 20)= 461.3
# Episode 2340  return=  357  avg(last 20)= 431.5
# Episode 2360  return=  392  avg(last 20)= 386.6
# Episode 2380  return=  365  avg(last 20)= 367.6
# Episode 2400  return=  440  avg(last 20)= 389.1
# Episode 2420  return=  371  avg(last 20)= 360.9
# Episode 2440  return=  369  avg(last 20)= 380.9
# Episode 2460  return=  419  avg(last 20)= 393.4
# Episode 2480  return=  426  avg(last 20)= 396.0
# Episode 2500  return=  401  avg(last 20)= 386.3
# Episode 2520  return=  537  avg(last 20)= 404.4
# Episode 2540  return=  356  avg(last 20)= 397.3
# Episode 2560  return=   70  avg(last 20)= 376.0
# Episode 2580  return=  281  avg(last 20)= 400.0
# Episode 2600  return=  358  avg(last 20)= 359.3
# Episode 2620  return=  376  avg(last 20)= 365.9
# Episode 2640  return=   86  avg(last 20)= 379.6
# Episode 2660  return=  391  avg(last 20)= 411.1
# Episode 2680  return=  381  avg(last 20)= 421.8
# Episode 2700  return=  670  avg(last 20)= 445.1
# Episode 2720  return=  401  avg(last 20)= 400.8
# Episode 2740  return=  406  avg(last 20)= 392.8
# Episode 2760  return=  541  avg(last 20)= 410.4
# Episode 2780  return=  309  avg(last 20)= 370.9
# Episode 2800  return=  564  avg(last 20)= 411.5
# Episode 2820  return=  516  avg(last 20)= 449.8
# Episode 2840  return=  445  avg(last 20)= 492.6
# Episode 2860  return=  366  avg(last 20)= 473.1
# Episode 2880  return=  368  avg(last 20)= 461.0
# Episode 2900  return=  455  avg(last 20)= 527.1
# Episode 2920  return=  332  avg(last 20)= 435.6
# Episode 2940  return=  420  avg(last 20)= 449.0
# Episode 2960  return=  500  avg(last 20)= 417.3
# Episode 2980  return=  590  avg(last 20)= 435.7
# Saved model_ema_a0.5000.pt and history_ema_a0.5000.pkl and time_ema_a0.5000.pkl

# %%
import pickle
import os
import numpy as np
import matplotlib.pyplot as plt

def load_time(suffix):
    path = os.path.join(PREFIX, f'time_{suffix}.pkl')
    with open(path, 'rb') as f:
        return pickle.load(f)

PREFIX = 'results'

def smooth(x, w=20):
    return np.convolve(x, np.ones(w)/w, mode='valid')

def smooth_50(x, w=50):
    return np.convolve(x, np.ones(w)/w, mode='valid')

def load_history(suffix):
    path = os.path.join(PREFIX, f'history_{suffix}.pkl')
    with open(path, 'rb') as f:
        return pickle.load(f)

def final_mean(suffix, last_n=50):
    h = load_history(suffix)
    return float(np.mean(h[-last_n:]))

EMA_SLOW   = 'ema_a0.0005'
EMA_MEDIUM = 'ema_a0.0500'
EMA_FAST   = 'ema_a0.5000'

# %%
fig, (ax_const, ax_ema) = plt.subplots(1, 2, figsize=(14, 5))

# --- Left: constant baseline sensitivity ---
const_runs = [
    ('none',          'vanilla (no preproc)',      {'linestyle': ':',  'color': 'black'}),
    ('constant_b0',   'b = 0',                     {}),
    ('constant_b20',  'b = 20',                    {}),
    ('constant_b100', 'b = 100',                   {}),
]
for suffix, label, style in const_runs:
    h = load_history(suffix)

    ax_const.plot(smooth(h), label=label, **style)

ax_const.set_xlabel('Episode')
ax_const.set_ylabel('Return (20-ep moving avg)')
ax_const.set_title('(a) Constant baseline sensitivity')
ax_const.legend(fontsize=9)
ax_const.grid(alpha=0.3)

# --- Right: EMA alpha sensitivity ---
ema_runs = [
    ('none',     'vanilla (no preproc)',      {'linestyle': ':',  'color': 'black'}),
    (EMA_SLOW,   'α = 0.0005',                {}),
    (EMA_MEDIUM, 'α = 0.05',                  {}),
    (EMA_FAST,   'α = 0.5',                   {}),
]
for suffix, label, style in ema_runs:
    h = load_history(suffix)
    ax_ema.plot(smooth(h), label=label, **style)

ax_ema.set_xlabel('Episode')
ax_ema.set_ylabel('Return (20-ep moving avg)')
ax_ema.set_title('(b) EMA α sensitivity')
ax_ema.legend(fontsize=9)
ax_ema.grid(alpha=0.3)

plt.tight_layout()
plt.savefig(os.path.join(PREFIX, 'sensitivity_analysis.png'),
            dpi=120, bbox_inches='tight')
plt.show()
print("\nSaved: sensitivity_analysis.png")
# Out:
# Saved: sensitivity_analysis.png

# %%
def final_mean(suffix, last_n=50):
    """Average return over the last N episodes of a run."""
    h = load_history(suffix)
    return float(np.mean(h[-last_n:]))

# Constant variants
const_candidates = ['constant_b0', 'constant_b20', 'constant_b100']
const_scores = {c: final_mean(c) for c in const_candidates}
BEST_CONST = max(const_scores, key=const_scores.get)
print("Constant scores:", const_scores)
print(f"Best constant: {BEST_CONST}")

# EMA variants
ema_candidates = [EMA_SLOW, EMA_MEDIUM, EMA_FAST]
ema_scores = {e: final_mean(e) for e in ema_candidates}
BEST_EMA = max(ema_scores, key=ema_scores.get)
print("EMA scores:", ema_scores)
print(f"Best EMA: {BEST_EMA}")

summary_runs = [
    ('none',      'vanilla (no preproc)',   {'linestyle': ':',  'color': 'black'}),
    (BEST_CONST,  'constant (best)',        {}),
    (BEST_EMA,    'EMA (best)',             {}),
]

plt.figure(figsize=(10, 5))

for suffix, label, style in summary_runs:
    h = load_history(suffix)
    plt.plot(smooth(h), label=label, **style)

plt.xlabel('Episode')
plt.ylabel('Return (20-ep moving avg)')
plt.title('REINFORCE variants on Hopper — best-performing baselines')
plt.legend()
plt.grid(alpha=0.3)
plt.tight_layout()
plt.savefig(os.path.join(PREFIX, 'reinforce_best_summary.png'),
            dpi=120, bbox_inches='tight')
plt.show()


print("\nDone. Saved:")
print(f"  - sensitivity_analysis.png")
print(f"  - reinforce_best_summary.png")
# Out:
# Constant scores: {'constant_b0': 52.65064631136333, 'constant_b20': 97.87024754446843, 'constant_b100': 43.17274227498896}
# Best constant: constant_b20
# EMA scores: {'ema_a0.0005': 909.9395543653424, 'ema_a0.0500': 533.2793453996396, 'ema_a0.5000': 416.31419597415044}
# Best EMA: ema_a0.0005
# Done. Saved:
#   - sensitivity_analysis.png
#   - reinforce_best_summary.png

# %%
import importlib
import agent, train

importlib.reload(agent)
importlib.reload(train)

from train import main

# %%
import random
PREFIX = "results"
os.makedirs(PREFIX, exist_ok=True)

def loguniform(low, high):
    return float(np.exp(np.random.uniform(np.log(low), np.log(high))))

np.random.seed(123)
random.seed(123)

N_TRIALS = 12

ac_configs = []

for i in range(N_TRIALS):
    cfg = {
        "run_name": f"ac_trial_{i}",
        "actor_lr": loguniform(1e-5, 3e-4),
        "critic_lr": loguniform(3e-5, 1e-3),
        "entropy_weight": random.choice([0.0, 1e-4, 1e-3, 5e-3]),
        "critic_weight": random.choice([0.25, 0.5, 1.0]),
        "hidden": random.choice([64, 128, 256]),
        "gamma": random.choice([0.99, 0.995]),
        "grad_clip": random.choice([0.5, 1.0]),
        "normalize_advantage": random.choice([True, False]),
    }
    ac_configs.append(cfg)

for cfg in ac_configs:
    print(cfg)
# Out:
# {'run_name': 'ac_trial_0', 'actor_lr': 0.00010684874790620224, 'critic_lr': 8.182325763528696e-05, 'entropy_weight': 0.0, 'critic_weight': 0.5, 'hidden': 64, 'gamma': 0.995, 'grad_clip': 1.0, 'normalize_advantage': True}
# {'run_name': 'ac_trial_1', 'actor_lr': 2.163152330135122e-05, 'critic_lr': 0.00020735131717567522, 'entropy_weight': 0.0, 'critic_weight': 0.5, 'hidden': 256, 'gamma': 0.995, 'grad_clip': 1.0, 'normalize_advantage': True}
# {'run_name': 'ac_trial_2', 'actor_lr': 0.0001155428052138559, 'critic_lr': 0.00013226991968313137, 'entropy_weight': 0.0001, 'critic_weight': 0.25, 'hidden': 128, 'gamma': 0.995, 'grad_clip': 0.5, 'normalize_advantage': True}
# {'run_name': 'ac_trial_3', 'actor_lr': 0.00028100085627406896, 'critic_lr': 0.0003311569757103039, 'entropy_weight': 0.0, 'critic_weight': 0.5, 'hidden': 64, 'gamma': 0.995, 'grad_clip': 0.5, 'normalize_advantage': True}
# {'run_name': 'ac_trial_4', 'actor_lr': 5.133277397424096e-05, 'critic_lr': 0.00011865025852458269, 'entropy_weight': 0.001, 'critic_weight': 1.0, 'hidden': 128, 'gamma': 0.99, 'grad_clip': 0.5, 'normalize_advantage': True}
# {'run_name': 'ac_trial_5', 'actor_lr': 3.2130356318619384e-05, 'critic_lr': 0.00038670123435426227, 'entropy_weight': 0.0001, 'critic_weight': 0.25, 'hidden': 64, 'gamma': 0.995, 'grad_clip': 1.0, 'normalize_advantage': False}
# {'run_name': 'ac_trial_6', 'actor_lr': 4.4445150827671884e-05, 'critic_lr': 3.6983112195976435e-05, 'entropy_weight': 0.001, 'critic_weight': 0.5, 'hidden': 64, 'gamma': 0.995, 'grad_clip': 1.0, 'normalize_advantage': False}
# {'run_name': 'ac_trial_7', 'actor_lr': 3.872216488027649e-05, 'critic_lr': 0.00039902377429646666, 'entropy_weight': 0.0001, 'critic_weight': 1.0, 'hidden': 256, 'gamma': 0.995, 'grad_clip': 0.5, 'normalize_advantage': False}
# {'run_name': 'ac_trial_8', 'actor_lr': 1.8602118810743473e-05, 'critic_lr': 5.550255872150227e-05, 'entropy_weight': 0.005, 'critic_weight': 1.0, 'hidden': 256, 'gamma': 0.995, 'grad_clip': 1.0, 'normalize_advantage': False}
# {'run_name': 'ac_trial_9', 'actor_lr': 6.097696890367453e-05, 'critic_lr': 0.0001936556549043446, 'entropy_weight': 0.0, 'critic_weight': 1.0, 'hidden': 64, 'gamma': 0.99, 'grad_clip': 1.0, 'normalize_advantage': False}
# {'run_name': 'ac_trial_10', 'actor_lr': 8.651414894178233e-05, 'critic_lr': 0.000589797434988458, 'entropy_weight': 0.0001, 'critic_weight': 0.5, 'hidden': 128, 'gamma': 0.995, 'grad_clip': 0.5, 'normalize_advantage': False}
# {'run_name': 'ac_trial_11', 'actor_lr': 0.00011751907337909231, 'critic_lr': 0.000255644216482894, 'entropy_weight': 0.005, 'critic_weight': 1.0, 'hidden': 128, 'gamma': 0.99, 'grad_clip': 0.5, 'normalize_advantage': True}

# %%
for cfg in ac_configs:
    print("\nRunning:", cfg["run_name"])
    print(cfg)

    main(
        algorithm="actor_critic",
        n_episodes=3000,
        seed=42,
        actor_lr=cfg["actor_lr"],
        critic_lr=cfg["critic_lr"],
        entropy_weight=cfg["entropy_weight"],
        critic_weight=cfg["critic_weight"],
        hidden_size=cfg["hidden"],
        gamma=cfg["gamma"],
        grad_clip=cfg["grad_clip"],
        normalize_advantage=cfg["normalize_advantage"],
        run_name=cfg["run_name"],
        save_dir=PREFIX
    )
# Out:
# Running: ac_trial_0
# {'run_name': 'ac_trial_0', 'actor_lr': 0.00010684874790620224, 'critic_lr': 8.182325763528696e-05, 'entropy_weight': 0.0, 'critic_weight': 0.5, 'hidden': 64, 'gamma': 0.995, 'grad_clip': 1.0, 'normalize_advantage': True}
# State space: Box(-inf, inf, (11,), float64)
# Action space: Box(-1.0, 1.0, (3,), float32)
# Episode    0  return=   10  avg(last 20)=   9.7
# Episode   20  return=   19  avg(last 20)=  10.4
# Episode   40  return=    6  avg(last 20)=   7.5
# Episode   60  return=    5  avg(last 20)=   7.5
# Episode   80  return=    7  avg(last 20)=   7.2
# Episode  100  return=    6  avg(last 20)=   6.3
# Episode  120  return=    8  avg(last 20)=   6.4
# Episode  140  return=    7  avg(last 20)=   6.7
# Episode  160  return=    6  avg(last 20)=   6.1
# Episode  180  return=    5  avg(last 20)=   6.6
# Episode  200  return=    6  avg(last 20)=   6.7
# Episode  220  return=    6  avg(last 20)=   6.5
# Episode  240  return=    6  avg(last 20)=   6.6
# Episode  260  return=    7  avg(last 20)=   6.3
# Episode  280  return=    7  avg(last 20)=   6.6
# Episode  300  return=    6  avg(last 20)=   6.4
# Episode  320  return=    5  avg(last 20)=   6.1
# Episode  340  return=    5  avg(last 20)=   6.0
# Episode  360  return=    5  avg(last 20)=   5.8
# Episode  380  return=    6  avg(last 20)=   5.7
# Episode  400  return=    6  avg(last 20)=   5.5
# Episode  420  return=    5  avg(last 20)=   5.4
# Episode  440  return=    6  avg(last 20)=   5.8
# Episode  460  return=    5  avg(last 20)=   5.3
# Episode  480  return=    4  avg(last 20)=   5.1
# Episode  500  return=    4  avg(last 20)=   5.2
# Episode  520  return=    6  avg(last 20)=   5.0
# Episode  540  return=    5  avg(last 20)=   5.1
# Episode  560  return=    5  avg(last 20)=   4.9
# Episode  580  return=    5  avg(last 20)=   4.7
# Episode  600  return=    5  avg(last 20)=   4.6
# Episode  620  return=    6  avg(last 20)=   5.0
# Episode  640  return=    7  avg(last 20)=   4.7
# Episode  660  return=    4  avg(last 20)=   4.6
# Episode  680  return=    5  avg(last 20)=   4.8
# Episode  700  return=    5  avg(last 20)=   5.0
# Episode  720  return=    6  avg(last 20)=   5.4
# Episode  740  return=    5  avg(last 20)=   7.3
# Episode  760  return=   13  avg(last 20)=   8.2
# Episode  780  return=    7  avg(last 20)=   7.4
# Episode  800  return=    9  avg(last 20)=   9.2
# Episode  820  return=    6  avg(last 20)=   9.5
# Episode  840  return=   12  avg(last 20)=  11.9
# Episode  860  return=   18  avg(last 20)=  10.7
# Episode  880  return=   11  avg(last 20)=  10.2
# Episode  900  return=    7  avg(last 20)=  13.1
# Episode  920  return=    7  avg(last 20)=  13.4
# Episode  940  return=    9  avg(last 20)=  10.8
# Episode  960  return=    9  avg(last 20)=  12.3
# Episode  980  return=   12  avg(last 20)=  15.0
# Episode 1000  return=   25  avg(last 20)=  16.4
# Episode 1020  return=   62  avg(last 20)=  25.0
# Episode 1040  return=   12  avg(last 20)=  29.7
# Episode 1060  return=   16  avg(last 20)=  25.0
# Episode 1080  return=   34  avg(last 20)=  28.1
# Episode 1100  return=   15  avg(last 20)=  25.5
# Episode 1120  return=   25  avg(last 20)=  33.0
# Episode 1140  return=   99  avg(last 20)=  32.4
# Episode 1160  return=   19  avg(last 20)=  22.0
# Episode 1180  return=   33  avg(last 20)=  26.2
# Episode 1200  return=   17  avg(last 20)=  34.6
# Episode 1220  return=   28  avg(last 20)=  25.7
# Episode 1240  return=   13  avg(last 20)=  27.2
# Episode 1260  return=   27  avg(last 20)=  25.2
# Episode 1280  return=   34  avg(last 20)=  21.6
# Episode 1300  return=   21  avg(last 20)=  30.4
# Episode 1320  return=   35  avg(last 20)=  20.5
# Episode 1340  return=   25  avg(last 20)=  16.2
# Episode 1360  return=   15  avg(last 20)=  20.3
# Episode 1380  return=   21  avg(last 20)=  19.2
# Episode 1400  return=   15  avg(last 20)=  18.1
# Episode 1420  return=   16  avg(last 20)=  23.1
# Episode 1440  return=   25  avg(last 20)=  19.7
# Episode 1460  return=   24  avg(last 20)=  22.2
# Episode 1480  return=   35  avg(last 20)=  33.0
# Episode 1500  return=   32  avg(last 20)=  29.0
# Episode 1520  return=   83  avg(last 20)=  36.3
# Episode 1540  return=   32  avg(last 20)=  46.1
# Episode 1560  return=   17  avg(last 20)=  36.0
# Episode 1580  return=   18  avg(last 20)=  35.1
# Episode 1600  return=   18  avg(last 20)=  36.8
# Episode 1620  return=   36  avg(last 20)=  44.1
# Episode 1640  return=  182  avg(last 20)=  67.4
# Episode 1660  return=   23  avg(last 20)=  97.2
# Episode 1680  return=  165  avg(last 20)=  73.2
# Episode 1700  return=   31  avg(last 20)=  71.6
# Episode 1720  return=   86  avg(last 20)=  63.6
# Episode 1740  return=   48  avg(last 20)=  78.1
# Episode 1760  return=  222  avg(last 20)=  58.1
# Episode 1780  return=  106  avg(last 20)=  84.3
# Episode 1800  return=   27  avg(last 20)=  46.5
# Episode 1820  return=   33  avg(last 20)=  35.8
# Episode 1840  return=   24  avg(last 20)=  46.7
# Episode 1860  return=   53  avg(last 20)=  33.7
# Episode 1880  return=   27  avg(last 20)=  44.8
# Episode 1900  return=   54  avg(last 20)=  47.6
# Episode 1920  return=   77  avg(last 20)=  41.5
# Episode 1940  return=   28  avg(last 20)=  27.2
# Episode 1960  return=   59  avg(last 20)=  33.0
# Episode 1980  return=   20  avg(last 20)=  27.3
# Episode 2000  return=   30  avg(last 20)=  31.7
# Episode 2020  return=   41  avg(last 20)=  35.2
# Episode 2040  return=   30  avg(last 20)=  59.1
# Episode 2060  return=   50  avg(last 20)= 107.8
# Episode 2080  return=   42  avg(last 20)=  61.2
# Episode 2100  return=  165  avg(last 20)= 125.2
# Episode 2120  return=   75  avg(last 20)= 116.8
# Episode 2140  return=   73  avg(last 20)=  89.9
# Episode 2160  return=   68  avg(last 20)=  99.2
# Episode 2180  return=  161  avg(last 20)= 113.0
# Episode 2200  return=  133  avg(last 20)=  93.6
# Episode 2220  return=   26  avg(last 20)= 116.2
# Episode 2240  return=   52  avg(last 20)=  99.7
# Episode 2260  return=   67  avg(last 20)=  65.1
# Episode 2280  return=   14  avg(last 20)=  94.0
# Episode 2300  return=   39  avg(last 20)=  83.2
# Episode 2320  return=   79  avg(last 20)= 105.8
# Episode 2340  return=   33  avg(last 20)= 132.0
# Episode 2360  return=   23  avg(last 20)= 129.0
# Episode 2380  return=  123  avg(last 20)= 131.1
# Episode 2400  return=  247  avg(last 20)= 147.5
# Episode 2420  return=  197  avg(last 20)= 168.9
# Episode 2440  return=   39  avg(last 20)= 166.2
# Episode 2460  return=   88  avg(last 20)= 112.5
# Episode 2480  return=  272  avg(last 20)= 174.7
# Episode 2500  return=  109  avg(last 20)= 111.0
# Episode 2520  return=  262  avg(last 20)= 123.5
# Episode 2540  return=  335  avg(last 20)= 213.7
# Episode 2560  return=   83  avg(last 20)= 200.5
# Episode 2580  return=  288  avg(last 20)= 250.3
# Episode 2600  return=   33  avg(last 20)= 170.6
# Episode 2620  return=  281  avg(last 20)= 214.3
# Episode 2640  return=  347  avg(last 20)= 193.4
# Episode 2660  return=  366  avg(last 20)= 189.8
# Episode 2680  return=  118  avg(last 20)= 195.4
# Episode 2700  return=  374  avg(last 20)= 215.8
# Episode 2720  return=  307  avg(last 20)= 184.6
# Episode 2740  return=  271  avg(last 20)= 174.1
# Episode 2760  return=  254  avg(last 20)= 144.4
# Episode 2780  return=   64  avg(last 20)= 139.3
# Episode 2800  return=   82  avg(last 20)= 118.7
# Episode 2820  return=  115  avg(last 20)= 148.9
# Episode 2840  return=   53  avg(last 20)= 155.6
# Episode 2860  return=  359  avg(last 20)= 210.3
# Episode 2880  return=  326  avg(last 20)= 155.5
# Episode 2900  return=   72  avg(last 20)= 162.4
# Episode 2920  return=  276  avg(last 20)= 178.5
# Episode 2940  return=  341  avg(last 20)= 220.9
# Episode 2960  return=   82  avg(last 20)= 218.7
# Episode 2980  return=  254  avg(last 20)= 180.6
# Saved model_ac_trial_0.pt and history_ac_trial_0.pkl and time_ac_trial_0.pkl
#
# Running: ac_trial_1
# {'run_name': 'ac_trial_1', 'actor_lr': 2.163152330135122e-05, 'critic_lr': 0.00020735131717567522, 'entropy_weight': 0.0, 'critic_weight': 0.5, 'hidden': 256, 'gamma': 0.995, 'grad_clip': 1.0, 'normalize_advantage': True}
# State space: Box(-inf, inf, (11,), float64)
# Action space: Box(-1.0, 1.0, (3,), float32)
# Episode    0  return=    8  avg(last 20)=   7.6
# Episode   20  return=   12  avg(last 20)=  10.6
# Episode   40  return=    8  avg(last 20)=   8.6
# Episode   60  return=   19  avg(last 20)=  10.2
# Episode   80  return=    8  avg(last 20)=   9.1
# Episode  100  return=    7  avg(last 20)=   8.8
# Episode  120  return=    5  avg(last 20)=  10.4
# Episode  140  return=   10  avg(last 20)=  12.0
# Episode  160  return=   30  avg(last 20)=  24.6
# Episode  180  return=    8  avg(last 20)=  40.9
# Episode  200  return=   30  avg(last 20)=  55.9
# Episode  220  return=   48  avg(last 20)=  71.3
# Episode  240  return=  137  avg(last 20)=  97.6
# Episode  260  return=  127  avg(last 20)= 121.6
# Episode  280  return=   44  avg(last 20)= 104.6
# Episode  300  return=  111  avg(last 20)= 115.5
# Episode  320  return=   87  avg(last 20)= 127.4
# Episode  340  return=  170  avg(last 20)= 136.2
# Episode  360  return=  149  avg(last 20)= 111.4
# Episode  380  return=  122  avg(last 20)= 139.9
# Episode  400  return=  253  avg(last 20)= 148.5
# Episode  420  return=  106  avg(last 20)= 157.8
# Episode  440  return=  209  avg(last 20)= 134.6
# Episode  460  return=   95  avg(last 20)= 121.9
# Episode  480  return=  196  avg(last 20)= 154.0
# Episode  500  return=  153  avg(last 20)= 135.9
# Episode  520  return=  122  avg(last 20)= 151.2
# Episode  540  return=  111  avg(last 20)= 164.3
# Episode  560  return=   82  avg(last 20)= 150.1
# Episode  580  return=   90  avg(last 20)= 122.3
# Episode  600  return=   77  avg(last 20)= 118.9
# Episode  620  return=  150  avg(last 20)= 123.7
# Episode  640  return=  102  avg(last 20)= 122.0
# Episode  660  return=  110  avg(last 20)= 121.5
# Episode  680  return=  127  avg(last 20)= 133.4
# Episode  700  return=  120  avg(last 20)= 127.7
# Episode  720  return=  137  avg(last 20)= 125.1
# Episode  740  return=  132  avg(last 20)= 145.8
# Episode  760  return=  107  avg(last 20)= 139.4
# Episode  780  return=  143  avg(last 20)= 166.7
# Episode  800  return=  223  avg(last 20)= 169.4
# Episode  820  return=  190  avg(last 20)= 172.0
# Episode  840  return=  190  avg(last 20)= 208.4
# Episode  860  return=  155  avg(last 20)= 201.6
# Episode  880  return=  236  avg(last 20)= 178.9
# Episode  900  return=  137  avg(last 20)= 165.4
# Episode  920  return=  206  avg(last 20)= 206.9
# Episode  940  return=  117  avg(last 20)= 203.0
# Episode  960  return=  264  avg(last 20)= 215.2
# Episode  980  return=  370  avg(last 20)= 225.4
# Episode 1000  return=  354  avg(last 20)= 248.9
# Episode 1020  return=  192  avg(last 20)= 235.8
# Episode 1040  return=  103  avg(last 20)= 250.9
# Episode 1060  return=  231  avg(last 20)= 235.6
# Episode 1080  return=  175  avg(last 20)= 188.0
# Episode 1100  return=  143  avg(last 20)= 201.0
# Episode 1120  return=  269  avg(last 20)= 261.9
# Episode 1140  return=  320  avg(last 20)= 245.1
# Episode 1160  return=  137  avg(last 20)= 255.3
# Episode 1180  return=  182  avg(last 20)= 258.6
# Episode 1200  return=  327  avg(last 20)= 274.4
# Episode 1220  return=  188  avg(last 20)= 293.3
# Episode 1240  return=  271  avg(last 20)= 304.6
# Episode 1260  return=  319  avg(last 20)= 288.9
# Episode 1280  return=  118  avg(last 20)= 245.6
# Episode 1300  return=  356  avg(last 20)= 279.3
# Episode 1320  return=  372  avg(last 20)= 287.1
# Episode 1340  return=  263  avg(last 20)= 280.3
# Episode 1360  return=  328  avg(last 20)= 316.4
# Episode 1380  return=  399  avg(last 20)= 286.9
# Episode 1400  return=   98  avg(last 20)= 316.7
# Episode 1420  return=  323  avg(last 20)= 292.7
# Episode 1440  return=   94  avg(last 20)= 272.1
# Episode 1460  return=  206  avg(last 20)= 285.0
# Episode 1480  return=  392  avg(last 20)= 287.8
# Episode 1500  return=  173  avg(last 20)= 268.4
# Episode 1520  return=  291  avg(last 20)= 268.4
# Episode 1540  return=  292  avg(last 20)= 291.8
# Episode 1560  return=  328  avg(last 20)= 300.1
# Episode 1580  return=  339  avg(last 20)= 229.0
# Episode 1600  return=  194  avg(last 20)= 275.9
# Episode 1620  return=  291  avg(last 20)= 268.1
# Episode 1640  return=   51  avg(last 20)= 262.0
# Episode 1660  return=  238  avg(last 20)= 272.1
# Episode 1680  return=  224  avg(last 20)= 248.2
# Episode 1700  return=  383  avg(last 20)= 287.5
# Episode 1720  return=  382  avg(last 20)= 266.5
# Episode 1740  return=   37  avg(last 20)= 305.8
# Episode 1760  return=  393  avg(last 20)= 319.8
# Episode 1780  return=  335  avg(last 20)= 317.7
# Episode 1800  return=  400  avg(last 20)= 303.2
# Episode 1820  return=  299  avg(last 20)= 317.9
# Episode 1840  return=  324  avg(last 20)= 301.3
# Episode 1860  return=  311  avg(last 20)= 314.2
# Episode 1880  return=  331  avg(last 20)= 337.6
# Episode 1900  return=  326  avg(last 20)= 294.6
# Episode 1920  return=  139  avg(last 20)= 283.5
# Episode 1940  return=  259  avg(last 20)= 296.1
# Episode 1960  return=  353  avg(last 20)= 272.5
# Episode 1980  return=  227  avg(last 20)= 312.8
# Episode 2000  return=  291  avg(last 20)= 289.5
# Episode 2020  return=  345  avg(last 20)= 311.5
# Episode 2040  return=  301  avg(last 20)= 297.1
# Episode 2060  return=  295  avg(last 20)= 302.2
# Episode 2080  return=  317  avg(last 20)= 238.6
# Episode 2100  return=  327  avg(last 20)= 310.9
# Episode 2120  return=  287  avg(last 20)= 281.6
# Episode 2140  return=  268  avg(last 20)= 295.6
# Episode 2160  return=  345  avg(last 20)= 268.6
# Episode 2180  return=  326  avg(last 20)= 301.7
# Episode 2200  return=  275  avg(last 20)= 306.2
# Episode 2220  return=  344  avg(last 20)= 316.2
# Episode 2240  return=  273  avg(last 20)= 304.1
# Episode 2260  return=  300  avg(last 20)= 297.6
# Episode 2280  return=  393  avg(last 20)= 305.4
# Episode 2300  return=  372  avg(last 20)= 308.8
# Episode 2320  return=  361  avg(last 20)= 324.9
# Episode 2340  return=  288  avg(last 20)= 282.4
# Episode 2360  return=  319  avg(last 20)= 305.8
# Episode 2380  return=  306  avg(last 20)= 308.4
# Episode 2400  return=  378  avg(last 20)= 321.7
# Episode 2420  return=  310  avg(last 20)= 328.6
# Episode 2440  return=  308  avg(last 20)= 300.4
# Episode 2460  return=  298  avg(last 20)= 300.2
# Episode 2480  return=  303  avg(last 20)= 305.4
# Episode 2500  return=  317  avg(last 20)= 302.7
# Episode 2520  return=  361  avg(last 20)= 290.2
# Episode 2540  return=  368  avg(last 20)= 282.6
# Episode 2560  return=  228  avg(last 20)= 271.7
# Episode 2580  return=  308  avg(last 20)= 279.6
# Episode 2600  return=  236  avg(last 20)= 277.2
# Episode 2620  return=  276  avg(last 20)= 274.4
# Episode 2640  return=  232  avg(last 20)= 272.9
# Episode 2660  return=  304  avg(last 20)= 276.5
# Episode 2680  return=  287  avg(last 20)= 268.7
# Episode 2700  return=  311  avg(last 20)= 276.2
# Episode 2720  return=  317  avg(last 20)= 284.9
# Episode 2740  return=  292  avg(last 20)= 294.3
# Episode 2760  return=  297  avg(last 20)= 320.6
# Episode 2780  return=  314  avg(last 20)= 288.1
# Episode 2800  return=  274  avg(last 20)= 294.3
# Episode 2820  return=  288  avg(last 20)= 287.9
# Episode 2840  return=  262  avg(last 20)= 279.3
# Episode 2860  return=  253  avg(last 20)= 280.8
# Episode 2880  return=  246  avg(last 20)= 251.8
# Episode 2900  return=  283  avg(last 20)= 255.2
# Episode 2920  return=  133  avg(last 20)= 243.1
# Episode 2940  return=  238  avg(last 20)= 251.7
# Episode 2960  return=  278  avg(last 20)= 247.6
# Episode 2980  return=  295  avg(last 20)= 255.5
# Saved model_ac_trial_1.pt and history_ac_trial_1.pkl and time_ac_trial_1.pkl
#
# Running: ac_trial_2
# {'run_name': 'ac_trial_2', 'actor_lr': 0.0001155428052138559, 'critic_lr': 0.00013226991968313137, 'entropy_weight': 0.0001, 'critic_weight': 0.25, 'hidden': 128, 'gamma': 0.995, 'grad_clip': 0.5, 'normalize_advantage': True}
# State space: Box(-inf, inf, (11,), float64)
# Action space: Box(-1.0, 1.0, (3,), float32)
# Episode    0  return=   43  avg(last 20)=  43.5
# Episode   20  return=   26  avg(last 20)=  30.3
# Episode   40  return=   16  avg(last 20)=  29.4
# Episode   60  return=    9  avg(last 20)=  20.6
# Episode   80  return=    8  avg(last 20)=  11.5
# Episode  100  return=    9  avg(last 20)=  10.0
# Episode  120  return=   22  avg(last 20)=   9.2
# Episode  140  return=   10  avg(last 20)=   8.6
# Episode  160  return=    8  avg(last 20)=   7.4
# Episode  180  return=    7  avg(last 20)=   6.8
# Episode  200  return=   12  avg(last 20)=   7.7
# Episode  220  return=    6  avg(last 20)=   7.0
# Episode  240  return=    6  avg(last 20)=   7.8
# Episode  260  return=    7  avg(last 20)=   7.9
# Episode  280  return=    8  avg(last 20)=   8.4
# Episode  300  return=   10  avg(last 20)=   8.2
# Episode  320  return=    9  avg(last 20)=  10.5
# Episode  340  return=   15  avg(last 20)=  13.0
# Episode  360  return=   40  avg(last 20)=  26.2
# Episode  380  return=   37  avg(last 20)=  52.5
# Episode  400  return=   34  avg(last 20)=  50.9
# Episode  420  return=   41  avg(last 20)=  38.4
# Episode  440  return=   25  avg(last 20)=  36.3
# Episode  460  return=   35  avg(last 20)=  29.7
# Episode  480  return=   12  avg(last 20)=  25.2
# Episode  500  return=   32  avg(last 20)=  27.8
# Episode  520  return=   43  avg(last 20)=  28.7
# Episode  540  return=   37  avg(last 20)=  39.2
# Episode  560  return=   37  avg(last 20)=  40.7
# Episode  580  return=   29  avg(last 20)=  39.5
# Episode  600  return=   35  avg(last 20)=  36.5
# Episode  620  return=   47  avg(last 20)=  49.3
# Episode  640  return=   39  avg(last 20)=  46.5
# Episode  660  return=   35  avg(last 20)=  46.9
# Episode  680  return=   54  avg(last 20)=  64.8
# Episode  700  return=   64  avg(last 20)=  91.0
# Episode  720  return=  170  avg(last 20)= 146.8
# Episode  740  return=  154  avg(last 20)= 138.7
# Episode  760  return=  174  avg(last 20)= 150.5
# Episode  780  return=  174  avg(last 20)= 135.2
# Episode  800  return=  171  avg(last 20)= 159.9
# Episode  820  return=  176  avg(last 20)= 144.8
# Episode  840  return=  168  avg(last 20)= 145.9
# Episode  860  return=  171  avg(last 20)= 148.0
# Episode  880  return=  168  avg(last 20)= 140.9
# Episode  900  return=  171  avg(last 20)= 163.6
# Episode  920  return=  166  avg(last 20)= 149.4
# Episode  940  return=  171  avg(last 20)= 151.6
# Episode  960  return=  177  avg(last 20)= 161.0
# Episode  980  return=  170  avg(last 20)= 157.0
# Episode 1000  return=  170  avg(last 20)= 171.4
# Episode 1020  return=  176  avg(last 20)= 163.3
# Episode 1040  return=   73  avg(last 20)= 159.6
# Episode 1060  return=  110  avg(last 20)= 164.7
# Episode 1080  return=  176  avg(last 20)= 171.3
# Episode 1100  return=  137  avg(last 20)= 161.2
# Episode 1120  return=  145  avg(last 20)= 161.5
# Episode 1140  return=  175  avg(last 20)= 159.1
# Episode 1160  return=  149  avg(last 20)= 162.1
# Episode 1180  return=  177  avg(last 20)= 161.9
# Episode 1200  return=  172  avg(last 20)= 167.0
# Episode 1220  return=  176  avg(last 20)= 169.8
# Episode 1240  return=  178  avg(last 20)= 165.3
# Episode 1260  return=  172  avg(last 20)= 174.4
# Episode 1280  return=  164  avg(last 20)= 167.0
# Episode 1300  return=  170  avg(last 20)= 156.7
# Episode 1320  return=  177  avg(last 20)= 167.2
# Episode 1340  return=  168  avg(last 20)= 171.7
# Episode 1360  return=  178  avg(last 20)= 172.9
# Episode 1380  return=  175  avg(last 20)= 172.1
# Episode 1400  return=  177  avg(last 20)= 173.6
# Episode 1420  return=  172  avg(last 20)= 159.0
# Episode 1440  return=  174  avg(last 20)= 170.4
# Episode 1460  return=  169  avg(last 20)= 171.8
# Episode 1480  return=  169  avg(last 20)= 166.8
# Episode 1500  return=  176  avg(last 20)= 167.1
# Episode 1520  return=  147  avg(last 20)= 165.1
# Episode 1540  return=  135  avg(last 20)= 153.3
# Episode 1560  return=  161  avg(last 20)= 148.5
# Episode 1580  return=  153  avg(last 20)= 150.2
# Episode 1600  return=  173  avg(last 20)= 174.3
# Episode 1620  return=  158  avg(last 20)= 173.2
# Episode 1640  return=  136  avg(last 20)= 158.5
# Episode 1660  return=  148  avg(last 20)= 155.8
# Episode 1680  return=  153  avg(last 20)= 151.4
# Episode 1700  return=  144  avg(last 20)= 144.8
# Episode 1720  return=  161  avg(last 20)= 149.9
# Episode 1740  return=  175  avg(last 20)= 168.6
# Episode 1760  return=  153  avg(last 20)= 165.2
# Episode 1780  return=  165  avg(last 20)= 167.7
# Episode 1800  return=  170  avg(last 20)= 150.4
# Episode 1820  return=  136  avg(last 20)= 149.6
# Episode 1840  return=  155  avg(last 20)= 147.4
# Episode 1860  return=  142  avg(last 20)= 164.6
# Episode 1880  return=  168  avg(last 20)= 151.4
# Episode 1900  return=  171  avg(last 20)= 166.0
# Episode 1920  return=  175  avg(last 20)= 172.2
# Episode 1940  return=  170  avg(last 20)= 168.1
# Episode 1960  return=  168  avg(last 20)= 164.6
# Episode 1980  return=  158  avg(last 20)= 160.3
# Episode 2000  return=  170  avg(last 20)= 163.6
# Episode 2020  return=  167  avg(last 20)= 157.5
# Episode 2040  return=  166  avg(last 20)= 168.5
# Episode 2060  return=  171  avg(last 20)= 159.2
# Episode 2080  return=  171  avg(last 20)= 170.4
# Episode 2100  return=  173  avg(last 20)= 171.2
# Episode 2120  return=  172  avg(last 20)= 171.7
# Episode 2140  return=  175  avg(last 20)= 173.6
# Episode 2160  return=  173  avg(last 20)= 173.5
# Episode 2180  return=  170  avg(last 20)= 170.4
# Episode 2200  return=  173  avg(last 20)= 170.7
# Episode 2220  return=  173  avg(last 20)= 173.7
# Episode 2240  return=  178  avg(last 20)= 173.6
# Episode 2260  return=  174  avg(last 20)= 168.7
# Episode 2280  return=  176  avg(last 20)= 165.3
# Episode 2300  return=  171  avg(last 20)= 159.9
# Episode 2320  return=  172  avg(last 20)= 167.7
# Episode 2340  return=  174  avg(last 20)= 170.0
# Episode 2360  return=  169  avg(last 20)= 165.7
# Episode 2380  return=  177  avg(last 20)= 176.3
# Episode 2400  return=  174  avg(last 20)= 159.9
# Episode 2420  return=  170  avg(last 20)= 171.0
# Episode 2440  return=  169  avg(last 20)= 171.3
# Episode 2460  return=  172  avg(last 20)= 172.2
# Episode 2480  return=  172  avg(last 20)= 171.3
# Episode 2500  return=  173  avg(last 20)= 171.6
# Episode 2520  return=  174  avg(last 20)= 173.4
# Episode 2540  return=  174  avg(last 20)= 168.8
# Episode 2560  return=  174  avg(last 20)= 168.3
# Episode 2580  return=  112  avg(last 20)= 157.6
# Episode 2600  return=  116  avg(last 20)= 134.7
# Episode 2620  return=  176  avg(last 20)= 161.9
# Episode 2640  return=  113  avg(last 20)= 164.3
# Episode 2660  return=  174  avg(last 20)= 170.0
# Episode 2680  return=  166  avg(last 20)= 166.9
# Episode 2700  return=  133  avg(last 20)= 153.2
# Episode 2720  return=  128  avg(last 20)= 147.7
# Episode 2740  return=  121  avg(last 20)= 162.0
# Episode 2760  return=  165  avg(last 20)= 164.7
# Episode 2780  return=  165  avg(last 20)= 167.3
# Episode 2800  return=  172  avg(last 20)= 169.4
# Episode 2820  return=  155  avg(last 20)= 164.6
# Episode 2840  return=  164  avg(last 20)= 148.2
# Episode 2860  return=  164  avg(last 20)= 161.8
# Episode 2880  return=  169  avg(last 20)= 162.0
# Episode 2900  return=  171  avg(last 20)= 164.9
# Episode 2920  return=  169  avg(last 20)= 165.9
# Episode 2940  return=  164  avg(last 20)= 164.0
# Episode 2960  return=  168  avg(last 20)= 165.3
# Episode 2980  return=  174  avg(last 20)= 167.3
# Saved model_ac_trial_2.pt and history_ac_trial_2.pkl and time_ac_trial_2.pkl
#
# Running: ac_trial_3
# {'run_name': 'ac_trial_3', 'actor_lr': 0.00028100085627406896, 'critic_lr': 0.0003311569757103039, 'entropy_weight': 0.0, 'critic_weight': 0.5, 'hidden': 64, 'gamma': 0.995, 'grad_clip': 0.5, 'normalize_advantage': True}
# State space: Box(-inf, inf, (11,), float64)
# Action space: Box(-1.0, 1.0, (3,), float32)
# Episode    0  return=   10  avg(last 20)=   9.7
# Episode   20  return=   11  avg(last 20)=   8.6
# Episode   40  return=    2  avg(last 20)=   6.7
# Episode   60  return=    6  avg(last 20)=   6.0
# Episode   80  return=    7  avg(last 20)=   5.5
# Episode  100  return=    5  avg(last 20)=   5.2
# Episode  120  return=    6  avg(last 20)=   5.1
# Episode  140  return=    5  avg(last 20)=   5.0
# Episode  160  return=    3  avg(last 20)=   5.3
# Episode  180  return=    5  avg(last 20)=   5.5
# Episode  200  return=   10  avg(last 20)=   9.1
# Episode  220  return=   33  avg(last 20)=  20.7
# Episode  240  return=    9  avg(last 20)=  14.4
# Episode  260  return=   13  avg(last 20)=  13.8
# Episode  280  return=   15  avg(last 20)=  11.5
# Episode  300  return=   15  avg(last 20)=  12.3
# Episode  320  return=   18  avg(last 20)=  14.3
# Episode  340  return=   21  avg(last 20)=  16.6
# Episode  360  return=   16  avg(last 20)=  17.6
# Episode  380  return=   34  avg(last 20)=  24.9
# Episode  400  return=   12  avg(last 20)=  21.4
# Episode  420  return=   17  avg(last 20)=  25.5
# Episode  440  return=   27  avg(last 20)=  21.7
# Episode  460  return=   38  avg(last 20)=  23.1
# Episode  480  return=   38  avg(last 20)=  21.7
# Episode  500  return=   11  avg(last 20)=  30.2
# Episode  520  return=    9  avg(last 20)=  19.3
# Episode  540  return=   13  avg(last 20)=  14.9
# Episode  560  return=   11  avg(last 20)=  16.8
# Episode  580  return=    9  avg(last 20)=  16.5
# Episode  600  return=   19  avg(last 20)=  18.2
# Episode  620  return=   85  avg(last 20)=  24.0
# Episode  640  return=  283  avg(last 20)= 110.3
# Episode  660  return=  149  avg(last 20)= 183.9
# Episode  680  return=  280  avg(last 20)= 195.2
# Episode  700  return=  173  avg(last 20)= 180.3
# Episode  720  return=  187  avg(last 20)= 175.5
# Episode  740  return=  217  avg(last 20)= 173.0
# Episode  760  return=  171  avg(last 20)= 172.9
# Episode  780  return=  218  avg(last 20)= 210.6
# Episode  800  return=  211  avg(last 20)= 217.7
# Episode  820  return=  240  avg(last 20)= 222.1
# Episode  840  return=  228  avg(last 20)= 235.1
# Episode  860  return=  240  avg(last 20)= 233.3
# Episode  880  return=  238  avg(last 20)= 232.1
# Episode  900  return=  244  avg(last 20)= 239.5
# Episode  920  return=  266  avg(last 20)= 241.8
# Episode  940  return=  237  avg(last 20)= 242.3
# Episode  960  return=  215  avg(last 20)= 233.9
# Episode  980  return=  235  avg(last 20)= 236.4
# Episode 1000  return=  229  avg(last 20)= 229.0
# Episode 1020  return=  250  avg(last 20)= 234.9
# Episode 1040  return=  246  avg(last 20)= 229.7
# Episode 1060  return=  238  avg(last 20)= 233.3
# Episode 1080  return=  245  avg(last 20)= 235.9
# Episode 1100  return=  218  avg(last 20)= 228.6
# Episode 1120  return=  213  avg(last 20)= 225.1
# Episode 1140  return=  235  avg(last 20)= 226.0
# Episode 1160  return=  209  avg(last 20)= 223.3
# Episode 1180  return=  213  avg(last 20)= 226.3
# Episode 1200  return=  223  avg(last 20)= 228.3
# Episode 1220  return=  260  avg(last 20)= 226.9
# Episode 1240  return=  248  avg(last 20)= 230.3
# Episode 1260  return=  268  avg(last 20)= 231.9
# Episode 1280  return=  238  avg(last 20)= 229.8
# Episode 1300  return=  219  avg(last 20)= 232.4
# Episode 1320  return=  272  avg(last 20)= 242.5
# Episode 1340  return=  247  avg(last 20)= 244.1
# Episode 1360  return=  230  avg(last 20)= 245.1
# Episode 1380  return=  230  avg(last 20)= 245.9
# Episode 1400  return=  244  avg(last 20)= 236.5
# Episode 1420  return=  213  avg(last 20)= 234.7
# Episode 1440  return=  221  avg(last 20)= 232.0
# Episode 1460  return=  243  avg(last 20)= 230.0
# Episode 1480  return=  225  avg(last 20)= 230.3
# Episode 1500  return=  222  avg(last 20)= 230.0
# Episode 1520  return=  232  avg(last 20)= 237.6
# Episode 1540  return=  248  avg(last 20)= 239.8
# Episode 1560  return=  219  avg(last 20)= 241.4
# Episode 1580  return=  224  avg(last 20)= 232.2
# Episode 1600  return=  228  avg(last 20)= 233.2
# Episode 1620  return=  277  avg(last 20)= 252.0
# Episode 1640  return=  247  avg(last 20)= 253.3
# Episode 1660  return=  259  avg(last 20)= 259.4
# Episode 1680  return=  258  avg(last 20)= 267.1
# Episode 1700  return=  240  avg(last 20)= 257.0
# Episode 1720  return=  271  avg(last 20)= 258.7
# Episode 1740  return=  272  avg(last 20)= 259.6
# Episode 1760  return=  250  avg(last 20)= 263.2
# Episode 1780  return=  274  avg(last 20)= 290.8
# Episode 1800  return=  277  avg(last 20)= 299.6
# Episode 1820  return=  275  avg(last 20)= 275.2
# Episode 1840  return=  293  avg(last 20)= 280.1
# Episode 1860  return=  259  avg(last 20)= 275.5
# Episode 1880  return=  240  avg(last 20)= 265.2
# Episode 1900  return=  278  avg(last 20)= 267.6
# Episode 1920  return=  306  avg(last 20)= 282.5
# Episode 1940  return=  294  avg(last 20)= 294.3
# Episode 1960  return=  314  avg(last 20)= 294.9
# Episode 1980  return=  310  avg(last 20)= 293.1
# Episode 2000  return=  265  avg(last 20)= 278.1
# Episode 2020  return=  264  avg(last 20)= 264.4
# Episode 2040  return=  260  avg(last 20)= 289.9
# Episode 2060  return=  359  avg(last 20)= 315.4
# Episode 2080  return=  309  avg(last 20)= 310.8
# Episode 2100  return=  326  avg(last 20)= 316.7
# Episode 2120  return=  311  avg(last 20)= 332.5
# Episode 2140  return=  227  avg(last 20)= 292.7
# Episode 2160  return=  274  avg(last 20)= 286.9
# Episode 2180  return=  242  avg(last 20)= 284.4
# Episode 2200  return=  285  avg(last 20)= 274.7
# Episode 2220  return=  258  avg(last 20)= 268.4
# Episode 2240  return=  272  avg(last 20)= 264.2
# Episode 2260  return=  249  avg(last 20)= 258.5
# Episode 2280  return=  258  avg(last 20)= 253.8
# Episode 2300  return=  262  avg(last 20)= 263.6
# Episode 2320  return=  248  avg(last 20)= 260.0
# Episode 2340  return=  262  avg(last 20)= 245.9
# Episode 2360  return=  230  avg(last 20)= 240.2
# Episode 2380  return=  224  avg(last 20)= 237.0
# Episode 2400  return=  226  avg(last 20)= 228.4
# Episode 2420  return=  254  avg(last 20)= 226.3
# Episode 2440  return=  231  avg(last 20)= 230.6
# Episode 2460  return=  223  avg(last 20)= 232.0
# Episode 2480  return=  234  avg(last 20)= 224.4
# Episode 2500  return=  218  avg(last 20)= 229.9
# Episode 2520  return=  226  avg(last 20)= 224.6
# Episode 2540  return=  218  avg(last 20)= 213.7
# Episode 2560  return=  222  avg(last 20)= 217.7
# Episode 2580  return=  213  avg(last 20)= 220.6
# Episode 2600  return=  215  avg(last 20)= 213.1
# Episode 2620  return=  214  avg(last 20)= 212.1
# Episode 2640  return=  208  avg(last 20)= 211.7
# Episode 2660  return=  208  avg(last 20)= 209.6
# Episode 2680  return=  208  avg(last 20)= 209.7
# Episode 2700  return=  210  avg(last 20)= 210.0
# Episode 2720  return=  207  avg(last 20)= 209.5
# Episode 2740  return=  209  avg(last 20)= 210.3
# Episode 2760  return=  209  avg(last 20)= 211.7
# Episode 2780  return=  209  avg(last 20)= 211.5
# Episode 2800  return=  212  avg(last 20)= 211.8
# Episode 2820  return=  211  avg(last 20)= 212.4
# Episode 2840  return=  207  avg(last 20)= 212.7
# Episode 2860  return=  214  avg(last 20)= 201.5
# Episode 2880  return=  215  avg(last 20)= 207.6
# Episode 2900  return=  222  avg(last 20)= 217.9
# Episode 2920  return=  227  avg(last 20)= 223.9
# Episode 2940  return=  221  avg(last 20)= 227.0
# Episode 2960  return=  258  avg(last 20)= 233.1
# Episode 2980  return=  223  avg(last 20)= 232.3
# Saved model_ac_trial_3.pt and history_ac_trial_3.pkl and time_ac_trial_3.pkl
#
# Running: ac_trial_4
# {'run_name': 'ac_trial_4', 'actor_lr': 5.133277397424096e-05, 'critic_lr': 0.00011865025852458269, 'entropy_weight': 0.001, 'critic_weight': 1.0, 'hidden': 128, 'gamma': 0.99, 'grad_clip': 0.5, 'normalize_advantage': True}
# State space: Box(-inf, inf, (11,), float64)
# Action space: Box(-1.0, 1.0, (3,), float32)
# Episode    0  return=   43  avg(last 20)=  43.5
# Episode   20  return=    8  avg(last 20)=  20.5
# Episode   40  return=   17  avg(last 20)=  23.4
# Episode   60  return=   18  avg(last 20)=  27.4
# Episode   80  return=   11  avg(last 20)=  20.8
# Episode  100  return=    9  avg(last 20)=  15.9
# Episode  120  return=    7  avg(last 20)=  16.3
# Episode  140  return=   11  avg(last 20)=  13.9
# Episode  160  return=   15  avg(last 20)=  12.9
# Episode  180  return=   11  avg(last 20)=  13.7
# Episode  200  return=   14  avg(last 20)=  13.4
# Episode  220  return=   14  avg(last 20)=  12.1
# Episode  240  return=    9  avg(last 20)=  12.2
# Episode  260  return=   10  avg(last 20)=   9.4
# Episode  280  return=   12  avg(last 20)=   8.6
# Episode  300  return=   10  avg(last 20)=   9.2
# Episode  320  return=   12  avg(last 20)=  11.8
# Episode  340  return=   18  avg(last 20)=  16.5
# Episode  360  return=   26  avg(last 20)=  18.0
# Episode  380  return=    6  avg(last 20)=  26.1
# Episode  400  return=   14  avg(last 20)=  24.0
# Episode  420  return=   41  avg(last 20)=  36.3
# Episode  440  return=   68  avg(last 20)=  28.9
# Episode  460  return=   13  avg(last 20)=  37.6
# Episode  480  return=   49  avg(last 20)=  35.9
# Episode  500  return=   29  avg(last 20)=  46.2
# Episode  520  return=   49  avg(last 20)=  49.1
# Episode  540  return=   27  avg(last 20)=  45.6
# Episode  560  return=   61  avg(last 20)=  42.5
# Episode  580  return=   51  avg(last 20)=  49.6
# Episode  600  return=   54  avg(last 20)=  45.8
# Episode  620  return=   58  avg(last 20)=  48.8
# Episode  640  return=   51  avg(last 20)=  51.9
# Episode  660  return=   35  avg(last 20)=  50.2
# Episode  680  return=   58  avg(last 20)=  50.4
# Episode  700  return=   42  avg(last 20)=  50.4
# Episode  720  return=   66  avg(last 20)=  57.9
# Episode  740  return=   12  avg(last 20)=  58.9
# Episode  760  return=   21  avg(last 20)=  52.8
# Episode  780  return=   74  avg(last 20)=  63.7
# Episode  800  return=   61  avg(last 20)=  60.4
# Episode  820  return=   36  avg(last 20)=  48.9
# Episode  840  return=   31  avg(last 20)=  42.7
# Episode  860  return=   66  avg(last 20)=  64.3
# Episode  880  return=   69  avg(last 20)=  78.0
# Episode  900  return=   36  avg(last 20)=  68.8
# Episode  920  return=   63  avg(last 20)=  91.0
# Episode  940  return=   78  avg(last 20)=  93.6
# Episode  960  return=  103  avg(last 20)= 102.3
# Episode  980  return=  152  avg(last 20)= 123.0
# Episode 1000  return=   75  avg(last 20)=  88.5
# Episode 1020  return=  175  avg(last 20)= 112.7
# Episode 1040  return=   45  avg(last 20)= 149.5
# Episode 1060  return=  129  avg(last 20)= 127.1
# Episode 1080  return=  175  avg(last 20)= 130.8
# Episode 1100  return=  180  avg(last 20)= 142.3
# Episode 1120  return=  124  avg(last 20)= 133.7
# Episode 1140  return=   22  avg(last 20)= 121.6
# Episode 1160  return=  106  avg(last 20)= 130.8
# Episode 1180  return=  143  avg(last 20)= 124.8
# Episode 1200  return=  172  avg(last 20)= 116.0
# Episode 1220  return=  183  avg(last 20)= 123.4
# Episode 1240  return=   62  avg(last 20)= 111.7
# Episode 1260  return=   32  avg(last 20)= 131.0
# Episode 1280  return=  161  avg(last 20)= 123.1
# Episode 1300  return=  174  avg(last 20)= 138.8
# Episode 1320  return=  145  avg(last 20)= 131.5
# Episode 1340  return=  140  avg(last 20)= 135.9
# Episode 1360  return=  176  avg(last 20)= 140.8
# Episode 1380  return=  177  avg(last 20)= 139.3
# Episode 1400  return=  146  avg(last 20)= 143.8
# Episode 1420  return=  146  avg(last 20)= 117.7
# Episode 1440  return=  172  avg(last 20)= 131.6
# Episode 1460  return=  166  avg(last 20)= 137.7
# Episode 1480  return=  115  avg(last 20)= 120.8
# Episode 1500  return=   98  avg(last 20)= 120.1
# Episode 1520  return=  114  avg(last 20)=  94.2
# Episode 1540  return=  143  avg(last 20)= 103.2
# Episode 1560  return=  110  avg(last 20)= 132.5
# Episode 1580  return=  157  avg(last 20)= 137.7
# Episode 1600  return=  127  avg(last 20)= 141.8
# Episode 1620  return=  180  avg(last 20)= 127.2
# Episode 1640  return=  143  avg(last 20)= 151.8
# Episode 1660  return=  172  avg(last 20)= 134.4
# Episode 1680  return=  178  avg(last 20)= 132.1
# Episode 1700  return=  178  avg(last 20)= 153.2
# Episode 1720  return=  147  avg(last 20)= 142.0
# Episode 1740  return=  177  avg(last 20)= 146.1
# Episode 1760  return=   99  avg(last 20)= 130.0
# Episode 1780  return=  106  avg(last 20)= 137.5
# Episode 1800  return=  179  avg(last 20)= 158.8
# Episode 1820  return=  145  avg(last 20)= 146.9
# Episode 1840  return=  157  avg(last 20)= 143.9
# Episode 1860  return=  122  avg(last 20)= 141.7
# Episode 1880  return=  170  avg(last 20)= 140.0
# Episode 1900  return=  179  avg(last 20)= 141.4
# Episode 1920  return=  138  avg(last 20)= 127.9
# Episode 1940  return=  177  avg(last 20)= 135.9
# Episode 1960  return=  149  avg(last 20)= 139.3
# Episode 1980  return=  176  avg(last 20)= 159.5
# Episode 2000  return=  182  avg(last 20)= 169.7
# Episode 2020  return=   22  avg(last 20)= 152.5
# Episode 2040  return=  158  avg(last 20)= 165.7
# Episode 2060  return=  175  avg(last 20)= 158.9
# Episode 2080  return=  180  avg(last 20)= 153.3
# Episode 2100  return=  160  avg(last 20)= 150.0
# Episode 2120  return=  177  avg(last 20)= 160.2
# Episode 2140  return=  178  avg(last 20)= 146.6
# Episode 2160  return=  178  avg(last 20)= 153.3
# Episode 2180  return=   26  avg(last 20)= 135.2
# Episode 2200  return=  181  avg(last 20)= 159.6
# Episode 2220  return=  173  avg(last 20)= 165.4
# Episode 2240  return=  179  avg(last 20)= 157.7
# Episode 2260  return=  149  avg(last 20)= 143.8
# Episode 2280  return=  181  avg(last 20)= 145.6
# Episode 2300  return=  175  avg(last 20)= 158.4
# Episode 2320  return=  174  avg(last 20)= 136.7
# Episode 2340  return=  160  avg(last 20)= 147.8
# Episode 2360  return=  169  avg(last 20)= 164.3
# Episode 2380  return=  150  avg(last 20)= 169.5
# Episode 2400  return=  149  avg(last 20)= 157.6
# Episode 2420  return=  162  avg(last 20)= 154.8
# Episode 2440  return=  173  avg(last 20)= 140.7
# Episode 2460  return=  176  avg(last 20)= 150.2
# Episode 2480  return=  105  avg(last 20)= 149.4
# Episode 2500  return=   52  avg(last 20)=  89.9
# Episode 2520  return=   30  avg(last 20)=  77.2
# Episode 2540  return=  180  avg(last 20)=  98.6
# Episode 2560  return=  181  avg(last 20)= 155.9
# Episode 2580  return=  177  avg(last 20)= 157.4
# Episode 2600  return=  162  avg(last 20)= 140.4
# Episode 2620  return=  181  avg(last 20)= 159.1
# Episode 2640  return=  152  avg(last 20)= 152.5
# Episode 2660  return=  180  avg(last 20)= 162.0
# Episode 2680  return=  178  avg(last 20)= 149.6
# Episode 2700  return=  173  avg(last 20)= 164.9
# Episode 2720  return=  179  avg(last 20)= 161.7
# Episode 2740  return=  113  avg(last 20)= 153.6
# Episode 2760  return=  139  avg(last 20)= 139.1
# Episode 2780  return=  103  avg(last 20)= 145.6
# Episode 2800  return=  176  avg(last 20)= 137.2
# Episode 2820  return=  174  avg(last 20)= 154.0
# Episode 2840  return=  176  avg(last 20)= 159.2
# Episode 2860  return=  177  avg(last 20)= 171.6
# Episode 2880  return=  174  avg(last 20)= 170.6
# Episode 2900  return=  175  avg(last 20)= 167.1
# Episode 2920  return=  174  avg(last 20)= 176.1
# Episode 2940  return=  175  avg(last 20)= 168.4
# Episode 2960  return=  161  avg(last 20)= 165.3
# Episode 2980  return=  180  avg(last 20)= 169.9
# Saved model_ac_trial_4.pt and history_ac_trial_4.pkl and time_ac_trial_4.pkl
#
# Running: ac_trial_5
# {'run_name': 'ac_trial_5', 'actor_lr': 3.2130356318619384e-05, 'critic_lr': 0.00038670123435426227, 'entropy_weight': 0.0001, 'critic_weight': 0.25, 'hidden': 64, 'gamma': 0.995, 'grad_clip': 1.0, 'normalize_advantage': False}
# State space: Box(-inf, inf, (11,), float64)
# Action space: Box(-1.0, 1.0, (3,), float32)
# Episode    0  return=   10  avg(last 20)=   9.7
# Episode   20  return=   40  avg(last 20)=  13.5
# Episode   40  return=   16  avg(last 20)=  10.5
# Episode   60  return=    7  avg(last 20)=   9.3
# Episode   80  return=   10  avg(last 20)=   6.7
# Episode  100  return=   10  avg(last 20)=   8.6
# Episode  120  return=    4  avg(last 20)=   8.2
# Episode  140  return=    9  avg(last 20)=   7.7
# Episode  160  return=    9  avg(last 20)=   8.8
# Episode  180  return=    7  avg(last 20)=   9.0
# Episode  200  return=    9  avg(last 20)=   9.2
# Episode  220  return=    8  avg(last 20)=  10.4
# Episode  240  return=    7  avg(last 20)=   9.7
# Episode  260  return=    7  avg(last 20)=  10.7
# Episode  280  return=   36  avg(last 20)=  21.0
# Episode  300  return=    7  avg(last 20)=  16.0
# Episode  320  return=   42  avg(last 20)=  28.6
# Episode  340  return=   23  avg(last 20)=  29.3
# Episode  360  return=   17  avg(last 20)=  45.7
# Episode  380  return=   59  avg(last 20)=  32.8
# Episode  400  return=   43  avg(last 20)=  31.2
# Episode  420  return=   52  avg(last 20)=  42.8
# Episode  440  return=  113  avg(last 20)=  43.0
# Episode  460  return=   55  avg(last 20)=  50.1
# Episode  480  return=   54  avg(last 20)=  62.9
# Episode  500  return=   33  avg(last 20)=  53.4
# Episode  520  return=   48  avg(last 20)=  65.4
# Episode  540  return=   58  avg(last 20)=  70.5
# Episode  560  return=   55  avg(last 20)=  71.3
# Episode  580  return=   13  avg(last 20)=  90.7
# Episode  600  return=  110  avg(last 20)=  98.1
# Episode  620  return=   62  avg(last 20)=  86.6
# Episode  640  return=   21  avg(last 20)=  73.7
# Episode  660  return=   20  avg(last 20)= 111.4
# Episode  680  return=  137  avg(last 20)= 129.3
# Episode  700  return=  190  avg(last 20)= 118.5
# Episode  720  return=  140  avg(last 20)= 116.6
# Episode  740  return=   58  avg(last 20)= 125.1
# Episode  760  return=  148  avg(last 20)= 124.4
# Episode  780  return=   82  avg(last 20)= 119.2
# Episode  800  return=  114  avg(last 20)= 126.6
# Episode  820  return=   41  avg(last 20)= 103.7
# Episode  840  return=  169  avg(last 20)= 118.4
# Episode  860  return=   98  avg(last 20)= 107.5
# Episode  880  return=   76  avg(last 20)= 105.8
# Episode  900  return=   67  avg(last 20)= 128.6
# Episode  920  return=   51  avg(last 20)= 118.4
# Episode  940  return=  193  avg(last 20)= 123.6
# Episode  960  return=  212  avg(last 20)= 119.1
# Episode  980  return=  190  avg(last 20)= 131.3
# Episode 1000  return=   41  avg(last 20)= 115.6
# Episode 1020  return=  140  avg(last 20)= 131.0
# Episode 1040  return=  175  avg(last 20)= 133.1
# Episode 1060  return=  168  avg(last 20)= 134.7
# Episode 1080  return=  141  avg(last 20)= 138.1
# Episode 1100  return=  136  avg(last 20)= 142.5
# Episode 1120  return=  126  avg(last 20)= 133.2
# Episode 1140  return=  146  avg(last 20)= 141.7
# Episode 1160  return=  105  avg(last 20)= 141.9
# Episode 1180  return=  133  avg(last 20)= 148.6
# Episode 1200  return=  136  avg(last 20)= 148.2
# Episode 1220  return=  182  avg(last 20)= 137.5
# Episode 1240  return=  165  avg(last 20)= 151.4
# Episode 1260  return=  202  avg(last 20)= 165.2
# Episode 1280  return=  188  avg(last 20)= 171.0
# Episode 1300  return=  191  avg(last 20)= 165.0
# Episode 1320  return=  170  avg(last 20)= 163.6
# Episode 1340  return=  188  avg(last 20)= 176.0
# Episode 1360  return=  201  avg(last 20)= 178.9
# Episode 1380  return=  179  avg(last 20)= 179.0
# Episode 1400  return=  194  avg(last 20)= 175.1
# Episode 1420  return=  192  avg(last 20)= 173.1
# Episode 1440  return=  182  avg(last 20)= 174.4
# Episode 1460  return=  189  avg(last 20)= 171.8
# Episode 1480  return=  188  avg(last 20)= 185.3
# Episode 1500  return=  194  avg(last 20)= 186.4
# Episode 1520  return=  190  avg(last 20)= 171.4
# Episode 1540  return=  194  avg(last 20)= 180.2
# Episode 1560  return=  121  avg(last 20)= 164.8
# Episode 1580  return=  191  avg(last 20)= 179.8
# Episode 1600  return=  184  avg(last 20)= 173.6
# Episode 1620  return=  201  avg(last 20)= 186.8
# Episode 1640  return=  187  avg(last 20)= 185.3
# Episode 1660  return=  169  avg(last 20)= 187.1
# Episode 1680  return=  204  avg(last 20)= 183.1
# Episode 1700  return=  194  avg(last 20)= 193.0
# Episode 1720  return=  180  avg(last 20)= 182.6
# Episode 1740  return=  211  avg(last 20)= 179.2
# Episode 1760  return=  163  avg(last 20)= 169.7
# Episode 1780  return=  207  avg(last 20)= 182.8
# Episode 1800  return=  192  avg(last 20)= 187.8
# Episode 1820  return=  187  avg(last 20)= 171.6
# Episode 1840  return=  193  avg(last 20)= 185.4
# Episode 1860  return=  201  avg(last 20)= 188.5
# Episode 1880  return=  200  avg(last 20)= 185.2
# Episode 1900  return=  201  avg(last 20)= 188.6
# Episode 1920  return=  199  avg(last 20)= 187.9
# Episode 1940  return=  174  avg(last 20)= 187.2
# Episode 1960  return=  191  avg(last 20)= 185.6
# Episode 1980  return=  197  avg(last 20)= 189.6
# Episode 2000  return=  186  avg(last 20)= 191.8
# Episode 2020  return=  197  avg(last 20)= 192.1
# Episode 2040  return=  197  avg(last 20)= 190.0
# Episode 2060  return=  194  avg(last 20)= 189.4
# Episode 2080  return=  182  avg(last 20)= 184.7
# Episode 2100  return=  190  avg(last 20)= 183.9
# Episode 2120  return=  190  avg(last 20)= 184.2
# Episode 2140  return=  171  avg(last 20)= 186.9
# Episode 2160  return=  197  avg(last 20)= 194.5
# Episode 2180  return=  203  avg(last 20)= 192.2
# Episode 2200  return=  210  avg(last 20)= 193.9
# Episode 2220  return=  186  avg(last 20)= 189.1
# Episode 2240  return=  194  avg(last 20)= 189.9
# Episode 2260  return=  197  avg(last 20)= 182.7
# Episode 2280  return=  181  avg(last 20)= 184.8
# Episode 2300  return=  188  avg(last 20)= 187.0
# Episode 2320  return=  184  avg(last 20)= 185.7
# Episode 2340  return=  186  avg(last 20)= 185.8
# Episode 2360  return=  185  avg(last 20)= 190.4
# Episode 2380  return=  193  avg(last 20)= 185.8
# Episode 2400  return=  171  avg(last 20)= 184.7
# Episode 2420  return=  199  avg(last 20)= 188.7
# Episode 2440  return=  185  avg(last 20)= 186.6
# Episode 2460  return=  165  avg(last 20)= 189.9
# Episode 2480  return=  169  avg(last 20)= 189.9
# Episode 2500  return=  187  avg(last 20)= 188.8
# Episode 2520  return=  177  avg(last 20)= 186.8
# Episode 2540  return=  189  avg(last 20)= 185.7
# Episode 2560  return=  201  avg(last 20)= 185.6
# Episode 2580  return=  182  avg(last 20)= 182.8
# Episode 2600  return=  188  avg(last 20)= 186.4
# Episode 2620  return=  198  avg(last 20)= 188.1
# Episode 2640  return=  170  avg(last 20)= 187.4
# Episode 2660  return=  193  avg(last 20)= 189.5
# Episode 2680  return=  181  avg(last 20)= 185.6
# Episode 2700  return=  185  avg(last 20)= 189.7
# Episode 2720  return=  187  avg(last 20)= 187.2
# Episode 2740  return=  192  avg(last 20)= 180.9
# Episode 2760  return=  182  avg(last 20)= 181.0
# Episode 2780  return=  189  avg(last 20)= 189.3
# Episode 2800  return=  186  avg(last 20)= 184.8
# Episode 2820  return=  155  avg(last 20)= 187.4
# Episode 2840  return=  191  avg(last 20)= 185.0
# Episode 2860  return=  172  avg(last 20)= 188.1
# Episode 2880  return=  171  avg(last 20)= 176.9
# Episode 2900  return=  180  avg(last 20)= 184.7
# Episode 2920  return=  192  avg(last 20)= 180.9
# Episode 2940  return=  185  avg(last 20)= 180.1
# Episode 2960  return=  182  avg(last 20)= 188.1
# Episode 2980  return=  182  avg(last 20)= 177.7
# Saved model_ac_trial_5.pt and history_ac_trial_5.pkl and time_ac_trial_5.pkl
#
# Running: ac_trial_6
# {'run_name': 'ac_trial_6', 'actor_lr': 4.4445150827671884e-05, 'critic_lr': 3.6983112195976435e-05, 'entropy_weight': 0.001, 'critic_weight': 0.5, 'hidden': 64, 'gamma': 0.995, 'grad_clip': 1.0, 'normalize_advantage': False}
# State space: Box(-inf, inf, (11,), float64)
# Action space: Box(-1.0, 1.0, (3,), float32)
# Episode    0  return=   10  avg(last 20)=   9.7
# Episode   20  return=   44  avg(last 20)=  13.7
# Episode   40  return=   16  avg(last 20)=   8.4
# Episode   60  return=    7  avg(last 20)=   9.5
# Episode   80  return=   11  avg(last 20)=   6.8
# Episode  100  return=    6  avg(last 20)=   7.0
# Episode  120  return=    6  avg(last 20)=   8.0
# Episode  140  return=    6  avg(last 20)=   6.6
# Episode  160  return=    9  avg(last 20)=   7.6
# Episode  180  return=   10  avg(last 20)=   9.4
# Episode  200  return=    8  avg(last 20)=   6.8
# Episode  220  return=    9  avg(last 20)=  10.5
# Episode  240  return=    5  avg(last 20)=   7.3
# Episode  260  return=    9  avg(last 20)=   7.9
# Episode  280  return=    7  avg(last 20)=   7.1
# Episode  300  return=    6  avg(last 20)=   6.4
# Episode  320  return=    5  avg(last 20)=   7.5
# Episode  340  return=    6  avg(last 20)=   7.6
# Episode  360  return=    8  avg(last 20)=   6.9
# Episode  380  return=    6  avg(last 20)=   6.6
# Episode  400  return=    6  avg(last 20)=   6.5
# Episode  420  return=   22  avg(last 20)=   7.4
# Episode  440  return=   17  avg(last 20)=   6.9
# Episode  460  return=   10  avg(last 20)=   6.9
# Episode  480  return=    6  avg(last 20)=   6.4
# Episode  500  return=    6  avg(last 20)=   6.7
# Episode  520  return=    6  avg(last 20)=   6.6
# Episode  540  return=    5  avg(last 20)=   6.1
# Episode  560  return=    6  avg(last 20)=   6.2
# Episode  580  return=    7  avg(last 20)=   6.2
# Episode  600  return=    8  avg(last 20)=   6.1
# Episode  620  return=    6  avg(last 20)=   5.9
# Episode  640  return=    5  avg(last 20)=   5.7
# Episode  660  return=    7  avg(last 20)=   5.7
# Episode  680  return=   10  avg(last 20)=   6.1
# Episode  700  return=    3  avg(last 20)=   5.7
# Episode  720  return=    5  avg(last 20)=   5.2
# Episode  740  return=    4  avg(last 20)=   5.2
# Episode  760  return=    6  avg(last 20)=   5.5
# Episode  780  return=    5  avg(last 20)=   5.4
# Episode  800  return=    6  avg(last 20)=   5.5
# ...
# Episode 2720  return=  214  avg(last 20)= 203.7
# Episode 2740  return=  178  avg(last 20)= 207.8
# Episode 2760  return=  221  avg(last 20)= 201.2
# Episode 2780  return=  210  avg(last 20)= 197.2
# Episode 2800  return=  191  avg(last 20)= 206.0
# Episode 2820  return=   82  avg(last 20)= 164.6
# Episode 2840  return=  209  avg(last 20)= 192.5
# Episode 2860  return=  207  avg(last 20)= 209.7
# Episode 2880  return=  205  avg(last 20)= 207.0
# Episode 2900  return=  204  avg(last 20)= 203.3
# Episode 2920  return=  216  avg(last 20)= 208.1
# Episode 2940  return=  203  avg(last 20)= 202.2
# Episode 2960  return=  197  avg(last 20)= 197.3
# Episode 2980  return=  205  avg(last 20)= 199.8
# Saved model_ac_trial_9.pt and history_ac_trial_9.pkl and time_ac_trial_9.pkl
#
# Running: ac_trial_10
# {'run_name': 'ac_trial_10', 'actor_lr': 8.651414894178233e-05, 'critic_lr': 0.000589797434988458, 'entropy_weight': 0.0001, 'critic_weight': 0.5, 'hidden': 128, 'gamma': 0.995, 'grad_clip': 0.5, 'normalize_advantage': False}
# State space: Box(-inf, inf, (11,), float64)
# Action space: Box(-1.0, 1.0, (3,), float32)
# Episode    0  return=   43  avg(last 20)=  43.5
# Episode   20  return=   17  avg(last 20)=  17.2
# Episode   40  return=   14  avg(last 20)=  15.1
# Episode   60  return=   16  avg(last 20)=  10.8
# Episode   80  return=   11  avg(last 20)=  11.4
# Episode  100  return=    8  avg(last 20)=  13.3
# Episode  120  return=  102  avg(last 20)=  26.8
# Episode  140  return=   37  avg(last 20)=  46.0
# Episode  160  return=  141  avg(last 20)=  99.8
# Episode  180  return=  185  avg(last 20)= 142.1
# Episode  200  return=  196  avg(last 20)= 121.7
# Episode  220  return=  191  avg(last 20)= 124.2
# Episode  240  return=  180  avg(last 20)= 137.7
# Episode  260  return=   88  avg(last 20)= 111.7
# Episode  280  return=   92  avg(last 20)= 113.2
# Episode  300  return=   83  avg(last 20)= 107.5
# Episode  320  return=   20  avg(last 20)= 116.7
# Episode  340  return=  174  avg(last 20)= 113.7
# Episode  360  return=   88  avg(last 20)= 121.6
# Episode  380  return=  188  avg(last 20)= 141.3
# Episode  400  return=   49  avg(last 20)= 122.2
# Episode  420  return=   77  avg(last 20)= 130.4
# Episode  440  return=  190  avg(last 20)= 129.9
# Episode  460  return=   85  avg(last 20)= 111.8
# Episode  480  return=  185  avg(last 20)= 116.3
# Episode  500  return=   59  avg(last 20)= 154.5
# Episode  520  return=  146  avg(last 20)= 167.1
# Episode  540  return=  177  avg(last 20)= 147.1
# Episode  560  return=  193  avg(last 20)= 138.9
# Episode  580  return=  187  avg(last 20)= 162.9
# Episode  600  return=  180  avg(last 20)= 146.3
# Episode  620  return=  188  avg(last 20)= 159.0
# Episode  640  return=  189  avg(last 20)= 152.0
# Episode  660  return=  182  avg(last 20)= 165.5
# Episode  680  return=  192  avg(last 20)= 180.2
# Episode  700  return=  188  avg(last 20)= 173.7
# Episode  720  return=  180  avg(last 20)= 178.4
# Episode  740  return=   51  avg(last 20)= 166.4
# Episode  760  return=  175  avg(last 20)= 180.6
# Episode  780  return=   99  avg(last 20)= 164.5
# Episode  800  return=  175  avg(last 20)= 170.2
# Episode  820  return=  175  avg(last 20)= 172.1
# Episode  840  return=  178  avg(last 20)= 180.4
# Episode  860  return=  180  avg(last 20)= 171.3
# Episode  880  return=  198  avg(last 20)= 179.6
# Episode  900  return=  176  avg(last 20)= 173.2
# Episode  920  return=  182  avg(last 20)= 179.5
# Episode  940  return=  172  avg(last 20)= 169.5
# Episode  960  return=  135  avg(last 20)= 164.5
# Episode  980  return=  169  avg(last 20)= 169.0
# Episode 1000  return=  179  avg(last 20)= 172.3
# Episode 1020  return=  174  avg(last 20)= 174.4
# Episode 1040  return=  171  avg(last 20)= 167.0
# Episode 1060  return=  149  avg(last 20)= 168.9
# Episode 1080  return=  149  avg(last 20)= 170.4
# Episode 1100  return=  110  avg(last 20)= 131.9
# Episode 1120  return=   65  avg(last 20)= 134.7
# Episode 1140  return=  176  avg(last 20)= 148.3
# Episode 1160  return=  144  avg(last 20)= 161.8
# Episode 1180  return=  120  avg(last 20)= 146.8
# Episode 1200  return=  177  avg(last 20)= 164.2
# Episode 1220  return=  183  avg(last 20)= 167.6
# Episode 1240  return=  175  avg(last 20)= 159.4
# Episode 1260  return=  173  avg(last 20)= 147.1
# Episode 1280  return=  162  avg(last 20)= 171.5
# Episode 1300  return=  167  avg(last 20)= 165.6
# Episode 1320  return=  165  avg(last 20)= 167.1
# Episode 1340  return=  171  avg(last 20)= 171.8
# Episode 1360  return=  171  avg(last 20)= 171.9
# Episode 1380  return=  162  avg(last 20)= 172.0
# Episode 1400  return=  168  avg(last 20)= 170.8
# Episode 1420  return=  173  avg(last 20)= 171.3
# Episode 1440  return=  168  avg(last 20)= 168.7
# Episode 1460  return=  169  avg(last 20)= 172.1
# Episode 1480  return=  170  avg(last 20)= 169.5
# Episode 1500  return=  161  avg(last 20)= 164.0
# Episode 1520  return=  167  avg(last 20)= 165.8
# Episode 1540  return=  175  avg(last 20)= 169.7
# Episode 1560  return=  174  avg(last 20)= 170.0
# Episode 1580  return=  171  avg(last 20)= 172.2
# Episode 1600  return=  171  avg(last 20)= 171.2
# Episode 1620  return=  132  avg(last 20)= 168.8
# Episode 1640  return=  146  avg(last 20)= 153.0
# Episode 1660  return=  171  avg(last 20)= 169.9
# Episode 1680  return=  171  avg(last 20)= 170.8
# Episode 1700  return=  177  avg(last 20)= 171.5
# Episode 1720  return=  173  avg(last 20)= 170.0
# Episode 1740  return=  174  avg(last 20)= 170.3
# Episode 1760  return=  159  avg(last 20)= 168.9
# Episode 1780  return=  164  avg(last 20)= 166.1
# Episode 1800  return=  164  avg(last 20)= 169.3
# Episode 1820  return=  174  avg(last 20)= 169.1
# Episode 1840  return=  171  avg(last 20)= 171.0
# Episode 1860  return=  169  avg(last 20)= 170.4
# Episode 1880  return=  172  avg(last 20)= 170.0
# Episode 1900  return=  170  avg(last 20)= 169.3
# Episode 1920  return=  170  avg(last 20)= 168.7
# Episode 1940  return=  170  avg(last 20)= 169.3
# Episode 1960  return=  170  avg(last 20)= 171.7
# Episode 1980  return=  170  avg(last 20)= 170.8
# Episode 2000  return=  175  avg(last 20)= 173.4
# Episode 2020  return=  164  avg(last 20)= 150.7
# Episode 2040  return=  169  avg(last 20)= 155.9
# Episode 2060  return=  173  avg(last 20)= 166.2
# Episode 2080  return=  172  avg(last 20)= 171.5
# Episode 2100  return=  171  avg(last 20)= 171.4
# Episode 2120  return=  173  avg(last 20)= 172.3
# Episode 2140  return=  169  avg(last 20)= 170.8
# Episode 2160  return=  174  avg(last 20)= 171.8
# Episode 2180  return=  173  avg(last 20)= 171.1
# Episode 2200  return=  173  avg(last 20)= 170.5
# Episode 2220  return=  172  avg(last 20)= 170.7
# Episode 2240  return=  165  avg(last 20)= 169.3
# Episode 2260  return=  175  avg(last 20)= 170.6
# Episode 2280  return=  174  avg(last 20)= 171.9
# Episode 2300  return=  166  avg(last 20)= 171.0
# Episode 2320  return=  163  avg(last 20)= 166.5
# Episode 2340  return=  161  avg(last 20)= 149.5
# Episode 2360  return=  169  avg(last 20)= 150.3
# Episode 2380  return=  173  avg(last 20)= 167.7
# Episode 2400  return=  168  avg(last 20)= 167.7
# Episode 2420  return=  169  avg(last 20)= 165.7
# Episode 2440  return=  145  avg(last 20)= 155.1
# Episode 2460  return=  133  avg(last 20)= 125.1
# Episode 2480  return=   71  avg(last 20)= 103.2
# Episode 2500  return=   74  avg(last 20)=  77.1
# Episode 2520  return=   46  avg(last 20)=  57.4
# Episode 2540  return=   44  avg(last 20)=  50.4
# Episode 2560  return=   60  avg(last 20)=  54.3
# Episode 2580  return=   87  avg(last 20)=  64.8
# Episode 2600  return=   92  avg(last 20)=  89.4
# Episode 2620  return=  166  avg(last 20)= 128.3
# Episode 2640  return=  164  avg(last 20)= 155.4
# Episode 2660  return=  165  avg(last 20)= 151.2
# Episode 2680  return=  163  avg(last 20)= 131.7
# Episode 2700  return=  166  avg(last 20)= 154.0
# Episode 2720  return=  169  avg(last 20)= 168.4
# Episode 2740  return=  170  avg(last 20)= 171.5
# Episode 2760  return=  174  avg(last 20)= 172.9
# Episode 2780  return=  173  avg(last 20)= 171.5
# Episode 2800  return=  177  avg(last 20)= 172.9
# Episode 2820  return=  167  avg(last 20)= 171.5
# Episode 2840  return=  174  avg(last 20)= 172.6
# Episode 2860  return=  172  avg(last 20)= 172.5
# Episode 2880  return=  175  avg(last 20)= 173.8
# Episode 2900  return=  174  avg(last 20)= 174.2
# Episode 2920  return=  177  avg(last 20)= 170.1
# Episode 2940  return=  172  avg(last 20)= 159.2
# Episode 2960  return=  177  avg(last 20)= 163.9
# Episode 2980  return=  179  avg(last 20)= 165.1
# Saved model_ac_trial_10.pt and history_ac_trial_10.pkl and time_ac_trial_10.pkl
#
# Running: ac_trial_11
# {'run_name': 'ac_trial_11', 'actor_lr': 0.00011751907337909231, 'critic_lr': 0.000255644216482894, 'entropy_weight': 0.005, 'critic_weight': 1.0, 'hidden': 128, 'gamma': 0.99, 'grad_clip': 0.5, 'normalize_advantage': True}
# State space: Box(-inf, inf, (11,), float64)
# Action space: Box(-1.0, 1.0, (3,), float32)
# Episode    0  return=   43  avg(last 20)=  43.5
# Episode   20  return=   21  avg(last 20)=  26.7
# Episode   40  return=   15  avg(last 20)=  21.6
# Episode   60  return=   11  avg(last 20)=  17.1
# Episode   80  return=   11  avg(last 20)=  11.6
# Episode  100  return=    8  avg(last 20)=  10.8
# Episode  120  return=   12  avg(last 20)=   9.1
# Episode  140  return=    8  avg(last 20)=   9.2
# Episode  160  return=    6  avg(last 20)=   8.0
# Episode  180  return=    8  avg(last 20)=   7.7
# Episode  200  return=   12  avg(last 20)=  24.4
# Episode  220  return=   76  avg(last 20)=  58.8
# Episode  240  return=   67  avg(last 20)=  78.7
# Episode  260  return=   89  avg(last 20)=  75.4
# Episode  280  return=   48  avg(last 20)=  66.5
# Episode  300  return=   47  avg(last 20)=  69.8
# Episode  320  return=   72  avg(last 20)=  86.4
# Episode  340  return=   29  avg(last 20)=  64.9
# Episode  360  return=   74  avg(last 20)=  73.2
# Episode  380  return=  190  avg(last 20)=  79.1
# Episode  400  return=   45  avg(last 20)=  76.6
# Episode  420  return=   43  avg(last 20)=  71.3
# Episode  440  return=   77  avg(last 20)=  80.3
# Episode  460  return=   83  avg(last 20)=  73.7
# Episode  480  return=  191  avg(last 20)=  83.7
# Episode  500  return=  103  avg(last 20)=  98.7
# Episode  520  return=   95  avg(last 20)=  86.4
# Episode  540  return=  207  avg(last 20)= 106.0
# Episode  560  return=   41  avg(last 20)= 114.6
# Episode  580  return=   17  avg(last 20)= 131.1
# Episode  600  return=   17  avg(last 20)= 121.0
# Episode  620  return=   24  avg(last 20)= 109.9
# Episode  640  return=   19  avg(last 20)=  83.1
# Episode  660  return=  176  avg(last 20)=  91.6
# Episode  680  return=  191  avg(last 20)= 131.1
# Episode  700  return=   34  avg(last 20)= 131.3
# Episode  720  return=  155  avg(last 20)= 155.5
# Episode  740  return=  177  avg(last 20)= 153.8
# Episode  760  return=  193  avg(last 20)= 164.9
# Episode  780  return=  206  avg(last 20)= 156.6
# Episode  800  return=  183  avg(last 20)= 186.8
# Episode  820  return=   89  avg(last 20)= 149.8
# Episode  840  return=  138  avg(last 20)= 164.4
# Episode  860  return=  164  avg(last 20)= 174.5
# Episode  880  return=  180  avg(last 20)= 163.2
# Episode  900  return=  188  avg(last 20)= 167.7
# Episode  920  return=  193  avg(last 20)= 159.6
# Episode  940  return=  205  avg(last 20)= 181.6
# Episode  960  return=  206  avg(last 20)= 179.1
# Episode  980  return=  189  avg(last 20)= 179.0
# Episode 1000  return=  185  avg(last 20)= 191.4
# Episode 1020  return=  185  avg(last 20)= 175.7
# Episode 1040  return=  206  avg(last 20)= 159.6
# Episode 1060  return=  169  avg(last 20)= 153.4
# Episode 1080  return=  172  avg(last 20)= 171.4
# Episode 1100  return=  201  avg(last 20)= 196.8
# Episode 1120  return=  183  avg(last 20)= 174.4
# Episode 1140  return=  209  avg(last 20)= 166.2
# Episode 1160  return=  184  avg(last 20)= 184.7
# Episode 1180  return=  194  avg(last 20)= 188.0
# Episode 1200  return=  180  avg(last 20)= 188.5
# Episode 1220  return=  195  avg(last 20)= 180.6
# Episode 1240  return=  190  avg(last 20)= 178.9
# Episode 1260  return=  203  avg(last 20)= 191.1
# Episode 1280  return=  193  avg(last 20)= 185.5
# Episode 1300  return=  183  avg(last 20)= 183.0
# Episode 1320  return=  186  avg(last 20)= 177.4
# Episode 1340  return=  143  avg(last 20)= 181.3
# Episode 1360  return=  201  avg(last 20)= 191.6
# Episode 1380  return=  179  avg(last 20)= 178.5
# Episode 1400  return=  200  avg(last 20)= 187.2
# Episode 1420  return=  180  avg(last 20)= 189.1
# Episode 1440  return=  173  avg(last 20)= 183.5
# Episode 1460  return=  195  avg(last 20)= 182.9
# Episode 1480  return=  193  avg(last 20)= 184.0
# Episode 1500  return=  184  avg(last 20)= 176.5
# Episode 1520  return=  185  avg(last 20)= 169.7
# Episode 1540  return=  100  avg(last 20)= 164.8
# Episode 1560  return=  179  avg(last 20)= 172.3
# Episode 1580  return=  206  avg(last 20)= 184.9
# Episode 1600  return=  177  avg(last 20)= 183.8
# Episode 1620  return=  183  avg(last 20)= 175.9
# Episode 1640  return=  147  avg(last 20)= 163.9
# Episode 1660  return=  128  avg(last 20)= 162.6
# Episode 1680  return=  165  avg(last 20)= 180.4
# Episode 1700  return=  172  avg(last 20)= 175.1
# Episode 1720  return=  181  avg(last 20)= 164.6
# Episode 1740  return=  174  avg(last 20)= 179.5
# Episode 1760  return=  177  avg(last 20)= 184.3
# Episode 1780  return=  176  avg(last 20)= 180.1
# Episode 1800  return=  190  avg(last 20)= 163.5
# Episode 1820  return=  186  avg(last 20)= 177.4
# Episode 1840  return=  174  avg(last 20)= 174.2
# Episode 1860  return=  203  avg(last 20)= 155.3
# Episode 1880  return=  184  avg(last 20)= 174.0
# Episode 1900  return=  176  avg(last 20)= 174.4
# Episode 1920  return=  185  avg(last 20)= 177.3
# Episode 1940  return=  134  avg(last 20)= 156.6
# Episode 1960  return=  127  avg(last 20)= 126.6
# Episode 1980  return=  168  avg(last 20)= 157.8
# Episode 2000  return=  230  avg(last 20)= 177.8
# Episode 2020  return=  228  avg(last 20)= 198.9
# Episode 2040  return=  219  avg(last 20)= 225.0
# Episode 2060  return=  145  avg(last 20)= 221.1
# Episode 2080  return=  220  avg(last 20)= 223.8
# Episode 2100  return=  221  avg(last 20)= 206.7
# Episode 2120  return=  196  avg(last 20)= 213.8
# Episode 2140  return=  223  avg(last 20)= 218.3
# Episode 2160  return=  208  avg(last 20)= 214.1
# Episode 2180  return=  219  avg(last 20)= 217.0
# Episode 2200  return=  208  avg(last 20)= 210.4
# Episode 2220  return=  194  avg(last 20)= 210.1
# Episode 2240  return=  204  avg(last 20)= 208.0
# Episode 2260  return=  211  avg(last 20)= 211.5
# Episode 2280  return=  192  avg(last 20)= 216.7
# Episode 2300  return=  214  avg(last 20)= 218.2
# Episode 2320  return=  193  avg(last 20)= 215.7
# Episode 2340  return=  217  avg(last 20)= 213.5
# Episode 2360  return=  211  avg(last 20)= 210.9
# Episode 2380  return=  219  avg(last 20)= 209.8
# Episode 2400  return=  218  avg(last 20)= 209.6
# Episode 2420  return=  217  avg(last 20)= 212.3
# Episode 2440  return=  201  avg(last 20)= 209.3
# Episode 2460  return=  203  avg(last 20)= 206.6
# Episode 2480  return=  199  avg(last 20)= 196.8
# Episode 2500  return=  201  avg(last 20)= 200.9
# Episode 2520  return=  193  avg(last 20)= 200.5
# Episode 2540  return=  200  avg(last 20)= 201.8
# Episode 2560  return=  156  avg(last 20)= 167.4
# Episode 2580  return=  205  avg(last 20)= 188.2
# Episode 2600  return=  195  avg(last 20)= 192.7
# Episode 2620  return=  201  avg(last 20)= 198.6
# Episode 2640  return=  193  avg(last 20)= 192.2
# Episode 2660  return=  202  avg(last 20)= 193.5
# Episode 2680  return=  187  avg(last 20)= 194.3
# Episode 2700  return=  134  avg(last 20)= 183.3
# Episode 2720  return=  171  avg(last 20)= 164.3
# Episode 2740  return=  188  avg(last 20)= 181.8
# Episode 2760  return=  195  avg(last 20)= 194.7
# Episode 2780  return=  198  avg(last 20)= 197.9
# Episode 2800  return=  204  avg(last 20)= 201.4
# Episode 2820  return=  207  avg(last 20)= 201.1
# Episode 2840  return=  208  avg(last 20)= 201.3
# Episode 2860  return=  207  avg(last 20)= 206.0
# Episode 2880  return=  197  avg(last 20)= 203.2
# Episode 2900  return=  192  avg(last 20)= 196.0
# Episode 2920  return=  194  avg(last 20)= 188.2
# Episode 2940  return=  171  avg(last 20)= 189.3
# Episode 2960  return=  107  avg(last 20)= 136.7
# Episode 2980  return=  185  avg(last 20)= 126.6
# Saved model_ac_trial_11.pt and history_ac_trial_11.pkl and time_ac_trial_11.pkl

# %%
def ac_final_mean(run_name, last_n=20):
    h = load_history(run_name)
    return float(np.mean(h[-last_n:]))

ac_scores = {}

for cfg in ac_configs:
    name = cfg["run_name"]
    ac_scores[name] = ac_final_mean(name, last_n=20)

print("Actor-Critic sweep scores:")
for name, score in ac_scores.items():
    print(f"{name:15s} {score:.2f}")

BEST_AC = max(ac_scores, key=ac_scores.get)
print("\nBest Actor-Critic:", BEST_AC)

best_cfg = None
for cfg in ac_configs:
    if cfg["run_name"] == BEST_AC:
        best_cfg = cfg

print("\nBest config:")
print(best_cfg)
# Out:
# Actor-Critic sweep scores:
# ac_trial_0      241.80
# ac_trial_1      253.90
# ac_trial_2      169.20
# ac_trial_3      233.06
# ac_trial_4      156.32
# ac_trial_5      185.89
# ac_trial_6      19.58
# ac_trial_7      415.39
# ac_trial_8      245.94
# ac_trial_9      211.10
# ac_trial_10     173.98
# ac_trial_11     173.87
#
# Best Actor-Critic: ac_trial_7
#
# Best config:
# {'run_name': 'ac_trial_7', 'actor_lr': 3.872216488027649e-05, 'critic_lr': 0.00039902377429646666, 'entropy_weight': 0.0001, 'critic_weight': 1.0, 'hidden': 256, 'gamma': 0.995, 'grad_clip': 0.5, 'normalize_advantage': False}

# %%
FOCUS_TRIAL = "ac_trial_7"

plt.figure(figsize=(11, 5.5))

for cfg in ac_configs:
    name = cfg["run_name"]
    h = load_history(name)

    if name == FOCUS_TRIAL:
        plt.plot(
            smooth_50(h),
            label=f"{name} BEST, final={ac_scores[name]:.1f}",
            color="tab:red",
            linewidth=3.0,
            zorder=5
        )
    else:
        plt.plot(
            smooth_50(h),
            label=f"{name}, final={ac_scores[name]:.1f}",
            color="gray",
            alpha=0.35,
            linewidth=1.0
        )

plt.xlabel("Episode")
plt.ylabel("Return (50-episode moving average)")
plt.title("Actor-Critic hyperparameter sweep: highlighting best trial")
plt.legend(fontsize=8)
plt.grid(alpha=0.3)
plt.tight_layout()
plt.savefig(os.path.join(PREFIX, "actor_critic_sweep_highlight_best.png"),
            dpi=120,
            bbox_inches="tight")
plt.show()

print("Saved: actor_critic_sweep_highlight_best.png")
# Out:
# Saved: actor_critic_sweep_highlight_best.png

# %%
FOCUS_TRIAL = "ac_trial_7"

print("Best trial configuration:")
for key, value in best_cfg.items():
    print(f"{key:20s}: {value}")

print("\nBest trial final score:")
print(f"{FOCUS_TRIAL}: {ac_scores[FOCUS_TRIAL]:.2f}")
# Out:
# Best trial configuration:
# run_name            : ac_trial_7
# actor_lr            : 3.872216488027649e-05
# critic_lr           : 0.00039902377429646666
# entropy_weight      : 0.0001
# critic_weight       : 1.0
# hidden              : 256
# gamma               : 0.995
# grad_clip           : 0.5
# normalize_advantage : False
#
# Best trial final score:
# ac_trial_7: 415.39

# %%
history_ac_final = main(
    algorithm="actor_critic",
    n_episodes=3000,
    seed=42,
    actor_lr=best_cfg["actor_lr"],
    critic_lr=best_cfg["critic_lr"],
    entropy_weight=best_cfg["entropy_weight"],
    critic_weight=best_cfg["critic_weight"],
    hidden_size=best_cfg["hidden"],
    gamma=best_cfg["gamma"],
    grad_clip=best_cfg["grad_clip"],
    normalize_advantage=best_cfg["normalize_advantage"],
    save_dir=PREFIX
)
# Out:
# State space: Box(-inf, inf, (11,), float64)
# Action space: Box(-1.0, 1.0, (3,), float32)
# Episode    0  return=    8  avg(last 20)=   7.6
# Episode   20  return=    9  avg(last 20)=  10.1
# Episode   40  return=    7  avg(last 20)=  10.2
# Episode   60  return=   10  avg(last 20)=   8.6
# Episode   80  return=    7  avg(last 20)=   9.5
# Episode  100  return=   12  avg(last 20)=  14.6
# Episode  120  return=   42  avg(last 20)=  62.4
# Episode  140  return=  153  avg(last 20)=  93.9
# Episode  160  return=  235  avg(last 20)=  99.3
# Episode  180  return=  176  avg(last 20)= 129.3
# Episode  200  return=  149  avg(last 20)= 192.7
# Episode  220  return=  105  avg(last 20)= 167.0
# Episode  240  return=  157  avg(last 20)= 138.5
# Episode  260  return=  114  avg(last 20)= 167.8
# Episode  280  return=  284  avg(last 20)= 182.0
# Episode  300  return=  236  avg(last 20)= 157.7
# Episode  320  return=  173  avg(last 20)= 181.5
# Episode  340  return=  130  avg(last 20)= 137.4
# Episode  360  return=  130  avg(last 20)= 187.2
# Episode  380  return=  152  avg(last 20)= 165.4
# Episode  400  return=  164  avg(last 20)= 188.9
# Episode  420  return=  228  avg(last 20)= 201.5
# Episode  440  return=  187  avg(last 20)= 216.3
# Episode  460  return=  279  avg(last 20)= 257.8
# Episode  480  return=  135  avg(last 20)= 280.1
# Episode  500  return=  311  avg(last 20)= 255.0
# Episode  520  return=  248  avg(last 20)= 303.8
# Episode  540  return=  328  avg(last 20)= 263.8
# Episode  560  return=  357  avg(last 20)= 271.1
# Episode  580  return=  344  avg(last 20)= 315.5
# Episode  600  return=  167  avg(last 20)= 272.6
# Episode  620  return=   99  avg(last 20)= 221.9
# Episode  640  return=  195  avg(last 20)= 234.1
# Episode  660  return=  276  avg(last 20)= 238.3
# Episode  680  return=  284  avg(last 20)= 261.8
# Episode  700  return=  319  avg(last 20)= 265.5
# Episode  720  return=  167  avg(last 20)= 247.3
# Episode  740  return=  343  avg(last 20)= 270.5
# Episode  760  return=  179  avg(last 20)= 295.6
# Episode  780  return=  193  avg(last 20)= 272.7
# Episode  800  return=  139  avg(last 20)= 217.7
# Episode  820  return=  304  avg(last 20)= 260.4
# Episode  840  return=  306  avg(last 20)= 307.1
# Episode  860  return=  311  avg(last 20)= 343.3
# Episode  880  return=  331  avg(last 20)= 353.6
# Episode  900  return=  344  avg(last 20)= 316.2
# Episode  920  return=  210  avg(last 20)= 342.1
# Episode  940  return=  369  avg(last 20)= 347.8
# Episode  960  return=  336  avg(last 20)= 354.8
# Episode  980  return=  413  avg(last 20)= 408.3
# Episode 1000  return=  170  avg(last 20)= 375.2
# Episode 1020  return=  450  avg(last 20)= 369.8
# Episode 1040  return=  407  avg(last 20)= 384.7
# Episode 1060  return=  401  avg(last 20)= 421.7
# Episode 1080  return=  424  avg(last 20)= 422.2
# Episode 1100  return=  391  avg(last 20)= 465.6
# Episode 1120  return=  467  avg(last 20)= 497.7
# Episode 1140  return=  543  avg(last 20)= 477.5
# Episode 1160  return=  464  avg(last 20)= 474.7
# Episode 1180  return=  513  avg(last 20)= 428.2
# Episode 1200  return=  488  avg(last 20)= 415.2
# Episode 1220  return=  498  avg(last 20)= 446.3
# Episode 1240  return=  583  avg(last 20)= 510.8
# Episode 1260  return=  550  avg(last 20)= 484.3
# Episode 1280  return=  509  avg(last 20)= 456.5
# Episode 1300  return=  442  avg(last 20)= 488.4
# Episode 1320  return=  551  avg(last 20)= 517.1
# Episode 1340  return=  240  avg(last 20)= 476.3
# Episode 1360  return=  493  avg(last 20)= 545.4
# Episode 1380  return=  750  avg(last 20)= 542.7
# Episode 1400  return=  539  avg(last 20)= 608.0
# Episode 1420  return=  267  avg(last 20)= 585.5
# Episode 1440  return=   38  avg(last 20)= 506.3
# Episode 1460  return=  803  avg(last 20)= 629.4
# Episode 1480  return=  607  avg(last 20)= 545.0
# Episode 1500  return=  751  avg(last 20)= 493.7
# Episode 1520  return=  538  avg(last 20)= 596.7
# Episode 1540  return=  527  avg(last 20)= 556.0
# Episode 1560  return=  544  avg(last 20)= 550.8
# Episode 1580  return=  568  avg(last 20)= 509.9
# Episode 1600  return=  615  avg(last 20)= 502.4
# Episode 1620  return=  503  avg(last 20)= 494.7
# Episode 1640  return=  546  avg(last 20)= 529.8
# Episode 1660  return=  578  avg(last 20)= 530.9
# Episode 1680  return=  483  avg(last 20)= 511.8
# Episode 1700  return=  486  avg(last 20)= 525.2
# Episode 1720  return=  485  avg(last 20)= 489.9
# Episode 1740  return=  422  avg(last 20)= 425.5
# Episode 1760  return=  408  avg(last 20)= 447.4
# Episode 1780  return=  495  avg(last 20)= 435.0
# Episode 1800  return=  427  avg(last 20)= 451.6
# Episode 1820  return=  461  avg(last 20)= 423.7
# Episode 1840  return=  376  avg(last 20)= 410.2
# Episode 1860  return=  372  avg(last 20)= 386.8
# Episode 1880  return=  354  avg(last 20)= 372.3
# Episode 1900  return=  367  avg(last 20)= 365.7
# Episode 1920  return=  337  avg(last 20)= 352.0
# Episode 1940  return=  365  avg(last 20)= 349.1
# Episode 1960  return=  327  avg(last 20)= 358.4
# Episode 1980  return=  335  avg(last 20)= 353.3
# Episode 2000  return=  360  avg(last 20)= 334.5
# Episode 2020  return=  352  avg(last 20)= 346.2
# Episode 2040  return=  290  avg(last 20)= 337.1
# Episode 2060  return=  285  avg(last 20)= 324.0
# Episode 2080  return=  257  avg(last 20)= 321.0
# Episode 2100  return=  286  avg(last 20)= 317.5
# Episode 2120  return=  293  avg(last 20)= 327.4
# Episode 2140  return=  372  avg(last 20)= 352.5
# Episode 2160  return=  371  avg(last 20)= 348.6
# Episode 2180  return=  344  avg(last 20)= 362.4
# Episode 2200  return=  402  avg(last 20)= 373.6
# Episode 2220  return=  367  avg(last 20)= 357.7
# Episode 2240  return=  404  avg(last 20)= 358.4
# Episode 2260  return=  376  avg(last 20)= 366.3
# Episode 2280  return=  359  avg(last 20)= 356.3
# Episode 2300  return=  385  avg(last 20)= 360.3
# Episode 2320  return=  314  avg(last 20)= 368.9
# Episode 2340  return=  394  avg(last 20)= 409.9
# Episode 2360  return=  398  avg(last 20)= 399.5
# Episode 2380  return=  368  avg(last 20)= 396.6
# Episode 2400  return=  390  avg(last 20)= 383.3
# Episode 2420  return=  383  avg(last 20)= 381.3
# Episode 2440  return=  422  avg(last 20)= 417.9
# Episode 2460  return=  417  avg(last 20)= 415.0
# Episode 2480  return=  380  avg(last 20)= 405.6
# Episode 2500  return=  329  avg(last 20)= 385.6
# Episode 2520  return=  436  avg(last 20)= 388.9
# Episode 2540  return=  378  avg(last 20)= 397.9
# Episode 2560  return=  415  avg(last 20)= 415.4
# Episode 2580  return=  388  avg(last 20)= 413.2
# Episode 2600  return=  362  avg(last 20)= 392.2
# Episode 2620  return=  393  avg(last 20)= 402.9
# Episode 2640  return=  372  avg(last 20)= 413.8
# Episode 2660  return=  492  avg(last 20)= 384.0
# Episode 2680  return=  392  avg(last 20)= 392.0
# Episode 2700  return=  343  avg(last 20)= 354.7
# Episode 2720  return=  382  avg(last 20)= 352.3
# Episode 2740  return=  362  avg(last 20)= 351.5
# Episode 2760  return=  301  avg(last 20)= 337.0
# Episode 2780  return=  354  avg(last 20)= 335.1
# Episode 2800  return=  342  avg(last 20)= 307.8
# Episode 2820  return=  281  avg(last 20)= 307.5
# Episode 2840  return=  394  avg(last 20)= 334.3
# Episode 2860  return=  434  avg(last 20)= 353.2
# Episode 2880  return=  367  avg(last 20)= 376.1
# Episode 2900  return=  382  avg(last 20)= 405.9
# Episode 2920  return=  441  avg(last 20)= 407.7
# Episode 2940  return=  404  avg(last 20)= 401.7
# Episode 2960  return=  341  avg(last 20)= 419.9
# Episode 2980  return=  410  avg(last 20)= 408.1
# Saved model_actor_critic.pt and history_actor_critic.pkl and time_actor_critic.pkl

# %% [markdown]
# ## Refining Actor-Critic from the sweep winner
#
# `ac_trial_7` peaks at ~621 around episode 1364, then **decays to ~400** by episode 3000 — the failure mode is *late-training instability*, not under-training. So the goal here is to **hold the peak**, not train longer.
#
# These runs start from ac_7's recipe (low `actor_lr`, fast critic, `hidden=256`, `gamma=0.995`) and add stabilizers — `normalize_advantage=True`, a lower `actor_lr`, and a tighter `grad_clip` — across multiple seeds. We rank by **peak** (best-case) and by the **peak-to-final gap** (smaller = more stable).

# %%
refined_cfg = dict(
    actor_lr=2.5e-5,          
    critic_lr=4.0e-4,         
    critic_weight=1.0,
    hidden_size=256,
    gamma=0.995,
    grad_clip=0.3,            
    entropy_weight=1e-4,
    normalize_advantage=True, 
)

REFINE_SEEDS = [42, 0, 1]     

for seed in REFINE_SEEDS:
    name = f"ac_refined_seed{seed}"
    print(f"\n=== {name} ===")
    main(algorithm="actor_critic", n_episodes=3000, seed=seed,
         run_name=name, save_dir=PREFIX, **refined_cfg)
# Out:
# === ac_refined_seed42 ===
# State space: Box(-inf, inf, (11,), float64)
# Action space: Box(-1.0, 1.0, (3,), float32)
# Episode    0  return=    8  avg(last 20)=   7.6
# Episode   20  return=   10  avg(last 20)=   9.4
# Episode   40  return=    7  avg(last 20)=  10.4
# Episode   60  return=   11  avg(last 20)=   9.0
# Episode   80  return=    9  avg(last 20)=  10.7
# Episode  100  return=   14  avg(last 20)=  16.0
# Episode  120  return=   17  avg(last 20)=  30.6
# Episode  140  return=  200  avg(last 20)=  66.7
# Episode  160  return=   14  avg(last 20)=  62.7
# Episode  180  return=  173  avg(last 20)=  93.8
# Episode  200  return=  111  avg(last 20)= 145.0
# Episode  220  return=   16  avg(last 20)=  99.6
# Episode  240  return=  176  avg(last 20)= 122.3
# Episode  260  return=  190  avg(last 20)= 127.3
# Episode  280  return=  259  avg(last 20)= 165.5
# Episode  300  return=  250  avg(last 20)= 144.8
# Episode  320  return=  107  avg(last 20)= 148.3
# Episode  340  return=  215  avg(last 20)= 146.7
# Episode  360  return=   79  avg(last 20)= 168.9
# Episode  380  return=  113  avg(last 20)= 139.6
# Episode  400  return=  120  avg(last 20)= 152.6
# Episode  420  return=  119  avg(last 20)= 157.9
# Episode  440  return=  112  avg(last 20)= 158.3
# Episode  460  return=  159  avg(last 20)= 142.7
# Episode  480  return=   99  avg(last 20)= 147.5
# Episode  500  return=  174  avg(last 20)= 166.4
# Episode  520  return=  213  avg(last 20)= 152.4
# Episode  540  return=   89  avg(last 20)= 162.9
# Episode  560  return=  122  avg(last 20)= 152.6
# Episode  580  return=  133  avg(last 20)= 144.1
# Episode  600  return=  193  avg(last 20)= 163.7
# Episode  620  return=  135  avg(last 20)= 166.3
# Episode  640  return=  143  avg(last 20)= 173.6
# Episode  660  return=  346  avg(last 20)= 199.7
# Episode  680  return=  141  avg(last 20)= 214.7
# Episode  700  return=  445  avg(last 20)= 246.7
# Episode  720  return=  183  avg(last 20)= 257.2
# Episode  740  return=  288  avg(last 20)= 264.7
# Episode  760  return=  164  avg(last 20)= 224.2
# Episode  780  return=  192  avg(last 20)= 226.1
# Episode  800  return=  230  avg(last 20)= 171.8
# Episode  820  return=  291  avg(last 20)= 257.6
# Episode  840  return=  147  avg(last 20)= 248.6
# Episode  860  return=  277  avg(last 20)= 259.0
# Episode  880  return=   75  avg(last 20)= 235.7
# Episode  900  return=  134  avg(last 20)= 245.2
# Episode  920  return=  280  avg(last 20)= 242.0
# Episode  940  return=  321  avg(last 20)= 272.6
# Episode  960  return=  313  avg(last 20)= 261.8
# Episode  980  return=  111  avg(last 20)= 258.4
# Episode 1000  return=  311  avg(last 20)= 279.5
# Episode 1020  return=  184  avg(last 20)= 268.7
# Episode 1040  return=  291  avg(last 20)= 279.0
# Episode 1060  return=  334  avg(last 20)= 279.6
# Episode 1080  return=  261  avg(last 20)= 293.6
# Episode 1100  return=  170  avg(last 20)= 289.4
# Episode 1120  return=  282  avg(last 20)= 275.7
# Episode 1140  return=  143  avg(last 20)= 251.6
# Episode 1160  return=  269  avg(last 20)= 255.2
# Episode 1180  return=  357  avg(last 20)= 264.5
# Episode 1200  return=  166  avg(last 20)= 268.5
# Episode 1220  return=  289  avg(last 20)= 274.8
# Episode 1240  return=  295  avg(last 20)= 266.6
# Episode 1260  return=  231  avg(last 20)= 292.3
# Episode 1280  return=  181  avg(last 20)= 287.6
# Episode 1300  return=  303  avg(last 20)= 289.6
# Episode 1320  return=  326  avg(last 20)= 282.7
# Episode 1340  return=  179  avg(last 20)= 271.4
# Episode 1360  return=  149  avg(last 20)= 275.7
# Episode 1380  return=  162  avg(last 20)= 264.7
# Episode 1400  return=  250  avg(last 20)= 289.9
# Episode 1420  return=  258  avg(last 20)= 302.5
# Episode 1440  return=  340  avg(last 20)= 304.8
# Episode 1460  return=  307  avg(last 20)= 243.2
# Episode 1480  return=  200  avg(last 20)= 261.4
# Episode 1500  return=  300  avg(last 20)= 271.5
# Episode 1520  return=  292  avg(last 20)= 284.1
# Episode 1540  return=  287  avg(last 20)= 307.7
# Episode 1560  return=  266  avg(last 20)= 259.4
# Episode 1580  return=   85  avg(last 20)= 274.8
# Episode 1600  return=  268  avg(last 20)= 294.5
# Episode 1620  return=  295  avg(last 20)= 275.8
# Episode 1640  return=  375  avg(last 20)= 306.3
# Episode 1660  return=  393  avg(last 20)= 328.2
# Episode 1680  return=  367  avg(last 20)= 283.1
# Episode 1700  return=  292  avg(last 20)= 285.8
# Episode 1720  return=  290  avg(last 20)= 285.2
# Episode 1740  return=  291  avg(last 20)= 276.9
# Episode 1760  return=  237  avg(last 20)= 275.6
# Episode 1780  return=  342  avg(last 20)= 271.2
# Episode 1800  return=  343  avg(last 20)= 288.4
# Episode 1820  return=  250  avg(last 20)= 277.8
# Episode 1840  return=  278  avg(last 20)= 299.6
# Episode 1860  return=  289  avg(last 20)= 286.5
# Episode 1880  return=  245  avg(last 20)= 284.3
# Episode 1900  return=  291  avg(last 20)= 295.0
# Episode 1920  return=  263  avg(last 20)= 288.6
# Episode 1940  return=  295  avg(last 20)= 321.1
# Episode 1960  return=  380  avg(last 20)= 339.7
# Episode 1980  return=  346  avg(last 20)= 317.2
# Episode 2000  return=  253  avg(last 20)= 362.8
# Episode 2020  return=  395  avg(last 20)= 342.1
# Episode 2040  return=  255  avg(last 20)= 343.2
# Episode 2060  return=  287  avg(last 20)= 337.9
# Episode 2080  return=  287  avg(last 20)= 341.5
# Episode 2100  return=  387  avg(last 20)= 319.5
# Episode 2120  return=  341  avg(last 20)= 315.1
# Episode 2140  return=  393  avg(last 20)= 296.6
# Episode 2160  return=  302  avg(last 20)= 323.0
# Episode 2180  return=  326  avg(last 20)= 310.1
# Episode 2200  return=  287  avg(last 20)= 318.8
# Episode 2220  return=  342  avg(last 20)= 295.8
# Episode 2240  return=  333  avg(last 20)= 281.9
# Episode 2260  return=  332  avg(last 20)= 339.9
# Episode 2280  return=  298  avg(last 20)= 301.2
# Episode 2300  return=  327  avg(last 20)= 298.4
# Episode 2320  return=  409  avg(last 20)= 330.7
# Episode 2340  return=  386  avg(last 20)= 335.9
# Episode 2360  return=  341  avg(last 20)= 349.8
# Episode 2380  return=  389  avg(last 20)= 333.0
# Episode 2400  return=  332  avg(last 20)= 367.4
# Episode 2420  return=  356  avg(last 20)= 386.0
# Episode 2440  return=  342  avg(last 20)= 388.6
# Episode 2460  return=  192  avg(last 20)= 320.1
# Episode 2480  return=  103  avg(last 20)= 351.6
# Episode 2500  return=  747  avg(last 20)= 289.3
# Episode 2520  return=  537  avg(last 20)= 355.3
# Episode 2540  return=   96  avg(last 20)= 293.2
# Episode 2560  return=  273  avg(last 20)= 197.8
# Episode 2580  return=  585  avg(last 20)= 330.4
# Episode 2600  return=  279  avg(last 20)= 215.8
# Episode 2620  return=  115  avg(last 20)= 238.3
# Episode 2640  return=  147  avg(last 20)= 246.4
# Episode 2660  return=  297  avg(last 20)= 348.2
# Episode 2680  return=  545  avg(last 20)= 417.2
# Episode 2700  return=  265  avg(last 20)= 353.3
# Episode 2720  return=  376  avg(last 20)= 363.7
# Episode 2740  return=  620  avg(last 20)= 312.9
# Episode 2760  return=  472  avg(last 20)= 397.0
# Episode 2780  return=  338  avg(last 20)= 396.4
# Episode 2800  return=  484  avg(last 20)= 411.9
# Episode 2820  return=  201  avg(last 20)= 527.8
# Episode 2840  return=  522  avg(last 20)= 468.6
# Episode 2860  return=  469  avg(last 20)= 502.0
# Episode 2880  return=  729  avg(last 20)= 505.7
# Episode 2900  return=  438  avg(last 20)= 461.6
# Episode 2920  return=  710  avg(last 20)= 548.3
# Episode 2940  return=  460  avg(last 20)= 539.6
# Episode 2960  return=  822  avg(last 20)= 411.8
# Episode 2980  return=  336  avg(last 20)= 532.6
# Saved model_ac_refined_seed42.pt and history_ac_refined_seed42.pkl and time_ac_refined_seed42.pkl
#
# === ac_refined_seed0 ===
# State space: Box(-inf, inf, (11,), float64)
# Action space: Box(-1.0, 1.0, (3,), float32)
# Episode    0  return=    7  avg(last 20)=   7.1
# Episode   20  return=   13  avg(last 20)=  10.4
# Episode   40  return=    9  avg(last 20)=  10.6
# Episode   60  return=    9  avg(last 20)=   9.4
# Episode   80  return=   12  avg(last 20)=  11.9
# Episode  100  return=   34  avg(last 20)=  20.0
# Episode  120  return=   69  avg(last 20)=  52.5
# Episode  140  return=   20  avg(last 20)=  61.6
# Episode  160  return=   23  avg(last 20)=  66.5
# Episode  180  return=   32  avg(last 20)=  77.8
# Episode  200  return=   12  avg(last 20)=  62.4
# Episode  220  return=  214  avg(last 20)= 103.0
# Episode  240  return=   89  avg(last 20)= 114.0
# Episode  260  return=   86  avg(last 20)= 103.1
# Episode  280  return=  219  avg(last 20)= 149.6
# Episode  300  return=  103  avg(last 20)=  98.6
# Episode  320  return=  150  avg(last 20)= 137.3
# Episode  340  return=   12  avg(last 20)= 113.8
# Episode  360  return=    9  avg(last 20)=  99.3
# Episode  380  return=  130  avg(last 20)= 104.3
# Episode  400  return=   78  avg(last 20)= 110.3
# Episode  420  return=   59  avg(last 20)=  88.1
# Episode  440  return=   67  avg(last 20)= 118.8
# Episode  460  return=   75  avg(last 20)= 105.4
# Episode  480  return=  107  avg(last 20)=  93.2
# Episode  500  return=   56  avg(last 20)=  84.8
# Episode  520  return=   65  avg(last 20)=  94.0
# Episode  540  return=  128  avg(last 20)= 118.9
# Episode  560  return=  100  avg(last 20)= 101.0
# Episode  580  return=  112  avg(last 20)=  90.9
# Episode  600  return=   85  avg(last 20)= 102.7
# Episode  620  return=  188  avg(last 20)= 106.1
# Episode  640  return=  147  avg(last 20)= 132.8
# Episode  660  return=  134  avg(last 20)= 140.7
# Episode  680  return=  118  avg(last 20)= 136.0
# Episode  700  return=  191  avg(last 20)= 124.0
# Episode  720  return=   34  avg(last 20)= 136.1
# Episode  740  return=  146  avg(last 20)= 133.1
# Episode  760  return=  161  avg(last 20)= 122.8
# Episode  780  return=  104  avg(last 20)= 137.9
# Episode  800  return=  221  avg(last 20)= 169.0
# Episode  820  return=   34  avg(last 20)= 124.3
# Episode  840  return=  209  avg(last 20)= 138.9
# Episode  860  return=  144  avg(last 20)= 156.2
# Episode  880  return=   95  avg(last 20)= 155.2
# Episode  900  return=  205  avg(last 20)= 177.2
# Episode  920  return=  247  avg(last 20)= 156.6
# Episode  940  return=  229  avg(last 20)= 179.1
# Episode  960  return=  214  avg(last 20)= 178.9
# Episode  980  return=  203  avg(last 20)= 188.1
# Episode 1000  return=  135  avg(last 20)= 159.7
# Episode 1020  return=  209  avg(last 20)= 159.2
# Episode 1040  return=  229  avg(last 20)= 186.5
# Episode 1060  return=  217  avg(last 20)= 182.5
# Episode 1080  return=  197  avg(last 20)= 166.3
# Episode 1100  return=  123  avg(last 20)= 173.2
# Episode 1120  return=  206  avg(last 20)= 198.9
# Episode 1140  return=  192  avg(last 20)= 196.3
# Episode 1160  return=  258  avg(last 20)= 204.5
# Episode 1180  return=  218  avg(last 20)= 209.8
# Episode 1200  return=  238  avg(last 20)= 207.8
# Episode 1220  return=  276  avg(last 20)= 209.5
# Episode 1240  return=  226  avg(last 20)= 185.3
# Episode 1260  return=   70  avg(last 20)= 190.1
# Episode 1280  return=  224  avg(last 20)= 230.0
# Episode 1300  return=  204  avg(last 20)= 199.7
# Episode 1320  return=  355  avg(last 20)= 229.6
# Episode 1340  return=  200  avg(last 20)= 211.5
# Episode 1360  return=  236  avg(last 20)= 219.5
# Episode 1380  return=   54  avg(last 20)= 246.8
# Episode 1400  return=  362  avg(last 20)= 279.0
# Episode 1420  return=  393  avg(last 20)= 288.2
# Episode 1440  return=  222  avg(last 20)= 287.4
# Episode 1460  return=  355  avg(last 20)= 292.4
# Episode 1480  return=  415  avg(last 20)= 277.7
# Episode 1500  return=   83  avg(last 20)= 263.7
# Episode 1520  return=  202  avg(last 20)= 300.7
# Episode 1540  return=  403  avg(last 20)= 312.6
# Episode 1560  return=  282  avg(last 20)= 238.8
# Episode 1580  return=  467  avg(last 20)= 316.2
# Episode 1600  return=  318  avg(last 20)= 311.6
# Episode 1620  return=  512  avg(last 20)= 308.8
# Episode 1640  return=  156  avg(last 20)= 316.1
# Episode 1660  return=  429  avg(last 20)= 252.6
# Episode 1680  return=  333  avg(last 20)= 290.3
# Episode 1700  return=  118  avg(last 20)= 235.7
# Episode 1720  return=  495  avg(last 20)= 301.7
# Episode 1740  return=  575  avg(last 20)= 291.6
# Episode 1760  return=  521  avg(last 20)= 327.8
# Episode 1780  return=  508  avg(last 20)= 395.0
# Episode 1800  return=  452  avg(last 20)= 254.6
# Episode 1820  return=  253  avg(last 20)= 331.1
# Episode 1840  return=   87  avg(last 20)= 306.8
# Episode 1860  return=  477  avg(last 20)= 379.0
# Episode 1880  return=  307  avg(last 20)= 462.8
# Episode 1900  return=  632  avg(last 20)= 344.4
# Episode 1920  return=  395  avg(last 20)= 412.6
# Episode 1940  return=  105  avg(last 20)= 380.7
# Episode 1960  return=  363  avg(last 20)= 374.5
# Episode 1980  return=  408  avg(last 20)= 410.5
# Episode 2000  return=  446  avg(last 20)= 427.8
# Episode 2020  return=  471  avg(last 20)= 453.2
# Episode 2040  return=  379  avg(last 20)= 461.1
# Episode 2060  return=  282  avg(last 20)= 451.9
# Episode 2080  return=  379  avg(last 20)= 422.3
# Episode 2100  return=  374  avg(last 20)= 516.7
# Episode 2120  return=  527  avg(last 20)= 539.2
# Episode 2140  return=  348  avg(last 20)= 472.3
# Episode 2160  return=  572  avg(last 20)= 496.2
# Episode 2180  return=  633  avg(last 20)= 503.4
# Episode 2200  return=  478  avg(last 20)= 512.6
# Episode 2220  return=  468  avg(last 20)= 476.9
# Episode 2240  return=  411  avg(last 20)= 418.1
# Episode 2260  return=  449  avg(last 20)= 445.2
# Episode 2280  return=  388  avg(last 20)= 369.1
# Episode 2300  return=  417  avg(last 20)= 358.4
# Episode 2320  return=  388  avg(last 20)= 392.7
# Episode 2340  return=  541  avg(last 20)= 480.5
# Episode 2360  return=  504  avg(last 20)= 555.0
# Episode 2380  return=  708  avg(last 20)= 563.8
# Episode 2400  return=  486  avg(last 20)= 610.4
# Episode 2420  return=  769  avg(last 20)= 627.5
# Episode 2440  return=  727  avg(last 20)= 633.6
# Episode 2460  return=  551  avg(last 20)= 479.7
# Episode 2480  return=  364  avg(last 20)= 396.3
# Episode 2500  return=  352  avg(last 20)= 394.9
# Episode 2520  return=  565  avg(last 20)= 467.3
# Episode 2540  return=  451  avg(last 20)= 558.0
# Episode 2560  return=  576  avg(last 20)= 433.0
# Episode 2580  return=  337  avg(last 20)= 424.3
# Episode 2600  return=  647  avg(last 20)= 432.0
# Episode 2620  return=  774  avg(last 20)= 558.2
# Episode 2640  return=  607  avg(last 20)= 405.9
# Episode 2660  return=  473  avg(last 20)= 428.7
# Episode 2680  return=  359  avg(last 20)= 488.5
# Episode 2700  return=  583  avg(last 20)= 566.9
# Episode 2720  return= 1085  avg(last 20)= 607.8
# Episode 2740  return=  540  avg(last 20)= 589.3
# Episode 2760  return=  168  avg(last 20)= 441.2
# Episode 2780  return=  794  avg(last 20)= 710.2
# Episode 2800  return=  519  avg(last 20)= 524.7
# Episode 2820  return= 1043  avg(last 20)= 764.5
# Episode 2840  return= 1016  avg(last 20)= 848.6
# Episode 2860  return=  549  avg(last 20)= 782.5
# Episode 2880  return=  551  avg(last 20)= 574.4
# Episode 2900  return=  398  avg(last 20)= 452.6
# Episode 2920  return=  353  avg(last 20)= 409.5
# Episode 2940  return=  445  avg(last 20)= 407.8
# Episode 2960  return=  415  avg(last 20)= 377.4
# Episode 2980  return=  424  avg(last 20)= 403.7
# Saved model_ac_refined_seed0.pt and history_ac_refined_seed0.pkl and time_ac_refined_seed0.pkl
#
# === ac_refined_seed1 ===
# State space: Box(-inf, inf, (11,), float64)
# Action space: Box(-1.0, 1.0, (3,), float32)
# Episode    0  return=    8  avg(last 20)=   7.8
# Episode   20  return=   27  avg(last 20)=  19.8
# Episode   40  return=   10  avg(last 20)=  13.7
# Episode   60  return=    6  avg(last 20)=  12.0
# Episode   80  return=    7  avg(last 20)=  11.4
# Episode  100  return=    8  avg(last 20)=  12.4
# Episode  120  return=   56  avg(last 20)=  17.7
# Episode  140  return=   42  avg(last 20)=  25.8
# Episode  160  return=   50  avg(last 20)=  35.1
# Episode  180  return=   14  avg(last 20)=  86.5
# Episode  200  return=  231  avg(last 20)= 109.9
# Episode  220  return=   34  avg(last 20)= 137.8
# Episode  240  return=  245  avg(last 20)= 143.6
# Episode  260  return=  187  avg(last 20)= 131.4
# Episode  280  return=   84  avg(last 20)= 145.5
# Episode  300  return=  228  avg(last 20)= 183.1
# Episode  320  return=  151  avg(last 20)= 143.1
# Episode  340  return=   74  avg(last 20)= 144.3
# Episode  360  return=  136  avg(last 20)= 170.7
# Episode  380  return=   80  avg(last 20)= 187.6
# Episode  400  return=  123  avg(last 20)= 169.2
# Episode  420  return=  210  avg(last 20)= 147.6
# Episode  440  return=  153  avg(last 20)= 137.0
# Episode  460  return=  144  avg(last 20)= 144.7
# Episode  480  return=  209  avg(last 20)= 162.8
# Episode  500  return=  185  avg(last 20)= 131.8
# Episode  520  return=  115  avg(last 20)= 139.2
# Episode  540  return=  115  avg(last 20)= 138.4
# Episode  560  return=  161  avg(last 20)= 165.7
# Episode  580  return=  208  avg(last 20)= 155.7
# Episode  600  return=   35  avg(last 20)= 188.2
# Episode  620  return=  172  avg(last 20)= 165.4
# Episode  640  return=  235  avg(last 20)= 196.5
# Episode  660  return=  227  avg(last 20)= 191.2
# Episode  680  return=  117  avg(last 20)= 205.6
# Episode  700  return=  227  avg(last 20)= 197.3
# Episode  720  return=  226  avg(last 20)= 206.2
# Episode  740  return=  242  avg(last 20)= 214.8
# Episode  760  return=  236  avg(last 20)= 181.6
# Episode  780  return=  226  avg(last 20)= 188.9
# Episode  800  return=  212  avg(last 20)= 171.8
# Episode  820  return=  253  avg(last 20)= 194.3
# Episode  840  return=  217  avg(last 20)= 211.1
# Episode  860  return=   65  avg(last 20)= 183.0
# Episode  880  return=  212  avg(last 20)= 192.7
# Episode  900  return=  227  avg(last 20)= 194.6
# Episode  920  return=   97  avg(last 20)= 155.0
# Episode  940  return=  199  avg(last 20)= 162.3
# Episode  960  return=  220  avg(last 20)= 143.1
# Episode  980  return=  122  avg(last 20)= 129.3
# Episode 1000  return=  113  avg(last 20)= 153.7
# Episode 1020  return=   89  avg(last 20)= 124.8
# Episode 1040  return=  208  avg(last 20)= 123.8
# Episode 1060  return=  138  avg(last 20)= 152.6
# Episode 1080  return=  217  avg(last 20)= 186.0
# Episode 1100  return=  245  avg(last 20)= 173.0
# Episode 1120  return=  213  avg(last 20)= 197.9
# Episode 1140  return=  234  avg(last 20)= 186.9
# Episode 1160  return=  214  avg(last 20)= 179.0
# Episode 1180  return=  251  avg(last 20)= 198.3
# Episode 1200  return=  142  avg(last 20)= 199.9
# Episode 1220  return=  152  avg(last 20)= 187.3
# Episode 1240  return=  123  avg(last 20)= 192.0
# Episode 1260  return=   90  avg(last 20)= 165.1
# Episode 1280  return=  129  avg(last 20)= 162.5
# Episode 1300  return=  136  avg(last 20)= 163.1
# Episode 1320  return=  221  avg(last 20)= 188.1
# Episode 1340  return=  205  avg(last 20)= 185.5
# Episode 1360  return=   96  avg(last 20)= 184.1
# Episode 1380  return=   85  avg(last 20)= 173.0
# Episode 1400  return=  226  avg(last 20)= 197.9
# Episode 1420  return=  190  avg(last 20)= 217.8
# Episode 1440  return=  292  avg(last 20)= 212.2
# Episode 1460  return=   27  avg(last 20)= 198.7
# Episode 1480  return=  223  avg(last 20)= 194.3
# Episode 1500  return=  215  avg(last 20)= 191.5
# Episode 1520  return=  219  avg(last 20)= 220.8
# Episode 1540  return=  128  avg(last 20)= 204.0
# Episode 1560  return=  203  avg(last 20)= 212.3
# Episode 1580  return=  244  avg(last 20)= 215.2
# Episode 1600  return=  199  avg(last 20)= 213.9
# Episode 1620  return=  272  avg(last 20)= 231.1
# Episode 1640  return=  245  avg(last 20)= 208.3
# Episode 1660  return=  254  avg(last 20)= 219.3
# Episode 1680  return=  259  avg(last 20)= 224.4
# Episode 1700  return=  189  avg(last 20)= 193.0
# Episode 1720  return=  237  avg(last 20)= 189.1
# Episode 1740  return=  228  avg(last 20)= 210.7
# Episode 1760  return=  237  avg(last 20)= 229.9
# Episode 1780  return=  104  avg(last 20)= 197.5
# Episode 1800  return=  217  avg(last 20)= 196.6
# Episode 1820  return=  209  avg(last 20)= 214.3
# Episode 1840  return=  170  avg(last 20)= 217.9
# Episode 1860  return=  208  avg(last 20)= 207.8
# Episode 1880  return=  227  avg(last 20)= 205.1
# Episode 1900  return=  175  avg(last 20)= 198.6
# Episode 1920  return=  228  avg(last 20)= 214.1
# Episode 1940  return=  219  avg(last 20)= 222.5
# Episode 1960  return=  130  avg(last 20)= 204.2
# Episode 1980  return=  120  avg(last 20)= 207.6
# Episode 2000  return=  177  avg(last 20)= 204.5
# Episode 2020  return=  247  avg(last 20)= 200.1
# Episode 2040  return=  242  avg(last 20)= 202.9
# Episode 2060  return=  219  avg(last 20)= 212.6
# Episode 2080  return=  212  avg(last 20)= 210.4
# Episode 2100  return=  235  avg(last 20)= 215.1
# Episode 2120  return=  187  avg(last 20)= 194.1
# Episode 2140  return=  208  avg(last 20)= 206.3
# Episode 2160  return=  197  avg(last 20)= 192.4
# Episode 2180  return=  202  avg(last 20)= 194.6
# Episode 2200  return=   33  avg(last 20)= 174.1
# Episode 2220  return=  137  avg(last 20)= 168.7
# Episode 2240  return=  201  avg(last 20)= 198.8
# Episode 2260  return=  160  avg(last 20)= 181.5
# Episode 2280  return=  230  avg(last 20)= 223.0
# Episode 2300  return=  194  avg(last 20)= 187.4
# Episode 2320  return=  175  avg(last 20)= 186.9
# Episode 2340  return=  198  avg(last 20)= 177.2
# Episode 2360  return=  153  avg(last 20)= 179.8
# Episode 2380  return=  145  avg(last 20)= 149.9
# Episode 2400  return=   94  avg(last 20)= 143.2
# Episode 2420  return=  136  avg(last 20)= 164.5
# Episode 2440  return=  197  avg(last 20)= 174.8
# Episode 2460  return=  200  avg(last 20)= 169.3
# Episode 2480  return=  111  avg(last 20)= 176.9
# Episode 2500  return=  205  avg(last 20)= 189.4
# Episode 2520  return=  194  avg(last 20)= 204.3
# Episode 2540  return=  181  avg(last 20)= 198.8
# Episode 2560  return=  215  avg(last 20)= 190.8
# Episode 2580  return=  203  avg(last 20)= 194.2
# Episode 2600  return=  196  avg(last 20)= 197.3
# Episode 2620  return=  201  avg(last 20)= 184.6
# Episode 2640  return=  204  avg(last 20)= 192.8
# Episode 2660  return=  197  avg(last 20)= 191.8
# Episode 2680  return=  202  avg(last 20)= 198.7
# Episode 2700  return=  211  avg(last 20)= 192.7
# Episode 2720  return=  201  avg(last 20)= 184.2
# Episode 2740  return=  192  avg(last 20)= 200.9
# Episode 2760  return=  201  avg(last 20)= 189.3
# Episode 2780  return=  113  avg(last 20)= 181.9
# Episode 2800  return=  183  avg(last 20)= 193.6
# Episode 2820  return=  197  avg(last 20)= 196.7
# Episode 2840  return=  162  avg(last 20)= 193.6
# Episode 2860  return=  194  avg(last 20)= 191.6
# Episode 2880  return=  211  avg(last 20)= 193.9
# Episode 2900  return=  199  avg(last 20)= 188.6
# Episode 2920  return=  200  avg(last 20)= 193.9
# Episode 2940  return=  198  avg(last 20)= 196.1
# Episode 2960  return=  224  avg(last 20)= 200.4
# Episode 2980  return=  196  avg(last 20)= 192.8
# Saved model_ac_refined_seed1.pt and history_ac_refined_seed1.pkl and time_ac_refined_seed1.pkl

# %%
RUN_SEARCH = True
SEARCH_SEEDS = REFINE_SEEDS          

search_grid = [
    {"actor_lr": 3.5e-5, "normalize_advantage": True},
    {"actor_lr": 2.5e-5, "normalize_advantage": False},
    {"actor_lr": 3.5e-5, "normalize_advantage": False},
]

if RUN_SEARCH:
    for i, override in enumerate(search_grid):
        cfg = {**refined_cfg, **override}
        for seed in SEARCH_SEEDS:
            name = f"ac_search_{i}_seed{seed}"
            print(f"\n=== {name}: {override} ===")
            main(algorithm="actor_critic", n_episodes=3000, seed=seed,
                 run_name=name, save_dir=PREFIX, **cfg)
# Out:
# === ac_search_0_seed42: {'actor_lr': 3.5e-05, 'normalize_advantage': True} ===
# State space: Box(-inf, inf, (11,), float64)
# Action space: Box(-1.0, 1.0, (3,), float32)
# Episode    0  return=    8  avg(last 20)=   7.6
# Episode   20  return=    8  avg(last 20)=   9.0
# Episode   40  return=    7  avg(last 20)=   9.6
# Episode   60  return=   10  avg(last 20)=   8.0
# Episode   80  return=    7  avg(last 20)=  11.7
# Episode  100  return=    9  avg(last 20)=  26.9
# Episode  120  return=   19  avg(last 20)=  65.2
# Episode  140  return=  232  avg(last 20)=  90.2
# Episode  160  return=   19  avg(last 20)= 124.2
# Episode  180  return=  137  avg(last 20)= 119.4
# Episode  200  return=   41  avg(last 20)= 139.0
# Episode  220  return=   40  avg(last 20)= 114.8
# Episode  240  return=  234  avg(last 20)= 132.4
# Episode  260  return=  107  avg(last 20)= 133.7
# Episode  280  return=  200  avg(last 20)= 124.4
# Episode  300  return=   83  avg(last 20)= 142.8
# Episode  320  return=  114  avg(last 20)= 146.7
# Episode  340  return=  114  avg(last 20)= 137.6
# Episode  360  return=  184  avg(last 20)= 164.0
# Episode  380  return=  173  avg(last 20)= 130.9
# Episode  400  return=   72  avg(last 20)= 125.1
# Episode  420  return=  110  avg(last 20)= 161.7
# Episode  440  return=  167  avg(last 20)= 149.2
# Episode  460  return=  228  avg(last 20)= 137.9
# Episode  480  return=  231  avg(last 20)= 146.4
# Episode  500  return=  114  avg(last 20)= 128.3
# Episode  520  return=  163  avg(last 20)= 149.7
# Episode  540  return=   19  avg(last 20)= 142.4
# Episode  560  return=  126  avg(last 20)= 142.6
# Episode  580  return=  196  avg(last 20)= 141.9
# Episode  600  return=  115  avg(last 20)= 159.4
# Episode  620  return=  106  avg(last 20)= 174.6
# Episode  640  return=  327  avg(last 20)= 242.8
# Episode  660  return=  340  avg(last 20)= 275.0
# Episode  680  return=  317  avg(last 20)= 232.5
# Episode  700  return=   85  avg(last 20)= 208.2
# Episode  720  return=  285  avg(last 20)= 283.2
# Episode  740  return=  293  avg(last 20)= 273.8
# Episode  760  return=  178  avg(last 20)= 240.9
# Episode  780  return=   49  avg(last 20)= 238.1
# Episode  800  return=  295  avg(last 20)= 226.0
# Episode  820  return=  154  avg(last 20)= 273.1
# Episode  840  return=  260  avg(last 20)= 280.9
# Episode  860  return=  328  avg(last 20)= 261.7
# Episode  880  return=  256  avg(last 20)= 224.4
# Episode  900  return=  244  avg(last 20)= 264.7
# Episode  920  return=  276  avg(last 20)= 261.6
# Episode  940  return=  267  avg(last 20)= 231.2
# Episode  960  return=  104  avg(last 20)= 222.7
# Episode  980  return=  264  avg(last 20)= 237.4
# Episode 1000  return=  285  avg(last 20)= 263.7
# Episode 1020  return=  259  avg(last 20)= 244.8
# Episode 1040  return=  261  avg(last 20)= 248.3
# Episode 1060  return=  265  avg(last 20)= 243.4
# Episode 1080  return=  284  avg(last 20)= 241.3
# Episode 1100  return=  240  avg(last 20)= 245.8
# Episode 1120  return=  313  avg(last 20)= 278.5
# Episode 1140  return=  269  avg(last 20)= 257.4
# Episode 1160  return=  147  avg(last 20)= 252.5
# Episode 1180  return=  273  avg(last 20)= 262.2
# Episode 1200  return=  318  avg(last 20)= 278.9
# Episode 1220  return=  298  avg(last 20)= 268.6
# Episode 1240  return=  234  avg(last 20)= 268.9
# Episode 1260  return=  245  avg(last 20)= 258.2
# Episode 1280  return=  272  avg(last 20)= 273.3
# Episode 1300  return=  236  avg(last 20)= 249.1
# Episode 1320  return=  264  avg(last 20)= 242.7
# Episode 1340  return=  207  avg(last 20)= 230.5
# Episode 1360  return=  220  avg(last 20)= 204.6
# Episode 1380  return=  222  avg(last 20)= 235.7
# Episode 1400  return=  212  avg(last 20)= 208.5
# Episode 1420  return=  213  avg(last 20)= 221.6
# Episode 1440  return=  229  avg(last 20)= 233.5
# Episode 1460  return=  241  avg(last 20)= 237.5
# Episode 1480  return=  212  avg(last 20)= 248.2
# Episode 1500  return=  234  avg(last 20)= 246.3
# Episode 1520  return=  215  avg(last 20)= 221.5
# Episode 1540  return=  170  avg(last 20)= 198.0
# Episode 1560  return=  183  avg(last 20)= 172.1
# Episode 1580  return=  114  avg(last 20)= 187.0
# Episode 1600  return=  225  avg(last 20)= 211.9
# Episode 1620  return=  230  avg(last 20)= 236.0
# Episode 1640  return=  243  avg(last 20)= 228.4
# Episode 1660  return=  222  avg(last 20)= 229.3
# Episode 1680  return=  255  avg(last 20)= 236.4
# Episode 1700  return=  252  avg(last 20)= 232.5
# Episode 1720  return=  219  avg(last 20)= 227.8
# Episode 1740  return=  226  avg(last 20)= 219.3
# Episode 1760  return=  246  avg(last 20)= 234.5
# Episode 1780  return=  240  avg(last 20)= 240.7
# Episode 1800  return=  221  avg(last 20)= 230.9
# Episode 1820  return=  275  avg(last 20)= 245.2
# Episode 1840  return=  178  avg(last 20)= 227.7
# Episode 1860  return=  221  avg(last 20)= 225.4
# Episode 1880  return=  230  avg(last 20)= 223.9
# Episode 1900  return=  234  avg(last 20)= 219.4
# Episode 1920  return=  249  avg(last 20)= 194.7
# Episode 1940  return=  152  avg(last 20)= 196.3
# Episode 1960  return=  218  avg(last 20)= 201.7
# Episode 1980  return=  234  avg(last 20)= 213.9
# Episode 2000  return=  229  avg(last 20)= 212.6
# Episode 2020  return=  148  avg(last 20)= 210.6
# Episode 2040  return=  194  avg(last 20)= 217.6
# Episode 2060  return=  221  avg(last 20)= 225.5
# Episode 2080  return=  249  avg(last 20)= 231.0
# Episode 2100  return=  228  avg(last 20)= 222.5
# Episode 2120  return=  269  avg(last 20)= 228.1
# Episode 2140  return=  232  avg(last 20)= 232.6
# Episode 2160  return=  223  avg(last 20)= 239.7
# Episode 2180  return=  247  avg(last 20)= 248.8
# Episode 2200  return=  228  avg(last 20)= 239.1
# Episode 2220  return=  207  avg(last 20)= 236.7
# Episode 2240  return=  274  avg(last 20)= 235.3
# Episode 2260  return=  175  avg(last 20)= 227.6
# Episode 2280  return=  218  avg(last 20)= 232.1
# Episode 2300  return=  254  avg(last 20)= 228.8
# Episode 2320  return=  247  avg(last 20)= 235.7
# Episode 2340  return=  302  avg(last 20)= 234.2
# Episode 2360  return=  227  avg(last 20)= 224.0
# Episode 2380  return=  290  avg(last 20)= 228.6
# Episode 2400  return=  218  avg(last 20)= 224.7
# Episode 2420  return=  217  avg(last 20)= 220.9
# Episode 2440  return=  211  avg(last 20)= 216.9
# Episode 2460  return=  273  avg(last 20)= 225.9
# Episode 2480  return=  165  avg(last 20)= 228.1
# Episode 2500  return=  201  avg(last 20)= 236.4
# Episode 2520  return=  325  avg(last 20)= 243.5
# Episode 2540  return=  271  avg(last 20)= 231.5
# Episode 2560  return=  240  avg(last 20)= 242.7
# Episode 2580  return=  351  avg(last 20)= 292.7
# Episode 2600  return=  277  avg(last 20)= 239.9
# Episode 2620  return=  302  avg(last 20)= 287.6
# Episode 2640  return=  290  avg(last 20)= 320.7
# Episode 2660  return=  458  avg(last 20)= 313.4
# Episode 2680  return=  411  avg(last 20)= 261.9
# Episode 2700  return=  191  avg(last 20)= 312.2
# Episode 2720  return=  227  avg(last 20)= 309.3
# Episode 2740  return=   81  avg(last 20)= 218.5
# Episode 2760  return=   47  avg(last 20)= 272.4
# Episode 2780  return=   70  avg(last 20)= 255.0
# Episode 2800  return=  257  avg(last 20)= 253.5
# Episode 2820  return=  529  avg(last 20)= 311.8
# Episode 2840  return=  259  avg(last 20)= 239.3
# Episode 2860  return=  484  avg(last 20)= 236.3
# Episode 2880  return=  262  avg(last 20)= 337.7
# Episode 2900  return=  294  avg(last 20)= 387.1
# Episode 2920  return=  445  avg(last 20)= 406.9
# Episode 2940  return=  612  avg(last 20)= 418.2
# Episode 2960  return=  187  avg(last 20)= 410.3
# Episode 2980  return=  482  avg(last 20)= 444.5
# Saved model_ac_search_0_seed42.pt and history_ac_search_0_seed42.pkl and time_ac_search_0_seed42.pkl
#
# === ac_search_0_seed0: {'actor_lr': 3.5e-05, 'normalize_advantage': True} ===
# State space: Box(-inf, inf, (11,), float64)
# Action space: Box(-1.0, 1.0, (3,), float32)
# Episode    0  return=    7  avg(last 20)=   7.1
# Episode   20  return=    9  avg(last 20)=  10.2
# Episode   40  return=   12  avg(last 20)=   9.9
# Episode   60  return=    9  avg(last 20)=   9.2
# Episode   80  return=    9  avg(last 20)=  11.6
# Episode  100  return=   11  avg(last 20)=  19.6
# Episode  120  return=   16  avg(last 20)=  57.1
# Episode  140  return=  190  avg(last 20)=  63.1
# Episode  160  return=  145  avg(last 20)=  80.7
# Episode  180  return=   12  avg(last 20)=  83.2
# Episode  200  return=   31  avg(last 20)=  86.4
# Episode  220  return=  143  avg(last 20)= 100.7
# Episode  240  return=  164  avg(last 20)= 115.2
# Episode  260  return=   25  avg(last 20)= 121.7
# Episode  280  return=  100  avg(last 20)= 120.0
# Episode  300  return=  107  avg(last 20)= 135.4
# Episode  320  return=  168  avg(last 20)= 129.3
# Episode  340  return=   66  avg(last 20)= 117.8
# Episode  360  return=  211  avg(last 20)= 122.0
# Episode  380  return=  128  avg(last 20)= 113.0
# Episode  400  return=  129  avg(last 20)= 134.8
# Episode  420  return=  110  avg(last 20)= 119.5
# Episode  440  return=   42  avg(last 20)= 132.1
# Episode  460  return=   98  avg(last 20)= 126.2
# Episode  480  return=  103  avg(last 20)= 139.5
# Episode  500  return=   72  avg(last 20)= 134.8
# Episode  520  return=  177  avg(last 20)= 162.0
# Episode  540  return=  107  avg(last 20)= 151.1
# Episode  560  return=  144  avg(last 20)= 133.1
# Episode  580  return=  151  avg(last 20)= 179.3
# Episode  600  return=  111  avg(last 20)= 172.6
# Episode  620  return=   75  avg(last 20)= 181.4
# Episode  640  return=  156  avg(last 20)= 167.8
# Episode  660  return=  176  avg(last 20)= 181.3
# Episode  680  return=  222  avg(last 20)= 187.6
# Episode  700  return=  191  avg(last 20)= 176.1
# Episode  720  return=  185  avg(last 20)= 196.8
# Episode  740  return=  215  avg(last 20)= 184.9
# Episode  760  return=   91  avg(last 20)= 191.3
# Episode  780  return=  262  avg(last 20)= 195.1
# Episode  800  return=  253  avg(last 20)= 204.2
# Episode  820  return=  222  avg(last 20)= 189.2
# Episode  840  return=  208  avg(last 20)= 169.9
# Episode  860  return=  257  avg(last 20)= 197.6
# Episode  880  return=  153  avg(last 20)= 170.3
# Episode  900  return=  231  avg(last 20)= 215.3
# Episode  920  return=  228  avg(last 20)= 218.3
# Episode  940  return=  184  avg(last 20)= 223.2
# Episode  960  return=  302  avg(last 20)= 202.6
# Episode  980  return=  243  avg(last 20)= 199.6
# Episode 1000  return=  144  avg(last 20)= 195.9
# Episode 1020  return=  192  avg(last 20)= 191.3
# Episode 1040  return=  115  avg(last 20)= 209.2
# Episode 1060  return=  232  avg(last 20)= 256.6
# Episode 1080  return=  351  avg(last 20)= 352.5
# Episode 1100  return=   73  avg(last 20)= 289.5
# Episode 1120  return=   38  avg(last 20)= 280.3
# Episode 1140  return=  272  avg(last 20)= 205.1
# Episode 1160  return=  227  avg(last 20)= 279.3
# Episode 1180  return=  356  avg(last 20)= 352.8
# Episode 1200  return=  462  avg(last 20)= 367.2
# Episode 1220  return=   45  avg(last 20)= 291.3
# Episode 1240  return=   75  avg(last 20)= 372.1
# Episode 1260  return=   72  avg(last 20)= 386.3
# Episode 1280  return=   62  avg(last 20)= 273.1
# Episode 1300  return=  375  avg(last 20)= 384.0
# Episode 1320  return=  124  avg(last 20)= 308.3
# Episode 1340  return=  282  avg(last 20)= 263.3
# Episode 1360  return=  564  avg(last 20)= 429.4
# Episode 1380  return= 1056  avg(last 20)= 576.3
# Episode 1400  return=  476  avg(last 20)= 441.1
# Episode 1420  return=  109  avg(last 20)= 518.5
# Episode 1440  return=  374  avg(last 20)= 515.4
# Episode 1460  return=  849  avg(last 20)= 455.3
# Episode 1480  return=  655  avg(last 20)= 514.7
# Episode 1500  return=  555  avg(last 20)= 497.5
# Episode 1520  return=  658  avg(last 20)= 506.8
# Episode 1540  return=  232  avg(last 20)= 556.8
# Episode 1560  return=  750  avg(last 20)= 500.8
# Episode 1580  return=  670  avg(last 20)= 554.5
# Episode 1600  return=  491  avg(last 20)= 508.8
# Episode 1620  return=  460  avg(last 20)= 496.9
# Episode 1640  return=  448  avg(last 20)= 414.3
# Episode 1660  return=  452  avg(last 20)= 373.3
# Episode 1680  return=  477  avg(last 20)= 409.8
# Episode 1700  return=  479  avg(last 20)= 427.4
# Episode 1720  return=  522  avg(last 20)= 463.4
# Episode 1740  return=  507  avg(last 20)= 483.7
# Episode 1760  return=  348  avg(last 20)= 469.9
# Episode 1780  return=   77  avg(last 20)= 406.0
# Episode 1800  return=  241  avg(last 20)= 438.1
# Episode 1820  return=  155  avg(last 20)= 447.3
# Episode 1840  return=  607  avg(last 20)= 379.2
# Episode 1860  return=  230  avg(last 20)= 356.6
# Episode 1880  return=  385  avg(last 20)= 387.2
# Episode 1900  return=  697  avg(last 20)= 487.5
# Episode 1920  return=  724  avg(last 20)= 577.5
# Episode 1940  return=  564  avg(last 20)= 533.1
# Episode 1960  return=  564  avg(last 20)= 460.6
# Episode 1980  return=  437  avg(last 20)= 378.8
# Episode 2000  return=  460  avg(last 20)= 417.4
# Episode 2020  return=  449  avg(last 20)= 474.8
# Episode 2040  return=  388  avg(last 20)= 426.6
# Episode 2060  return=  378  avg(last 20)= 373.6
# Episode 2080  return=  402  avg(last 20)= 389.4
# Episode 2100  return=  283  avg(last 20)= 397.3
# Episode 2120  return=  224  avg(last 20)= 313.8
# Episode 2140  return=  287  avg(last 20)= 261.2
# Episode 2160  return=  184  avg(last 20)= 242.8
# Episode 2180  return=  218  avg(last 20)= 261.0
# Episode 2200  return=  246  avg(last 20)= 324.6
# Episode 2220  return=  437  avg(last 20)= 375.6
# Episode 2240  return=  882  avg(last 20)= 533.2
# Episode 2260  return=  542  avg(last 20)= 620.3
# Episode 2280  return=  243  avg(last 20)= 710.8
# Episode 2300  return= 1009  avg(last 20)= 811.1
# Episode 2320  return= 1063  avg(last 20)= 764.9
# Episode 2340  return= 1024  avg(last 20)= 871.2
# Episode 2360  return=  293  avg(last 20)= 995.7
# Episode 2380  return= 1029  avg(last 20)= 952.2
# Episode 2400  return= 1016  avg(last 20)=1020.0
# Episode 2420  return= 1014  avg(last 20)= 998.9
# Episode 2440  return=  796  avg(last 20)= 984.2
# Episode 2460  return=  614  avg(last 20)= 710.0
# Episode 2480  return=  640  avg(last 20)= 599.0
# Episode 2500  return=  917  avg(last 20)= 772.1
# Episode 2520  return=  675  avg(last 20)= 722.8
# Episode 2540  return=  353  avg(last 20)= 539.1
# Episode 2560  return=  301  avg(last 20)= 358.5
# Episode 2580  return=  309  avg(last 20)= 403.0
# Episode 2600  return=  286  avg(last 20)= 372.7
# Episode 2620  return=  652  avg(last 20)= 421.6
# Episode 2640  return=  689  avg(last 20)= 451.0
# Episode 2660  return= 1180  avg(last 20)= 730.1
# Episode 2680  return=  924  avg(last 20)= 848.0
# Episode 2700  return=  138  avg(last 20)= 444.1
# Episode 2720  return=  986  avg(last 20)= 745.8
# Episode 2740  return=  645  avg(last 20)= 607.1
# Episode 2760  return=  596  avg(last 20)= 726.3
# Episode 2780  return=  862  avg(last 20)= 935.3
# Episode 2800  return= 1020  avg(last 20)= 994.2
# Episode 2820  return=  993  avg(last 20)= 969.4
# Episode 2840  return= 1014  avg(last 20)=1000.8
# Episode 2860  return=  773  avg(last 20)= 973.4
# Episode 2880  return=  815  avg(last 20)= 849.0
# Episode 2900  return= 1012  avg(last 20)= 931.8
# Episode 2920  return= 1013  avg(last 20)= 992.0
# Episode 2940  return=  660  avg(last 20)= 983.6
# Episode 2960  return= 1004  avg(last 20)=1008.6
# Episode 2980  return= 1010  avg(last 20)=1007.4
# Saved model_ac_search_0_seed0.pt and history_ac_search_0_seed0.pkl and time_ac_search_0_seed0.pkl
#
# === ac_search_0_seed1: {'actor_lr': 3.5e-05, 'normalize_advantage': True} ===
# State space: Box(-inf, inf, (11,), float64)
# Action space: Box(-1.0, 1.0, (3,), float32)
# Episode    0  return=    8  avg(last 20)=   7.8
# Episode   20  return=   18  avg(last 20)=  18.8
# Episode   40  return=   15  avg(last 20)=  12.4
# Episode   60  return=    8  avg(last 20)=  12.7
# Episode   80  return=    9  avg(last 20)=  12.8
# Episode  100  return=   17  avg(last 20)=  16.3
# Episode  120  return=  244  avg(last 20)=  58.4
# Episode  140  return=   48  avg(last 20)= 111.0
# Episode  160  return=   29  avg(last 20)=  93.4
# Episode  180  return=  162  avg(last 20)= 139.0
# Episode  200  return=  112  avg(last 20)= 105.4
# Episode  220  return=  140  avg(last 20)= 147.3
# Episode  240  return=  186  avg(last 20)= 143.9
# Episode  260  return=  247  avg(last 20)= 152.3
# Episode  280  return=  175  avg(last 20)= 153.7
# Episode  300  return=  141  avg(last 20)= 149.7
# Episode  320  return=  162  avg(last 20)= 124.4
# Episode  340  return=   48  avg(last 20)= 137.8
# Episode  360  return=  124  avg(last 20)= 125.7
# Episode  380  return=  226  avg(last 20)= 140.5
# Episode  400  return=  225  avg(last 20)= 163.6
# Episode  420  return=  188  avg(last 20)= 141.4
# Episode  440  return=  126  avg(last 20)= 143.8
# Episode  460  return=  112  avg(last 20)= 165.3
# Episode  480  return=  164  avg(last 20)= 192.3
# Episode  500  return=  225  avg(last 20)= 178.8
# Episode  520  return=  232  avg(last 20)= 183.4
# Episode  540  return=  143  avg(last 20)= 167.6
# Episode  560  return=   64  avg(last 20)= 193.2
# Episode  580  return=  231  avg(last 20)= 195.7
# Episode  600  return=  225  avg(last 20)= 209.4
# Episode  620  return=  254  avg(last 20)= 211.3
# Episode  640  return=  176  avg(last 20)= 210.9
# Episode  660  return=  272  avg(last 20)= 227.0
# Episode  680  return=  225  avg(last 20)= 213.8
# Episode  700  return=  195  avg(last 20)= 234.7
# Episode  720  return=  258  avg(last 20)= 222.7
# Episode  740  return=  243  avg(last 20)= 218.3
# Episode  760  return=  191  avg(last 20)= 220.0
# Episode  780  return=  110  avg(last 20)= 182.1
# Episode  800  return=  264  avg(last 20)= 225.5
# Episode  820  return=  233  avg(last 20)= 239.5
# Episode  840  return=  124  avg(last 20)= 244.4
# Episode  860  return=  234  avg(last 20)= 263.0
# Episode  880  return=  244  avg(last 20)= 243.0
# Episode  900  return=  269  avg(last 20)= 238.6
# Episode  920  return=  243  avg(last 20)= 258.5
# Episode  940  return=  273  avg(last 20)= 229.5
# Episode  960  return=  250  avg(last 20)= 237.8
# Episode  980  return=  133  avg(last 20)= 284.5
# Episode 1000  return=  294  avg(last 20)= 283.8
# Episode 1020  return=  315  avg(last 20)= 260.0
# Episode 1040  return=  207  avg(last 20)= 223.0
# Episode 1060  return=  319  avg(last 20)= 245.3
# Episode 1080  return=  282  avg(last 20)= 248.1
# Episode 1100  return=  297  avg(last 20)= 249.2
# Episode 1120  return=   49  avg(last 20)= 240.9
# Episode 1140  return=  176  avg(last 20)= 256.0
# Episode 1160  return=  256  avg(last 20)= 242.9
# Episode 1180  return=  271  avg(last 20)= 233.7
# Episode 1200  return=  249  avg(last 20)= 241.2
# Episode 1220  return=  252  avg(last 20)= 228.2
# Episode 1240  return=  110  avg(last 20)= 227.8
# Episode 1260  return=  213  avg(last 20)= 245.7
# Episode 1280  return=  277  avg(last 20)= 241.6
# Episode 1300  return=  221  avg(last 20)= 225.5
# Episode 1320  return=  241  avg(last 20)= 222.5
# Episode 1340  return=  253  avg(last 20)= 217.0
# Episode 1360  return=  222  avg(last 20)= 208.6
# Episode 1380  return=   35  avg(last 20)= 203.0
# Episode 1400  return=  201  avg(last 20)= 210.4
# Episode 1420  return=  235  avg(last 20)= 209.3
# Episode 1440  return=  231  avg(last 20)= 226.4
# Episode 1460  return=  232  avg(last 20)= 222.0
# Episode 1480  return=  213  avg(last 20)= 239.4
# Episode 1500  return=  230  avg(last 20)= 244.6
# Episode 1520  return=  242  avg(last 20)= 246.6
# Episode 1540  return=  272  avg(last 20)= 229.4
# Episode 1560  return=  301  avg(last 20)= 262.1
# Episode 1580  return=  203  avg(last 20)= 253.5
# Episode 1600  return=  264  avg(last 20)= 281.3
# Episode 1620  return=  308  avg(last 20)= 253.3
# Episode 1640  return=  218  avg(last 20)= 259.8
# Episode 1660  return=  307  avg(last 20)= 275.2
# Episode 1680  return=  321  avg(last 20)= 261.9
# Episode 1700  return=  394  avg(last 20)= 288.3
# Episode 1720  return=  301  avg(last 20)= 262.6
# Episode 1740  return=  304  avg(last 20)= 237.9
# Episode 1760  return=  220  avg(last 20)= 272.4
# Episode 1780  return=   38  avg(last 20)= 256.5
# Episode 1800  return=  323  avg(last 20)= 297.3
# Episode 1820  return=  205  avg(last 20)= 279.2
# Episode 1840  return=  330  avg(last 20)= 271.4
# Episode 1860  return=  386  avg(last 20)= 276.4
# Episode 1880  return=  290  avg(last 20)= 305.2
# Episode 1900  return=  225  avg(last 20)= 250.3
# Episode 1920  return=  340  avg(last 20)= 249.3
# Episode 1940  return=   84  avg(last 20)= 313.7
# Episode 1960  return=  271  avg(last 20)= 290.1
# Episode 1980  return=  366  avg(last 20)= 308.6
# Episode 2000  return=  483  avg(last 20)= 332.1
# Episode 2020  return=  129  avg(last 20)= 234.4
# Episode 2040  return=   94  avg(last 20)= 215.2
# Episode 2060  return=  237  avg(last 20)= 140.1
# Episode 2080  return=  284  avg(last 20)= 189.1
# Episode 2100  return=   61  avg(last 20)= 191.8
# Episode 2120  return=  297  avg(last 20)= 269.9
# Episode 2140  return=  312  avg(last 20)= 330.2
# Episode 2160  return=  467  avg(last 20)= 429.5
# Episode 2180  return=  417  avg(last 20)= 386.0
# Episode 2200  return=  544  avg(last 20)= 376.1
# Episode 2220  return=  440  avg(last 20)= 402.1
# Episode 2240  return=  241  avg(last 20)= 359.3
# Episode 2260  return=  385  avg(last 20)= 350.9
# Episode 2280  return=  355  avg(last 20)= 345.9
# Episode 2300  return=  394  avg(last 20)= 334.8
# Episode 2320  return=  404  avg(last 20)= 401.1
# Episode 2340  return=  372  avg(last 20)= 368.7
# Episode 2360  return=  395  avg(last 20)= 330.3
# Episode 2380  return=  252  avg(last 20)= 393.3
# Episode 2400  return=  115  avg(last 20)= 372.7
# Episode 2420  return=  456  avg(last 20)= 358.6
# Episode 2440  return=  259  avg(last 20)= 426.3
# Episode 2460  return=  112  avg(last 20)= 231.4
# Episode 2480  return=  415  avg(last 20)= 423.8
# Episode 2500  return=  414  avg(last 20)= 407.7
# Episode 2520  return=  364  avg(last 20)= 372.9
# Episode 2540  return=  317  avg(last 20)= 354.5
# Episode 2560  return=  481  avg(last 20)= 386.6
# Episode 2580  return=  133  avg(last 20)= 473.8
# Episode 2600  return=  538  avg(last 20)= 488.9
# Episode 2620  return=  648  avg(last 20)= 460.4
# Episode 2640  return=  465  avg(last 20)= 438.7
# Episode 2660  return=  636  avg(last 20)= 379.5
# Episode 2680  return=  190  avg(last 20)= 313.1
# Episode 2700  return=  350  avg(last 20)= 291.3
# Episode 2720  return=  325  avg(last 20)= 378.1
# Episode 2740  return=  299  avg(last 20)= 388.4
# Episode 2760  return=  647  avg(last 20)= 552.8
# Episode 2780  return=  196  avg(last 20)= 590.4
# Episode 2800  return=  595  avg(last 20)= 655.0
# Episode 2820  return=  538  avg(last 20)= 415.5
# Episode 2840  return=  525  avg(last 20)= 471.8
# Episode 2860  return=  321  avg(last 20)= 487.1
# Episode 2880  return=  656  avg(last 20)= 558.0
# Episode 2900  return=  631  avg(last 20)= 623.4
# Episode 2920  return= 1118  avg(last 20)= 857.6
# Episode 2940  return=  325  avg(last 20)= 734.0
# Episode 2960  return=  314  avg(last 20)= 464.9
# Episode 2980  return=  284  avg(last 20)= 384.9
# Saved model_ac_search_0_seed1.pt and history_ac_search_0_seed1.pkl and time_ac_search_0_seed1.pkl
#
# === ac_search_1_seed42: {'actor_lr': 2.5e-05, 'normalize_advantage': False} ===
# State space: Box(-inf, inf, (11,), float64)
# Action space: Box(-1.0, 1.0, (3,), float32)
# Episode    0  return=    8  avg(last 20)=   7.6
# Episode   20  return=   11  avg(last 20)=  10.5
# Episode   40  return=    6  avg(last 20)=   8.4
# Episode   60  return=    9  avg(last 20)=   9.0
# Episode   80  return=   15  avg(last 20)=  11.5
# Episode  100  return=   16  avg(last 20)=  18.0
# Episode  120  return=   22  avg(last 20)=  32.4
# Episode  140  return=   11  avg(last 20)=  49.9
# Episode  160  return=  140  avg(last 20)=  75.5
# Episode  180  return=  119  avg(last 20)= 144.3
# Episode  200  return=  112  avg(last 20)= 131.3
# Episode  220  return=  191  avg(last 20)= 138.8
# Episode  240  return=  142  avg(last 20)= 151.3
# Episode  260  return=  231  avg(last 20)= 176.3
# Episode  280  return=  220  avg(last 20)= 154.7
# Episode  300  return=  238  avg(last 20)= 151.2
# Episode  320  return=  262  avg(last 20)= 164.4
# Episode  340  return=  138  avg(last 20)= 156.3
# Episode  360  return=   90  avg(last 20)= 171.9
# Episode  380  return=  111  avg(last 20)= 178.1
# Episode  400  return=  279  avg(last 20)= 203.8
# Episode  420  return=   72  avg(last 20)= 193.9
# Episode  440  return=  276  avg(last 20)= 232.1
# Episode  460  return=  328  avg(last 20)= 247.3
# Episode  480  return=  258  avg(last 20)= 230.1
# Episode  500  return=  138  avg(last 20)= 212.9
# Episode  520  return=  306  avg(last 20)= 226.4
# Episode  540  return=  258  avg(last 20)= 202.3
# Episode  560  return=  262  avg(last 20)= 246.4
# Episode  580  return=  262  avg(last 20)= 226.0
# Episode  600  return=  237  avg(last 20)= 193.9
# Episode  620  return=  249  avg(last 20)= 206.4
# Episode  640  return=  240  avg(last 20)= 221.2
# Episode  660  return=  227  avg(last 20)= 216.1
# Episode  680  return=  237  avg(last 20)= 218.1
# Episode  700  return=  246  avg(last 20)= 210.5
# Episode  720  return=  171  avg(last 20)= 182.3
# Episode  740  return=  236  avg(last 20)= 213.8
# Episode  760  return=  222  avg(last 20)= 219.5
# Episode  780  return=  196  avg(last 20)= 227.4
# Episode  800  return=  145  avg(last 20)= 206.7
# Episode  820  return=  245  avg(last 20)= 207.2
# Episode  840  return=  241  avg(last 20)= 199.1
# Episode  860  return=  248  avg(last 20)= 230.2
# Episode  880  return=  248  avg(last 20)= 238.4
# Episode  900  return=  230  avg(last 20)= 253.7
# Episode  920  return=  118  avg(last 20)= 216.1
# Episode  940  return=  213  avg(last 20)= 210.6
# Episode  960  return=  205  avg(last 20)= 218.6
# Episode  980  return=  180  avg(last 20)= 219.9
# Episode 1000  return=  225  avg(last 20)= 218.9
# Episode 1020  return=  197  avg(last 20)= 221.0
# Episode 1040  return=  159  avg(last 20)= 208.8
# Episode 1060  return=  152  avg(last 20)= 181.6
# Episode 1080  return=  225  avg(last 20)= 188.2
# Episode 1100  return=  170  avg(last 20)= 203.2
# Episode 1120  return=   67  avg(last 20)= 220.3
# Episode 1140  return=  223  avg(last 20)= 204.8
# Episode 1160  return=  240  avg(last 20)= 218.9
# Episode 1180  return=  235  avg(last 20)= 215.9
# Episode 1200  return=  238  avg(last 20)= 202.4
# Episode 1220  return=  238  avg(last 20)= 215.4
# Episode 1240  return=  219  avg(last 20)= 203.1
# Episode 1260  return=  211  avg(last 20)= 211.5
# Episode 1280  return=  204  avg(last 20)= 203.9
# Episode 1300  return=  205  avg(last 20)= 204.6
# Episode 1320  return=  212  avg(last 20)= 213.1
# Episode 1340  return=  206  avg(last 20)= 196.6
# Episode 1360  return=  215  avg(last 20)= 203.9
# Episode 1380  return=  211  avg(last 20)= 200.5
# Episode 1400  return=  210  avg(last 20)= 208.2
# Episode 1420  return=  206  avg(last 20)= 172.3
# Episode 1440  return=   63  avg(last 20)= 170.0
# Episode 1460  return=  214  avg(last 20)= 176.9
# Episode 1480  return=  204  avg(last 20)= 196.7
# Episode 1500  return=  207  avg(last 20)= 201.8
# Episode 1520  return=  196  avg(last 20)= 196.1
# Episode 1540  return=  200  avg(last 20)= 191.4
# Episode 1560  return=  203  avg(last 20)= 209.0
# Episode 1580  return=  211  avg(last 20)= 203.3
# Episode 1600  return=  208  avg(last 20)= 194.1
# Episode 1620  return=   93  avg(last 20)= 200.2
# Episode 1640  return=  205  avg(last 20)= 205.5
# Episode 1660  return=  212  avg(last 20)= 185.2
# Episode 1680  return=  194  avg(last 20)= 202.3
# Episode 1700  return=  205  avg(last 20)= 183.3
# Episode 1720  return=  206  avg(last 20)= 202.2
# Episode 1740  return=  204  avg(last 20)= 196.6
# Episode 1760  return=  199  avg(last 20)= 187.6
# Episode 1780  return=  204  avg(last 20)= 185.9
# Episode 1800  return=  208  avg(last 20)= 171.1
# Episode 1820  return=  217  avg(last 20)= 190.4
# Episode 1840  return=   42  avg(last 20)= 193.4
# Episode 1860  return=  198  avg(last 20)= 199.3
# Episode 1880  return=  200  avg(last 20)= 182.4
# Episode 1900  return=  203  avg(last 20)= 196.6
# Episode 1920  return=  186  avg(last 20)= 198.9
# Episode 1940  return=  203  avg(last 20)= 198.5
# Episode 1960  return=  192  avg(last 20)= 188.6
# Episode 1980  return=   91  avg(last 20)= 169.8
# Episode 2000  return=  196  avg(last 20)= 177.1
# Episode 2020  return=  200  avg(last 20)= 191.1
# Episode 2040  return=  180  avg(last 20)= 188.0
# Episode 2060  return=  191  avg(last 20)= 190.1
# Episode 2080  return=  149  avg(last 20)= 139.1
# Episode 2100  return=  175  avg(last 20)= 180.0
# Episode 2120  return=  212  avg(last 20)= 182.4
# Episode 2140  return=  195  avg(last 20)= 191.7
# Episode 2160  return=  189  avg(last 20)= 184.1
# Episode 2180  return=  187  avg(last 20)= 181.7
# Episode 2200  return=  196  avg(last 20)= 161.2
# Episode 2220  return=  194  avg(last 20)= 177.0
# Episode 2240  return=  197  avg(last 20)= 193.9
# Episode 2260  return=  192  avg(last 20)= 193.5
# Episode 2280  return=  186  avg(last 20)= 185.4
# Episode 2300  return=  199  avg(last 20)= 178.6
# Episode 2320  return=  194  avg(last 20)= 195.4
# Episode 2340  return=  195  avg(last 20)= 195.3
# Episode 2360  return=  203  avg(last 20)= 192.8
# Episode 2380  return=  188  avg(last 20)= 192.9
# Episode 2400  return=  206  avg(last 20)= 192.9
# Episode 2420  return=  192  avg(last 20)= 191.0
# Episode 2440  return=  192  avg(last 20)= 190.8
# Episode 2460  return=  185  avg(last 20)= 188.5
# Episode 2480  return=  188  avg(last 20)= 171.4
# Episode 2500  return=  182  avg(last 20)= 188.9
# Episode 2520  return=  183  avg(last 20)= 190.5
# Episode 2540  return=  196  avg(last 20)= 192.1
# Episode 2560  return=  189  avg(last 20)= 192.1
# Episode 2580  return=  190  avg(last 20)= 177.9
# Episode 2600  return=   48  avg(last 20)= 171.1
# Episode 2620  return=  205  avg(last 20)= 181.1
# Episode 2640  return=  186  avg(last 20)= 182.9
# Episode 2660  return=  196  avg(last 20)= 185.9
# Episode 2680  return=  170  avg(last 20)= 172.0
# Episode 2700  return=  186  avg(last 20)= 174.4
# Episode 2720  return=  130  avg(last 20)= 156.3
# Episode 2740  return=  160  avg(last 20)= 145.4
# Episode 2760  return=  177  avg(last 20)= 134.8
# Episode 2780  return=  124  avg(last 20)= 111.7
# Episode 2800  return=  131  avg(last 20)= 147.1
# Episode 2820  return=  175  avg(last 20)= 160.9
# Episode 2840  return=  146  avg(last 20)= 164.7
# Episode 2860  return=  176  avg(last 20)= 172.3
# Episode 2880  return=  151  avg(last 20)= 183.0
# Episode 2900  return=  192  avg(last 20)= 184.9
# Episode 2920  return=  180  avg(last 20)= 174.7
# Episode 2940  return=  178  avg(last 20)= 186.4
# Episode 2960  return=  176  avg(last 20)= 179.7
# Episode 2980  return=  190  avg(last 20)= 184.5
# Saved model_ac_search_1_seed42.pt and history_ac_search_1_seed42.pkl and time_ac_search_1_seed42.pkl
#
# === ac_search_1_seed0: {'actor_lr': 2.5e-05, 'normalize_advantage': False} ===
# State space: Box(-inf, inf, (11,), float64)
# Action space: Box(-1.0, 1.0, (3,), float32)
# Episode    0  return=    7  avg(last 20)=   7.1
# Episode   20  return=   13  avg(last 20)=  10.6
# Episode   40  return=    9  avg(last 20)=  10.9
# Episode   60  return=    6  avg(last 20)=   9.0
# Episode   80  return=    9  avg(last 20)=  11.8
# Episode  100  return=   29  avg(last 20)=  16.7
# Episode  120  return=   12  avg(last 20)=  55.8
# Episode  140  return=   28  avg(last 20)=  69.0
# Episode  160  return=   99  avg(last 20)=  87.3
# Episode  180  return=   80  avg(last 20)= 122.4
# Episode  200  return=   68  avg(last 20)= 105.2
# Episode  220  return=   93  avg(last 20)= 124.0
# Episode  240  return=   42  avg(last 20)= 129.4
# Episode  260  return=  108  avg(last 20)= 145.8
# Episode  280  return=   17  avg(last 20)= 123.8
# Episode  300  return=  205  avg(last 20)= 143.9
# Episode  320  return=   12  avg(last 20)= 128.8
# Episode  340  return=   69  avg(last 20)= 114.4
# Episode  360  return=   90  avg(last 20)= 117.3
# Episode  380  return=   93  avg(last 20)= 135.5
# Episode  400  return=  170  avg(last 20)= 143.4
# Episode  420  return=  224  avg(last 20)= 144.7
# Episode  440  return=  103  avg(last 20)= 112.8
# Episode  460  return=  151  avg(last 20)= 151.5
# Episode  480  return=  232  avg(last 20)= 135.9
# Episode  500  return=  157  avg(last 20)= 152.1
# Episode  520  return=  103  avg(last 20)= 125.5
# Episode  540  return=  179  avg(last 20)= 127.9
# Episode  560  return=   90  avg(last 20)= 127.2
# Episode  580  return=   82  avg(last 20)= 133.0
# Episode  600  return=   68  avg(last 20)= 141.2
# Episode  620  return=  158  avg(last 20)= 133.2
# Episode  640  return=   51  avg(last 20)= 114.7
# Episode  660  return=   57  avg(last 20)= 135.6
# Episode  680  return=  100  avg(last 20)= 120.6
# Episode  700  return=  188  avg(last 20)= 136.6
# Episode  720  return=  210  avg(last 20)= 159.2
# Episode  740  return=  193  avg(last 20)= 150.4
# Episode  760  return=  181  avg(last 20)= 153.4
# Episode  780  return=  208  avg(last 20)= 165.1
# Episode  800  return=  192  avg(last 20)= 185.1
# Episode  820  return=  140  avg(last 20)= 157.8
# Episode  840  return=  216  avg(last 20)= 184.7
# Episode  860  return=  204  avg(last 20)= 189.3
# Episode  880  return=  193  avg(last 20)= 189.3
# Episode  900  return=  194  avg(last 20)= 184.4
# Episode  920  return=  169  avg(last 20)= 177.4
# Episode  940  return=  199  avg(last 20)= 188.7
# Episode  960  return=  215  avg(last 20)= 173.1
# Episode  980  return=   55  avg(last 20)= 165.6
# Episode 1000  return=  212  avg(last 20)= 182.5
# Episode 1020  return=  187  avg(last 20)= 171.2
# Episode 1040  return=  191  avg(last 20)= 183.5
# Episode 1060  return=  208  avg(last 20)= 190.2
# Episode 1080  return=  212  avg(last 20)= 176.2
# Episode 1100  return=  193  avg(last 20)= 173.7
# Episode 1120  return=  189  avg(last 20)= 160.5
# Episode 1140  return=  191  avg(last 20)= 153.3
# Episode 1160  return=  199  avg(last 20)= 172.3
# Episode 1180  return=  167  avg(last 20)= 170.1
# Episode 1200  return=  142  avg(last 20)= 151.9
# Episode 1220  return=  137  avg(last 20)= 143.6
# Episode 1240  return=  182  avg(last 20)= 167.5
# Episode 1260  return=  194  avg(last 20)= 183.6
# Episode 1280  return=  187  avg(last 20)= 169.5
# Episode 1300  return=  192  avg(last 20)= 186.0
# Episode 1320  return=  175  avg(last 20)= 184.8
# Episode 1340  return=  175  avg(last 20)= 180.9
# Episode 1360  return=  110  avg(last 20)= 157.2
# Episode 1380  return=   55  avg(last 20)= 132.1
# Episode 1400  return=   53  avg(last 20)= 125.4
# Episode 1420  return=   84  avg(last 20)= 132.8
# Episode 1440  return=  150  avg(last 20)= 137.8
# Episode 1460  return=  103  avg(last 20)= 144.0
# Episode 1480  return=   66  avg(last 20)= 120.7
# Episode 1500  return=  204  avg(last 20)= 150.0
# Episode 1520  return=  187  avg(last 20)= 170.8
# Episode 1540  return=  170  avg(last 20)= 181.1
# Episode 1560  return=   99  avg(last 20)= 163.6
# Episode 1580  return=   96  avg(last 20)= 121.1
# Episode 1600  return=  172  avg(last 20)= 127.3
# Episode 1620  return=  175  avg(last 20)= 172.1
# Episode 1640  return=  181  avg(last 20)= 169.7
# Episode 1660  return=   98  avg(last 20)= 146.0
# Episode 1680  return=  176  avg(last 20)= 148.9
# Episode 1700  return=  163  avg(last 20)= 135.4
# Episode 1720  return=   91  avg(last 20)= 120.5
# Episode 1740  return=  124  avg(last 20)= 142.8
# Episode 1760  return=  187  avg(last 20)= 156.8
# Episode 1780  return=  173  avg(last 20)= 178.9
# Episode 1800  return=  177  avg(last 20)= 181.5
# Episode 1820  return=  168  avg(last 20)= 175.5
# Episode 1840  return=  164  avg(last 20)= 174.0
# Episode 1860  return=  178  avg(last 20)= 172.3
# Episode 1880  return=  180  avg(last 20)= 183.9
# Episode 1900  return=  204  avg(last 20)= 185.8
# Episode 1920  return=  204  avg(last 20)= 196.8
# Episode 1940  return=  186  avg(last 20)= 194.7
# Episode 1960  return=  187  avg(last 20)= 191.2
# Episode 1980  return=  198  avg(last 20)= 189.9
# Episode 2000  return=  190  avg(last 20)= 191.7
# Episode 2020  return=  197  avg(last 20)= 192.2
# Episode 2040  return=  203  avg(last 20)= 201.0
# Episode 2060  return=  205  avg(last 20)= 194.0
# Episode 2080  return=  186  avg(last 20)= 200.3
# Episode 2100  return=  204  avg(last 20)= 202.2
# Episode 2120  return=  205  avg(last 20)= 207.4
# Episode 2140  return=  221  avg(last 20)= 210.9
# Episode 2160  return=  195  avg(last 20)= 209.8
# Episode 2180  return=  210  avg(last 20)= 209.2
# Episode 2200  return=  203  avg(last 20)= 204.2
# Episode 2220  return=  204  avg(last 20)= 207.9
# Episode 2240  return=  212  avg(last 20)= 210.2
# Episode 2260  return=  216  avg(last 20)= 204.8
# Episode 2280  return=  113  avg(last 20)= 202.9
# Episode 2300  return=  203  avg(last 20)= 205.3
# Episode 2320  return=  221  avg(last 20)= 207.6
# Episode 2340  return=  213  avg(last 20)= 199.6
# Episode 2360  return=  214  avg(last 20)= 187.7
# Episode 2380  return=  156  avg(last 20)= 187.5
# Episode 2400  return=  206  avg(last 20)= 200.5
# Episode 2420  return=  213  avg(last 20)= 200.4
# Episode 2440  return=  202  avg(last 20)= 201.9
# Episode 2460  return=  208  avg(last 20)= 200.9
# Episode 2480  return=  216  avg(last 20)= 199.4
# Episode 2500  return=  124  avg(last 20)= 201.3
# Episode 2520  return=  221  avg(last 20)= 205.6
# Episode 2540  return=  214  avg(last 20)= 210.0
# Episode 2560  return=  213  avg(last 20)= 208.1
# Episode 2580  return=  210  avg(last 20)= 208.4
# Episode 2600  return=  202  avg(last 20)= 199.4
# Episode 2620  return=  126  avg(last 20)= 174.8
# Episode 2640  return=  198  avg(last 20)= 185.1
# Episode 2660  return=  214  avg(last 20)= 199.9
# Episode 2680  return=  218  avg(last 20)= 211.1
# Episode 2700  return=  212  avg(last 20)= 212.5
# Episode 2720  return=  215  avg(last 20)= 214.9
# Episode 2740  return=  211  avg(last 20)= 211.0
# Episode 2760  return=  208  avg(last 20)= 211.0
# Episode 2780  return=  222  avg(last 20)= 201.4
# Episode 2800  return=  214  avg(last 20)= 201.7
# Episode 2820  return=  215  avg(last 20)= 219.3
# Episode 2840  return=  220  avg(last 20)= 218.1
# Episode 2860  return=  214  avg(last 20)= 214.5
# Episode 2880  return=  210  avg(last 20)= 211.7
# Episode 2900  return=  191  avg(last 20)= 208.7
# Episode 2920  return=  215  avg(last 20)= 213.2
# Episode 2940  return=  206  avg(last 20)= 215.3
# Episode 2960  return=  214  avg(last 20)= 216.5
# Episode 2980  return=  216  avg(last 20)= 215.1
# Saved model_ac_search_1_seed0.pt and history_ac_search_1_seed0.pkl and time_ac_search_1_seed0.pkl
#
# === ac_search_1_seed1: {'actor_lr': 2.5e-05, 'normalize_advantage': False} ===
# State space: Box(-inf, inf, (11,), float64)
# Action space: Box(-1.0, 1.0, (3,), float32)
# Episode    0  return=    8  avg(last 20)=   7.8
# Episode   20  return=   27  avg(last 20)=  21.1
# Episode   40  return=    9  avg(last 20)=  14.7
# Episode   60  return=    6  avg(last 20)=  12.1
# Episode   80  return=    9  avg(last 20)=  10.5
# Episode  100  return=   10  avg(last 20)=  10.6
# Episode  120  return=   43  avg(last 20)=  16.9
# Episode  140  return=  175  avg(last 20)=  54.6
# Episode  160  return=   34  avg(last 20)=  66.2
# Episode  180  return=   71  avg(last 20)=  86.4
# Episode  200  return=   50  avg(last 20)= 125.9
# Episode  220  return=   85  avg(last 20)= 123.7
# Episode  240  return=   96  avg(last 20)= 136.8
# Episode  260  return=  224  avg(last 20)= 134.9
# Episode  280  return=  237  avg(last 20)= 146.5
# Episode  300  return=  187  avg(last 20)= 135.7
# Episode  320  return=  264  avg(last 20)= 155.5
# Episode  340  return=  166  avg(last 20)= 157.2
# Episode  360  return=  250  avg(last 20)= 175.5
# Episode  380  return=  222  avg(last 20)= 150.4
# Episode  400  return=  228  avg(last 20)= 174.9
# Episode  420  return=  124  avg(last 20)= 179.5
# Episode  440  return=   92  avg(last 20)= 159.9
# Episode  460  return=  211  avg(last 20)= 151.8
# Episode  480  return=  146  avg(last 20)= 146.3
# Episode  500  return=  162  avg(last 20)= 143.8
# Episode  520  return=  124  avg(last 20)= 160.6
# Episode  540  return=  102  avg(last 20)= 174.3
# Episode  560  return=  113  avg(last 20)= 154.2
# Episode  580  return=  193  avg(last 20)= 164.9
# Episode  600  return=  244  avg(last 20)= 166.8
# Episode  620  return=  140  avg(last 20)= 177.7
# Episode  640  return=  209  avg(last 20)= 169.9
# Episode  660  return=  187  avg(last 20)= 161.4
# Episode  680  return=  172  avg(last 20)= 174.0
# Episode  700  return=  223  avg(last 20)= 200.0
# Episode  720  return=  206  avg(last 20)= 188.7
# Episode  740  return=  212  avg(last 20)= 194.9
# Episode  760  return=  109  avg(last 20)= 180.1
# Episode  780  return=  214  avg(last 20)= 203.1
# Episode  800  return=  222  avg(last 20)= 202.5
# Episode  820  return=  212  avg(last 20)= 206.0
# Episode  840  return=  216  avg(last 20)= 208.0
# Episode  860  return=  141  avg(last 20)= 201.6
# Episode  880  return=  127  avg(last 20)= 185.8
# Episode  900  return=  224  avg(last 20)= 199.3
# Episode  920  return=  214  avg(last 20)= 211.1
# Episode  940  return=  217  avg(last 20)= 212.9
# Episode  960  return=  209  avg(last 20)= 202.1
# Episode  980  return=  196  avg(last 20)= 188.8
# Episode 1000  return=  215  avg(last 20)= 206.3
# Episode 1020  return=  144  avg(last 20)= 165.7
# Episode 1040  return=  213  avg(last 20)= 196.8
# Episode 1060  return=  165  avg(last 20)= 204.5
# Episode 1080  return=  166  avg(last 20)= 209.0
# Episode 1100  return=  211  avg(last 20)= 193.3
# Episode 1120  return=  206  avg(last 20)= 204.1
# Episode 1140  return=  203  avg(last 20)= 191.3
# Episode 1160  return=  215  avg(last 20)= 190.0
# Episode 1180  return=  202  avg(last 20)= 202.0
# Episode 1200  return=  210  avg(last 20)= 204.8
# Episode 1220  return=  208  avg(last 20)= 203.1
# Episode 1240  return=  211  avg(last 20)= 195.6
# Episode 1260  return=  205  avg(last 20)= 209.9
# Episode 1280  return=  212  avg(last 20)= 208.5
# Episode 1300  return=  220  avg(last 20)= 212.2
# Episode 1320  return=  207  avg(last 20)= 210.5
# Episode 1340  return=  206  avg(last 20)= 210.7
# Episode 1360  return=  209  avg(last 20)= 210.5
# Episode 1380  return=  219  avg(last 20)= 214.4
# Episode 1400  return=  219  avg(last 20)= 210.6
# Episode 1420  return=  167  avg(last 20)= 212.7
# Episode 1440  return=  215  avg(last 20)= 212.4
# Episode 1460  return=  211  avg(last 20)= 210.3
# Episode 1480  return=  211  avg(last 20)= 213.6
# Episode 1500  return=  206  avg(last 20)= 213.2
# Episode 1520  return=  211  avg(last 20)= 217.4
# Episode 1540  return=  220  avg(last 20)= 213.2
# Episode 1560  return=  177  avg(last 20)= 206.9
# Episode 1580  return=  210  avg(last 20)= 212.5
# Episode 1600  return=  213  avg(last 20)= 213.5
# Episode 1620  return=  214  avg(last 20)= 210.2
# Episode 1640  return=  121  avg(last 20)= 204.0
# Episode 1660  return=  212  avg(last 20)= 209.7
# Episode 1680  return=  224  avg(last 20)= 201.0
# Episode 1700  return=  210  avg(last 20)= 210.6
# Episode 1720  return=  222  avg(last 20)= 210.9
# Episode 1740  return=  209  avg(last 20)= 206.8
# Episode 1760  return=  213  avg(last 20)= 208.8
# Episode 1780  return=  210  avg(last 20)= 211.9
# Episode 1800  return=  213  avg(last 20)= 212.0
# Episode 1820  return=  221  avg(last 20)= 215.5
# Episode 1840  return=  221  avg(last 20)= 216.7
# Episode 1860  return=  231  avg(last 20)= 217.6
# Episode 1880  return=  213  avg(last 20)= 213.9
# Episode 1900  return=  210  avg(last 20)= 210.0
# Episode 1920  return=  219  avg(last 20)= 208.0
# Episode 1940  return=  197  avg(last 20)= 208.6
# Episode 1960  return=  229  avg(last 20)= 213.9
# Episode 1980  return=  218  avg(last 20)= 218.6
# Episode 2000  return=  218  avg(last 20)= 218.8
# Episode 2020  return=  208  avg(last 20)= 217.5
# Episode 2040  return=  215  avg(last 20)= 214.1
# Episode 2060  return=  172  avg(last 20)= 214.6
# Episode 2080  return=  221  avg(last 20)= 217.1
# Episode 2100  return=  215  avg(last 20)= 213.9
# Episode 2120  return=  213  avg(last 20)= 216.4
# Episode 2140  return=  221  avg(last 20)= 219.1
# Episode 2160  return=  211  avg(last 20)= 215.4
# Episode 2180  return=  170  avg(last 20)= 213.1
# Episode 2200  return=  168  avg(last 20)= 220.9
# Episode 2220  return=  212  avg(last 20)= 228.5
# Episode 2240  return=  215  avg(last 20)= 213.0
# Episode 2260  return=  222  avg(last 20)= 229.9
# Episode 2280  return=  220  avg(last 20)= 224.3
# Episode 2300  return=  256  avg(last 20)= 236.1
# Episode 2320  return=  237  avg(last 20)= 227.0
# Episode 2340  return=  228  avg(last 20)= 222.2
# Episode 2360  return=  224  avg(last 20)= 221.4
# Episode 2380  return=  218  avg(last 20)= 223.1
# Episode 2400  return=  211  avg(last 20)= 220.2
# Episode 2420  return=  218  avg(last 20)= 220.0
# Episode 2440  return=  222  avg(last 20)= 222.4
# Episode 2460  return=  215  avg(last 20)= 215.9
# Episode 2480  return=  224  avg(last 20)= 223.4
# Episode 2500  return=  224  avg(last 20)= 224.7
# Episode 2520  return=  229  avg(last 20)= 215.9
# Episode 2540  return=  203  avg(last 20)= 223.6
# Episode 2560  return=  221  avg(last 20)= 227.4
# Episode 2580  return=  218  avg(last 20)= 220.5
# Episode 2600  return=  218  avg(last 20)= 226.1
# Episode 2620  return=   81  avg(last 20)= 213.6
# Episode 2640  return=  231  avg(last 20)= 229.8
# Episode 2660  return=  198  avg(last 20)= 223.6
# Episode 2680  return=  242  avg(last 20)= 218.2
# Episode 2700  return=  254  avg(last 20)= 231.5
# Episode 2720  return=  216  avg(last 20)= 223.1
# Episode 2740  return=  218  avg(last 20)= 217.8
# Episode 2760  return=  232  avg(last 20)= 226.0
# Episode 2780  return=  230  avg(last 20)= 225.5
# Episode 2800  return=  128  avg(last 20)= 216.5
# Episode 2820  return=  219  avg(last 20)= 213.4
# Episode 2840  return=  213  avg(last 20)= 219.6
# Episode 2860  return=  219  avg(last 20)= 222.1
# Episode 2880  return=  226  avg(last 20)= 223.5
# Episode 2900  return=  234  avg(last 20)= 227.8
# Episode 2920  return=  224  avg(last 20)= 227.8
# Episode 2940  return=  222  avg(last 20)= 223.2
# Episode 2960  return=  232  avg(last 20)= 221.9
# Episode 2980  return=  236  avg(last 20)= 227.9
# Saved model_ac_search_1_seed1.pt and history_ac_search_1_seed1.pkl and time_ac_search_1_seed1.pkl
#
# === ac_search_2_seed42: {'actor_lr': 3.5e-05, 'normalize_advantage': False} ===
# State space: Box(-inf, inf, (11,), float64)
# Action space: Box(-1.0, 1.0, (3,), float32)
# Episode    0  return=    8  avg(last 20)=   7.6
# Episode   20  return=    8  avg(last 20)=  10.0
# Episode   40  return=    6  avg(last 20)=   9.5
# Episode   60  return=   11  avg(last 20)=   9.4
# Episode   80  return=   10  avg(last 20)=  10.5
# Episode  100  return=   29  avg(last 20)=  16.9
# Episode  120  return=   80  avg(last 20)=  23.4
# Episode  140  return=  353  avg(last 20)=  56.3
# Episode  160  return=  209  avg(last 20)=  94.9
# Episode  180  return=  118  avg(last 20)= 133.6
# Episode  200  return=  167  avg(last 20)= 132.8
# Episode  220  return=  139  avg(last 20)= 149.0
# Episode  240  return=  161  avg(last 20)= 156.3
# Episode  260  return=  162  avg(last 20)= 143.0
# Episode  280  return=  164  avg(last 20)= 146.4
# Episode  300  return=  111  avg(last 20)= 170.3
# Episode  320  return=  165  avg(last 20)= 181.5
# Episode  340  return=  153  avg(last 20)= 185.6
# Episode  360  return=  141  avg(last 20)= 212.8
# Episode  380  return=  164  avg(last 20)= 209.0
# Episode  400  return=  293  avg(last 20)= 217.3
# Episode  420  return=  294  avg(last 20)= 209.0
# Episode  440  return=  281  avg(last 20)= 257.8
# Episode  460  return=  303  avg(last 20)= 244.1
# Episode  480  return=  288  avg(last 20)= 278.0
# Episode  500  return=  264  avg(last 20)= 268.6
# Episode  520  return=  340  avg(last 20)= 244.3
# Episode  540  return=  203  avg(last 20)= 291.4
# Episode  560  return=  308  avg(last 20)= 269.0
# Episode  580  return=  194  avg(last 20)= 300.6
# Episode  600  return=  317  avg(last 20)= 266.7
# Episode  620  return=  347  avg(last 20)= 305.1
# Episode  640  return=  307  avg(last 20)= 269.1
# Episode  660  return=  288  avg(last 20)= 256.3
# Episode  680  return=  279  avg(last 20)= 268.4
# Episode  700  return=  293  avg(last 20)= 293.1
# Episode  720  return=  340  avg(last 20)= 273.8
# Episode  740  return=  158  avg(last 20)= 272.1
# Episode  760  return=  396  avg(last 20)= 276.0
# Episode  780  return=  353  avg(last 20)= 326.1
# Episode  800  return=  327  avg(last 20)= 312.1
# Episode  820  return=   80  avg(last 20)= 301.4
# Episode  840  return=  306  avg(last 20)= 308.7
# Episode  860  return=  297  avg(last 20)= 308.0
# Episode  880  return=  280  avg(last 20)= 281.7
# Episode  900  return=  238  avg(last 20)= 275.6
# Episode  920  return=  305  avg(last 20)= 238.8
# Episode  940  return=  268  avg(last 20)= 276.3
# Episode  960  return=  331  avg(last 20)= 297.1
# Episode  980  return=  314  avg(last 20)= 299.2
# Episode 1000  return=  257  avg(last 20)= 280.8
# Episode 1020  return=  229  avg(last 20)= 278.5
# Episode 1040  return=  319  avg(last 20)= 274.5
# Episode 1060  return=  297  avg(last 20)= 288.9
# Episode 1080  return=  345  avg(last 20)= 304.4
# Episode 1100  return=  380  avg(last 20)= 328.8
# Episode 1120  return=  379  avg(last 20)= 365.2
# Episode 1140  return=  394  avg(last 20)= 344.0
# Episode 1160  return=  380  avg(last 20)= 378.3
# Episode 1180  return=  411  avg(last 20)= 365.1
# Episode 1200  return=  333  avg(last 20)= 337.1
# Episode 1220  return=  315  avg(last 20)= 300.4
# Episode 1240  return=  278  avg(last 20)= 297.8
# ...
# Episode 2600  return=  176  avg(last 20)= 190.5
# Episode 2620  return=  193  avg(last 20)= 202.4
# Episode 2640  return=  195  avg(last 20)= 187.9
# Episode 2660  return=  206  avg(last 20)= 196.9
# Episode 2680  return=  184  avg(last 20)= 195.1
# Episode 2700  return=  189  avg(last 20)= 190.0
# Episode 2720  return=  182  avg(last 20)= 182.4
# Episode 2740  return=  113  avg(last 20)= 156.3
# Episode 2760  return=  185  avg(last 20)= 158.7
# Episode 2780  return=   89  avg(last 20)= 155.7
# Episode 2800  return=  181  avg(last 20)= 160.0
# Episode 2820  return=  106  avg(last 20)= 146.2
# Episode 2840  return=  190  avg(last 20)= 172.9
# Episode 2860  return=  193  avg(last 20)= 179.7
# Episode 2880  return=  192  avg(last 20)= 191.0
# Episode 2900  return=  176  avg(last 20)= 187.4
# Episode 2920  return=  183  avg(last 20)= 181.1
# Episode 2940  return=  172  avg(last 20)= 181.8
# Episode 2960  return=  176  avg(last 20)= 170.3
# Episode 2980  return=  147  avg(last 20)= 164.7
# Saved model_ac_search_2_seed42.pt and history_ac_search_2_seed42.pkl and time_ac_search_2_seed42.pkl
#
# === ac_search_2_seed0: {'actor_lr': 3.5e-05, 'normalize_advantage': False} ===
# State space: Box(-inf, inf, (11,), float64)
# Action space: Box(-1.0, 1.0, (3,), float32)
# Episode    0  return=    7  avg(last 20)=   7.1
# Episode   20  return=   10  avg(last 20)=  10.1
# Episode   40  return=   12  avg(last 20)=  10.2
# Episode   60  return=    4  avg(last 20)=   8.8
# Episode   80  return=    8  avg(last 20)=   9.5
# Episode  100  return=   12  avg(last 20)=  12.4
# Episode  120  return=  133  avg(last 20)=  55.8
# Episode  140  return=   11  avg(last 20)=  61.5
# Episode  160  return=   20  avg(last 20)=  49.6
# Episode  180  return=   21  avg(last 20)=  50.9
# Episode  200  return=  215  avg(last 20)=  91.0
# Episode  220  return=  186  avg(last 20)=  95.0
# Episode  240  return=  136  avg(last 20)= 132.5
# Episode  260  return=  183  avg(last 20)= 118.2
# Episode  280  return=  116  avg(last 20)= 119.5
# Episode  300  return=   89  avg(last 20)= 111.5
# Episode  320  return=  129  avg(last 20)= 117.0
# Episode  340  return=   29  avg(last 20)= 125.6
# Episode  360  return=   97  avg(last 20)= 141.0
# Episode  380  return=   78  avg(last 20)= 115.8
# Episode  400  return=  110  avg(last 20)= 101.6
# Episode  420  return=  115  avg(last 20)= 114.7
# Episode  440  return=  134  avg(last 20)= 126.5
# Episode  460  return=  188  avg(last 20)= 122.2
# Episode  480  return=  173  avg(last 20)= 138.6
# Episode  500  return=  117  avg(last 20)= 136.5
# Episode  520  return=  185  avg(last 20)= 150.4
# Episode  540  return=  142  avg(last 20)= 146.6
# Episode  560  return=  157  avg(last 20)= 194.0
# Episode  580  return=  214  avg(last 20)= 237.3
# Episode  600  return=  257  avg(last 20)= 209.6
# Episode  620  return=  312  avg(last 20)= 219.3
# Episode  640  return=  303  avg(last 20)= 255.8
# Episode  660  return=  274  avg(last 20)= 233.7
# Episode  680  return=  283  avg(last 20)= 256.2
# Episode  700  return=  272  avg(last 20)= 275.1
# Episode  720  return=  264  avg(last 20)= 246.5
# Episode  740  return=  271  avg(last 20)= 263.0
# Episode  760  return=  129  avg(last 20)= 244.9
# Episode  780  return=  136  avg(last 20)= 236.8
# Episode  800  return=  137  avg(last 20)= 243.6
# Episode  820  return=  293  avg(last 20)= 244.1
# Episode  840  return=  274  avg(last 20)= 283.2
# Episode  860  return=  256  avg(last 20)= 273.8
# Episode  880  return=  266  avg(last 20)= 267.6
# Episode  900  return=  307  avg(last 20)= 292.5
# Episode  920  return=  287  avg(last 20)= 284.5
# Episode  940  return=  272  avg(last 20)= 277.2
# Episode  960  return=  280  avg(last 20)= 261.7
# Episode  980  return=  292  avg(last 20)= 254.9
# Episode 1000  return=  281  avg(last 20)= 267.4
# Episode 1020  return=  283  avg(last 20)= 246.9
# Episode 1040  return=  267  avg(last 20)= 254.3
# Episode 1060  return=  251  avg(last 20)= 271.8
# Episode 1080  return=  280  avg(last 20)= 284.7
# Episode 1100  return=  316  avg(last 20)= 293.6
# Episode 1120  return=  273  avg(last 20)= 293.3
# Episode 1140  return=  313  avg(last 20)= 286.2
# Episode 1160  return=  284  avg(last 20)= 297.3
# Episode 1180  return=  254  avg(last 20)= 289.0
# Episode 1200  return=  249  avg(last 20)= 247.2
# Episode 1220  return=  232  avg(last 20)= 234.3
# Episode 1240  return=  255  avg(last 20)= 239.1
# Episode 1260  return=  252  avg(last 20)= 248.7
# Episode 1280  return=  150  avg(last 20)= 229.2
# Episode 1300  return=  186  avg(last 20)= 238.3
# Episode 1320  return=  563  avg(last 20)= 266.7
# Episode 1340  return=   78  avg(last 20)= 324.3
# Episode 1360  return=   51  avg(last 20)= 251.8
# Episode 1380  return=   60  avg(last 20)= 104.3
# Episode 1400  return=   66  avg(last 20)=  86.9
# Episode 1420  return=  120  avg(last 20)= 172.1
# Episode 1440  return=  187  avg(last 20)= 290.2
# Episode 1460  return=  299  avg(last 20)= 245.7
# Episode 1480  return=  504  avg(last 20)= 317.7
# Episode 1500  return=  452  avg(last 20)= 388.4
# Episode 1520  return=  297  avg(last 20)= 411.1
# Episode 1540  return=  656  avg(last 20)= 558.9
# Episode 1560  return=  554  avg(last 20)= 515.9
# Episode 1580  return=  245  avg(last 20)= 533.4
# Episode 1600  return=  929  avg(last 20)= 569.0
# Episode 1620  return= 1119  avg(last 20)= 809.0
# Episode 1640  return= 1070  avg(last 20)= 877.7
# Episode 1660  return=  958  avg(last 20)= 798.8
# Episode 1680  return= 1001  avg(last 20)= 819.9
# Episode 1700  return=  744  avg(last 20)= 894.4
# Episode 1720  return=  396  avg(last 20)= 825.4
# Episode 1740  return=  869  avg(last 20)= 806.2
# Episode 1760  return= 1025  avg(last 20)= 836.8
# Episode 1780  return= 1035  avg(last 20)= 957.2
# Episode 1800  return= 1057  avg(last 20)= 932.5
# Episode 1820  return= 1042  avg(last 20)= 992.3
# Episode 1840  return= 1030  avg(last 20)=1037.0
# Episode 1860  return= 1057  avg(last 20)= 995.6
# Episode 1880  return=  936  avg(last 20)= 963.5
# Episode 1900  return=  518  avg(last 20)=1000.0
# Episode 1920  return=  196  avg(last 20)= 954.2
# Episode 1940  return= 1057  avg(last 20)= 953.2
# Episode 1960  return= 1040  avg(last 20)=1002.4
# Episode 1980  return= 1047  avg(last 20)=1026.0
# Episode 2000  return= 1029  avg(last 20)= 970.6
# Episode 2020  return=  807  avg(last 20)=1013.4
# Episode 2040  return= 1027  avg(last 20)= 906.7
# Episode 2060  return= 1035  avg(last 20)= 990.1
# Episode 2080  return= 1028  avg(last 20)=1031.1
# Episode 2100  return= 1033  avg(last 20)=1034.6
# Episode 2120  return= 1029  avg(last 20)= 956.3
# Episode 2140  return= 1041  avg(last 20)= 982.1
# Episode 2160  return= 1033  avg(last 20)= 895.0
# Episode 2180  return= 1038  avg(last 20)= 980.0
# Episode 2200  return= 1038  avg(last 20)=1034.7
# Episode 2220  return= 1032  avg(last 20)=1036.6
# Episode 2240  return=  419  avg(last 20)= 911.2
# Episode 2260  return=  454  avg(last 20)= 820.1
# Episode 2280  return= 1042  avg(last 20)= 824.7
# Episode 2300  return= 1043  avg(last 20)= 963.8
# Episode 2320  return=  861  avg(last 20)= 893.3
# Episode 2340  return=  412  avg(last 20)= 921.3
# Episode 2360  return=  498  avg(last 20)= 842.5
# Episode 2380  return= 1034  avg(last 20)= 870.1
# Episode 2400  return= 1028  avg(last 20)= 885.0
# Episode 2420  return=  690  avg(last 20)= 957.6
# Episode 2440  return= 1036  avg(last 20)= 929.7
# Episode 2460  return= 1030  avg(last 20)= 938.3
# Episode 2480  return= 1032  avg(last 20)= 966.2
# Episode 2500  return=  935  avg(last 20)= 878.6
# Episode 2520  return= 1026  avg(last 20)= 911.5
# Episode 2540  return= 1017  avg(last 20)= 974.2
# Episode 2560  return=  634  avg(last 20)= 643.5
# Episode 2580  return=  885  avg(last 20)= 640.2
# Episode 2600  return=  755  avg(last 20)= 663.6
# Episode 2620  return= 1025  avg(last 20)= 976.8
# Episode 2640  return=  455  avg(last 20)= 918.6
# Episode 2660  return=  647  avg(last 20)= 853.0
# Episode 2680  return= 1029  avg(last 20)= 834.5
# Episode 2700  return=  633  avg(last 20)= 926.5
# Episode 2720  return=  811  avg(last 20)= 869.2
# Episode 2740  return= 1036  avg(last 20)= 986.8
# Episode 2760  return= 1032  avg(last 20)=1020.2
# Episode 2780  return= 1025  avg(last 20)= 981.5
# Episode 2800  return=  386  avg(last 20)= 991.6
# Episode 2820  return= 1031  avg(last 20)= 940.4
# Episode 2840  return= 1041  avg(last 20)= 980.1
# Episode 2860  return= 1027  avg(last 20)=1032.7
# Episode 2880  return= 1037  avg(last 20)= 988.7
# Episode 2900  return= 1035  avg(last 20)=1036.5
# Episode 2920  return= 1029  avg(last 20)=1005.1
# Episode 2940  return= 1042  avg(last 20)= 987.5
# Episode 2960  return= 1037  avg(last 20)= 935.9
# Episode 2980  return= 1032  avg(last 20)=1013.6
# Saved model_ac_search_2_seed0.pt and history_ac_search_2_seed0.pkl and time_ac_search_2_seed0.pkl
#
# === ac_search_2_seed1: {'actor_lr': 3.5e-05, 'normalize_advantage': False} ===
# State space: Box(-inf, inf, (11,), float64)
# Action space: Box(-1.0, 1.0, (3,), float32)
# Episode    0  return=    8  avg(last 20)=   7.8
# Episode   20  return=   24  avg(last 20)=  19.9
# Episode   40  return=   12  avg(last 20)=  11.6
# Episode   60  return=   11  avg(last 20)=  11.1
# Episode   80  return=   16  avg(last 20)=   9.8
# Episode  100  return=   25  avg(last 20)=  12.4
# Episode  120  return=  219  avg(last 20)=  34.0
# Episode  140  return=   56  avg(last 20)=  64.0
# Episode  160  return=   49  avg(last 20)= 114.3
# Episode  180  return=  121  avg(last 20)= 125.2
# Episode  200  return=  191  avg(last 20)= 128.1
# Episode  220  return=  146  avg(last 20)= 142.8
# Episode  240  return=   80  avg(last 20)= 124.6
# Episode  260  return=  148  avg(last 20)= 130.6
# Episode  280  return=   93  avg(last 20)= 143.8
# Episode  300  return=  219  avg(last 20)= 173.2
# Episode  320  return=  265  avg(last 20)= 192.5
# Episode  340  return=  231  avg(last 20)= 195.1
# Episode  360  return=  216  avg(last 20)= 217.6
# Episode  380  return=  228  avg(last 20)= 215.1
# Episode  400  return=  241  avg(last 20)= 212.4
# Episode  420  return=  165  avg(last 20)= 201.2
# Episode  440  return=  165  avg(last 20)= 190.3
# Episode  460  return=  209  avg(last 20)= 202.4
# Episode  480  return=  208  avg(last 20)= 217.8
# Episode  500  return=  115  avg(last 20)= 178.7
# Episode  520  return=  151  avg(last 20)= 168.3
# Episode  540  return=  185  avg(last 20)= 162.4
# Episode  560  return=  205  avg(last 20)= 191.0
# Episode  580  return=  194  avg(last 20)= 207.0
# Episode  600  return=  205  avg(last 20)= 200.3
# Episode  620  return=  198  avg(last 20)= 188.6
# Episode  640  return=  232  avg(last 20)= 197.2
# Episode  660  return=  216  avg(last 20)= 200.2
# Episode  680  return=  204  avg(last 20)= 183.5
# Episode  700  return=  207  avg(last 20)= 195.8
# Episode  720  return=  204  avg(last 20)= 193.3
# Episode  740  return=  204  avg(last 20)= 189.9
# Episode  760  return=  201  avg(last 20)= 190.2
# Episode  780  return=  208  avg(last 20)= 189.0
# Episode  800  return=  242  avg(last 20)= 207.3
# Episode  820  return=  214  avg(last 20)= 201.3
# Episode  840  return=  190  avg(last 20)= 193.7
# Episode  860  return=  206  avg(last 20)= 189.7
# Episode  880  return=  200  avg(last 20)= 193.7
# Episode  900  return=  206  avg(last 20)= 205.0
# Episode  920  return=  207  avg(last 20)= 204.3
# Episode  940  return=  213  avg(last 20)= 195.7
# Episode  960  return=  206  avg(last 20)= 188.6
# Episode  980  return=  209  avg(last 20)= 201.9
# Episode 1000  return=  209  avg(last 20)= 198.3
# Episode 1020  return=  211  avg(last 20)= 209.1
# Episode 1040  return=  206  avg(last 20)= 178.9
# Episode 1060  return=  211  avg(last 20)= 197.3
# Episode 1080  return=  209  avg(last 20)= 202.8
# Episode 1100  return=  201  avg(last 20)= 201.1
# Episode 1120  return=  205  avg(last 20)= 202.6
# Episode 1140  return=  200  avg(last 20)= 200.8
# Episode 1160  return=  205  avg(last 20)= 205.4
# Episode 1180  return=  211  avg(last 20)= 195.1
# Episode 1200  return=  198  avg(last 20)= 197.4
# Episode 1220  return=  201  avg(last 20)= 199.8
# Episode 1240  return=  200  avg(last 20)= 192.7
# Episode 1260  return=  183  avg(last 20)= 200.2
# Episode 1280  return=  209  avg(last 20)= 190.0
# Episode 1300  return=   70  avg(last 20)= 162.0
# Episode 1320  return=  197  avg(last 20)= 156.7
# Episode 1340  return=  201  avg(last 20)= 166.0
# Episode 1360  return=  212  avg(last 20)= 189.5
# Episode 1380  return=  202  avg(last 20)= 195.9
# Episode 1400  return=  186  avg(last 20)= 192.5
# Episode 1420  return=  202  avg(last 20)= 185.8
# Episode 1440  return=  197  avg(last 20)= 191.9
# Episode 1460  return=  210  avg(last 20)= 194.3
# Episode 1480  return=  198  avg(last 20)= 190.0
# Episode 1500  return=  192  avg(last 20)= 197.0
# Episode 1520  return=  198  avg(last 20)= 200.5
# Episode 1540  return=  188  avg(last 20)= 194.7
# Episode 1560  return=  188  avg(last 20)= 185.0
# Episode 1580  return=  206  avg(last 20)= 189.8
# Episode 1600  return=  196  avg(last 20)= 195.1
# Episode 1620  return=  184  avg(last 20)= 190.4
# Episode 1640  return=  187  avg(last 20)= 192.3
# Episode 1660  return=  211  avg(last 20)= 196.0
# Episode 1680  return=  197  avg(last 20)= 189.7
# Episode 1700  return=  179  avg(last 20)= 187.8
# Episode 1720  return=  192  avg(last 20)= 187.5
# Episode 1740  return=  184  avg(last 20)= 187.3
# Episode 1760  return=  191  avg(last 20)= 187.7
# Episode 1780  return=  188  avg(last 20)= 184.9
# Episode 1800  return=  178  avg(last 20)= 187.0
# Episode 1820  return=  183  avg(last 20)= 185.7
# Episode 1840  return=  101  avg(last 20)= 180.6
# Episode 1860  return=  192  avg(last 20)= 187.2
# Episode 1880  return=  187  avg(last 20)= 182.1
# Episode 1900  return=  191  avg(last 20)= 181.9
# Episode 1920  return=  198  avg(last 20)= 188.8
# Episode 1940  return=  126  avg(last 20)= 181.9
# Episode 1960  return=  181  avg(last 20)= 182.9
# Episode 1980  return=  178  avg(last 20)= 189.4
# Episode 2000  return=  187  avg(last 20)= 185.4
# Episode 2020  return=  191  avg(last 20)= 190.6
# Episode 2040  return=  183  avg(last 20)= 188.1
# Episode 2060  return=  191  avg(last 20)= 184.1
# Episode 2080  return=  187  avg(last 20)= 187.0
# Episode 2100  return=  184  avg(last 20)= 181.2
# Episode 2120  return=  110  avg(last 20)= 184.3
# Episode 2140  return=  185  avg(last 20)= 187.7
# Episode 2160  return=  194  avg(last 20)= 182.4
# Episode 2180  return=  202  avg(last 20)= 194.4
# Episode 2200  return=  200  avg(last 20)= 197.5
# Episode 2220  return=  192  avg(last 20)= 200.1
# Episode 2240  return=  187  avg(last 20)= 199.3
# Episode 2260  return=  203  avg(last 20)= 202.0
# Episode 2280  return=  183  avg(last 20)= 202.8
# Episode 2300  return=  226  avg(last 20)= 206.1
# Episode 2320  return=  191  avg(last 20)= 198.8
# Episode 2340  return=  190  avg(last 20)= 198.9
# Episode 2360  return=  211  avg(last 20)= 203.5
# Episode 2380  return=  196  avg(last 20)= 202.2
# Episode 2400  return=  196  avg(last 20)= 199.5
# Episode 2420  return=  209  avg(last 20)= 196.1
# Episode 2440  return=  212  avg(last 20)= 210.2
# Episode 2460  return=  190  avg(last 20)= 212.0
# Episode 2480  return=  215  avg(last 20)= 209.8
# Episode 2500  return=  194  avg(last 20)= 207.4
# Episode 2520  return=  200  avg(last 20)= 199.1
# Episode 2540  return=  203  avg(last 20)= 199.6
# Episode 2560  return=  188  avg(last 20)= 195.5
# Episode 2580  return=  199  avg(last 20)= 195.2
# Episode 2600  return=  196  avg(last 20)= 195.4
# Episode 2620  return=  193  avg(last 20)= 193.0
# Episode 2640  return=  197  avg(last 20)= 194.0
# Episode 2660  return=  202  avg(last 20)= 187.4
# Episode 2680  return=  182  avg(last 20)= 183.9
# Episode 2700  return=  190  avg(last 20)= 180.2
# Episode 2720  return=  202  avg(last 20)= 188.0
# Episode 2740  return=  193  avg(last 20)= 193.9
# Episode 2760  return=  190  avg(last 20)= 198.1
# Episode 2780  return=  188  avg(last 20)= 196.9
# Episode 2800  return=  203  avg(last 20)= 200.0
# Episode 2820  return=  205  avg(last 20)= 196.3
# Episode 2840  return=  195  avg(last 20)= 199.0
# Episode 2860  return=  197  avg(last 20)= 187.3
# Episode 2880  return=  195  avg(last 20)= 191.6
# Episode 2900  return=  211  avg(last 20)= 198.2
# Episode 2920  return=  198  avg(last 20)= 184.8
# Episode 2940  return=  208  avg(last 20)= 182.3
# Episode 2960  return=  211  avg(last 20)= 184.4
# Episode 2980  return=  196  avg(last 20)= 198.9
# Saved model_ac_search_2_seed1.pt and history_ac_search_2_seed1.pkl and time_ac_search_2_seed1.pkl

# %%
import os

def ac_metrics(suffix, w=50, last_n=50):
    h = load_history(suffix)
    sm = smooth_50(h)
    peak = float(sm.max())
    final = float(np.mean(h[-last_n:]))
    return dict(peak=peak, peak_ep=int(np.argmax(sm)) + w, final=final, gap=peak - final)

compare = (["ac_trial_7"]
           + [f"ac_refined_seed{s}" for s in REFINE_SEEDS]
           + [f"ac_search_{i}" for i in range(len(search_grid))])

print(f'{"run":22s}{"peak":>7}{"peak_ep":>9}{"final":>7}{"gap":>7}')
plt.figure(figsize=(11, 5.5))
for name in compare:
    if not os.path.exists(os.path.join(PREFIX, f"history_{name}.pkl")):
        continue
    m = ac_metrics(name)
    print(f'{name:22s}{m["peak"]:7.0f}{m["peak_ep"]:9d}{m["final"]:7.0f}{m["gap"]:7.0f}')
    h = load_history(name)
    if name == "ac_trial_7":
        plt.plot(smooth_50(h), label=f"{name} (sweep best)",
                 color="tab:red", linewidth=3, zorder=5)
    else:
        plt.plot(smooth_50(h), label=name, alpha=0.8, linewidth=1.5)

plt.xlabel("Episode")
plt.ylabel("Return (50-episode moving average)")
plt.title("Refined Actor-Critic vs sweep winner (ac_trial_7)")
plt.legend(fontsize=8)
plt.grid(alpha=0.3)
plt.tight_layout()
plt.savefig(os.path.join(PREFIX, "actor_critic_refined.png"),
            dpi=120, bbox_inches="tight")
plt.show()
print("\nLower 'gap' = holds its peak (more stable). Higher 'peak' = better best-case.")
# Out:
# run                      peak  peak_ep  final    gap
# ac_trial_7                621     1414    413    208
# ac_refined_seed42         538     2934    499     39
# ac_refined_seed0          836     2855    395    441
# ac_refined_seed1          226     1634    193     33
# Lower 'gap' = holds its peak (more stable). Higher 'peak' = better best-case.

# %%
seeds = [0, 1, 2]
multi_seed_results = {}

best_const_value = float(BEST_CONST.replace("constant_b", ""))

ema_alpha_map = {
    "ema_a0.0005": 0.0005,
    "ema_a0.0500": 0.05,
    "ema_a0.5000": 0.5,
}
best_ema_alpha = ema_alpha_map[BEST_EMA]

methods = [
    {
        "name": "reinforce_none",
        "algorithm": "reinforce",
        "baseline_mode": "none",
    },
    {
        "name": "reinforce_constant_best",
        "algorithm": "reinforce",
        "baseline_mode": "constant",
        "baseline_value": best_const_value,
    },
    {
        "name": "reinforce_ema_best",
        "algorithm": "reinforce",
        "baseline_mode": "ema",
        "baseline_alpha": best_ema_alpha,
    },
    {
        "name": "actor_critic",
        "algorithm": "actor_critic",
    },
]

for method in methods:
    multi_seed_results[method["name"]] = []

    for seed in seeds:
        run_name = f"{method['name']}_seed{seed}"

        print("\nRunning:", run_name)

        if method["algorithm"] == "actor_critic":
            h = main(
                algorithm="actor_critic",
                n_episodes=3000,
                seed=seed,
                actor_lr=best_cfg["actor_lr"],
                critic_lr=best_cfg["critic_lr"],
                entropy_weight=best_cfg["entropy_weight"],
                critic_weight=best_cfg["critic_weight"],
                hidden_size=best_cfg["hidden"],
                gamma=best_cfg["gamma"],
                grad_clip=best_cfg["grad_clip"],
                normalize_advantage=best_cfg["normalize_advantage"],
                run_name=run_name,
                save_dir=PREFIX
            )
        else:
            h = main(
                algorithm="reinforce",
                baseline_mode=method["baseline_mode"],
                baseline_value=method.get("baseline_value", 0.0),
                baseline_alpha=method.get("baseline_alpha", 0.0),
                n_episodes=3000,
                seed=seed,
                run_name=run_name,
                save_dir=PREFIX
            )

        score = float(np.mean(h[-50:]))
        multi_seed_results[method["name"]].append(score)
# Out:
# Running: reinforce_none_seed0
# State space: Box(-inf, inf, (11,), float64)
# Action space: Box(-1.0, 1.0, (3,), float32)
# Episode    0  return=    5  avg(last 20)=   5.3
# Episode   20  return=    6  avg(last 20)=   6.0
# Episode   40  return=    7  avg(last 20)=   6.1
# Episode   60  return=    4  avg(last 20)=   5.5
# Episode   80  return=    6  avg(last 20)=   5.9
# Episode  100  return=   10  avg(last 20)=  10.2
# Episode  120  return=    7  avg(last 20)=  11.9
# Episode  140  return=    7  avg(last 20)=   6.9
# Episode  160  return=    8  avg(last 20)=   7.3
# Episode  180  return=   14  avg(last 20)=  11.1
# Episode  200  return=   11  avg(last 20)=  12.5
# Episode  220  return=   12  avg(last 20)=  11.5
# Episode  240  return=   28  avg(last 20)=  22.2
# Episode  260  return=   81  avg(last 20)=  60.3
# Episode  280  return=   76  avg(last 20)=  54.5
# Episode  300  return=   40  avg(last 20)=  61.9
# Episode  320  return=  665  avg(last 20)= 112.8
# Episode  340  return=   26  avg(last 20)=  41.0
# Episode  360  return=   30  avg(last 20)=  18.5
# Episode  380  return=   33  avg(last 20)=  34.4
# Episode  400  return=  189  avg(last 20)= 100.5
# Episode  420  return=  269  avg(last 20)= 241.3
# Episode  440  return=  971  avg(last 20)= 501.4
# Episode  460  return=  973  avg(last 20)= 543.9
# Episode  480  return=  996  avg(last 20)= 986.0
# Episode  500  return=  998  avg(last 20)= 997.8
# Episode  520  return=  523  avg(last 20)= 971.0
# Episode  540  return=  977  avg(last 20)= 647.6
# Episode  560  return=  989  avg(last 20)= 985.2
# Episode  580  return=  994  avg(last 20)= 988.5
# Episode  600  return=  761  avg(last 20)= 889.9
# Episode  620  return= 1027  avg(last 20)= 693.5
# Episode  640  return= 1076  avg(last 20)= 982.0
# Episode  660  return= 1023  avg(last 20)=1024.4
# Episode  680  return= 1012  avg(last 20)=1012.9
# Episode  700  return= 1013  avg(last 20)=1017.4
# Episode  720  return= 1016  avg(last 20)=1011.5
# Episode  740  return= 1014  avg(last 20)=1016.8
# Episode  760  return= 1001  avg(last 20)=1002.3
# Episode  780  return=  995  avg(last 20)= 996.6
# Episode  800  return=  991  avg(last 20)= 996.9
# Episode  820  return=  982  avg(last 20)= 987.1
# Episode  840  return=  984  avg(last 20)= 983.0
# Episode  860  return=  233  avg(last 20)= 575.1
# Episode  880  return=  162  avg(last 20)= 190.0
# Episode  900  return=  550  avg(last 20)= 669.1
# Episode  920  return= 1039  avg(last 20)= 704.1
# Episode  940  return= 1046  avg(last 20)=1040.3
# Episode  960  return=  773  avg(last 20)= 936.4
# Episode  980  return=  739  avg(last 20)= 637.1
# Episode 1000  return=  578  avg(last 20)= 606.5
# Episode 1020  return=  324  avg(last 20)= 484.0
# Episode 1040  return=  151  avg(last 20)= 210.3
# Episode 1060  return=  162  avg(last 20)= 155.2
# Episode 1080  return=  335  avg(last 20)= 234.9
# Episode 1100  return= 1060  avg(last 20)= 478.6
# Episode 1120  return=  286  avg(last 20)= 676.4
# Episode 1140  return=  396  avg(last 20)= 773.5
# Episode 1160  return=  174  avg(last 20)= 219.6
# Episode 1180  return=  118  avg(last 20)= 158.6
# Episode 1200  return=  107  avg(last 20)= 109.6
# Episode 1220  return=   13  avg(last 20)=  28.6
# Episode 1240  return=   17  avg(last 20)=  13.6
# Episode 1260  return=  175  avg(last 20)=  56.3
# Episode 1280  return=  214  avg(last 20)= 109.1
# Episode 1300  return=  173  avg(last 20)=  36.3
# Episode 1320  return=   15  avg(last 20)=  50.0
# Episode 1340  return=   13  avg(last 20)=  13.9
# Episode 1360  return=   15  avg(last 20)=  16.0
# Episode 1380  return=   13  avg(last 20)=  16.9
# Episode 1400  return=  210  avg(last 20)=  56.6
# Episode 1420  return=  244  avg(last 20)= 188.0
# Episode 1440  return=  248  avg(last 20)= 252.8
# Episode 1460  return=  146  avg(last 20)= 194.1
# Episode 1480  return=  129  avg(last 20)= 141.2
# Episode 1500  return=  125  avg(last 20)= 132.2
# Episode 1520  return=  124  avg(last 20)= 121.2
# Episode 1540  return=  247  avg(last 20)= 166.4
# Episode 1560  return=  240  avg(last 20)= 181.6
# Episode 1580  return=  137  avg(last 20)= 206.4
# Episode 1600  return=  205  avg(last 20)= 494.1
# Episode 1620  return=  131  avg(last 20)= 282.5
# Episode 1640  return=  120  avg(last 20)= 154.6
# Episode 1660  return=  238  avg(last 20)= 170.3
# Episode 1680  return=  244  avg(last 20)= 304.5
# Episode 1700  return=  168  avg(last 20)= 172.3
# Episode 1720  return=  163  avg(last 20)= 159.1
# Episode 1740  return=   95  avg(last 20)= 123.1
# Episode 1760  return=   83  avg(last 20)=  94.1
# Episode 1780  return=   86  avg(last 20)=  92.4
# Episode 1800  return=  129  avg(last 20)= 116.5
# Episode 1820  return=  134  avg(last 20)= 125.5
# Episode 1840  return=  128  avg(last 20)= 156.0
# Episode 1860  return=  114  avg(last 20)= 169.9
# Episode 1880  return= 1027  avg(last 20)= 349.6
# Episode 1900  return= 1020  avg(last 20)=1017.0
# Episode 1920  return= 1038  avg(last 20)= 920.7
# Episode 1940  return= 1062  avg(last 20)= 804.1
# Episode 1960  return= 1059  avg(last 20)=1042.5
# Episode 1980  return= 1049  avg(last 20)=1000.0
# Episode 2000  return= 1037  avg(last 20)=1034.6
# Episode 2020  return= 1041  avg(last 20)=1041.2
# Episode 2040  return= 1026  avg(last 20)=1038.2
# Episode 2060  return= 1018  avg(last 20)=1019.5
# Episode 2080  return= 1023  avg(last 20)=1019.6
# Episode 2100  return= 1023  avg(last 20)=1023.8
# Episode 2120  return= 1028  avg(last 20)=1021.1
# Episode 2140  return= 1018  avg(last 20)=1022.4
# Episode 2160  return= 1030  avg(last 20)=1026.8
# Episode 2180  return= 1036  avg(last 20)=1035.5
# Episode 2200  return= 1026  avg(last 20)=1026.2
# Episode 2220  return= 1024  avg(last 20)=1022.5
# Episode 2240  return=  999  avg(last 20)=1010.1
# Episode 2260  return=  571  avg(last 20)= 863.8
# Episode 2280  return=  263  avg(last 20)= 563.6
# Episode 2300  return=  731  avg(last 20)= 572.6
# Episode 2320  return=  376  avg(last 20)= 688.7
# Episode 2340  return=  159  avg(last 20)= 271.2
# Episode 2360  return=   79  avg(last 20)=  92.4
# Episode 2380  return=   39  avg(last 20)=  68.7
# Episode 2400  return=   42  avg(last 20)=  47.6
# Episode 2420  return=   55  avg(last 20)=  40.6
# Episode 2440  return=   46  avg(last 20)=  42.7
# Episode 2460  return=   81  avg(last 20)=  53.2
# Episode 2480  return=   65  avg(last 20)=  53.3
# Episode 2500  return=   50  avg(last 20)=  62.0
# Episode 2520  return=  119  avg(last 20)= 110.4
# Episode 2540  return=  149  avg(last 20)= 174.2
# Episode 2560  return=  403  avg(last 20)= 258.7
# Episode 2580  return= 1004  avg(last 20)= 617.6
# Episode 2600  return= 1031  avg(last 20)=1023.3
# Episode 2620  return= 1036  avg(last 20)=1039.3
# Episode 2640  return= 1068  avg(last 20)=1051.0
# Episode 2660  return= 1073  avg(last 20)=1064.6
# Episode 2680  return=  594  avg(last 20)= 847.3
# Episode 2700  return=  275  avg(last 20)= 428.7
# Episode 2720  return=  471  avg(last 20)= 312.5
# Episode 2740  return=  194  avg(last 20)= 260.3
# Episode 2760  return=  202  avg(last 20)= 159.1
# Episode 2780  return=  263  avg(last 20)= 209.7
# Episode 2800  return=  267  avg(last 20)= 415.4
# Episode 2820  return=  279  avg(last 20)= 411.9
# Episode 2840  return=  132  avg(last 20)= 297.2
# Episode 2860  return=  380  avg(last 20)= 490.0
# Episode 2880  return=  358  avg(last 20)= 500.8
# Episode 2900  return=  252  avg(last 20)= 461.4
# Episode 2920  return=  120  avg(last 20)= 180.8
# Episode 2940  return=  143  avg(last 20)= 144.2
# Episode 2960  return=  196  avg(last 20)= 179.1
# Episode 2980  return=  205  avg(last 20)= 197.8
# Saved model_reinforce_none_seed0.pt and history_reinforce_none_seed0.pkl and time_reinforce_none_seed0.pkl
#
# Running: reinforce_none_seed1
# State space: Box(-inf, inf, (11,), float64)
# Action space: Box(-1.0, 1.0, (3,), float32)
# Episode    0  return=    8  avg(last 20)=   7.8
# Episode   20  return=   19  avg(last 20)=  10.6
# Episode   40  return=   37  avg(last 20)=  35.7
# Episode   60  return=   61  avg(last 20)=  62.4
# Episode   80  return=   87  avg(last 20)=  76.0
# Episode  100  return=  196  avg(last 20)=  80.0
# Episode  120  return=  407  avg(last 20)= 369.8
# Episode  140  return=   67  avg(last 20)=  98.8
# Episode  160  return=  246  avg(last 20)= 266.8
# Episode  180  return=  216  avg(last 20)= 236.9
# Episode  200  return=  200  avg(last 20)= 220.5
# Episode  220  return=  406  avg(last 20)= 238.3
# Episode  240  return=  304  avg(last 20)= 358.9
# Episode  260  return=  145  avg(last 20)= 236.9
# Episode  280  return=  262  avg(last 20)= 216.2
# Episode  300  return=  406  avg(last 20)= 518.0
# Episode  320  return=  468  avg(last 20)= 408.7
# Episode  340  return=  202  avg(last 20)= 389.6
# Episode  360  return=  140  avg(last 20)= 169.8
# Episode  380  return=  100  avg(last 20)= 111.1
# Episode  400  return=   89  avg(last 20)=  92.1
# Episode  420  return=   92  avg(last 20)=  87.7
# Episode  440  return=  101  avg(last 20)=  97.5
# Episode  460  return=   84  avg(last 20)=  90.4
# Episode  480  return=   85  avg(last 20)=  85.6
# Episode  500  return=   83  avg(last 20)=  83.2
# Episode  520  return=   74  avg(last 20)=  80.3
# Episode  540  return=   84  avg(last 20)=  82.5
# Episode  560  return=   88  avg(last 20)=  95.7
# Episode  580  return=  111  avg(last 20)= 106.0
# Episode  600  return=  125  avg(last 20)= 112.2
# Episode  620  return=  141  avg(last 20)= 124.3
# Episode  640  return=  138  avg(last 20)= 127.3
# Episode  660  return=  190  avg(last 20)= 152.4
# Episode  680  return=  121  avg(last 20)= 182.3
# Episode  700  return=  259  avg(last 20)= 222.2
# Episode  720  return=  251  avg(last 20)= 256.0
# Episode  740  return=  286  avg(last 20)= 210.2
# Episode  760  return=  185  avg(last 20)= 180.5
# Episode  780  return=  249  avg(last 20)= 172.1
# Episode  800  return=  107  avg(last 20)= 191.2
# Episode  820  return=  219  avg(last 20)= 201.3
# Episode  840  return=  137  avg(last 20)= 121.0
# Episode  860  return=  132  avg(last 20)= 119.1
# Episode  880  return=   86  avg(last 20)= 128.3
# Episode  900  return=   93  avg(last 20)= 101.1
# Episode  920  return=   89  avg(last 20)= 116.2
# Episode  940  return=  100  avg(last 20)= 105.0
# Episode  960  return=   94  avg(last 20)= 105.9
# Episode  980  return=   94  avg(last 20)= 110.4
# Episode 1000  return=   88  avg(last 20)= 103.4
# Episode 1020  return=  243  avg(last 20)= 152.3
# Episode 1040  return=  259  avg(last 20)= 243.7
# Episode 1060  return=  192  avg(last 20)= 216.3
# Episode 1080  return=  242  avg(last 20)= 220.8
# Episode 1100  return=  187  avg(last 20)= 212.1
# Episode 1120  return=  213  avg(last 20)= 208.0
# Episode 1140  return=  230  avg(last 20)= 214.4
# Episode 1160  return=  281  avg(last 20)= 211.1
# Episode 1180  return=  327  avg(last 20)= 284.9
# Episode 1200  return=  127  avg(last 20)= 272.3
# Episode 1220  return=   97  avg(last 20)= 123.3
# Episode 1240  return=   98  avg(last 20)= 127.3
# Episode 1260  return=   98  avg(last 20)=  94.9
# Episode 1280  return=   93  avg(last 20)=  94.3
# Episode 1300  return=   84  avg(last 20)=  83.0
# Episode 1320  return=   89  avg(last 20)=  89.3
# Episode 1340  return=   89  avg(last 20)=  89.6
# Episode 1360  return=   83  avg(last 20)= 107.0
# Episode 1380  return=  238  avg(last 20)= 204.8
# Episode 1400  return=  244  avg(last 20)= 217.6
# Episode 1420  return=   94  avg(last 20)= 179.0
# Episode 1440  return=  104  avg(last 20)= 118.8
# Episode 1460  return=  257  avg(last 20)= 126.8
# Episode 1480  return=  260  avg(last 20)= 205.0
# Episode 1500  return=  153  avg(last 20)= 166.4
# Episode 1520  return=  117  avg(last 20)= 132.3
# Episode 1540  return=   95  avg(last 20)= 108.6
# Episode 1560  return=  133  avg(last 20)= 155.1
# Episode 1580  return=  118  avg(last 20)= 145.7
# Episode 1600  return=  114  avg(last 20)= 114.6
# Episode 1620  return=  150  avg(last 20)= 154.1
# Episode 1640  return=  267  avg(last 20)= 185.5
# Episode 1660  return=  128  avg(last 20)= 154.1
# Episode 1680  return=  152  avg(last 20)= 144.4
# Episode 1700  return=  129  avg(last 20)= 142.4
# Episode 1720  return=  357  avg(last 20)= 190.2
# Episode 1740  return=  148  avg(last 20)= 245.3
# Episode 1760  return=  132  avg(last 20)= 255.9
# Episode 1780  return=  152  avg(last 20)= 224.7
# Episode 1800  return=  157  avg(last 20)= 183.1
# Episode 1820  return=   76  avg(last 20)=  98.7
# Episode 1840  return=  146  avg(last 20)= 125.0
# Episode 1860  return=  133  avg(last 20)= 161.7
# Episode 1880  return=   92  avg(last 20)= 120.9
# Episode 1900  return=   63  avg(last 20)= 135.3
# Episode 1920  return=   99  avg(last 20)= 129.7
# Episode 1940  return=   53  avg(last 20)=  99.4
# Episode 1960  return=   37  avg(last 20)=  55.5
# Episode 1980  return=   86  avg(last 20)=  64.8
# Episode 2000  return=   67  avg(last 20)=  62.0
# Episode 2020  return=   90  avg(last 20)=  78.4
# Episode 2040  return=   24  avg(last 20)=  73.2
# Episode 2060  return=   21  avg(last 20)=  75.4
# Episode 2080  return=   81  avg(last 20)=  73.3
# Episode 2100  return=   80  avg(last 20)=  76.0
# Episode 2120  return=   34  avg(last 20)=  66.2
# Episode 2140  return=   54  avg(last 20)=  60.0
# Episode 2160  return=   37  avg(last 20)=  46.2
# Episode 2180  return=   58  avg(last 20)=  30.9
# Episode 2200  return=   33  avg(last 20)=  37.9
# Episode 2220  return=   91  avg(last 20)=  43.7
# Episode 2240  return=   24  avg(last 20)=  36.7
# Episode 2260  return=   20  avg(last 20)=  40.8
# Episode 2280  return=   19  avg(last 20)=  23.7
# Episode 2300  return=   31  avg(last 20)=  25.7
# Episode 2320  return=   12  avg(last 20)=  17.4
# Episode 2340  return=   11  avg(last 20)=  14.7
# Episode 2360  return=   18  avg(last 20)=  17.8
# Episode 2380  return=   23  avg(last 20)=  25.3
# Episode 2400  return=   24  avg(last 20)=  19.3
# Episode 2420  return=   19  avg(last 20)=  19.1
# Episode 2440  return=   13  avg(last 20)=  13.3
# Episode 2460  return=    8  avg(last 20)=   9.0
# Episode 2480  return=    8  avg(last 20)=   8.8
# Episode 2500  return=    7  avg(last 20)=   8.6
# Episode 2520  return=    8  avg(last 20)=   7.8
# Episode 2540  return=    7  avg(last 20)=   7.5
# Episode 2560  return=    7  avg(last 20)=   7.1
# Episode 2580  return=    7  avg(last 20)=   7.0
# Episode 2600  return=    7  avg(last 20)=   7.2
# Episode 2620  return=    6  avg(last 20)=   6.4
# Episode 2640  return=    7  avg(last 20)=   6.2
# Episode 2660  return=    7  avg(last 20)=   6.9
# Episode 2680  return=    7  avg(last 20)=   7.1
# Episode 2700  return=    8  avg(last 20)=   7.4
# Episode 2720  return=    7  avg(last 20)=   7.7
# Episode 2740  return=    6  avg(last 20)=   7.0
# Episode 2760  return=    7  avg(last 20)=   7.2
# Episode 2780  return=    8  avg(last 20)=   7.7
# Episode 2800  return=    8  avg(last 20)=   7.7
# Episode 2820  return=    8  avg(last 20)=   7.9
# Episode 2840  return=    7  avg(last 20)=   7.7
# Episode 2860  return=    7  avg(last 20)=   7.6
# Episode 2880  return=    7  avg(last 20)=   7.7
# Episode 2900  return=    9  avg(last 20)=   8.1
# Episode 2920  return=    9  avg(last 20)=   8.6
# Episode 2940  return=    9  avg(last 20)=   8.7
# Episode 2960  return=    9  avg(last 20)=   8.9
# Episode 2980  return=    8  avg(last 20)=   8.7
# Saved model_reinforce_none_seed1.pt and history_reinforce_none_seed1.pkl and time_reinforce_none_seed1.pkl
#
# Running: reinforce_none_seed2
# State space: Box(-inf, inf, (11,), float64)
# Action space: Box(-1.0, 1.0, (3,), float32)
# Episode    0  return=    8  avg(last 20)=   7.6
# Episode   20  return=   10  avg(last 20)=   9.2
# Episode   40  return=   10  avg(last 20)=   8.9
# Episode   60  return=   11  avg(last 20)=   8.7
# Episode   80  return=    6  avg(last 20)=   9.5
# Episode  100  return=    7  avg(last 20)=   7.7
# Episode  120  return=    8  avg(last 20)=   6.9
# Episode  140  return=   11  avg(last 20)=  11.9
# Episode  160  return=   22  avg(last 20)=  19.6
# Episode  180  return=  181  avg(last 20)=  58.0
# Episode  200  return=  159  avg(last 20)= 264.5
# Episode  220  return=  393  avg(last 20)= 213.6
# Episode  240  return=  113  avg(last 20)= 415.9
# Episode  260  return=   52  avg(last 20)=  78.5
# Episode  280  return=  253  avg(last 20)= 128.4
# Episode  300  return=  227  avg(last 20)= 339.7
# Episode  320  return=  542  avg(last 20)= 690.0
# Episode  340  return=  161  avg(last 20)= 482.4
# Episode  360  return=   82  avg(last 20)=  83.9
# Episode  380  return=  556  avg(last 20)= 266.4
# Episode  400  return=  680  avg(last 20)= 508.1
# Episode  420  return=  292  avg(last 20)= 779.1
# Episode  440  return=  970  avg(last 20)= 602.1
# Episode  460  return=  411  avg(last 20)= 771.7
# Episode  480  return=  162  avg(last 20)= 301.9
# Episode  500  return=  217  avg(last 20)= 277.3
# Episode  520  return=  246  avg(last 20)= 527.1
# Episode  540  return=  604  avg(last 20)= 544.6
# Episode  560  return=  973  avg(last 20)= 657.8
# Episode  580  return=  563  avg(last 20)= 597.2
# Episode  600  return=  984  avg(last 20)= 856.0
# Episode  620  return=  983  avg(last 20)= 987.1
# Episode  640  return=  705  avg(last 20)= 785.1
# Episode  660  return=  324  avg(last 20)= 464.3
# Episode  680  return=  999  avg(last 20)= 631.6
# Episode  700  return=  581  avg(last 20)= 987.0
# Episode  720  return=  510  avg(last 20)= 578.9
# Episode  740  return=  251  avg(last 20)= 450.0
# Episode  760  return=  158  avg(last 20)= 201.3
# Episode  780  return=  143  avg(last 20)= 139.8
# Episode  800  return=  136  avg(last 20)= 143.7
# Episode  820  return=  153  avg(last 20)= 161.5
# Episode  840  return=  168  avg(last 20)= 145.1
# Episode  860  return=  202  avg(last 20)= 169.1
# Episode  880  return=  177  avg(last 20)= 195.5
# Episode  900  return=  153  avg(last 20)= 150.6
# Episode  920  return=  123  avg(last 20)= 140.4
# Episode  940  return=  146  avg(last 20)= 138.4
# Episode  960  return=  187  avg(last 20)= 174.5
# Episode  980  return=  312  avg(last 20)= 239.9
# Episode 1000  return=  307  avg(last 20)= 395.7
# Episode 1020  return=  433  avg(last 20)= 362.9
# Episode 1040  return=  246  avg(last 20)= 384.9
# Episode 1060  return=  286  avg(last 20)= 271.9
# Episode 1080  return=  306  avg(last 20)= 323.5
# Episode 1100  return=  407  avg(last 20)= 392.1
# Episode 1120  return=  161  avg(last 20)= 385.7
# Episode 1140  return= 1019  avg(last 20)= 645.1
# Episode 1160  return= 1010  avg(last 20)=1017.1
# Episode 1180  return=  742  avg(last 20)= 951.3
# Episode 1200  return=  972  avg(last 20)= 562.4
# Episode 1220  return= 1004  avg(last 20)= 994.4
# Episode 1240  return= 1009  avg(last 20)=1008.0
# Episode 1260  return= 1011  avg(last 20)=1007.7
# Episode 1280  return= 1002  avg(last 20)=1012.6
# Episode 1300  return= 1005  avg(last 20)=1002.2
# Episode 1320  return= 1011  avg(last 20)=1007.5
# Episode 1340  return=  264  avg(last 20)= 809.3
# Episode 1360  return=  126  avg(last 20)= 157.1
# Episode 1380  return=   89  avg(last 20)= 110.9
# Episode 1400  return=   76  avg(last 20)=  80.6
# Episode 1420  return=   68  avg(last 20)=  73.9
# Episode 1440  return=   72  avg(last 20)=  68.4
# Episode 1460  return=   73  avg(last 20)=  73.4
# Episode 1480  return=   74  avg(last 20)=  75.4
# Episode 1500  return=   73  avg(last 20)=  74.0
# Episode 1520  return=   72  avg(last 20)=  68.8
# Episode 1540  return=   71  avg(last 20)=  70.2
# Episode 1560  return=   72  avg(last 20)=  72.1
# Episode 1580  return=   43  avg(last 20)=  56.2
# Episode 1600  return=   52  avg(last 20)=  45.2
# Episode 1620  return=   66  avg(last 20)=  63.5
# Episode 1640  return=   73  avg(last 20)=  73.9
# Episode 1660  return=   98  avg(last 20)=  79.0
# Episode 1680  return=  115  avg(last 20)= 102.9
# Episode 1700  return=  135  avg(last 20)= 129.8
# Episode 1720  return=  128  avg(last 20)= 137.1
# Episode 1740  return=  133  avg(last 20)= 129.3
# Episode 1760  return=  157  avg(last 20)= 139.8
# Episode 1780  return=  116  avg(last 20)= 137.8
# Episode 1800  return=   93  avg(last 20)= 106.7
# Episode 1820  return=   93  avg(last 20)=  92.6
# Episode 1840  return=   81  avg(last 20)=  85.3
# Episode 1860  return=   79  avg(last 20)=  82.0
# Episode 1880  return=   81  avg(last 20)=  78.6
# Episode 1900  return=   77  avg(last 20)=  76.0
# Episode 1920  return=   79  avg(last 20)=  76.8
# Episode 1940  return=   77  avg(last 20)=  77.4
# Episode 1960  return=  100  avg(last 20)=  85.7
# Episode 1980  return=  134  avg(last 20)= 115.9
# Episode 2000  return=  120  avg(last 20)= 124.5
# Episode 2020  return=  120  avg(last 20)= 114.0
# Episode 2040  return=  102  avg(last 20)= 112.2
# Episode 2060  return=   81  avg(last 20)=  92.3
# Episode 2080  return=   92  avg(last 20)=  83.9
# Episode 2100  return=  105  avg(last 20)=  88.6
# Episode 2120  return=  112  avg(last 20)= 105.7
# Episode 2140  return=  101  avg(last 20)= 106.1
# Episode 2160  return=  105  avg(last 20)= 107.1
# Episode 2180  return=  123  avg(last 20)= 117.5
# Episode 2200  return=  129  avg(last 20)= 125.8
# Episode 2220  return=  167  avg(last 20)= 142.3
# Episode 2240  return=  233  avg(last 20)= 182.5
# Episode 2260  return= 1019  avg(last 20)= 437.9
# Episode 2280  return=  996  avg(last 20)=1006.6
# Episode 2300  return=  982  avg(last 20)= 981.6
# Episode 2320  return= 1010  avg(last 20)= 995.9
# Episode 2340  return= 1015  avg(last 20)=1014.2
# Episode 2360  return= 1007  avg(last 20)=1012.2
# Episode 2380  return=  990  avg(last 20)= 999.2
# Episode 2400  return=  973  avg(last 20)= 979.8
# Episode 2420  return=  975  avg(last 20)= 958.7
# Episode 2440  return=  969  avg(last 20)= 972.9
# Episode 2460  return=  903  avg(last 20)= 954.3
# Episode 2480  return=  335  avg(last 20)= 537.9
# Episode 2500  return=  219  avg(last 20)= 298.5
# Episode 2520  return=  249  avg(last 20)= 237.5
# Episode 2540  return=  976  avg(last 20)= 580.2
# Episode 2560  return=  992  avg(last 20)= 982.5
# Episode 2580  return= 1000  avg(last 20)=1000.3
# Episode 2600  return=  983  avg(last 20)= 994.7
# Episode 2620  return=  984  avg(last 20)= 979.4
# Episode 2640  return=  655  avg(last 20)= 924.7
# Episode 2660  return=  995  avg(last 20)= 788.1
# Episode 2680  return= 1011  avg(last 20)=1000.3
# Episode 2700  return= 1018  avg(last 20)=1013.4
# Episode 2720  return=  352  avg(last 20)= 726.5
# Episode 2740  return=  274  avg(last 20)= 312.9
# Episode 2760  return=  231  avg(last 20)= 254.7
# Episode 2780  return=  312  avg(last 20)= 271.3
# Episode 2800  return=  249  avg(last 20)= 262.9
# Episode 2820  return=  182  avg(last 20)= 212.1
# Episode 2840  return=  167  avg(last 20)= 172.7
# Episode 2860  return=  153  avg(last 20)= 158.1
# Episode 2880  return=  134  avg(last 20)= 146.3
# Episode 2900  return=  139  avg(last 20)= 137.9
# Episode 2920  return=  126  avg(last 20)= 133.8
# Episode 2940  return=  109  avg(last 20)= 120.2
# Episode 2960  return=  115  avg(last 20)= 113.4
# Episode 2980  return=  134  avg(last 20)= 121.4
# Saved model_reinforce_none_seed2.pt and history_reinforce_none_seed2.pkl and time_reinforce_none_seed2.pkl
#
# Running: reinforce_constant_best_seed0
# State space: Box(-inf, inf, (11,), float64)
# Action space: Box(-1.0, 1.0, (3,), float32)
# Episode    0  return=    5  avg(last 20)=   5.3
# Episode   20  return=  125  avg(last 20)=  43.6
# Episode   40  return=  172  avg(last 20)= 125.0
# Episode   60  return=  101  avg(last 20)= 114.0
# Episode   80  return=  114  avg(last 20)= 117.5
# Episode  100  return=  258  avg(last 20)= 169.0
# Episode  120  return=  306  avg(last 20)= 194.9
# Episode  140  return=  151  avg(last 20)= 223.9
# Episode  160  return=  117  avg(last 20)= 149.9
# Episode  180  return=  453  avg(last 20)= 192.7
# Episode  200  return=  247  avg(last 20)= 738.2
# Episode  220  return=  611  avg(last 20)= 819.7
# Episode  240  return=  756  avg(last 20)= 661.7
# Episode  260  return=  225  avg(last 20)= 466.5
# Episode  280  return=  145  avg(last 20)= 151.8
# Episode  300  return=  140  avg(last 20)= 142.0
# Episode  320  return=  205  avg(last 20)= 193.5
# Episode  340  return=  207  avg(last 20)= 204.7
# Episode  360  return=  193  avg(last 20)= 202.6
# Episode  380  return=  153  avg(last 20)= 171.5
# Episode  400  return=  162  avg(last 20)= 170.7
# Episode  420  return=   97  avg(last 20)= 104.0
# Episode  440  return=  155  avg(last 20)= 120.7
# Episode  460  return=  215  avg(last 20)= 271.6
# Episode  480  return=  152  avg(last 20)= 197.6
# Episode  500  return=  195  avg(last 20)= 174.9
# Episode  520  return=  240  avg(last 20)= 213.6
# Episode  540  return=   85  avg(last 20)= 200.7
# Episode  560  return=   47  avg(last 20)= 103.6
# Episode  580  return=  127  avg(last 20)=  83.5
# Episode  600  return=  449  avg(last 20)= 350.9
# Episode  620  return=  314  avg(last 20)= 384.8
# Episode  640  return=  243  avg(last 20)= 269.4
# Episode  660  return=  830  avg(last 20)= 498.4
# Episode  680  return=  513  avg(last 20)= 798.8
# Episode  700  return=  505  avg(last 20)= 613.2
# Episode  720  return=  218  avg(last 20)= 350.2
# Episode  740  return=  176  avg(last 20)= 188.9
# Episode  760  return=  238  avg(last 20)= 203.4
# Episode  780  return=   99  avg(last 20)= 153.9
# Episode  800  return=  113  avg(last 20)= 108.8
# Episode  820  return=   98  avg(last 20)= 104.3
# Episode  840  return=  101  avg(last 20)=  98.6
# Episode  860  return=  104  avg(last 20)= 107.8
# Episode  880  return=  115  avg(last 20)= 123.4
# Episode  900  return=   98  avg(last 20)= 109.0
# Episode  920  return=   85  avg(last 20)=  91.1
# Episode  940  return=  102  avg(last 20)=  90.3
# Episode  960  return=  168  avg(last 20)= 133.5
# Episode  980  return=  150  avg(last 20)= 155.6
# Episode 1000  return=  132  avg(last 20)= 140.2
# Episode 1020  return=  130  avg(last 20)= 138.9
# Episode 1040  return=  140  avg(last 20)= 147.7
# Episode 1060  return=  159  avg(last 20)= 152.1
# Episode 1080  return=  160  avg(last 20)= 159.9
# Episode 1100  return=  247  avg(last 20)= 188.8
# Episode 1120  return=  200  avg(last 20)= 189.2
# Episode 1140  return=  183  avg(last 20)= 181.8
# Episode 1160  return=  247  avg(last 20)= 206.1
# Episode 1180  return=  215  avg(last 20)= 217.7
# Episode 1200  return=  322  avg(last 20)= 239.0
# Episode 1220  return=  479  avg(last 20)= 563.1
# Episode 1240  return=  455  avg(last 20)= 575.5
# Episode 1260  return=  165  avg(last 20)= 563.0
# Episode 1280  return= 1060  avg(last 20)= 532.5
# Episode 1300  return=  143  avg(last 20)= 817.8
# Episode 1320  return=  113  avg(last 20)= 497.2
# Episode 1340  return=  391  avg(last 20)= 428.9
# Episode 1360  return=  369  avg(last 20)= 361.0
# Episode 1380  return=  236  avg(last 20)= 293.0
# Episode 1400  return=  384  avg(last 20)= 268.6
# Episode 1420  return=  431  avg(last 20)= 326.4
# Episode 1440  return=  210  avg(last 20)= 267.2
# Episode 1460  return=  119  avg(last 20)= 135.3
# Episode 1480  return=  157  avg(last 20)= 124.5
# Episode 1500  return=   62  avg(last 20)= 105.6
# Episode 1520  return=   67  avg(last 20)= 118.7
# Episode 1540  return=  110  avg(last 20)= 106.2
# Episode 1560  return=   78  avg(last 20)=  99.2
# Episode 1580  return=   69  avg(last 20)=  70.3
# Episode 1600  return=   58  avg(last 20)=  64.0
# Episode 1620  return=   62  avg(last 20)=  61.5
# Episode 1640  return=  102  avg(last 20)=  77.4
# Episode 1660  return=   64  avg(last 20)=  85.0
# Episode 1680  return=   92  avg(last 20)=  68.9
# Episode 1700  return=   83  avg(last 20)=  81.2
# Episode 1720  return=  108  avg(last 20)=  89.0
# Episode 1740  return=   77  avg(last 20)=  86.7
# Episode 1760  return=   89  avg(last 20)=  78.3
# Episode 1780  return=   76  avg(last 20)= 101.6
# Episode 1800  return=  270  avg(last 20)= 164.3
# Episode 1820  return=  860  avg(last 20)= 462.6
# Episode 1840  return=  456  avg(last 20)= 503.8
# Episode 1860  return=  480  avg(last 20)= 482.7
# Episode 1880  return=  448  avg(last 20)= 518.8
# Episode 1900  return=  243  avg(last 20)= 501.5
# Episode 1920  return=   89  avg(last 20)= 526.8
# Episode 1940  return= 1049  avg(last 20)= 401.6
# Episode 1960  return= 1009  avg(last 20)= 870.0
# Episode 1980  return= 1008  avg(last 20)= 675.0
# Episode 2000  return=  371  avg(last 20)= 406.8
# Episode 2020  return= 1039  avg(last 20)= 587.9
# Episode 2040  return=  178  avg(last 20)= 226.5
# Episode 2060  return=   63  avg(last 20)= 152.6
# Episode 2080  return=  245  avg(last 20)= 269.3
# Episode 2100  return=  286  avg(last 20)= 877.9
# Episode 2120  return=  702  avg(last 20)= 608.2
# Episode 2140  return=   58  avg(last 20)= 184.9
# Episode 2160  return=  515  avg(last 20)= 273.2
# Episode 2180  return=  522  avg(last 20)= 555.3
# Episode 2200  return=  484  avg(last 20)= 409.7
# Episode 2220  return=  505  avg(last 20)= 466.6
# Episode 2240  return=  645  avg(last 20)= 564.0
# Episode 2260  return=  436  avg(last 20)= 519.2
# Episode 2280  return=  837  avg(last 20)= 636.9
# Episode 2300  return= 1004  avg(last 20)=1020.8
# Episode 2320  return= 1008  avg(last 20)=1006.5
# Episode 2340  return= 1008  avg(last 20)=1006.3
# Episode 2360  return= 1001  avg(last 20)=1006.8
# Episode 2380  return= 1006  avg(last 20)=1008.2
# Episode 2400  return= 1029  avg(last 20)=1016.5
# Episode 2420  return=  330  avg(last 20)= 808.0
# Episode 2440  return=  303  avg(last 20)= 469.0
# Episode 2460  return=  394  avg(last 20)= 375.9
# Episode 2480  return= 1201  avg(last 20)= 558.9
# Episode 2500  return= 1243  avg(last 20)= 891.6
# Episode 2520  return= 1032  avg(last 20)= 917.2
# Episode 2540  return=  679  avg(last 20)= 778.3
# Episode 2560  return=  293  avg(last 20)= 460.6
# Episode 2580  return=  522  avg(last 20)= 455.8
# Episode 2600  return=  266  avg(last 20)= 276.4
# Episode 2620  return=  250  avg(last 20)= 388.7
# Episode 2640  return=  809  avg(last 20)= 407.9
# Episode 2660  return=  342  avg(last 20)= 379.4
# Episode 2680  return=  294  avg(last 20)= 319.3
# Episode 2700  return=  260  avg(last 20)= 299.5
# Episode 2720  return=  260  avg(last 20)= 309.7
# Episode 2740  return=  279  avg(last 20)= 297.5
# Episode 2760  return=  428  avg(last 20)= 325.5
# Episode 2780  return=  263  avg(last 20)= 336.7
# Episode 2800  return=  272  avg(last 20)= 290.0
# Episode 2820  return=  330  avg(last 20)= 342.0
# Episode 2840  return=  448  avg(last 20)= 407.3
# Episode 2860  return=  455  avg(last 20)= 428.4
# Episode 2880  return=  446  avg(last 20)= 435.5
# Episode 2900  return=  404  avg(last 20)= 482.3
# Episode 2920  return=  519  avg(last 20)= 471.8
# Episode 2940  return=  255  avg(last 20)= 378.9
# Episode 2960  return=  263  avg(last 20)= 275.5
# Episode 2980  return=  244  avg(last 20)= 247.9
# Saved model_reinforce_constant_best_seed0.pt and history_reinforce_constant_best_seed0.pkl and time_reinforce_constant_best_seed0.pkl
#
# Running: reinforce_constant_best_seed1
# State space: Box(-inf, inf, (11,), float64)
# Action space: Box(-1.0, 1.0, (3,), float32)
# Episode    0  return=    8  avg(last 20)=   7.8
# Episode   20  return=   11  avg(last 20)=  10.6
# Episode   40  return=   42  avg(last 20)=  17.2
# Episode   60  return=  103  avg(last 20)=  65.0
# Episode   80  return=   86  avg(last 20)= 122.6
# Episode  100  return=  225  avg(last 20)= 192.4
# Episode  120  return=  229  avg(last 20)= 221.7
# Episode  140  return=  222  avg(last 20)= 219.0
# Episode  160  return=  214  avg(last 20)= 174.0
# Episode  180  return=  193  avg(last 20)= 194.2
# Episode  200  return=  174  avg(last 20)= 192.4
# Episode  220  return=  163  avg(last 20)= 179.3
# Episode  240  return=  180  avg(last 20)= 171.0
# Episode  260  return=  198  avg(last 20)= 164.9
# Episode  280  return=  186  avg(last 20)= 105.0
# Episode  300  return=  164  avg(last 20)= 140.2
# Episode  320  return=  152  avg(last 20)= 134.0
# Episode  340  return=  141  avg(last 20)= 126.7
# Episode  360  return=  102  avg(last 20)= 134.7
# Episode  380  return=  159  avg(last 20)= 146.7
# Episode  400  return=   99  avg(last 20)= 143.6
# Episode  420  return=  138  avg(last 20)= 112.2
# Episode  440  return=  149  avg(last 20)= 148.2
# Episode  460  return=   74  avg(last 20)=  80.3
# Episode  480  return=   88  avg(last 20)=  84.2
# Episode  500  return=  139  avg(last 20)= 120.9
# Episode  520  return=   93  avg(last 20)=  96.4
# Episode  540  return=   81  avg(last 20)=  60.2
# Episode  560  return=  166  avg(last 20)= 141.9
# Episode  580  return=  185  avg(last 20)= 175.0
# Episode  600  return=  193  avg(last 20)= 186.2
# Episode  620  return=  183  avg(last 20)= 190.4
# Episode  640  return=  204  avg(last 20)= 193.2
# Episode  660  return=  200  avg(last 20)= 191.4
# Episode  680  return=  173  avg(last 20)= 188.4
# Episode  700  return=  183  avg(last 20)= 187.1
# Episode  720  return=  211  avg(last 20)= 193.4
# Episode  740  return=  153  avg(last 20)= 185.1
# Episode  760  return=  185  avg(last 20)= 161.5
# Episode  780  return=  185  avg(last 20)= 167.6
# Episode  800  return=  156  avg(last 20)= 173.2
# Episode  820  return=  100  avg(last 20)= 128.2
# Episode  840  return=   88  avg(last 20)=  95.7
# Episode  860  return=   75  avg(last 20)=  82.4
# Episode  880  return=   79  avg(last 20)=  75.7
# Episode  900  return=   78  avg(last 20)=  77.6
# Episode  920  return=   87  avg(last 20)=  86.2
# Episode  940  return=   80  avg(last 20)=  81.3
# Episode  960  return=   70  avg(last 20)=  75.2
# Episode  980  return=   67  avg(last 20)=  61.1
# Episode 1000  return=   69  avg(last 20)=  64.4
# Episode 1020  return=   52  avg(last 20)=  60.6
# Episode 1040  return=   50  avg(last 20)=  56.1
# Episode 1060  return=   61  avg(last 20)=  57.1
# Episode 1080  return=   65  avg(last 20)=  62.1
# Episode 1100  return=   84  avg(last 20)=  76.5
# Episode 1120  return=   90  avg(last 20)=  91.3
# Episode 1140  return=   75  avg(last 20)=  82.2
# Episode 1160  return=  109  avg(last 20)=  92.0
# Episode 1180  return=  180  avg(last 20)= 148.6
# Episode 1200  return=  178  avg(last 20)= 180.1
# Episode 1220  return=  189  avg(last 20)= 185.0
# Episode 1240  return=  197  avg(last 20)= 189.7
# Episode 1260  return=  177  avg(last 20)= 190.1
# Episode 1280  return=  176  avg(last 20)= 176.8
# Episode 1300  return=  152  avg(last 20)= 164.4
# Episode 1320  return=   78  avg(last 20)= 113.3
# Episode 1340  return=   82  avg(last 20)=  78.3
# Episode 1360  return=   84  avg(last 20)=  78.9
# Episode 1380  return=   73  avg(last 20)=  82.6
# Episode 1400  return=   95  avg(last 20)=  81.0
# Episode 1420  return=   93  avg(last 20)=  96.4
# Episode 1440  return=   87  avg(last 20)= 101.7
# Episode 1460  return=   72  avg(last 20)=  74.6
# Episode 1480  return=   58  avg(last 20)=  60.8
# Episode 1500  return=   55  avg(last 20)=  57.0
# Episode 1520  return=   53  avg(last 20)=  52.6
# Episode 1540  return=   44  avg(last 20)=  48.9
# Episode 1560  return=   48  avg(last 20)=  47.4
# Episode 1580  return=   61  avg(last 20)=  55.3
# Episode 1600  return=   57  avg(last 20)=  61.1
# Episode 1620  return=   59  avg(last 20)=  58.3
# Episode 1640  return=   71  avg(last 20)=  62.8
# Episode 1660  return=  108  avg(last 20)=  90.5
# Episode 1680  return=  128  avg(last 20)= 106.2
# Episode 1700  return=  119  avg(last 20)= 118.9
# Episode 1720  return=  115  avg(last 20)= 105.8
# Episode 1740  return=  172  avg(last 20)= 146.4
# Episode 1760  return=  170  avg(last 20)= 161.8
# Episode 1780  return=  129  avg(last 20)= 137.1
# Episode 1800  return=  105  avg(last 20)= 123.7
# Episode 1820  return=  108  avg(last 20)= 109.1
# Episode 1840  return=  152  avg(last 20)= 114.5
# Episode 1860  return=  158  avg(last 20)= 152.8
# Episode 1880  return=  200  avg(last 20)= 179.5
# Episode 1900  return=  190  avg(last 20)= 185.1
# Episode 1920  return=  189  avg(last 20)= 189.0
# Episode 1940  return=  177  avg(last 20)= 184.5
# Episode 1960  return=  112  avg(last 20)= 156.3
# Episode 1980  return=   67  avg(last 20)=  72.8
# Episode 2000  return=   89  avg(last 20)=  72.2
# Episode 2020  return=   92  avg(last 20)=  94.7
# Episode 2040  return=  152  avg(last 20)= 142.0
# Episode 2060  return=  175  avg(last 20)= 169.0
# Episode 2080  return=  186  avg(last 20)= 188.2
# Episode 2100  return=  191  avg(last 20)= 188.7
# Episode 2120  return=  175  avg(last 20)= 178.9
# Episode 2140  return=  163  avg(last 20)= 172.7
# Episode 2160  return=  165  avg(last 20)= 165.0
# Episode 2180  return=  164  avg(last 20)= 164.9
# Episode 2200  return=  168  avg(last 20)= 163.7
# Episode 2220  return=  179  avg(last 20)= 170.2
# Episode 2240  return=  168  avg(last 20)= 178.9
# Episode 2260  return=  181  avg(last 20)= 177.9
# Episode 2280  return=  179  avg(last 20)= 182.4
# Episode 2300  return=  189  avg(last 20)= 191.7
# Episode 2320  return=  184  avg(last 20)= 185.1
# Episode 2340  return=  103  avg(last 20)= 155.7
# Episode 2360  return=  101  avg(last 20)= 104.9
# Episode 2380  return=   78  avg(last 20)= 102.1
# Episode 2400  return=   61  avg(last 20)=  64.6
# Episode 2420  return=   94  avg(last 20)=  78.2
# Episode 2440  return=   92  avg(last 20)=  87.6
# Episode 2460  return=  156  avg(last 20)= 135.0
# Episode 2480  return=  154  avg(last 20)= 153.4
# Episode 2500  return=  157  avg(last 20)= 155.7
# Episode 2520  return=   49  avg(last 20)=  89.9
# Episode 2540  return=   35  avg(last 20)=  41.6
# Episode 2560  return=   33  avg(last 20)=  30.2
# Episode 2580  return=   33  avg(last 20)=  37.4
# Episode 2600  return=   31  avg(last 20)=  31.9
# Episode 2620  return=   25  avg(last 20)=  29.0
# Episode 2640  return=   20  avg(last 20)=  21.7
# Episode 2660  return=   17  avg(last 20)=  20.0
# Episode 2680  return=   16  avg(last 20)=  14.0
# Episode 2700  return=   26  avg(last 20)=  20.8
# Episode 2720  return=   20  avg(last 20)=  25.6
# Episode 2740  return=   21  avg(last 20)=  21.5
# Episode 2760  return=   24  avg(last 20)=  24.7
# Episode 2780  return=   14  avg(last 20)=  18.4
# Episode 2800  return=   11  avg(last 20)=   9.6
# Episode 2820  return=    7  avg(last 20)=   8.0
# Episode 2840  return=   13  avg(last 20)=   9.4
# Episode 2860  return=    5  avg(last 20)=   6.7
# Episode 2880  return=    6  avg(last 20)=   6.1
# Episode 2900  return=    6  avg(last 20)=   6.9
# Episode 2920  return=    5  avg(last 20)=   5.8
# Episode 2940  return=   13  avg(last 20)=   9.0
# Episode 2960  return=   24  avg(last 20)=  15.6
# Episode 2980  return=   31  avg(last 20)=  30.2
# Saved model_reinforce_constant_best_seed1.pt and history_reinforce_constant_best_seed1.pkl and time_reinforce_constant_best_seed1.pkl
#
# Running: reinforce_constant_best_seed2
# State space: Box(-inf, inf, (11,), float64)
# Action space: Box(-1.0, 1.0, (3,), float32)
# Episode    0  return=    8  avg(last 20)=   7.6
# Episode   20  return=   11  avg(last 20)=  10.7
# Episode   40  return=    6  avg(last 20)=   9.0
# Episode   60  return=  221  avg(last 20)=  49.6
# Episode   80  return=  107  avg(last 20)= 122.1
# Episode  100  return=  104  avg(last 20)=  98.7
# Episode  120  return=   97  avg(last 20)= 109.5
# Episode  140  return=  365  avg(last 20)= 167.6
# Episode  160  return=  784  avg(last 20)= 562.3
# Episode  180  return= 1013  avg(last 20)= 792.8
# Episode  200  return=  178  avg(last 20)= 590.7
# Episode  220  return= 1019  avg(last 20)= 495.9
# Episode  240  return=  972  avg(last 20)= 764.1
# Episode  260  return=  167  avg(last 20)= 627.4
# Episode  280  return=  222  avg(last 20)= 207.7
# Episode  300  return= 1036  avg(last 20)= 695.2
# Episode  320  return=  255  avg(last 20)= 420.0
# Episode  340  return=  981  avg(last 20)= 616.5
# Episode  360  return=  484  avg(last 20)= 704.6
# Episode  380  return=  297  avg(last 20)= 376.8
# Episode  400  return=  319  avg(last 20)= 302.4
# Episode  420  return=  457  avg(last 20)= 404.8
# Episode  440  return=  675  avg(last 20)= 518.3
# Episode  460  return=  981  avg(last 20)= 752.5
# Episode  480  return=  818  avg(last 20)= 971.7
# Episode  500  return=  711  avg(last 20)= 714.8
# Episode  520  return=  419  avg(last 20)= 500.0
# Episode  540  return= 1021  avg(last 20)= 714.6
# Episode  560  return= 1013  avg(last 20)=1016.3
# Episode  580  return=  674  avg(last 20)= 988.9
# Episode  600  return=  262  avg(last 20)= 542.2
# Episode  620  return=  648  avg(last 20)= 565.2
# Episode  640  return=  394  avg(last 20)= 449.8
# Episode  660  return=  282  avg(last 20)= 324.1
# Episode  680  return=  200  avg(last 20)= 221.2
# Episode  700  return=  197  avg(last 20)= 209.3
# Episode  720  return=  188  avg(last 20)= 229.3
# Episode  740  return=  293  avg(last 20)= 253.3
# Episode  760  return=  318  avg(last 20)= 318.0
# Episode  780  return=  253  avg(last 20)= 288.3
# Episode  800  return=  290  avg(last 20)= 268.2
# Episode  820  return=  305  avg(last 20)= 304.4
# Episode  840  return=  313  avg(last 20)= 310.0
# Episode  860  return=  305  avg(last 20)= 309.8
# Episode  880  return=  257  avg(last 20)= 281.4
# Episode  900  return=  258  avg(last 20)= 260.4
# Episode  920  return=  285  avg(last 20)= 264.4
# Episode  940  return=  260  avg(last 20)= 266.7
# Episode  960  return=  158  avg(last 20)= 194.2
# Episode  980  return=  107  avg(last 20)= 126.5
# Episode 1000  return=  104  avg(last 20)= 105.7
# Episode 1020  return=  121  avg(last 20)= 113.1
# Episode 1040  return=  141  avg(last 20)= 126.9
# Episode 1060  return=  242  avg(last 20)= 188.1
# Episode 1080  return=  272  avg(last 20)= 262.8
# Episode 1100  return=  258  avg(last 20)= 275.2
# Episode 1120  return=  287  avg(last 20)= 275.6
# Episode 1140  return=  297  avg(last 20)= 306.3
# Episode 1160  return=  307  avg(last 20)= 290.9
# Episode 1180  return=  321  avg(last 20)= 303.4
# Episode 1200  return=  341  avg(last 20)= 319.4
# Episode 1220  return=  388  avg(last 20)= 379.6
# Episode 1240  return=  362  avg(last 20)= 373.5
# Episode 1260  return=  355  avg(last 20)= 357.1
# Episode 1280  return=  355  avg(last 20)= 374.5
# Episode 1300  return=  322  avg(last 20)= 329.2
# Episode 1320  return=  290  avg(last 20)= 302.7
# Episode 1340  return=  297  avg(last 20)= 285.3
# Episode 1360  return=  320  avg(last 20)= 308.4
# Episode 1380  return=  386  avg(last 20)= 354.7
# Episode 1400  return=  404  avg(last 20)= 415.4
# Episode 1420  return=  480  avg(last 20)= 449.1
# Episode 1440  return=  524  avg(last 20)= 511.3
# Episode 1460  return=  580  avg(last 20)= 548.9
# Episode 1480  return=  448  avg(last 20)= 490.0
# Episode 1500  return=  368  avg(last 20)= 426.5
# Episode 1520  return=  362  avg(last 20)= 362.7
# Episode 1540  return=  353  avg(last 20)= 355.3
# Episode 1560  return=  315  avg(last 20)= 315.1
# Episode 1580  return=  301  avg(last 20)= 305.4
# Episode 1600  return=  271  avg(last 20)= 235.8
# Episode 1620  return=  244  avg(last 20)= 228.6
# Episode 1640  return=  198  avg(last 20)= 230.3
# Episode 1660  return=  216  avg(last 20)= 213.3
# Episode 1680  return=  227  avg(last 20)= 235.2
# Episode 1700  return=  237  avg(last 20)= 244.9
# Episode 1720  return=  241  avg(last 20)= 228.2
# Episode 1740  return=  224  avg(last 20)= 221.2
# Episode 1760  return=  247  avg(last 20)= 227.9
# Episode 1780  return=  257  avg(last 20)= 246.1
# Episode 1800  return=  247  avg(last 20)= 250.3
# Episode 1820  return=  232  avg(last 20)= 233.8
# Episode 1840  return=  155  avg(last 20)= 195.1
# Episode 1860  return=  142  avg(last 20)= 129.5
# Episode 1880  return=  131  avg(last 20)= 119.3
# Episode 1900  return=  144  avg(last 20)= 115.9
# Episode 1920  return=  140  avg(last 20)= 143.9
# Episode 1940  return=  235  avg(last 20)= 184.8
# Episode 1960  return=  229  avg(last 20)= 234.2
# Episode 1980  return=  238  avg(last 20)= 241.0
# Episode 2000  return=  259  avg(last 20)= 241.6
# Episode 2020  return=  269  avg(last 20)= 257.0
# Episode 2040  return=  236  avg(last 20)= 256.3
# Episode 2060  return=  228  avg(last 20)= 252.8
# Episode 2080  return=  293  avg(last 20)= 244.6
# Episode 2100  return=  260  avg(last 20)= 260.8
# Episode 2120  return=  195  avg(last 20)= 241.9
# Episode 2140  return=  160  avg(last 20)= 182.4
# Episode 2160  return=  278  avg(last 20)= 200.3
# Episode 2180  return=  216  avg(last 20)= 238.3
# Episode 2200  return=  184  avg(last 20)= 194.3
# Episode 2220  return=  233  avg(last 20)= 189.4
# Episode 2240  return=  262  avg(last 20)= 244.3
# Episode 2260  return=  235  avg(last 20)= 246.6
# Episode 2280  return=  210  avg(last 20)= 224.4
# Episode 2300  return=  223  avg(last 20)= 227.4
# Episode 2320  return=  215  avg(last 20)= 227.1
# Episode 2340  return=  230  avg(last 20)= 221.1
# Episode 2360  return=  223  avg(last 20)= 228.7
# Episode 2380  return=  212  avg(last 20)= 214.4
# Episode 2400  return=  214  avg(last 20)= 210.7
# Episode 2420  return=  212  avg(last 20)= 212.9
# Episode 2440  return=  213  avg(last 20)= 212.9
# Episode 2460  return=  206  avg(last 20)= 208.3
# Episode 2480  return=  154  avg(last 20)= 177.9
# Episode 2500  return=  116  avg(last 20)= 133.5
# Episode 2520  return=  211  avg(last 20)= 135.0
# Episode 2540  return=  275  avg(last 20)= 251.3
# Episode 2560  return=  276  avg(last 20)= 295.8
# Episode 2580  return=  250  avg(last 20)= 264.4
# Episode 2600  return=  275  avg(last 20)= 199.2
# Episode 2620  return=  261  avg(last 20)= 262.4
# Episode 2640  return=  216  avg(last 20)= 227.3
# Episode 2660  return=  217  avg(last 20)= 216.8
# Episode 2680  return=  209  avg(last 20)= 214.9
# Episode 2700  return=  198  avg(last 20)= 201.5
# Episode 2720  return=  179  avg(last 20)= 186.6
# Episode 2740  return=  190  avg(last 20)= 190.1
# Episode 2760  return=  197  avg(last 20)= 193.9
# Episode 2780  return=  203  avg(last 20)= 198.3
# Episode 2800  return=  196  avg(last 20)= 203.8
# Episode 2820  return=  194  avg(last 20)= 197.4
# Episode 2840  return=  184  avg(last 20)= 193.0
# Episode 2860  return=  194  avg(last 20)= 190.6
# Episode 2880  return=  191  avg(last 20)= 194.8
# Episode 2900  return=  178  avg(last 20)= 189.2
# Episode 2920  return=  177  avg(last 20)= 178.5
# Episode 2940  return=  175  avg(last 20)= 180.1
# Episode 2960  return=  173  avg(last 20)= 175.4
# Episode 2980  return=   95  avg(last 20)= 150.1
# Saved model_reinforce_constant_best_seed2.pt and history_reinforce_constant_best_seed2.pkl and time_reinforce_constant_best_seed2.pkl
#
# Running: reinforce_ema_best_seed0
# State space: Box(-inf, inf, (11,), float64)
# Action space: Box(-1.0, 1.0, (3,), float32)
# Episode    0  return=    5  avg(last 20)=   5.3
# Episode   20  return=    6  avg(last 20)=   6.0
# Episode   40  return=    7  avg(last 20)=   6.1
# Episode   60  return=    4  avg(last 20)=   5.6
# Episode   80  return=    7  avg(last 20)=   5.9
# Episode  100  return=   11  avg(last 20)=   9.4
# Episode  120  return=   10  avg(last 20)=  11.3
# Episode  140  return=    6  avg(last 20)=   7.9
# Episode  160  return=    9  avg(last 20)=   8.9
# Episode  180  return=   13  avg(last 20)=  12.2
# Episode  200  return=   33  avg(last 20)=  17.8
# Episode  220  return=  140  avg(last 20)=  74.9
# Episode  240  return=  930  avg(last 20)= 254.1
# Episode  260  return=  996  avg(last 20)= 680.6
# Episode  280  return=  982  avg(last 20)= 871.2
# Episode  300  return= 1017  avg(last 20)=1005.4
# Episode  320  return=  183  avg(last 20)= 434.8
# Episode  340  return=  205  avg(last 20)= 187.8
# Episode  360  return=  205  avg(last 20)= 209.7
# Episode  380  return=  133  avg(last 20)= 164.5
# Episode  400  return=  144  avg(last 20)= 142.7
# Episode  420  return=  140  avg(last 20)= 143.2
# Episode  440  return=  120  avg(last 20)= 136.5
# Episode  460  return=  118  avg(last 20)= 143.4
# Episode  480  return=   66  avg(last 20)=  94.2
# Episode  500  return=   54  avg(last 20)=  58.9
# Episode  520  return=   71  avg(last 20)=  63.8
# Episode  540  return=   85  avg(last 20)=  75.8
# Episode  560  return=   96  avg(last 20)=  99.3
# Episode  580  return=  112  avg(last 20)= 108.1
# Episode  600  return=  121  avg(last 20)= 113.0
# Episode  620  return=  101  avg(last 20)= 120.6
# Episode  640  return=  124  avg(last 20)= 107.2
# Episode  660  return=  195  avg(last 20)= 162.7
# Episode  680  return=  232  avg(last 20)= 265.7
# Episode  700  return=  248  avg(last 20)= 222.5
# Episode  720  return=  630  avg(last 20)= 329.7
# Episode  740  return= 1008  avg(last 20)=1020.1
# Episode  760  return= 1005  avg(last 20)=1003.1
# Episode  780  return= 1035  avg(last 20)=1020.7
# Episode  800  return=  257  avg(last 20)= 452.0
# Episode  820  return=  301  avg(last 20)= 255.9
# Episode  840  return=  294  avg(last 20)= 348.9
# Episode  860  return=  347  avg(last 20)= 288.0
# Episode  880  return=  288  avg(last 20)= 403.7
# Episode  900  return=  225  avg(last 20)= 289.3
# Episode  920  return=   45  avg(last 20)= 110.6
# Episode  940  return= 1036  avg(last 20)= 214.7
# Episode  960  return=  679  avg(last 20)= 853.2
# Episode  980  return=  592  avg(last 20)= 499.0
# Episode 1000  return= 1048  avg(last 20)= 828.5
# Episode 1020  return=  478  avg(last 20)= 716.9
# Episode 1040  return=  800  avg(last 20)= 709.7
# Episode 1060  return=  650  avg(last 20)= 745.8
# Episode 1080  return=  718  avg(last 20)= 581.0
# Episode 1100  return=  413  avg(last 20)= 491.9
# Episode 1120  return= 1027  avg(last 20)= 667.3
# Episode 1140  return=  992  avg(last 20)= 802.2
# Episode 1160  return= 1025  avg(last 20)=1007.0
# Episode 1180  return=  997  avg(last 20)=1011.0
# Episode 1200  return=  984  avg(last 20)= 949.9
# Episode 1220  return=  160  avg(last 20)= 507.2
# Episode 1240  return=  138  avg(last 20)= 131.1
# Episode 1260  return=  992  avg(last 20)= 719.2
# Episode 1280  return=  995  avg(last 20)= 993.7
# Episode 1300  return=  994  avg(last 20)= 955.0
# ...
# Episode 2560  return= 1019  avg(last 20)=1003.2
# Episode 2580  return= 1019  avg(last 20)=1002.0
# Episode 2600  return= 1001  avg(last 20)=1007.2
# Episode 2620  return= 1041  avg(last 20)=1025.9
# Episode 2640  return= 1039  avg(last 20)=1034.6
# Episode 2660  return= 1024  avg(last 20)=1028.7
# Episode 2680  return=  596  avg(last 20)= 987.6
# Episode 2700  return= 1026  avg(last 20)= 996.7
# Episode 2720  return= 1026  avg(last 20)=1016.1
# Episode 2740  return= 1004  avg(last 20)=1017.7
# Episode 2760  return=  997  avg(last 20)=1002.7
# Episode 2780  return= 1016  avg(last 20)=1004.0
# Episode 2800  return= 1038  avg(last 20)= 789.3
# Episode 2820  return=  994  avg(last 20)=1004.6
# Episode 2840  return= 1016  avg(last 20)=1010.0
# Episode 2860  return= 1004  avg(last 20)=1012.3
# Episode 2880  return=  780  avg(last 20)= 999.5
# Episode 2900  return= 1009  avg(last 20)=1014.9
# Episode 2920  return= 1011  avg(last 20)= 988.2
# Episode 2940  return= 1004  avg(last 20)=1015.1
# Episode 2960  return= 1011  avg(last 20)=1006.9
# Episode 2980  return= 1021  avg(last 20)=1008.2
# Saved model_actor_critic_seed0.pt and history_actor_critic_seed0.pkl and time_actor_critic_seed0.pkl
#
# Running: actor_critic_seed1
# State space: Box(-inf, inf, (11,), float64)
# Action space: Box(-1.0, 1.0, (3,), float32)
# Episode    0  return=    8  avg(last 20)=   7.8
# Episode   20  return=   19  avg(last 20)=  18.6
# Episode   40  return=    9  avg(last 20)=  13.5
# Episode   60  return=    8  avg(last 20)=  11.0
# Episode   80  return=   11  avg(last 20)=  10.3
# Episode  100  return=    8  avg(last 20)=  12.8
# Episode  120  return=   57  avg(last 20)=  26.1
# Episode  140  return=   22  avg(last 20)=  66.5
# Episode  160  return=   58  avg(last 20)= 130.9
# Episode  180  return=  123  avg(last 20)= 102.3
# Episode  200  return=  147  avg(last 20)= 150.7
# Episode  220  return=  211  avg(last 20)= 150.4
# Episode  240  return=  151  avg(last 20)= 154.0
# Episode  260  return=  209  avg(last 20)= 152.0
# Episode  280  return=  230  avg(last 20)= 180.5
# Episode  300  return=  176  avg(last 20)= 186.6
# Episode  320  return=  207  avg(last 20)= 194.3
# Episode  340  return=  207  avg(last 20)= 205.4
# Episode  360  return=  208  avg(last 20)= 204.7
# Episode  380  return=  222  avg(last 20)= 207.8
# Episode  400  return=  137  avg(last 20)= 191.1
# Episode  420  return=  226  avg(last 20)= 187.1
# Episode  440  return=  172  avg(last 20)= 176.4
# Episode  460  return=  206  avg(last 20)= 197.0
# Episode  480  return=  210  avg(last 20)= 168.4
# Episode  500  return=  196  avg(last 20)= 173.0
# Episode  520  return=  196  avg(last 20)= 185.7
# Episode  540  return=  170  avg(last 20)= 173.1
# Episode  560  return=  146  avg(last 20)= 135.4
# Episode  580  return=  195  avg(last 20)= 130.7
# Episode  600  return=  190  avg(last 20)= 173.8
# Episode  620  return=  207  avg(last 20)= 182.7
# Episode  640  return=  163  avg(last 20)= 184.6
# Episode  660  return=  103  avg(last 20)= 160.6
# Episode  680  return=  213  avg(last 20)= 174.4
# Episode  700  return=  171  avg(last 20)= 193.3
# Episode  720  return=  183  avg(last 20)= 191.0
# Episode  740  return=  195  avg(last 20)= 197.0
# Episode  760  return=  192  avg(last 20)= 187.3
# Episode  780  return=  127  avg(last 20)= 185.3
# Episode  800  return=  193  avg(last 20)= 171.4
# Episode  820  return=  195  avg(last 20)= 181.3
# Episode  840  return=  191  avg(last 20)= 182.8
# Episode  860  return=  183  avg(last 20)= 191.8
# Episode  880  return=  152  avg(last 20)= 146.6
# Episode  900  return=  183  avg(last 20)= 167.3
# Episode  920  return=  190  avg(last 20)= 175.3
# Episode  940  return=  182  avg(last 20)= 170.8
# Episode  960  return=  127  avg(last 20)= 162.2
# Episode  980  return=  184  avg(last 20)= 176.6
# Episode 1000  return=  194  avg(last 20)= 172.2
# Episode 1020  return=  184  avg(last 20)= 169.1
# Episode 1040  return=  186  avg(last 20)= 176.2
# Episode 1060  return=  210  avg(last 20)= 183.3
# Episode 1080  return=  176  avg(last 20)= 181.5
# Episode 1100  return=  188  avg(last 20)= 186.4
# Episode 1120  return=  187  avg(last 20)= 187.6
# Episode 1140  return=  179  avg(last 20)= 182.2
# Episode 1160  return=   89  avg(last 20)= 179.0
# Episode 1180  return=  193  avg(last 20)= 183.3
# Episode 1200  return=  188  avg(last 20)= 188.3
# Episode 1220  return=  185  avg(last 20)= 184.7
# Episode 1240  return=  185  avg(last 20)= 181.7
# Episode 1260  return=  106  avg(last 20)= 173.4
# Episode 1280  return=  184  avg(last 20)= 167.0
# Episode 1300  return=  175  avg(last 20)= 174.2
# Episode 1320  return=  181  avg(last 20)= 181.8
# Episode 1340  return=  181  avg(last 20)= 178.1
# Episode 1360  return=  173  avg(last 20)= 181.1
# Episode 1380  return=  184  avg(last 20)= 177.4
# Episode 1400  return=  175  avg(last 20)= 175.9
# Episode 1420  return=  166  avg(last 20)= 176.4
# Episode 1440  return=  138  avg(last 20)= 172.3
# Episode 1460  return=  183  avg(last 20)= 173.5
# Episode 1480  return=  175  avg(last 20)= 171.2
# Episode 1500  return=  176  avg(last 20)= 171.4
# Episode 1520  return=  170  avg(last 20)= 175.0
# Episode 1540  return=  172  avg(last 20)= 177.5
# Episode 1560  return=  175  avg(last 20)= 177.0
# Episode 1580  return=  176  avg(last 20)= 172.8
# Episode 1600  return=  175  avg(last 20)= 169.5
# Episode 1620  return=  180  avg(last 20)= 174.2
# Episode 1640  return=  170  avg(last 20)= 173.0
# Episode 1660  return=  171  avg(last 20)= 173.2
# Episode 1680  return=  175  avg(last 20)= 175.3
# Episode 1700  return=  185  avg(last 20)= 177.4
# Episode 1720  return=  189  avg(last 20)= 177.8
# Episode 1740  return=  186  avg(last 20)= 176.9
# Episode 1760  return=  174  avg(last 20)= 176.6
# Episode 1780  return=  191  avg(last 20)= 177.0
# Episode 1800  return=  183  avg(last 20)= 177.8
# Episode 1820  return=  180  avg(last 20)= 163.8
# Episode 1840  return=  188  avg(last 20)= 175.8
# Episode 1860  return=  114  avg(last 20)= 163.9
# Episode 1880  return=  181  avg(last 20)= 177.6
# Episode 1900  return=  167  avg(last 20)= 173.4
# Episode 1920  return=  181  avg(last 20)= 173.5
# Episode 1940  return=   60  avg(last 20)= 155.9
# Episode 1960  return=  183  avg(last 20)= 149.1
# Episode 1980  return=  178  avg(last 20)= 148.6
# Episode 2000  return=  175  avg(last 20)= 172.5
# Episode 2020  return=  178  avg(last 20)= 172.2
# Episode 2040  return=  177  avg(last 20)= 171.7
# Episode 2060  return=  170  avg(last 20)= 169.9
# Episode 2080  return=  174  avg(last 20)= 174.4
# Episode 2100  return=  182  avg(last 20)= 176.7
# Episode 2120  return=  180  avg(last 20)= 175.1
# Episode 2140  return=  189  avg(last 20)= 174.2
# Episode 2160  return=  176  avg(last 20)= 173.9
# Episode 2180  return=  174  avg(last 20)= 175.4
# Episode 2200  return=  131  avg(last 20)= 172.7
# Episode 2220  return=  192  avg(last 20)= 168.4
# Episode 2240  return=  178  avg(last 20)= 171.3
# Episode 2260  return=  189  avg(last 20)= 170.0
# Episode 2280  return=  183  avg(last 20)= 159.2
# Episode 2300  return=  178  avg(last 20)= 173.8
# Episode 2320  return=  182  avg(last 20)= 165.4
# Episode 2340  return=  181  avg(last 20)= 167.8
# Episode 2360  return=  177  avg(last 20)= 175.3
# Episode 2380  return=  174  avg(last 20)= 175.8
# Episode 2400  return=  175  avg(last 20)= 171.8
# Episode 2420  return=  177  avg(last 20)= 178.2
# Episode 2440  return=  179  avg(last 20)= 177.9
# Episode 2460  return=  181  avg(last 20)= 178.3
# Episode 2480  return=  182  avg(last 20)= 177.5
# Episode 2500  return=  181  avg(last 20)= 172.5
# Episode 2520  return=  177  avg(last 20)= 175.8
# Episode 2540  return=  184  avg(last 20)= 176.8
# Episode 2560  return=  171  avg(last 20)= 175.5
# Episode 2580  return=  177  avg(last 20)= 175.5
# Episode 2600  return=  178  avg(last 20)= 176.5
# Episode 2620  return=  175  avg(last 20)= 178.1
# Episode 2640  return=  178  avg(last 20)= 176.9
# Episode 2660  return=  174  avg(last 20)= 175.4
# Episode 2680  return=  175  avg(last 20)= 173.7
# Episode 2700  return=  173  avg(last 20)= 173.3
# Episode 2720  return=  177  avg(last 20)= 174.8
# Episode 2740  return=  171  avg(last 20)= 175.4
# Episode 2760  return=  175  avg(last 20)= 172.3
# Episode 2780  return=  174  avg(last 20)= 172.3
# Episode 2800  return=  176  avg(last 20)= 174.0
# Episode 2820  return=  169  avg(last 20)= 171.3
# Episode 2840  return=  173  avg(last 20)= 173.9
# Episode 2860  return=  166  avg(last 20)= 170.2
# Episode 2880  return=  174  avg(last 20)= 168.5
# Episode 2900  return=  175  avg(last 20)= 172.9
# Episode 2920  return=  173  avg(last 20)= 165.9
# Episode 2940  return=  169  avg(last 20)= 171.4
# Episode 2960  return=  176  avg(last 20)= 173.3
# Episode 2980  return=  173  avg(last 20)= 173.4
# Saved model_actor_critic_seed1.pt and history_actor_critic_seed1.pkl and time_actor_critic_seed1.pkl
#
# Running: actor_critic_seed2
# State space: Box(-inf, inf, (11,), float64)
# Action space: Box(-1.0, 1.0, (3,), float32)
# Episode    0  return=    6  avg(last 20)=   5.6
# Episode   20  return=    7  avg(last 20)=  10.6
# Episode   40  return=   10  avg(last 20)=  10.7
# Episode   60  return=   11  avg(last 20)=  11.2
# Episode   80  return=   10  avg(last 20)=   9.8
# Episode  100  return=   10  avg(last 20)=  11.2
# Episode  120  return=   53  avg(last 20)=  17.5
# Episode  140  return=   14  avg(last 20)=  24.6
# Episode  160  return=   28  avg(last 20)=  54.6
# Episode  180  return=  148  avg(last 20)= 127.3
# Episode  200  return=  124  avg(last 20)= 152.3
# Episode  220  return=  156  avg(last 20)= 162.7
# Episode  240  return=  160  avg(last 20)= 154.4
# Episode  260  return=  129  avg(last 20)= 143.5
# Episode  280  return=  160  avg(last 20)= 149.9
# Episode  300  return=  178  avg(last 20)= 134.5
# Episode  320  return=  256  avg(last 20)= 155.8
# Episode  340  return=   98  avg(last 20)= 152.7
# Episode  360  return=  134  avg(last 20)= 152.1
# Episode  380  return=  178  avg(last 20)= 186.8
# Episode  400  return=  207  avg(last 20)= 183.5
# Episode  420  return=  204  avg(last 20)= 216.2
# Episode  440  return=  231  avg(last 20)= 221.6
# Episode  460  return=  246  avg(last 20)= 238.9
# Episode  480  return=  243  avg(last 20)= 235.2
# Episode  500  return=  241  avg(last 20)= 231.1
# Episode  520  return=  235  avg(last 20)= 235.1
# Episode  540  return=  230  avg(last 20)= 230.4
# Episode  560  return=  206  avg(last 20)= 230.9
# Episode  580  return=  143  avg(last 20)= 208.4
# Episode  600  return=  123  avg(last 20)= 193.2
# Episode  620  return=   93  avg(last 20)= 161.1
# Episode  640  return=  196  avg(last 20)= 181.9
# Episode  660  return=  209  avg(last 20)= 196.4
# Episode  680  return=  196  avg(last 20)= 207.7
# Episode  700  return=  227  avg(last 20)= 201.7
# Episode  720  return=  199  avg(last 20)= 199.7
# Episode  740  return=  208  avg(last 20)= 198.5
# Episode  760  return=   43  avg(last 20)= 132.1
# Episode  780  return=  211  avg(last 20)= 158.1
# Episode  800  return=  221  avg(last 20)= 202.7
# Episode  820  return=  224  avg(last 20)= 202.8
# Episode  840  return=  175  avg(last 20)= 196.4
# Episode  860  return=  209  avg(last 20)= 163.8
# Episode  880  return=  207  avg(last 20)= 195.2
# Episode  900  return=  103  avg(last 20)= 191.2
# Episode  920  return=  213  avg(last 20)= 186.8
# Episode  940  return=  207  avg(last 20)= 196.7
# Episode  960  return=  192  avg(last 20)= 201.1
# Episode  980  return=  192  avg(last 20)= 197.6
# Episode 1000  return=   61  avg(last 20)= 143.3
# Episode 1020  return=   95  avg(last 20)= 130.6
# Episode 1040  return=  141  avg(last 20)= 128.3
# Episode 1060  return=   96  avg(last 20)= 116.2
# Episode 1080  return=  180  avg(last 20)= 152.4
# Episode 1100  return=  238  avg(last 20)= 205.3
# Episode 1120  return=  216  avg(last 20)= 218.5
# Episode 1140  return=  223  avg(last 20)= 235.7
# Episode 1160  return=  233  avg(last 20)= 226.1
# Episode 1180  return=  226  avg(last 20)= 237.8
# Episode 1200  return=  219  avg(last 20)= 221.1
# Episode 1220  return=  179  avg(last 20)= 223.9
# Episode 1240  return=  269  avg(last 20)= 247.2
# Episode 1260  return=  269  avg(last 20)= 244.8
# Episode 1280  return=  234  avg(last 20)= 232.1
# Episode 1300  return=  207  avg(last 20)= 221.1
# Episode 1320  return=  221  avg(last 20)= 206.9
# Episode 1340  return=  214  avg(last 20)= 209.4
# Episode 1360  return=  136  avg(last 20)= 191.3
# Episode 1380  return=  278  avg(last 20)= 195.6
# Episode 1400  return=  170  avg(last 20)= 217.8
# Episode 1420  return=  268  avg(last 20)= 216.0
# Episode 1440  return=  217  avg(last 20)= 237.0
# Episode 1460  return=  267  avg(last 20)= 251.7
# Episode 1480  return=  234  avg(last 20)= 242.7
# Episode 1500  return=  235  avg(last 20)= 254.2
# Episode 1520  return=  247  avg(last 20)= 253.7
# Episode 1540  return=  251  avg(last 20)= 242.1
# Episode 1560  return=  267  avg(last 20)= 238.0
# Episode 1580  return=  331  avg(last 20)= 262.1
# Episode 1600  return=  303  avg(last 20)= 263.2
# Episode 1620  return=  275  avg(last 20)= 277.6
# Episode 1640  return=  257  avg(last 20)= 273.0
# Episode 1660  return=  272  avg(last 20)= 268.1
# Episode 1680  return=  281  avg(last 20)= 261.6
# Episode 1700  return=  261  avg(last 20)= 235.7
# Episode 1720  return=  261  avg(last 20)= 229.9
# Episode 1740  return=  243  avg(last 20)= 230.8
# Episode 1760  return=  179  avg(last 20)= 232.2
# Episode 1780  return=  236  avg(last 20)= 228.9
# Episode 1800  return=  247  avg(last 20)= 224.3
# Episode 1820  return=  226  avg(last 20)= 223.8
# Episode 1840  return=  197  avg(last 20)= 224.6
# Episode 1860  return=  247  avg(last 20)= 230.5
# Episode 1880  return=  281  avg(last 20)= 239.0
# Episode 1900  return=  229  avg(last 20)= 230.5
# Episode 1920  return=  244  avg(last 20)= 242.9
# Episode 1940  return=  255  avg(last 20)= 243.8
# Episode 1960  return=  234  avg(last 20)= 247.0
# Episode 1980  return=  219  avg(last 20)= 235.9
# Episode 2000  return=  256  avg(last 20)= 239.0
# Episode 2020  return=  243  avg(last 20)= 239.5
# Episode 2040  return=  246  avg(last 20)= 242.9
# Episode 2060  return=  247  avg(last 20)= 244.8
# Episode 2080  return=  235  avg(last 20)= 250.8
# Episode 2100  return=  238  avg(last 20)= 243.2
# Episode 2120  return=  246  avg(last 20)= 247.5
# Episode 2140  return=  243  avg(last 20)= 251.5
# Episode 2160  return=  236  avg(last 20)= 259.0
# Episode 2180  return=  261  avg(last 20)= 252.3
# Episode 2200  return=  252  avg(last 20)= 250.3
# Episode 2220  return=  210  avg(last 20)= 235.1
# Episode 2240  return=  235  avg(last 20)= 231.2
# Episode 2260  return=  227  avg(last 20)= 233.7
# Episode 2280  return=  228  avg(last 20)= 225.6
# Episode 2300  return=  246  avg(last 20)= 229.2
# Episode 2320  return=  246  avg(last 20)= 221.2
# Episode 2340  return=  244  avg(last 20)= 227.5
# Episode 2360  return=  211  avg(last 20)= 225.3
# Episode 2380  return=  211  avg(last 20)= 216.1
# Episode 2400  return=  161  avg(last 20)= 209.2
# Episode 2420  return=  245  avg(last 20)= 200.1
# Episode 2440  return=  222  avg(last 20)= 230.6
# Episode 2460  return=  222  avg(last 20)= 239.4
# Episode 2480  return=  253  avg(last 20)= 254.9
# Episode 2500  return=  256  avg(last 20)= 246.1
# Episode 2520  return=  212  avg(last 20)= 231.8
# Episode 2540  return=  214  avg(last 20)= 228.0
# Episode 2560  return=  231  avg(last 20)= 226.9
# Episode 2580  return=  226  avg(last 20)= 243.5
# Episode 2600  return=  266  avg(last 20)= 253.7
# Episode 2620  return=  267  avg(last 20)= 259.9
# Episode 2640  return=  321  avg(last 20)= 270.0
# Episode 2660  return=  275  avg(last 20)= 275.8
# Episode 2680  return=  210  avg(last 20)= 260.8
# Episode 2700  return=  280  avg(last 20)= 279.8
# Episode 2720  return=  275  avg(last 20)= 277.9
# Episode 2740  return=  305  avg(last 20)= 276.6
# Episode 2760  return=  326  avg(last 20)= 300.0
# Episode 2780  return=  333  avg(last 20)= 298.6
# Episode 2800  return=  336  avg(last 20)= 314.8
# Episode 2820  return=  334  avg(last 20)= 312.0
# Episode 2840  return=  310  avg(last 20)= 310.2
# Episode 2860  return=  326  avg(last 20)= 302.1
# Episode 2880  return=  309  avg(last 20)= 282.3
# Episode 2900  return=  276  avg(last 20)= 288.0
# Episode 2920  return=  272  avg(last 20)= 268.5
# Episode 2940  return=  272  avg(last 20)= 246.1
# Episode 2960  return=  238  avg(last 20)= 251.7
# Episode 2980  return=  264  avg(last 20)= 252.7
# Saved model_actor_critic_seed2.pt and history_actor_critic_seed2.pkl and time_actor_critic_seed2.pkl

# %%
MAX_EPISODES = 3000

BEST_AC_LABEL = (
    f"actor_lr={best_cfg['actor_lr']:.1e}, "
    f"critic_lr={best_cfg['critic_lr']:.1e}, "
    f"cw={best_cfg['critic_weight']}, "
    f"h={best_cfg['hidden']}"
)

summary_runs = [
    ('none',         'REINFORCE (vanilla)',        {'linestyle': ':',  'color': 'black'}),
    (BEST_CONST,     'REINFORCE (constant, best)', {'color': 'tab:orange'}),
    (BEST_EMA,       'REINFORCE (EMA, best)',      {'color': 'tab:green'}),
    ('actor_critic', f'Actor-Critic tuned ({BEST_AC_LABEL})', {'color': 'tab:red'}),
]

print(f"Final mean return over episodes {MAX_EPISODES-50+1}-{MAX_EPISODES}:")

plt.figure(figsize=(11, 5.5))

for suffix, label, style in summary_runs:
    h = load_history(suffix)

    h_cut = h[:MAX_EPISODES]
    score = float(np.mean(h_cut[-50:]))

    print(f"  {label:70s} {score:.2f}")

    y = smooth_50(h_cut)
    x = np.arange(50, len(h_cut) + 1)

    plt.plot(
        x,
        y,
        label=f'{label}  (final@3000={score:.1f})',
        **style
    )

plt.xlabel('Episode')
plt.ylabel('Return (50-episode moving average)')
plt.title('Fair comparison: first 3000 episodes only')
plt.legend(loc='best', fontsize=8)
plt.grid(alpha=0.3)
plt.tight_layout()
plt.savefig(os.path.join(PREFIX, 'fair_3000_episode_comparison.png'),
            dpi=120,
            bbox_inches='tight')
plt.show()

print("Saved: fair_3000_episode_comparison.png")
# Out:
# Final mean return over episodes 2951-3000:
#   REINFORCE (vanilla)                                                    52.65
#   REINFORCE (constant, best)                                             97.87
#   REINFORCE (EMA, best)                                                  909.94
#   Actor-Critic tuned (actor_lr=3.9e-05, critic_lr=4.0e-04, cw=1.0, h=256) 413.46
# Saved: fair_3000_episode_comparison.png

# %%
runs = [
    ('none', 'REINFORCE vanilla'),
    ('actor_critic', f'Actor-Critic best ({BEST_AC_LABEL})'),
]

w = 20

plt.figure(figsize=(10, 5))

for suffix, label in runs:
    h = load_history(suffix)
    t = load_time(suffix)['elapsed_times']

    y = smooth(h, w=w)
    x = np.array(t[w-1:]) / 60

    plt.plot(x, y, label=label)

plt.xlabel('Elapsed training time (minutes)')
plt.ylabel(f'Return ({w}-episode moving average)')
plt.title('Training performance over time')
plt.legend()
plt.grid(alpha=0.3)
plt.tight_layout()
plt.savefig(os.path.join(PREFIX, 'return_vs_time.png'),
            dpi=120,
            bbox_inches='tight')
plt.show()

print("Saved: return_vs_time.png")
# Out:
# Saved: return_vs_time.png

# %% [markdown]
# ## Promote the refined Actor-Critic into the multi-seed & fair comparison
#
# These cells pick the winning refined config (by peak), evaluate it over seeds `[0, 1, 2]` like the original `actor_critic` (cell 19), and add it as an extra line to the fair 3000-episode comparison (cell 20). The existing cells are left untouched.

# %%
import os, json as _json

ac_candidates = {f"ac_refined_seed{s}": dict(refined_cfg) for s in REFINE_SEEDS}
if RUN_SEARCH:
    for i, override in enumerate(search_grid):
        cfg = {**refined_cfg, **override}
        for s in SEARCH_SEEDS:
            ac_candidates[f"ac_search_{i}_seed{s}"] = cfg

def _exists(suffix):
    return os.path.exists(os.path.join(PREFIX, f"history_{suffix}.pkl"))

def _peak_gap(suffix, last_n=50):
    h = load_history(suffix)
    sm = smooth_50(h)
    peak = float(sm.max())
    final = float(np.mean(h[-last_n:]))
    return peak, peak - final

available = {n: c for n, c in ac_candidates.items() if _exists(n)}
if not available:
    raise RuntimeError("Run the refined cells (16-18) first to generate histories.")

groups = {}  
for name, cfg in available.items():
    g = groups.setdefault(_json.dumps(cfg, sort_keys=True), {"cfg": cfg, "runs": []})
    g["runs"].append(name)

ranking = [] 
for g in groups.values():
    stats = [_peak_gap(n) for n in g["runs"]]
    mean_peak = float(np.mean([s[0] for s in stats]))
    mean_gap = float(np.mean([s[1] for s in stats]))
    rep = max(g["runs"], key=lambda n: _peak_gap(n)[0])  
    ranking.append((mean_peak, mean_gap, g["cfg"], g["runs"], rep))

ranking.sort(key=lambda r: (-r[0], r[1]))

REFINED_BEST_NAME = None

print(f"{'mean_peak':>10}{'mean_gap':>10}{'n':>3}  config")
for i, (mean_peak, mean_gap, cfg, runs, rep) in enumerate(ranking):
    tag = "  <-- best" if i == 0 else ""
    print(f"{mean_peak:10.0f}{mean_gap:10.0f}{len(runs):3d}  "
          f"alr={cfg['actor_lr']:.1e} clr={cfg['critic_lr']:.1e} "
          f"normAdv={cfg['normalize_advantage']} gc={cfg['grad_clip']}{tag}")

best_mean_peak, best_mean_gap, REFINED_BEST_CFG, _, best_rep = ranking[0]
if REFINED_BEST_NAME is None:
    REFINED_BEST_NAME = best_rep   

print(f"\nPromoting config (mean_peak={best_mean_peak:.0f}, "
      f"mean_gap={best_mean_gap:.0f}) via run '{REFINED_BEST_NAME}'")
print("Config:", REFINED_BEST_CFG)
# Out:
#  mean_peak  mean_gap  n  config
#        748       121  3  alr=3.5e-05 clr=4.0e-04 normAdv=True gc=0.3  <-- best
#        541        96  3  alr=3.5e-05 clr=4.0e-04 normAdv=False gc=0.3
#        533       171  3  alr=2.5e-05 clr=4.0e-04 normAdv=True gc=0.3
#        231        22  3  alr=2.5e-05 clr=4.0e-04 normAdv=False gc=0.3
#
# Promoting config (mean_peak=748, mean_gap=121) via run 'ac_search_0_seed0'
# Config: {'actor_lr': 3.5e-05, 'critic_lr': 0.0004, 'critic_weight': 1.0, 'hidden_size': 256, 'gamma': 0.995, 'grad_clip': 0.3, 'entropy_weight': 0.0001, 'normalize_advantage': True}

# %%
refined_seeds = [0, 1, 2]
refined_multi_seed = []

for seed in refined_seeds:
    run_name = f"actor_critic_refined_seed{seed}"
    print("\nRunning:", run_name)
    h = main(
        algorithm="actor_critic",
        n_episodes=3000,
        seed=seed,
        run_name=run_name,
        save_dir=PREFIX,
        **REFINED_BEST_CFG,
    )
    refined_multi_seed.append(float(np.mean(h[-50:])))

try:
    multi_seed_results
except NameError:
    multi_seed_results = {}
multi_seed_results["actor_critic_refined"] = refined_multi_seed

print(f"\nRefined AC   final-50 over seeds {refined_seeds}: "
      f"{np.mean(refined_multi_seed):6.1f} +/- {np.std(refined_multi_seed):.1f}")
if "actor_critic" in multi_seed_results:
    orig = multi_seed_results["actor_critic"]
    print(f"Original AC  final-50 over seeds {refined_seeds}: "
          f"{np.mean(orig):6.1f} +/- {np.std(orig):.1f}")
# Out:
# Running: actor_critic_refined_seed0
# State space: Box(-inf, inf, (11,), float64)
# Action space: Box(-1.0, 1.0, (3,), float32)
# Episode    0  return=    7  avg(last 20)=   7.1
# Episode   20  return=    9  avg(last 20)=  10.2
# Episode   40  return=   12  avg(last 20)=   9.9
# Episode   60  return=    9  avg(last 20)=   9.2
# Episode   80  return=    9  avg(last 20)=  11.6
# Episode  100  return=   11  avg(last 20)=  19.6
# Episode  120  return=   16  avg(last 20)=  57.1
# Episode  140  return=  190  avg(last 20)=  63.1
# Episode  160  return=  145  avg(last 20)=  80.7
# Episode  180  return=   12  avg(last 20)=  83.2
# Episode  200  return=   31  avg(last 20)=  86.4
# Episode  220  return=  143  avg(last 20)= 100.7
# Episode  240  return=  164  avg(last 20)= 115.2
# Episode  260  return=   25  avg(last 20)= 121.7
# Episode  280  return=  100  avg(last 20)= 120.0
# Episode  300  return=  107  avg(last 20)= 135.4
# Episode  320  return=  168  avg(last 20)= 129.3
# Episode  340  return=   66  avg(last 20)= 117.8
# Episode  360  return=  211  avg(last 20)= 122.0
# Episode  380  return=  128  avg(last 20)= 113.0
# Episode  400  return=  129  avg(last 20)= 134.8
# Episode  420  return=  110  avg(last 20)= 119.5
# Episode  440  return=   42  avg(last 20)= 132.1
# Episode  460  return=   98  avg(last 20)= 126.2
# Episode  480  return=  103  avg(last 20)= 139.5
# Episode  500  return=   72  avg(last 20)= 134.8
# Episode  520  return=  177  avg(last 20)= 162.0
# Episode  540  return=  107  avg(last 20)= 151.1
# Episode  560  return=  144  avg(last 20)= 133.1
# Episode  580  return=  151  avg(last 20)= 179.3
# Episode  600  return=  111  avg(last 20)= 172.6
# Episode  620  return=   75  avg(last 20)= 181.4
# Episode  640  return=  156  avg(last 20)= 167.8
# Episode  660  return=  176  avg(last 20)= 181.3
# Episode  680  return=  222  avg(last 20)= 187.6
# Episode  700  return=  191  avg(last 20)= 176.1
# Episode  720  return=  185  avg(last 20)= 196.8
# Episode  740  return=  215  avg(last 20)= 184.9
# Episode  760  return=   91  avg(last 20)= 191.3
# Episode  780  return=  262  avg(last 20)= 195.1
# Episode  800  return=  253  avg(last 20)= 204.2
# Episode  820  return=  222  avg(last 20)= 189.2
# Episode  840  return=  208  avg(last 20)= 169.9
# Episode  860  return=  257  avg(last 20)= 197.6
# Episode  880  return=  153  avg(last 20)= 170.3
# Episode  900  return=  231  avg(last 20)= 215.3
# Episode  920  return=  228  avg(last 20)= 218.3
# Episode  940  return=  184  avg(last 20)= 223.2
# Episode  960  return=  302  avg(last 20)= 202.6
# Episode  980  return=  243  avg(last 20)= 199.6
# Episode 1000  return=  144  avg(last 20)= 195.9
# Episode 1020  return=  192  avg(last 20)= 191.3
# Episode 1040  return=  115  avg(last 20)= 209.2
# Episode 1060  return=  232  avg(last 20)= 256.6
# Episode 1080  return=  351  avg(last 20)= 352.5
# Episode 1100  return=   73  avg(last 20)= 289.5
# Episode 1120  return=   38  avg(last 20)= 280.3
# Episode 1140  return=  272  avg(last 20)= 205.1
# Episode 1160  return=  227  avg(last 20)= 279.3
# Episode 1180  return=  356  avg(last 20)= 352.8
# Episode 1200  return=  462  avg(last 20)= 367.2
# Episode 1220  return=   45  avg(last 20)= 291.3
# Episode 1240  return=   75  avg(last 20)= 372.1
# Episode 1260  return=   72  avg(last 20)= 386.3
# Episode 1280  return=   62  avg(last 20)= 273.1
# Episode 1300  return=  375  avg(last 20)= 384.0
# Episode 1320  return=  124  avg(last 20)= 308.3
# Episode 1340  return=  282  avg(last 20)= 263.3
# Episode 1360  return=  564  avg(last 20)= 429.4
# Episode 1380  return= 1056  avg(last 20)= 576.3
# Episode 1400  return=  476  avg(last 20)= 441.1
# Episode 1420  return=  109  avg(last 20)= 518.5
# Episode 1440  return=  374  avg(last 20)= 515.4
# Episode 1460  return=  849  avg(last 20)= 455.3
# Episode 1480  return=  655  avg(last 20)= 514.7
# Episode 1500  return=  555  avg(last 20)= 497.5
# Episode 1520  return=  658  avg(last 20)= 506.8
# Episode 1540  return=  232  avg(last 20)= 556.8
# Episode 1560  return=  750  avg(last 20)= 500.8
# Episode 1580  return=  670  avg(last 20)= 554.5
# Episode 1600  return=  491  avg(last 20)= 508.8
# Episode 1620  return=  460  avg(last 20)= 496.9
# Episode 1640  return=  448  avg(last 20)= 414.3
# Episode 1660  return=  452  avg(last 20)= 373.3
# Episode 1680  return=  477  avg(last 20)= 409.8
# Episode 1700  return=  479  avg(last 20)= 427.4
# Episode 1720  return=  522  avg(last 20)= 463.4
# Episode 1740  return=  507  avg(last 20)= 483.7
# Episode 1760  return=  348  avg(last 20)= 469.9
# Episode 1780  return=   77  avg(last 20)= 406.0
# Episode 1800  return=  241  avg(last 20)= 438.1
# Episode 1820  return=  155  avg(last 20)= 447.3
# Episode 1840  return=  607  avg(last 20)= 379.2
# Episode 1860  return=  230  avg(last 20)= 356.6
# Episode 1880  return=  385  avg(last 20)= 387.2
# Episode 1900  return=  697  avg(last 20)= 487.5
# Episode 1920  return=  724  avg(last 20)= 577.5
# Episode 1940  return=  564  avg(last 20)= 533.1
# Episode 1960  return=  564  avg(last 20)= 460.6
# Episode 1980  return=  437  avg(last 20)= 378.8
# Episode 2000  return=  460  avg(last 20)= 417.4
# Episode 2020  return=  449  avg(last 20)= 474.8
# Episode 2040  return=  388  avg(last 20)= 426.6
# Episode 2060  return=  378  avg(last 20)= 373.6
# Episode 2080  return=  402  avg(last 20)= 389.4
# Episode 2100  return=  283  avg(last 20)= 397.3
# Episode 2120  return=  224  avg(last 20)= 313.8
# Episode 2140  return=  287  avg(last 20)= 261.2
# Episode 2160  return=  184  avg(last 20)= 242.8
# Episode 2180  return=  218  avg(last 20)= 261.0
# Episode 2200  return=  246  avg(last 20)= 324.6
# Episode 2220  return=  437  avg(last 20)= 375.6
# Episode 2240  return=  882  avg(last 20)= 533.2
# Episode 2260  return=  542  avg(last 20)= 620.3
# Episode 2280  return=  243  avg(last 20)= 710.8
# Episode 2300  return= 1009  avg(last 20)= 811.1
# Episode 2320  return= 1063  avg(last 20)= 764.9
# Episode 2340  return= 1024  avg(last 20)= 871.2
# Episode 2360  return=  293  avg(last 20)= 995.7
# Episode 2380  return= 1029  avg(last 20)= 952.2
# Episode 2400  return= 1016  avg(last 20)=1020.0
# Episode 2420  return= 1014  avg(last 20)= 998.9
# Episode 2440  return=  796  avg(last 20)= 984.2
# Episode 2460  return=  614  avg(last 20)= 710.0
# Episode 2480  return=  640  avg(last 20)= 599.0
# Episode 2500  return=  917  avg(last 20)= 772.1
# Episode 2520  return=  675  avg(last 20)= 722.8
# Episode 2540  return=  353  avg(last 20)= 539.1
# Episode 2560  return=  301  avg(last 20)= 358.5
# Episode 2580  return=  309  avg(last 20)= 403.0
# Episode 2600  return=  286  avg(last 20)= 372.7
# Episode 2620  return=  652  avg(last 20)= 421.6
# Episode 2640  return=  689  avg(last 20)= 451.0
# Episode 2660  return= 1180  avg(last 20)= 730.1
# Episode 2680  return=  924  avg(last 20)= 848.0
# Episode 2700  return=  138  avg(last 20)= 444.1
# Episode 2720  return=  986  avg(last 20)= 745.8
# Episode 2740  return=  645  avg(last 20)= 607.1
# Episode 2760  return=  596  avg(last 20)= 726.3
# Episode 2780  return=  862  avg(last 20)= 935.3
# Episode 2800  return= 1020  avg(last 20)= 994.2
# Episode 2820  return=  993  avg(last 20)= 969.4
# Episode 2840  return= 1014  avg(last 20)=1000.8
# Episode 2860  return=  773  avg(last 20)= 973.4
# Episode 2880  return=  815  avg(last 20)= 849.0
# Episode 2900  return= 1012  avg(last 20)= 931.8
# Episode 2920  return= 1013  avg(last 20)= 992.0
# Episode 2940  return=  660  avg(last 20)= 983.6
# Episode 2960  return= 1004  avg(last 20)=1008.6
# Episode 2980  return= 1010  avg(last 20)=1007.4
# Saved model_actor_critic_refined_seed0.pt and history_actor_critic_refined_seed0.pkl and time_actor_critic_refined_seed0.pkl
#
# Running: actor_critic_refined_seed1
# State space: Box(-inf, inf, (11,), float64)
# Action space: Box(-1.0, 1.0, (3,), float32)
# Episode    0  return=    8  avg(last 20)=   7.8
# Episode   20  return=   18  avg(last 20)=  18.8
# Episode   40  return=   15  avg(last 20)=  12.4
# Episode   60  return=    8  avg(last 20)=  12.7
# Episode   80  return=    9  avg(last 20)=  12.8
# Episode  100  return=   17  avg(last 20)=  16.3
# Episode  120  return=  244  avg(last 20)=  58.4
# Episode  140  return=   48  avg(last 20)= 111.0
# Episode  160  return=   29  avg(last 20)=  93.4
# Episode  180  return=  162  avg(last 20)= 139.0
# Episode  200  return=  112  avg(last 20)= 105.4
# Episode  220  return=  140  avg(last 20)= 147.3
# Episode  240  return=  186  avg(last 20)= 143.9
# Episode  260  return=  247  avg(last 20)= 152.3
# Episode  280  return=  175  avg(last 20)= 153.7
# Episode  300  return=  141  avg(last 20)= 149.7
# Episode  320  return=  162  avg(last 20)= 124.4
# Episode  340  return=   48  avg(last 20)= 137.8
# Episode  360  return=  124  avg(last 20)= 125.7
# Episode  380  return=  226  avg(last 20)= 140.5
# Episode  400  return=  225  avg(last 20)= 163.6
# Episode  420  return=  188  avg(last 20)= 141.4
# Episode  440  return=  126  avg(last 20)= 143.8
# Episode  460  return=  112  avg(last 20)= 165.3
# Episode  480  return=  164  avg(last 20)= 192.3
# Episode  500  return=  225  avg(last 20)= 178.8
# Episode  520  return=  232  avg(last 20)= 183.4
# Episode  540  return=  143  avg(last 20)= 167.6
# Episode  560  return=   64  avg(last 20)= 193.2
# Episode  580  return=  231  avg(last 20)= 195.7
# Episode  600  return=  225  avg(last 20)= 209.4
# Episode  620  return=  254  avg(last 20)= 211.3
# Episode  640  return=  176  avg(last 20)= 210.9
# Episode  660  return=  272  avg(last 20)= 227.0
# Episode  680  return=  225  avg(last 20)= 213.8
# Episode  700  return=  195  avg(last 20)= 234.7
# Episode  720  return=  258  avg(last 20)= 222.7
# Episode  740  return=  243  avg(last 20)= 218.3
# Episode  760  return=  191  avg(last 20)= 220.0
# Episode  780  return=  110  avg(last 20)= 182.1
# Episode  800  return=  264  avg(last 20)= 225.5
# Episode  820  return=  233  avg(last 20)= 239.5
# Episode  840  return=  124  avg(last 20)= 244.4
# Episode  860  return=  234  avg(last 20)= 263.0
# Episode  880  return=  244  avg(last 20)= 243.0
# Episode  900  return=  269  avg(last 20)= 238.6
# Episode  920  return=  243  avg(last 20)= 258.5
# Episode  940  return=  273  avg(last 20)= 229.5
# Episode  960  return=  250  avg(last 20)= 237.8
# Episode  980  return=  133  avg(last 20)= 284.5
# Episode 1000  return=  294  avg(last 20)= 283.8
# Episode 1020  return=  315  avg(last 20)= 260.0
# Episode 1040  return=  207  avg(last 20)= 223.0
# Episode 1060  return=  319  avg(last 20)= 245.3
# Episode 1080  return=  282  avg(last 20)= 248.1
# Episode 1100  return=  297  avg(last 20)= 249.2
# Episode 1120  return=   49  avg(last 20)= 240.9
# Episode 1140  return=  176  avg(last 20)= 256.0
# Episode 1160  return=  256  avg(last 20)= 242.9
# Episode 1180  return=  271  avg(last 20)= 233.7
# Episode 1200  return=  249  avg(last 20)= 241.2
# Episode 1220  return=  252  avg(last 20)= 228.2
# Episode 1240  return=  110  avg(last 20)= 227.8
# Episode 1260  return=  213  avg(last 20)= 245.7
# Episode 1280  return=  277  avg(last 20)= 241.6
# Episode 1300  return=  221  avg(last 20)= 225.5
# Episode 1320  return=  241  avg(last 20)= 222.5
# Episode 1340  return=  253  avg(last 20)= 217.0
# Episode 1360  return=  222  avg(last 20)= 208.6
# Episode 1380  return=   35  avg(last 20)= 203.0
# Episode 1400  return=  201  avg(last 20)= 210.4
# Episode 1420  return=  235  avg(last 20)= 209.3
# Episode 1440  return=  231  avg(last 20)= 226.4
# Episode 1460  return=  232  avg(last 20)= 222.0
# Episode 1480  return=  213  avg(last 20)= 239.4
# Episode 1500  return=  230  avg(last 20)= 244.6
# Episode 1520  return=  242  avg(last 20)= 246.6
# Episode 1540  return=  272  avg(last 20)= 229.4
# Episode 1560  return=  301  avg(last 20)= 262.1
# Episode 1580  return=  203  avg(last 20)= 253.5
# Episode 1600  return=  264  avg(last 20)= 281.3
# Episode 1620  return=  308  avg(last 20)= 253.3
# Episode 1640  return=  218  avg(last 20)= 259.8
# Episode 1660  return=  307  avg(last 20)= 275.2
# Episode 1680  return=  321  avg(last 20)= 261.9
# Episode 1700  return=  394  avg(last 20)= 288.3
# Episode 1720  return=  301  avg(last 20)= 262.6
# Episode 1740  return=  304  avg(last 20)= 237.9
# Episode 1760  return=  220  avg(last 20)= 272.4
# Episode 1780  return=   38  avg(last 20)= 256.5
# Episode 1800  return=  323  avg(last 20)= 297.3
# Episode 1820  return=  205  avg(last 20)= 279.2
# Episode 1840  return=  330  avg(last 20)= 271.4
# Episode 1860  return=  386  avg(last 20)= 276.4
# Episode 1880  return=  290  avg(last 20)= 305.2
# Episode 1900  return=  225  avg(last 20)= 250.3
# Episode 1920  return=  340  avg(last 20)= 249.3
# Episode 1940  return=   84  avg(last 20)= 313.7
# Episode 1960  return=  271  avg(last 20)= 290.1
# Episode 1980  return=  366  avg(last 20)= 308.6
# Episode 2000  return=  483  avg(last 20)= 332.1
# Episode 2020  return=  129  avg(last 20)= 234.4
# Episode 2040  return=   94  avg(last 20)= 215.2
# Episode 2060  return=  237  avg(last 20)= 140.1
# Episode 2080  return=  284  avg(last 20)= 189.1
# Episode 2100  return=   61  avg(last 20)= 191.8
# Episode 2120  return=  297  avg(last 20)= 269.9
# Episode 2140  return=  312  avg(last 20)= 330.2
# Episode 2160  return=  467  avg(last 20)= 429.5
# Episode 2180  return=  417  avg(last 20)= 386.0
# Episode 2200  return=  544  avg(last 20)= 376.1
# Episode 2220  return=  440  avg(last 20)= 402.1
# Episode 2240  return=  241  avg(last 20)= 359.3
# Episode 2260  return=  385  avg(last 20)= 350.9
# Episode 2280  return=  355  avg(last 20)= 345.9
# Episode 2300  return=  394  avg(last 20)= 334.8
# Episode 2320  return=  404  avg(last 20)= 401.1
# Episode 2340  return=  372  avg(last 20)= 368.7
# Episode 2360  return=  395  avg(last 20)= 330.3
# Episode 2380  return=  252  avg(last 20)= 393.3
# Episode 2400  return=  115  avg(last 20)= 372.7
# Episode 2420  return=  456  avg(last 20)= 358.6
# Episode 2440  return=  259  avg(last 20)= 426.3
# Episode 2460  return=  112  avg(last 20)= 231.4
# Episode 2480  return=  415  avg(last 20)= 423.8
# Episode 2500  return=  414  avg(last 20)= 407.7
# Episode 2520  return=  364  avg(last 20)= 372.9
# Episode 2540  return=  317  avg(last 20)= 354.5
# Episode 2560  return=  481  avg(last 20)= 386.6
# Episode 2580  return=  133  avg(last 20)= 473.8
# Episode 2600  return=  538  avg(last 20)= 488.9
# Episode 2620  return=  648  avg(last 20)= 460.4
# Episode 2640  return=  465  avg(last 20)= 438.7
# Episode 2660  return=  636  avg(last 20)= 379.5
# Episode 2680  return=  190  avg(last 20)= 313.1
# Episode 2700  return=  350  avg(last 20)= 291.3
# Episode 2720  return=  325  avg(last 20)= 378.1
# Episode 2740  return=  299  avg(last 20)= 388.4
# Episode 2760  return=  647  avg(last 20)= 552.8
# Episode 2780  return=  196  avg(last 20)= 590.4
# Episode 2800  return=  595  avg(last 20)= 655.0
# Episode 2820  return=  538  avg(last 20)= 415.5
# Episode 2840  return=  525  avg(last 20)= 471.8
# Episode 2860  return=  321  avg(last 20)= 487.1
# Episode 2880  return=  656  avg(last 20)= 558.0
# Episode 2900  return=  631  avg(last 20)= 623.4
# Episode 2920  return= 1118  avg(last 20)= 857.6
# Episode 2940  return=  325  avg(last 20)= 734.0
# Episode 2960  return=  314  avg(last 20)= 464.9
# Episode 2980  return=  284  avg(last 20)= 384.9
# Saved model_actor_critic_refined_seed1.pt and history_actor_critic_refined_seed1.pkl and time_actor_critic_refined_seed1.pkl
#
# Running: actor_critic_refined_seed2
# State space: Box(-inf, inf, (11,), float64)
# Action space: Box(-1.0, 1.0, (3,), float32)
# Episode    0  return=    6  avg(last 20)=   5.6
# Episode   20  return=    8  avg(last 20)=  12.5
# Episode   40  return=   10  avg(last 20)=  12.4
# Episode   60  return=   20  avg(last 20)=  12.1
# Episode   80  return=   10  avg(last 20)=  11.0
# Episode  100  return=   24  avg(last 20)=  11.9
# Episode  120  return=   46  avg(last 20)=  21.0
# Episode  140  return=   89  avg(last 20)=  37.2
# Episode  160  return=   28  avg(last 20)=  41.5
# Episode  180  return=   19  avg(last 20)=  38.6
# Episode  200  return=  173  avg(last 20)=  88.1
# Episode  220  return=  172  avg(last 20)= 116.0
# Episode  240  return=  145  avg(last 20)= 136.0
# Episode  260  return=   24  avg(last 20)= 135.8
# Episode  280  return=   55  avg(last 20)= 131.3
# Episode  300  return=  217  avg(last 20)= 142.9
# Episode  320  return=   40  avg(last 20)= 127.9
# Episode  340  return=  128  avg(last 20)= 138.1
# Episode  360  return=  150  avg(last 20)= 129.7
# Episode  380  return=   99  avg(last 20)= 128.0
# Episode  400  return=  138  avg(last 20)= 159.2
# Episode  420  return=  168  avg(last 20)= 140.4
# Episode  440  return=  143  avg(last 20)= 151.7
# Episode  460  return=  193  avg(last 20)= 171.9
# Episode  480  return=  124  avg(last 20)= 171.0
# Episode  500  return=  203  avg(last 20)= 199.3
# Episode  520  return=  129  avg(last 20)= 198.6
# Episode  540  return=  237  avg(last 20)= 209.1
# Episode  560  return=  176  avg(last 20)= 211.8
# Episode  580  return=  179  avg(last 20)= 223.2
# Episode  600  return=  242  avg(last 20)= 198.2
# Episode  620  return=  235  avg(last 20)= 253.5
# Episode  640  return=  180  avg(last 20)= 224.7
# Episode  660  return=  149  avg(last 20)= 234.3
# Episode  680  return=  154  avg(last 20)= 231.3
# Episode  700  return=  264  avg(last 20)= 251.5
# Episode  720  return=  302  avg(last 20)= 249.2
# Episode  740  return=  204  avg(last 20)= 237.9
# Episode  760  return=  285  avg(last 20)= 259.0
# Episode  780  return=  195  avg(last 20)= 270.6
# Episode  800  return=  278  avg(last 20)= 233.4
# Episode  820  return=  233  avg(last 20)= 265.0
# Episode  840  return=  289  avg(last 20)= 231.9
# Episode  860  return=  259  avg(last 20)= 266.6
# Episode  880  return=  288  avg(last 20)= 254.3
# Episode  900  return=  355  avg(last 20)= 259.2
# Episode  920  return=  242  avg(last 20)= 246.5
# Episode  940  return=  239  avg(last 20)= 261.7
# Episode  960  return=  352  avg(last 20)= 271.8
# Episode  980  return=  271  avg(last 20)= 261.5
# Episode 1000  return=  287  avg(last 20)= 250.1
# Episode 1020  return=  275  avg(last 20)= 244.2
# Episode 1040  return=  281  avg(last 20)= 269.0
# Episode 1060  return=  273  avg(last 20)= 284.5
# Episode 1080  return=  261  avg(last 20)= 268.6
# Episode 1100  return=  257  avg(last 20)= 266.2
# Episode 1120  return=  288  avg(last 20)= 287.1
# Episode 1140  return=  282  avg(last 20)= 271.5
# Episode 1160  return=  262  avg(last 20)= 265.1
# Episode 1180  return=  246  avg(last 20)= 274.4
# Episode 1200  return=  265  avg(last 20)= 260.4
# Episode 1220  return=  236  avg(last 20)= 243.7
# Episode 1240  return=  244  avg(last 20)= 247.1
# Episode 1260  return=  215  avg(last 20)= 250.7
# Episode 1280  return=  231  avg(last 20)= 228.9
# Episode 1300  return=  225  avg(last 20)= 219.9
# Episode 1320  return=  244  avg(last 20)= 213.9
# Episode 1340  return=  290  avg(last 20)= 232.7
# Episode 1360  return=  248  avg(last 20)= 228.1
# Episode 1380  return=  232  avg(last 20)= 218.9
# Episode 1400  return=  217  avg(last 20)= 216.0
# Episode 1420  return=  206  avg(last 20)= 215.9
# Episode 1440  return=  215  avg(last 20)= 212.5
# Episode 1460  return=  212  avg(last 20)= 207.0
# Episode 1480  return=  195  avg(last 20)= 193.4
# Episode 1500  return=  244  avg(last 20)= 200.2
# Episode 1520  return=  171  avg(last 20)= 209.0
# Episode 1540  return=  216  avg(last 20)= 199.7
# Episode 1560  return=  216  avg(last 20)= 196.2
# Episode 1580  return=  231  avg(last 20)= 199.2
# Episode 1600  return=  208  avg(last 20)= 216.6
# Episode 1620  return=  191  avg(last 20)= 213.0
# Episode 1640  return=  259  avg(last 20)= 220.1
# Episode 1660  return=  214  avg(last 20)= 232.1
# Episode 1680  return=  222  avg(last 20)= 231.1
# Episode 1700  return=  239  avg(last 20)= 237.5
# Episode 1720  return=  251  avg(last 20)= 246.1
# Episode 1740  return=  277  avg(last 20)= 265.0
# Episode 1760  return=  314  avg(last 20)= 275.3
# Episode 1780  return=  278  avg(last 20)= 268.6
# Episode 1800  return=  255  avg(last 20)= 269.5
# Episode 1820  return=  241  avg(last 20)= 262.6
# Episode 1840  return=  250  avg(last 20)= 255.3
# Episode 1860  return=  264  avg(last 20)= 249.5
# Episode 1880  return=  261  avg(last 20)= 259.6
# Episode 1900  return=  252  avg(last 20)= 266.7
# Episode 1920  return=  214  avg(last 20)= 250.7
# Episode 1940  return=  273  avg(last 20)= 236.3
# Episode 1960  return=  242  avg(last 20)= 221.1
# Episode 1980  return=  215  avg(last 20)= 217.4
# Episode 2000  return=  215  avg(last 20)= 216.5
# Episode 2020  return=  227  avg(last 20)= 226.9
# Episode 2040  return=  226  avg(last 20)= 228.5
# Episode 2060  return=  230  avg(last 20)= 223.2
# Episode 2080  return=  206  avg(last 20)= 218.9
# Episode 2100  return=  214  avg(last 20)= 221.5
# Episode 2120  return=  217  avg(last 20)= 215.8
# Episode 2140  return=  220  avg(last 20)= 225.5
# Episode 2160  return=  258  avg(last 20)= 226.5
# Episode 2180  return=  219  avg(last 20)= 221.2
# Episode 2200  return=  235  avg(last 20)= 219.9
# Episode 2220  return=  212  avg(last 20)= 217.6
# Episode 2240  return=  202  avg(last 20)= 206.2
# Episode 2260  return=  219  avg(last 20)= 210.4
# Episode 2280  return=  212  avg(last 20)= 213.2
# Episode 2300  return=  205  avg(last 20)= 214.7
# Episode 2320  return=  212  avg(last 20)= 213.6
# Episode 2340  return=  207  avg(last 20)= 213.6
# Episode 2360  return=  214  avg(last 20)= 205.3
# Episode 2380  return=  201  avg(last 20)= 210.0
# Episode 2400  return=  178  avg(last 20)= 184.4
# Episode 2420  return=  193  avg(last 20)= 199.8
# Episode 2440  return=  196  avg(last 20)= 199.1
# Episode 2460  return=  190  avg(last 20)= 200.6
# Episode 2480  return=  186  avg(last 20)= 196.6
# Episode 2500  return=  201  avg(last 20)= 200.0
# Episode 2520  return=  195  avg(last 20)= 193.4
# Episode 2540  return=  195  avg(last 20)= 187.2
# Episode 2560  return=  224  avg(last 20)= 209.6
# Episode 2580  return=  225  avg(last 20)= 213.6
# Episode 2600  return=  214  avg(last 20)= 213.1
# Episode 2620  return=  214  avg(last 20)= 217.4
# Episode 2640  return=  206  avg(last 20)= 216.8
# Episode 2660  return=  206  avg(last 20)= 216.9
# Episode 2680  return=  205  avg(last 20)= 214.4
# Episode 2700  return=  222  avg(last 20)= 210.4
# Episode 2720  return=  236  avg(last 20)= 210.0
# Episode 2740  return=  221  avg(last 20)= 215.8
# Episode 2760  return=  209  avg(last 20)= 215.9
# Episode 2780  return=  210  avg(last 20)= 211.6
# Episode 2800  return=  151  avg(last 20)= 199.5
# Episode 2820  return=  261  avg(last 20)= 205.1
# Episode 2840  return=  203  avg(last 20)= 210.7
# Episode 2860  return=  233  avg(last 20)= 204.7
# Episode 2880  return=  239  avg(last 20)= 228.9
# Episode 2900  return=  240  avg(last 20)= 225.8
# Episode 2920  return=  222  avg(last 20)= 218.1
# Episode 2940  return=  209  avg(last 20)= 202.3
# Episode 2960  return=  224  avg(last 20)= 222.6
# Episode 2980  return=  229  avg(last 20)= 217.6
# Saved model_actor_critic_refined_seed2.pt and history_actor_critic_refined_seed2.pkl and time_actor_critic_refined_seed2.pkl
#
# Refined AC   final-50 over seeds [0, 1, 2]:  561.9 +/- 330.5
# Original AC  final-50 over seeds [0, 1, 2]:  479.3 +/- 376.4

# %%
MAX_EPISODES = 3000

try:
    BEST_AC_LABEL
except NameError:
    BEST_AC_LABEL = (f"actor_lr={best_cfg['actor_lr']:.1e}, "
                     f"critic_lr={best_cfg['critic_lr']:.1e}, h={best_cfg['hidden']}")

REFINED_AC_LABEL = (
    f"actor_lr={REFINED_BEST_CFG['actor_lr']:.1e}, "
    f"critic_lr={REFINED_BEST_CFG['critic_lr']:.1e}, "
    f"normAdv={REFINED_BEST_CFG['normalize_advantage']}, "
    f"gc={REFINED_BEST_CFG['grad_clip']}"
)

summary_runs = [
    ('none',            'REINFORCE (vanilla)',                    {'linestyle': ':', 'color': 'black'}),
    (BEST_CONST,        'REINFORCE (constant, best)',             {'color': 'tab:orange'}),
    (BEST_EMA,          'REINFORCE (EMA, best)',                  {'color': 'tab:green'}),
    ('actor_critic',    f'Actor-Critic tuned ({BEST_AC_LABEL})',  {'color': 'tab:red'}),
    (REFINED_BEST_NAME, f'Actor-Critic refined ({REFINED_AC_LABEL})',
                        {'color': 'tab:purple', 'linewidth': 2.5}),
]

print(f"Episodes {MAX_EPISODES-50+1}-{MAX_EPISODES}:")
plt.figure(figsize=(11, 5.5))
for suffix, label, style in summary_runs:
    h = load_history(suffix)
    h_cut = h[:MAX_EPISODES]
    score = float(np.mean(h_cut[-50:]))
    peak = float(smooth_50(h_cut).max())
    print(f"  {label:70s} final={score:7.1f}  peak={peak:7.1f}")
    y = smooth_50(h_cut)
    x = np.arange(50, len(h_cut) + 1)
    plt.plot(x, y, label=f'{label}  (final={score:.0f}, peak={peak:.0f})', **style)

plt.xlabel('Episode')
plt.ylabel('Return (50-episode moving average)')
plt.title('Fair comparison incl. refined Actor-Critic (first 3000 episodes)')
plt.legend(loc='best', fontsize=8)
plt.grid(alpha=0.3)
plt.tight_layout()
plt.savefig(os.path.join(PREFIX, 'fair_3000_with_refined.png'),
            dpi=120, bbox_inches='tight')
plt.show()
print("Saved: fair_3000_with_refined.png")
# Out:
# Episodes 2951-3000:
#   REINFORCE (vanilla)                                                    final=   52.7  peak=  419.2
#   REINFORCE (constant, best)                                             final=   97.9  peak=  241.0
#   REINFORCE (EMA, best)                                                  final=  909.9  peak= 1052.9
#   Actor-Critic tuned (actor_lr=3.9e-05, critic_lr=4.0e-04, cw=1.0, h=256) final=  413.5  peak=  621.2
#   Actor-Critic refined (actor_lr=3.5e-05, critic_lr=4.0e-04, normAdv=True, gc=0.3) final= 1010.1  peak= 1013.4
# Saved: fair_3000_with_refined.png

# %% [markdown]
# ## Is EMA's edge over Actor-Critic robust across seeds?
#
# EMA finishes far above Actor-Critic in the single-seed plots. That could be a real, robust gap — or one lucky seed. These append-only cells re-run **every method across several seeds** with identical budgets and report **mean +/- std** for both final-50 return and peak return, plus learning curves with std bands.
#
# What to read off the output:
# - If EMA's mean stays above AC's by **more than the std bands overlap**, the gap is real (not seed luck).
# - Compare **std** columns: a high-variance method (big std) that occasionally spikes high is different from one that is reliably good.
# - Compare **peak vs final-50**: Actor-Critic tends to peak then decay (unstable late), so its final-50 understates its best-case — EMA holds its level.
#
# Configs are reused from earlier cells (`BEST_EMA`, `BEST_CONST`, `best_cfg`, and the refined AC if present). Runs are cached by filename, so re-running is cheap.

# %%
import os

CMP_SEEDS = [0, 1, 2, 3, 4]   # trim for a quick pass

ema_alpha_map = {"ema_a0.0005": 0.0005, "ema_a0.0500": 0.05, "ema_a0.5000": 0.5}

cmp_methods = [
    {"label": "REINFORCE vanilla", "kind": "reinforce",
     "kwargs": {"baseline_mode": "none"}},
    {"label": "REINFORCE constant", "kind": "reinforce",
     "kwargs": {"baseline_mode": "constant",
                "baseline_value": float(BEST_CONST.replace("constant_b", ""))}},
    {"label": "REINFORCE EMA", "kind": "reinforce",
     "kwargs": {"baseline_mode": "ema", "baseline_alpha": ema_alpha_map[BEST_EMA]}},
    {"label": "Actor-Critic tuned", "kind": "actor_critic",
     "kwargs": {"actor_lr": best_cfg["actor_lr"], "critic_lr": best_cfg["critic_lr"],
                "entropy_weight": best_cfg["entropy_weight"],
                "critic_weight": best_cfg["critic_weight"],
                "hidden_size": best_cfg["hidden"], "gamma": best_cfg["gamma"],
                "grad_clip": best_cfg["grad_clip"],
                "normalize_advantage": best_cfg["normalize_advantage"]}},
]

try:
    cmp_methods.append({"label": "Actor-Critic refined", "kind": "actor_critic",
                        "kwargs": dict(REFINED_BEST_CFG)})
except NameError:
    print("(refined AC not found - run cell 23 to include it)")

def _key(label):
    return "cmp_" + label.lower().replace(" ", "_")

for m in cmp_methods:
    m["runs"] = []
    for seed in CMP_SEEDS:
        run_name = f"{_key(m['label'])}_seed{seed}"
        m["runs"].append(run_name)
        if os.path.exists(os.path.join(PREFIX, f"history_{run_name}.pkl")):
            print("skip (cached):", run_name)
            continue
        print("running:", run_name)
        main(algorithm=m["kind"], n_episodes=3000, seed=seed,
             run_name=run_name, save_dir=PREFIX, **m["kwargs"])

print("\nDone. Methods:", [m["label"] for m in cmp_methods], "| seeds:", CMP_SEEDS)
# Out:
# running: cmp_reinforce_vanilla_seed0
# State space: Box(-inf, inf, (11,), float64)
# Action space: Box(-1.0, 1.0, (3,), float32)
# Episode    0  return=    5  avg(last 20)=   5.3
# Episode   20  return=    6  avg(last 20)=   6.0
# Episode   40  return=    7  avg(last 20)=   6.1
# Episode   60  return=    4  avg(last 20)=   5.5
# Episode   80  return=    6  avg(last 20)=   5.9
# Episode  100  return=   10  avg(last 20)=  10.2
# Episode  120  return=    7  avg(last 20)=  11.9
# Episode  140  return=    7  avg(last 20)=   6.9
# Episode  160  return=    8  avg(last 20)=   7.3
# Episode  180  return=   14  avg(last 20)=  11.1
# Episode  200  return=   11  avg(last 20)=  12.5
# Episode  220  return=   12  avg(last 20)=  11.5
# Episode  240  return=   28  avg(last 20)=  22.2
# Episode  260  return=   81  avg(last 20)=  60.3
# Episode  280  return=   76  avg(last 20)=  54.5
# Episode  300  return=   40  avg(last 20)=  61.9
# Episode  320  return=  665  avg(last 20)= 112.8
# Episode  340  return=   26  avg(last 20)=  41.0
# Episode  360  return=   30  avg(last 20)=  18.5
# Episode  380  return=   33  avg(last 20)=  34.4
# Episode  400  return=  189  avg(last 20)= 100.5
# Episode  420  return=  269  avg(last 20)= 241.3
# Episode  440  return=  971  avg(last 20)= 501.4
# Episode  460  return=  973  avg(last 20)= 543.9
# Episode  480  return=  996  avg(last 20)= 986.0
# Episode  500  return=  998  avg(last 20)= 997.8
# Episode  520  return=  523  avg(last 20)= 971.0
# Episode  540  return=  977  avg(last 20)= 647.6
# Episode  560  return=  989  avg(last 20)= 985.2
# Episode  580  return=  994  avg(last 20)= 988.5
# Episode  600  return=  761  avg(last 20)= 889.9
# Episode  620  return= 1027  avg(last 20)= 693.5
# Episode  640  return= 1076  avg(last 20)= 982.0
# Episode  660  return= 1023  avg(last 20)=1024.4
# Episode  680  return= 1012  avg(last 20)=1012.9
# Episode  700  return= 1013  avg(last 20)=1017.4
# Episode  720  return= 1016  avg(last 20)=1011.5
# Episode  740  return= 1014  avg(last 20)=1016.8
# Episode  760  return= 1001  avg(last 20)=1002.3
# Episode  780  return=  995  avg(last 20)= 996.6
# Episode  800  return=  991  avg(last 20)= 996.9
# Episode  820  return=  982  avg(last 20)= 987.1
# Episode  840  return=  984  avg(last 20)= 983.0
# Episode  860  return=  233  avg(last 20)= 575.1
# Episode  880  return=  162  avg(last 20)= 190.0
# Episode  900  return=  550  avg(last 20)= 669.1
# Episode  920  return= 1039  avg(last 20)= 704.1
# Episode  940  return= 1046  avg(last 20)=1040.3
# Episode  960  return=  773  avg(last 20)= 936.4
# Episode  980  return=  739  avg(last 20)= 637.1
# Episode 1000  return=  578  avg(last 20)= 606.5
# Episode 1020  return=  324  avg(last 20)= 484.0
# Episode 1040  return=  151  avg(last 20)= 210.3
# Episode 1060  return=  162  avg(last 20)= 155.2
# Episode 1080  return=  335  avg(last 20)= 234.9
# Episode 1100  return= 1060  avg(last 20)= 478.6
# Episode 1120  return=  286  avg(last 20)= 676.4
# Episode 1140  return=  396  avg(last 20)= 773.5
# Episode 1160  return=  174  avg(last 20)= 219.6
# Episode 1180  return=  118  avg(last 20)= 158.6
# Episode 1200  return=  107  avg(last 20)= 109.6
# Episode 1220  return=   13  avg(last 20)=  28.6
# Episode 1240  return=   17  avg(last 20)=  13.6
# Episode 1260  return=  175  avg(last 20)=  56.3
# Episode 1280  return=  214  avg(last 20)= 109.1
# Episode 1300  return=  173  avg(last 20)=  36.3
# Episode 1320  return=   15  avg(last 20)=  50.0
# Episode 1340  return=   13  avg(last 20)=  13.9
# Episode 1360  return=   15  avg(last 20)=  16.0
# Episode 1380  return=   13  avg(last 20)=  16.9
# Episode 1400  return=  210  avg(last 20)=  56.6
# Episode 1420  return=  244  avg(last 20)= 188.0
# Episode 1440  return=  248  avg(last 20)= 252.8
# Episode 1460  return=  146  avg(last 20)= 194.1
# Episode 1480  return=  129  avg(last 20)= 141.2
# Episode 1500  return=  125  avg(last 20)= 132.2
# Episode 1520  return=  124  avg(last 20)= 121.2
# Episode 1540  return=  247  avg(last 20)= 166.4
# Episode 1560  return=  240  avg(last 20)= 181.6
# Episode 1580  return=  137  avg(last 20)= 206.4
# Episode 1600  return=  205  avg(last 20)= 494.1
# Episode 1620  return=  131  avg(last 20)= 282.5
# Episode 1640  return=  120  avg(last 20)= 154.6
# Episode 1660  return=  238  avg(last 20)= 170.3
# Episode 1680  return=  244  avg(last 20)= 304.5
# Episode 1700  return=  168  avg(last 20)= 172.3
# Episode 1720  return=  163  avg(last 20)= 159.1
# Episode 1740  return=   95  avg(last 20)= 123.1
# Episode 1760  return=   83  avg(last 20)=  94.1
# Episode 1780  return=   86  avg(last 20)=  92.4
# Episode 1800  return=  129  avg(last 20)= 116.5
# Episode 1820  return=  134  avg(last 20)= 125.5
# Episode 1840  return=  128  avg(last 20)= 156.0
# Episode 1860  return=  114  avg(last 20)= 169.9
# Episode 1880  return= 1027  avg(last 20)= 349.6
# Episode 1900  return= 1020  avg(last 20)=1017.0
# Episode 1920  return= 1038  avg(last 20)= 920.7
# Episode 1940  return= 1062  avg(last 20)= 804.1
# Episode 1960  return= 1059  avg(last 20)=1042.5
# Episode 1980  return= 1049  avg(last 20)=1000.0
# Episode 2000  return= 1037  avg(last 20)=1034.6
# Episode 2020  return= 1041  avg(last 20)=1041.2
# Episode 2040  return= 1026  avg(last 20)=1038.2
# Episode 2060  return= 1018  avg(last 20)=1019.5
# Episode 2080  return= 1023  avg(last 20)=1019.6
# Episode 2100  return= 1023  avg(last 20)=1023.8
# Episode 2120  return= 1028  avg(last 20)=1021.1
# Episode 2140  return= 1018  avg(last 20)=1022.4
# Episode 2160  return= 1030  avg(last 20)=1026.8
# Episode 2180  return= 1036  avg(last 20)=1035.5
# Episode 2200  return= 1026  avg(last 20)=1026.2
# Episode 2220  return= 1024  avg(last 20)=1022.5
# Episode 2240  return=  999  avg(last 20)=1010.1
# Episode 2260  return=  571  avg(last 20)= 863.8
# Episode 2280  return=  263  avg(last 20)= 563.6
# Episode 2300  return=  731  avg(last 20)= 572.6
# Episode 2320  return=  376  avg(last 20)= 688.7
# Episode 2340  return=  159  avg(last 20)= 271.2
# Episode 2360  return=   79  avg(last 20)=  92.4
# Episode 2380  return=   39  avg(last 20)=  68.7
# Episode 2400  return=   42  avg(last 20)=  47.6
# Episode 2420  return=   55  avg(last 20)=  40.6
# Episode 2440  return=   46  avg(last 20)=  42.7
# Episode 2460  return=   81  avg(last 20)=  53.2
# Episode 2480  return=   65  avg(last 20)=  53.3
# Episode 2500  return=   50  avg(last 20)=  62.0
# Episode 2520  return=  119  avg(last 20)= 110.4
# Episode 2540  return=  149  avg(last 20)= 174.2
# Episode 2560  return=  403  avg(last 20)= 258.7
# Episode 2580  return= 1004  avg(last 20)= 617.6
# Episode 2600  return= 1031  avg(last 20)=1023.3
# Episode 2620  return= 1036  avg(last 20)=1039.3
# Episode 2640  return= 1068  avg(last 20)=1051.0
# Episode 2660  return= 1073  avg(last 20)=1064.6
# Episode 2680  return=  594  avg(last 20)= 847.3
# Episode 2700  return=  275  avg(last 20)= 428.7
# Episode 2720  return=  471  avg(last 20)= 312.5
# Episode 2740  return=  194  avg(last 20)= 260.3
# Episode 2760  return=  202  avg(last 20)= 159.1
# Episode 2780  return=  263  avg(last 20)= 209.7
# Episode 2800  return=  267  avg(last 20)= 415.4
# Episode 2820  return=  279  avg(last 20)= 411.9
# Episode 2840  return=  132  avg(last 20)= 297.2
# Episode 2860  return=  380  avg(last 20)= 490.0
# Episode 2880  return=  358  avg(last 20)= 500.8
# Episode 2900  return=  252  avg(last 20)= 461.4
# Episode 2920  return=  120  avg(last 20)= 180.8
# Episode 2940  return=  143  avg(last 20)= 144.2
# Episode 2960  return=  196  avg(last 20)= 179.1
# Episode 2980  return=  205  avg(last 20)= 197.8
# Saved model_cmp_reinforce_vanilla_seed0.pt and history_cmp_reinforce_vanilla_seed0.pkl and time_cmp_reinforce_vanilla_seed0.pkl
# running: cmp_reinforce_vanilla_seed1
# State space: Box(-inf, inf, (11,), float64)
# Action space: Box(-1.0, 1.0, (3,), float32)
# Episode    0  return=    8  avg(last 20)=   7.8
# Episode   20  return=   19  avg(last 20)=  10.6
# Episode   40  return=   37  avg(last 20)=  35.7
# Episode   60  return=   61  avg(last 20)=  62.4
# Episode   80  return=   87  avg(last 20)=  76.0
# Episode  100  return=  196  avg(last 20)=  80.0
# Episode  120  return=  407  avg(last 20)= 369.8
# Episode  140  return=   67  avg(last 20)=  98.8
# Episode  160  return=  246  avg(last 20)= 266.8
# Episode  180  return=  216  avg(last 20)= 236.9
# Episode  200  return=  200  avg(last 20)= 220.5
# Episode  220  return=  406  avg(last 20)= 238.3
# Episode  240  return=  304  avg(last 20)= 358.9
# Episode  260  return=  145  avg(last 20)= 236.9
# Episode  280  return=  262  avg(last 20)= 216.2
# Episode  300  return=  406  avg(last 20)= 518.0
# Episode  320  return=  468  avg(last 20)= 408.7
# Episode  340  return=  202  avg(last 20)= 389.6
# Episode  360  return=  140  avg(last 20)= 169.8
# Episode  380  return=  100  avg(last 20)= 111.1
# Episode  400  return=   89  avg(last 20)=  92.1
# Episode  420  return=   92  avg(last 20)=  87.7
# Episode  440  return=  101  avg(last 20)=  97.5
# Episode  460  return=   84  avg(last 20)=  90.4
# Episode  480  return=   85  avg(last 20)=  85.6
# Episode  500  return=   83  avg(last 20)=  83.2
# Episode  520  return=   74  avg(last 20)=  80.3
# Episode  540  return=   84  avg(last 20)=  82.5
# Episode  560  return=   88  avg(last 20)=  95.7
# Episode  580  return=  111  avg(last 20)= 106.0
# Episode  600  return=  125  avg(last 20)= 112.2
# Episode  620  return=  141  avg(last 20)= 124.3
# Episode  640  return=  138  avg(last 20)= 127.3
# Episode  660  return=  190  avg(last 20)= 152.4
# Episode  680  return=  121  avg(last 20)= 182.3
# Episode  700  return=  259  avg(last 20)= 222.2
# Episode  720  return=  251  avg(last 20)= 256.0
# Episode  740  return=  286  avg(last 20)= 210.2
# Episode  760  return=  185  avg(last 20)= 180.5
# Episode  780  return=  249  avg(last 20)= 172.1
# Episode  800  return=  107  avg(last 20)= 191.2
# Episode  820  return=  219  avg(last 20)= 201.3
# Episode  840  return=  137  avg(last 20)= 121.0
# Episode  860  return=  132  avg(last 20)= 119.1
# Episode  880  return=   86  avg(last 20)= 128.3
# Episode  900  return=   93  avg(last 20)= 101.1
# Episode  920  return=   89  avg(last 20)= 116.2
# Episode  940  return=  100  avg(last 20)= 105.0
# Episode  960  return=   94  avg(last 20)= 105.9
# Episode  980  return=   94  avg(last 20)= 110.4
# Episode 1000  return=   88  avg(last 20)= 103.4
# Episode 1020  return=  243  avg(last 20)= 152.3
# Episode 1040  return=  259  avg(last 20)= 243.7
# Episode 1060  return=  192  avg(last 20)= 216.3
# Episode 1080  return=  242  avg(last 20)= 220.8
# Episode 1100  return=  187  avg(last 20)= 212.1
# Episode 1120  return=  213  avg(last 20)= 208.0
# Episode 1140  return=  230  avg(last 20)= 214.4
# Episode 1160  return=  281  avg(last 20)= 211.1
# Episode 1180  return=  327  avg(last 20)= 284.9
# Episode 1200  return=  127  avg(last 20)= 272.3
# Episode 1220  return=   97  avg(last 20)= 123.3
# Episode 1240  return=   98  avg(last 20)= 127.3
# Episode 1260  return=   98  avg(last 20)=  94.9
# Episode 1280  return=   93  avg(last 20)=  94.3
# Episode 1300  return=   84  avg(last 20)=  83.0
# Episode 1320  return=   89  avg(last 20)=  89.3
# Episode 1340  return=   89  avg(last 20)=  89.6
# Episode 1360  return=   83  avg(last 20)= 107.0
# Episode 1380  return=  238  avg(last 20)= 204.8
# Episode 1400  return=  244  avg(last 20)= 217.6
# Episode 1420  return=   94  avg(last 20)= 179.0
# Episode 1440  return=  104  avg(last 20)= 118.8
# Episode 1460  return=  257  avg(last 20)= 126.8
# Episode 1480  return=  260  avg(last 20)= 205.0
# Episode 1500  return=  153  avg(last 20)= 166.4
# Episode 1520  return=  117  avg(last 20)= 132.3
# Episode 1540  return=   95  avg(last 20)= 108.6
# Episode 1560  return=  133  avg(last 20)= 155.1
# Episode 1580  return=  118  avg(last 20)= 145.7
# Episode 1600  return=  114  avg(last 20)= 114.6
# Episode 1620  return=  150  avg(last 20)= 154.1
# Episode 1640  return=  267  avg(last 20)= 185.5
# Episode 1660  return=  128  avg(last 20)= 154.1
# Episode 1680  return=  152  avg(last 20)= 144.4
# Episode 1700  return=  129  avg(last 20)= 142.4
# Episode 1720  return=  357  avg(last 20)= 190.2
# Episode 1740  return=  148  avg(last 20)= 245.3
# Episode 1760  return=  132  avg(last 20)= 255.9
# Episode 1780  return=  152  avg(last 20)= 224.7
# Episode 1800  return=  157  avg(last 20)= 183.1
# Episode 1820  return=   76  avg(last 20)=  98.7
# Episode 1840  return=  146  avg(last 20)= 125.0
# Episode 1860  return=  133  avg(last 20)= 161.7
# Episode 1880  return=   92  avg(last 20)= 120.9
# Episode 1900  return=   63  avg(last 20)= 135.3
# Episode 1920  return=   99  avg(last 20)= 129.7
# Episode 1940  return=   53  avg(last 20)=  99.4
# Episode 1960  return=   37  avg(last 20)=  55.5
# Episode 1980  return=   86  avg(last 20)=  64.8
# Episode 2000  return=   67  avg(last 20)=  62.0
# Episode 2020  return=   90  avg(last 20)=  78.4
# Episode 2040  return=   24  avg(last 20)=  73.2
# Episode 2060  return=   21  avg(last 20)=  75.4
# Episode 2080  return=   81  avg(last 20)=  73.3
# Episode 2100  return=   80  avg(last 20)=  76.0
# Episode 2120  return=   34  avg(last 20)=  66.2
# Episode 2140  return=   54  avg(last 20)=  60.0
# Episode 2160  return=   37  avg(last 20)=  46.2
# Episode 2180  return=   58  avg(last 20)=  30.9
# Episode 2200  return=   33  avg(last 20)=  37.9
# Episode 2220  return=   91  avg(last 20)=  43.7
# Episode 2240  return=   24  avg(last 20)=  36.7
# Episode 2260  return=   20  avg(last 20)=  40.8
# Episode 2280  return=   19  avg(last 20)=  23.7
# Episode 2300  return=   31  avg(last 20)=  25.7
# Episode 2320  return=   12  avg(last 20)=  17.4
# Episode 2340  return=   11  avg(last 20)=  14.7
# Episode 2360  return=   18  avg(last 20)=  17.8
# Episode 2380  return=   23  avg(last 20)=  25.3
# Episode 2400  return=   24  avg(last 20)=  19.3
# Episode 2420  return=   19  avg(last 20)=  19.1
# Episode 2440  return=   13  avg(last 20)=  13.3
# Episode 2460  return=    8  avg(last 20)=   9.0
# Episode 2480  return=    8  avg(last 20)=   8.8
# Episode 2500  return=    7  avg(last 20)=   8.6
# Episode 2520  return=    8  avg(last 20)=   7.8
# Episode 2540  return=    7  avg(last 20)=   7.5
# Episode 2560  return=    7  avg(last 20)=   7.1
# Episode 2580  return=    7  avg(last 20)=   7.0
# Episode 2600  return=    7  avg(last 20)=   7.2
# Episode 2620  return=    6  avg(last 20)=   6.4
# Episode 2640  return=    7  avg(last 20)=   6.2
# Episode 2660  return=    7  avg(last 20)=   6.9
# Episode 2680  return=    7  avg(last 20)=   7.1
# Episode 2700  return=    8  avg(last 20)=   7.4
# Episode 2720  return=    7  avg(last 20)=   7.7
# Episode 2740  return=    6  avg(last 20)=   7.0
# Episode 2760  return=    7  avg(last 20)=   7.2
# Episode 2780  return=    8  avg(last 20)=   7.7
# Episode 2800  return=    8  avg(last 20)=   7.7
# Episode 2820  return=    8  avg(last 20)=   7.9
# Episode 2840  return=    7  avg(last 20)=   7.7
# Episode 2860  return=    7  avg(last 20)=   7.6
# Episode 2880  return=    7  avg(last 20)=   7.7
# Episode 2900  return=    9  avg(last 20)=   8.1
# Episode 2920  return=    9  avg(last 20)=   8.6
# Episode 2940  return=    9  avg(last 20)=   8.7
# Episode 2960  return=    9  avg(last 20)=   8.9
# Episode 2980  return=    8  avg(last 20)=   8.7
# Saved model_cmp_reinforce_vanilla_seed1.pt and history_cmp_reinforce_vanilla_seed1.pkl and time_cmp_reinforce_vanilla_seed1.pkl
# running: cmp_reinforce_vanilla_seed2
# State space: Box(-inf, inf, (11,), float64)
# Action space: Box(-1.0, 1.0, (3,), float32)
# Episode    0  return=    8  avg(last 20)=   7.6
# Episode   20  return=   10  avg(last 20)=   9.2
# Episode   40  return=   10  avg(last 20)=   8.9
# Episode   60  return=   11  avg(last 20)=   8.7
# Episode   80  return=    6  avg(last 20)=   9.5
# Episode  100  return=    7  avg(last 20)=   7.7
# Episode  120  return=    8  avg(last 20)=   6.9
# Episode  140  return=   11  avg(last 20)=  11.9
# Episode  160  return=   22  avg(last 20)=  19.6
# Episode  180  return=  181  avg(last 20)=  58.0
# Episode  200  return=  159  avg(last 20)= 264.5
# Episode  220  return=  393  avg(last 20)= 213.6
# Episode  240  return=  113  avg(last 20)= 415.9
# Episode  260  return=   52  avg(last 20)=  78.5
# Episode  280  return=  253  avg(last 20)= 128.4
# Episode  300  return=  227  avg(last 20)= 339.7
# Episode  320  return=  542  avg(last 20)= 690.0
# Episode  340  return=  161  avg(last 20)= 482.4
# Episode  360  return=   82  avg(last 20)=  83.9
# Episode  380  return=  556  avg(last 20)= 266.4
# Episode  400  return=  680  avg(last 20)= 508.1
# Episode  420  return=  292  avg(last 20)= 779.1
# Episode  440  return=  970  avg(last 20)= 602.1
# Episode  460  return=  411  avg(last 20)= 771.7
# Episode  480  return=  162  avg(last 20)= 301.9
# Episode  500  return=  217  avg(last 20)= 277.3
# Episode  520  return=  246  avg(last 20)= 527.1
# Episode  540  return=  604  avg(last 20)= 544.6
# Episode  560  return=  973  avg(last 20)= 657.8
# Episode  580  return=  563  avg(last 20)= 597.2
# Episode  600  return=  984  avg(last 20)= 856.0
# Episode  620  return=  983  avg(last 20)= 987.1
# Episode  640  return=  705  avg(last 20)= 785.1
# Episode  660  return=  324  avg(last 20)= 464.3
# Episode  680  return=  999  avg(last 20)= 631.6
# Episode  700  return=  581  avg(last 20)= 987.0
# Episode  720  return=  510  avg(last 20)= 578.9
# Episode  740  return=  251  avg(last 20)= 450.0
# Episode  760  return=  158  avg(last 20)= 201.3
# Episode  780  return=  143  avg(last 20)= 139.8
# Episode  800  return=  136  avg(last 20)= 143.7
# Episode  820  return=  153  avg(last 20)= 161.5
# Episode  840  return=  168  avg(last 20)= 145.1
# Episode  860  return=  202  avg(last 20)= 169.1
# Episode  880  return=  177  avg(last 20)= 195.5
# Episode  900  return=  153  avg(last 20)= 150.6
# Episode  920  return=  123  avg(last 20)= 140.4
# Episode  940  return=  146  avg(last 20)= 138.4
# Episode  960  return=  187  avg(last 20)= 174.5
# Episode  980  return=  312  avg(last 20)= 239.9
# Episode 1000  return=  307  avg(last 20)= 395.7
# Episode 1020  return=  433  avg(last 20)= 362.9
# Episode 1040  return=  246  avg(last 20)= 384.9
# Episode 1060  return=  286  avg(last 20)= 271.9
# Episode 1080  return=  306  avg(last 20)= 323.5
# Episode 1100  return=  407  avg(last 20)= 392.1
# Episode 1120  return=  161  avg(last 20)= 385.7
# Episode 1140  return= 1019  avg(last 20)= 645.1
# Episode 1160  return= 1010  avg(last 20)=1017.1
# Episode 1180  return=  742  avg(last 20)= 951.3
# Episode 1200  return=  972  avg(last 20)= 562.4
# Episode 1220  return= 1004  avg(last 20)= 994.4
# Episode 1240  return= 1009  avg(last 20)=1008.0
# Episode 1260  return= 1011  avg(last 20)=1007.7
# Episode 1280  return= 1002  avg(last 20)=1012.6
# Episode 1300  return= 1005  avg(last 20)=1002.2
# Episode 1320  return= 1011  avg(last 20)=1007.5
# Episode 1340  return=  264  avg(last 20)= 809.3
# Episode 1360  return=  126  avg(last 20)= 157.1
# Episode 1380  return=   89  avg(last 20)= 110.9
# Episode 1400  return=   76  avg(last 20)=  80.6
# Episode 1420  return=   68  avg(last 20)=  73.9
# Episode 1440  return=   72  avg(last 20)=  68.4
# Episode 1460  return=   73  avg(last 20)=  73.4
# Episode 1480  return=   74  avg(last 20)=  75.4
# Episode 1500  return=   73  avg(last 20)=  74.0
# Episode 1520  return=   72  avg(last 20)=  68.8
# Episode 1540  return=   71  avg(last 20)=  70.2
# Episode 1560  return=   72  avg(last 20)=  72.1
# Episode 1580  return=   43  avg(last 20)=  56.2
# Episode 1600  return=   52  avg(last 20)=  45.2
# Episode 1620  return=   66  avg(last 20)=  63.5
# Episode 1640  return=   73  avg(last 20)=  73.9
# Episode 1660  return=   98  avg(last 20)=  79.0
# Episode 1680  return=  115  avg(last 20)= 102.9
# Episode 1700  return=  135  avg(last 20)= 129.8
# Episode 1720  return=  128  avg(last 20)= 137.1
# Episode 1740  return=  133  avg(last 20)= 129.3
# Episode 1760  return=  157  avg(last 20)= 139.8
# Episode 1780  return=  116  avg(last 20)= 137.8
# Episode 1800  return=   93  avg(last 20)= 106.7
# Episode 1820  return=   93  avg(last 20)=  92.6
# Episode 1840  return=   81  avg(last 20)=  85.3
# Episode 1860  return=   79  avg(last 20)=  82.0
# Episode 1880  return=   81  avg(last 20)=  78.6
# Episode 1900  return=   77  avg(last 20)=  76.0
# Episode 1920  return=   79  avg(last 20)=  76.8
# Episode 1940  return=   77  avg(last 20)=  77.4
# Episode 1960  return=  100  avg(last 20)=  85.7
# Episode 1980  return=  134  avg(last 20)= 115.9
# Episode 2000  return=  120  avg(last 20)= 124.5
# Episode 2020  return=  120  avg(last 20)= 114.0
# Episode 2040  return=  102  avg(last 20)= 112.2
# Episode 2060  return=   81  avg(last 20)=  92.3
# Episode 2080  return=   92  avg(last 20)=  83.9
# Episode 2100  return=  105  avg(last 20)=  88.6
# Episode 2120  return=  112  avg(last 20)= 105.7
# Episode 2140  return=  101  avg(last 20)= 106.1
# Episode 2160  return=  105  avg(last 20)= 107.1
# Episode 2180  return=  123  avg(last 20)= 117.5
# Episode 2200  return=  129  avg(last 20)= 125.8
# Episode 2220  return=  167  avg(last 20)= 142.3
# Episode 2240  return=  233  avg(last 20)= 182.5
# Episode 2260  return= 1019  avg(last 20)= 437.9
# Episode 2280  return=  996  avg(last 20)=1006.6
# Episode 2300  return=  982  avg(last 20)= 981.6
# Episode 2320  return= 1010  avg(last 20)= 995.9
# Episode 2340  return= 1015  avg(last 20)=1014.2
# Episode 2360  return= 1007  avg(last 20)=1012.2
# Episode 2380  return=  990  avg(last 20)= 999.2
# Episode 2400  return=  973  avg(last 20)= 979.8
# Episode 2420  return=  975  avg(last 20)= 958.7
# Episode 2440  return=  969  avg(last 20)= 972.9
# Episode 2460  return=  903  avg(last 20)= 954.3
# Episode 2480  return=  335  avg(last 20)= 537.9
# Episode 2500  return=  219  avg(last 20)= 298.5
# Episode 2520  return=  249  avg(last 20)= 237.5
# Episode 2540  return=  976  avg(last 20)= 580.2
# Episode 2560  return=  992  avg(last 20)= 982.5
# Episode 2580  return= 1000  avg(last 20)=1000.3
# Episode 2600  return=  983  avg(last 20)= 994.7
# Episode 2620  return=  984  avg(last 20)= 979.4
# Episode 2640  return=  655  avg(last 20)= 924.7
# Episode 2660  return=  995  avg(last 20)= 788.1
# Episode 2680  return= 1011  avg(last 20)=1000.3
# Episode 2700  return= 1018  avg(last 20)=1013.4
# Episode 2720  return=  352  avg(last 20)= 726.5
# Episode 2740  return=  274  avg(last 20)= 312.9
# Episode 2760  return=  231  avg(last 20)= 254.7
# Episode 2780  return=  312  avg(last 20)= 271.3
# Episode 2800  return=  249  avg(last 20)= 262.9
# Episode 2820  return=  182  avg(last 20)= 212.1
# Episode 2840  return=  167  avg(last 20)= 172.7
# Episode 2860  return=  153  avg(last 20)= 158.1
# Episode 2880  return=  134  avg(last 20)= 146.3
# Episode 2900  return=  139  avg(last 20)= 137.9
# Episode 2920  return=  126  avg(last 20)= 133.8
# Episode 2940  return=  109  avg(last 20)= 120.2
# Episode 2960  return=  115  avg(last 20)= 113.4
# Episode 2980  return=  134  avg(last 20)= 121.4
# Saved model_cmp_reinforce_vanilla_seed2.pt and history_cmp_reinforce_vanilla_seed2.pkl and time_cmp_reinforce_vanilla_seed2.pkl
# running: cmp_reinforce_vanilla_seed3
# State space: Box(-inf, inf, (11,), float64)
# Action space: Box(-1.0, 1.0, (3,), float32)
# Episode    0  return=   29  avg(last 20)=  29.3
# Episode   20  return=   29  avg(last 20)=  21.0
# Episode   40  return=   16  avg(last 20)=  41.7
# Episode   60  return=   68  avg(last 20)=  53.5
# Episode   80  return=   26  avg(last 20)=  45.2
# Episode  100  return=  259  avg(last 20)= 267.4
# Episode  120  return=  133  avg(last 20)= 168.5
# Episode  140  return=  122  avg(last 20)= 125.1
# Episode  160  return=   51  avg(last 20)=  98.1
# Episode  180  return=  205  avg(last 20)=  67.9
# Episode  200  return=  116  avg(last 20)= 140.7
# Episode  220  return=  110  avg(last 20)= 121.8
# Episode  240  return=  119  avg(last 20)= 111.6
# Episode  260  return=  117  avg(last 20)= 110.7
# Episode  280  return=   98  avg(last 20)=  94.4
# Episode  300  return=   74  avg(last 20)=  84.3
# Episode  320  return=  105  avg(last 20)=  98.4
# Episode  340  return=  128  avg(last 20)= 119.6
# Episode  360  return=  147  avg(last 20)= 142.4
# Episode  380  return=  178  avg(last 20)= 181.6
# Episode  400  return=   23  avg(last 20)= 135.4
# Episode  420  return=   18  avg(last 20)=  49.7
# Episode  440  return=   14  avg(last 20)=  15.2
# Episode  460  return=   13  avg(last 20)=  13.2
# Episode  480  return=   13  avg(last 20)=  11.3
# Episode  500  return=   10  avg(last 20)=  10.8
# Episode  520  return=   27  avg(last 20)=  15.3
# Episode  540  return=  158  avg(last 20)=  35.8
# Episode  560  return=  126  avg(last 20)= 130.1
# Episode  580  return=  114  avg(last 20)= 118.2
# Episode  600  return=  105  avg(last 20)= 108.9
# Episode  620  return=   85  avg(last 20)=  94.7
# Episode  640  return=   72  avg(last 20)=  75.4
# Episode  660  return=   73  avg(last 20)=  74.4
# Episode  680  return=   72  avg(last 20)=  74.2
# Episode  700  return=   82  avg(last 20)=  77.6
# Episode  720  return=   78  avg(last 20)=  78.7
# Episode  740  return=   80  avg(last 20)=  83.2
# Episode  760  return=   88  avg(last 20)=  84.7
# Episode  780  return=   86  avg(last 20)=  85.6
# Episode  800  return=   76  avg(last 20)=  82.4
# Episode  820  return=   82  avg(last 20)=  77.9
# Episode  840  return=   80  avg(last 20)=  79.9
# Episode  860  return=   89  avg(last 20)=  81.4
# Episode  880  return=  101  avg(last 20)=  96.6
# Episode  900  return=  106  avg(last 20)= 105.7
# Episode  920  return=  131  avg(last 20)= 116.5
# Episode  940  return=  121  avg(last 20)= 124.7
# Episode  960  return=  101  avg(last 20)= 111.3
# Episode  980  return=  106  avg(last 20)= 101.4
# Episode 1000  return=   92  avg(last 20)=  96.8
# Episode 1020  return=   84  avg(last 20)=  86.7
# Episode 1040  return=  113  avg(last 20)= 100.7
# Episode 1060  return=  105  avg(last 20)= 109.3
# Episode 1080  return=   98  avg(last 20)=  96.1
# Episode 1100  return=   75  avg(last 20)=  82.7
# Episode 1120  return=   71  avg(last 20)=  71.6
# Episode 1140  return=   69  avg(last 20)=  70.2
# Episode 1160  return=   73  avg(last 20)=  71.6
# Episode 1180  return=   73  avg(last 20)=  73.8
# Episode 1200  return=   70  avg(last 20)=  71.0
# Episode 1220  return=   65  avg(last 20)=  68.5
# Episode 1240  return=   62  avg(last 20)=  63.8
# Episode 1260  return=   57  avg(last 20)=  59.7
# Episode 1280  return=   54  avg(last 20)=  55.8
# Episode 1300  return=   56  avg(last 20)=  55.7
# Episode 1320  return=   55  avg(last 20)=  55.6
# Episode 1340  return=   54  avg(last 20)=  55.3
# Episode 1360  return=   51  avg(last 20)=  52.0
# Episode 1380  return=   48  avg(last 20)=  50.6
# Episode 1400  return=   49  avg(last 20)=  46.8
# Episode 1420  return=   48  avg(last 20)=  46.5
# Episode 1440  return=   50  avg(last 20)=  49.5
# Episode 1460  return=   45  avg(last 20)=  47.2
# Episode 1480  return=   47  avg(last 20)=  47.2
# Episode 1500  return=   44  avg(last 20)=  45.9
# Episode 1520  return=   42  avg(last 20)=  43.2
# Episode 1540  return=   40  avg(last 20)=  41.0
# Episode 1560  return=   38  avg(last 20)=  39.6
# Episode 1580  return=   37  avg(last 20)=  38.8
# Episode 1600  return=   44  avg(last 20)=  41.2
# Episode 1620  return=   45  avg(last 20)=  43.4
# Episode 1640  return=   43  avg(last 20)=  44.2
# Episode 1660  return=   45  avg(last 20)=  45.2
# Episode 1680  return=   42  avg(last 20)=  44.6
# Episode 1700  return=   51  avg(last 20)=  48.4
# Episode 1720  return=   46  avg(last 20)=  48.5
# Episode 1740  return=   47  avg(last 20)=  47.3
# Episode 1760  return=   44  avg(last 20)=  45.5
# Episode 1780  return=   42  avg(last 20)=  44.0
# Episode 1800  return=   40  avg(last 20)=  42.1
# Episode 1820  return=   41  avg(last 20)=  41.0
# Episode 1840  return=   44  avg(last 20)=  42.2
# Episode 1860  return=   42  avg(last 20)=  44.5
# Episode 1880  return=   43  avg(last 20)=  43.7
# Episode 1900  return=   42  avg(last 20)=  40.9
# Episode 1920  return=   41  avg(last 20)=  40.3
# Episode 1940  return=   43  avg(last 20)=  42.8
# Episode 1960  return=   44  avg(last 20)=  44.9
# Episode 1980  return=   46  avg(last 20)=  43.6
# Episode 2000  return=   39  avg(last 20)=  41.4
# Episode 2020  return=   39  avg(last 20)=  39.3
# Episode 2040  return=   39  avg(last 20)=  39.1
# Episode 2060  return=   37  avg(last 20)=  38.8
# Episode 2080  return=   41  avg(last 20)=  39.0
# Episode 2100  return=   39  avg(last 20)=  38.5
# Episode 2120  return=   37  avg(last 20)=  38.4
# Episode 2140  return=   38  avg(last 20)=  38.9
# Episode 2160  return=   39  avg(last 20)=  39.2
# Episode 2180  return=   39  avg(last 20)=  38.8
# Episode 2200  return=   38  avg(last 20)=  38.9
# Episode 2220  return=   39  avg(last 20)=  38.9
# Episode 2240  return=   41  avg(last 20)=  39.4
# Episode 2260  return=   49  avg(last 20)=  41.4
# Episode 2280  return=   44  avg(last 20)=  45.1
# Episode 2300  return=   48  avg(last 20)=  46.2
# Episode 2320  return=   45  avg(last 20)=  46.2
# Episode 2340  return=   41  avg(last 20)=  44.8
# Episode 2360  return=   43  avg(last 20)=  44.1
# Episode 2380  return=   44  avg(last 20)=  42.5
# Episode 2400  return=   39  avg(last 20)=  41.0
# Episode 2420  return=   39  avg(last 20)=  39.5
# Episode 2440  return=   40  avg(last 20)=  38.9
# Episode 2460  return=   39  avg(last 20)=  39.1
# Episode 2480  return=   40  avg(last 20)=  39.4
# Episode 2500  return=   40  avg(last 20)=  40.0
# Episode 2520  return=   41  avg(last 20)=  43.9
# Episode 2540  return=   44  avg(last 20)=  41.5
# Episode 2560  return=   40  avg(last 20)=  41.3
# Episode 2580  return=   41  avg(last 20)=  41.5
# Episode 2600  return=   39  avg(last 20)=  40.2
# Episode 2620  return=   37  avg(last 20)=  39.2
# Episode 2640  return=   39  avg(last 20)=  39.4
# Episode 2660  return=   39  avg(last 20)=  39.1
# Episode 2680  return=   39  avg(last 20)=  39.3
# Episode 2700  return=   39  avg(last 20)=  38.8
# Episode 2720  return=   39  avg(last 20)=  39.1
# Episode 2740  return=   40  avg(last 20)=  39.7
# Episode 2760  return=   39  avg(last 20)=  39.1
# Episode 2780  return=   39  avg(last 20)=  39.3
# Episode 2800  return=   39  avg(last 20)=  39.7
# Episode 2820  return=   41  avg(last 20)=  40.4
# Episode 2840  return=   42  avg(last 20)=  40.0
# Episode 2860  return=   39  avg(last 20)=  39.1
# Episode 2880  return=   40  avg(last 20)=  39.1
# Episode 2900  return=   40  avg(last 20)=  38.7
# Episode 2920  return=   39  avg(last 20)=  38.9
# Episode 2940  return=   37  avg(last 20)=  38.7
# Episode 2960  return=   39  avg(last 20)=  38.9
# Episode 2980  return=   37  avg(last 20)=  38.7
# Saved model_cmp_reinforce_vanilla_seed3.pt and history_cmp_reinforce_vanilla_seed3.pkl and time_cmp_reinforce_vanilla_seed3.pkl
# running: cmp_reinforce_vanilla_seed4
# State space: Box(-inf, inf, (11,), float64)
# Action space: Box(-1.0, 1.0, (3,), float32)
# Episode    0  return=   31  avg(last 20)=  31.0
# Episode   20  return=    8  avg(last 20)=  14.6
# Episode   40  return=    7  avg(last 20)=  13.0
# Episode   60  return=   17  avg(last 20)=  16.7
# Episode   80  return=    8  avg(last 20)=  10.7
# Episode  100  return=    8  avg(last 20)=   8.1
# Episode  120  return=    5  avg(last 20)=   6.5
# Episode  140  return=    5  avg(last 20)=   5.9
# Episode  160  return=    5  avg(last 20)=   5.3
# Episode  180  return=    5  avg(last 20)=   5.2
# Episode  200  return=    5  avg(last 20)=   5.5
# Episode  220  return=    5  avg(last 20)=   5.3
# Episode  240  return=    5  avg(last 20)=   5.5
# Episode  260  return=    5  avg(last 20)=   5.4
# Episode  280  return=    6  avg(last 20)=   5.8
# Episode  300  return=    6  avg(last 20)=   6.0
# Episode  320  return=    8  avg(last 20)=   7.4
# Episode  340  return=   15  avg(last 20)=  11.9
# Episode  360  return=   33  avg(last 20)=  17.6
# Episode  380  return=   41  avg(last 20)=  23.4
# Episode  400  return=    7  avg(last 20)=  29.1
# Episode  420  return=    5  avg(last 20)=  13.3
# Episode  440  return=    4  avg(last 20)=   6.9
# Episode  460  return=    5  avg(last 20)=   3.7
# Episode  480  return=    4  avg(last 20)=   8.8
# Episode  500  return=    3  avg(last 20)=   6.5
# Episode  520  return=    7  avg(last 20)=   4.7
# Episode  540  return=    5  avg(last 20)=   9.0
# Episode  560  return=    6  avg(last 20)=  12.3
# Episode  580  return=    8  avg(last 20)=  10.2
# Episode  600  return=   11  avg(last 20)=   7.8
# Episode  620  return=  118  avg(last 20)=  34.1
# Episode  640  return=   31  avg(last 20)=  46.0
# Episode  660  return=   91  avg(last 20)=  91.1
# Episode  680  return=   55  avg(last 20)=  83.7
# Episode  700  return=   31  avg(last 20)=  35.9
# Episode  720  return=  200  avg(last 20)= 176.2
# Episode  740  return=  118  avg(last 20)= 166.6
# Episode  760  return=  163  avg(last 20)= 141.0
# Episode  780  return=  179  avg(last 20)= 176.5
# Episode  800  return=  203  avg(last 20)= 207.3
# Episode  820  return=  173  avg(last 20)= 198.2
# Episode  840  return=  113  avg(last 20)= 134.1
# Episode  860  return=   90  avg(last 20)=  98.3
# Episode  880  return=   84  avg(last 20)=  86.8
# Episode  900  return=   67  avg(last 20)=  73.1
# Episode  920  return=   59  avg(last 20)=  64.1
# Episode  940  return=   74  avg(last 20)=  61.1
# Episode  960  return=   75  avg(last 20)=  73.5
# Episode  980  return=   76  avg(last 20)=  72.8
# Episode 1000  return=   66  avg(last 20)=  67.8
# Episode 1020  return=   82  avg(last 20)=  78.3
# Episode 1040  return=  108  avg(last 20)= 101.4
# Episode 1060  return=  111  avg(last 20)= 112.0
# Episode 1080  return=  103  avg(last 20)= 106.4
# Episode 1100  return=  112  avg(last 20)= 111.6
# Episode 1120  return=  124  avg(last 20)= 114.1
# Episode 1140  return=  109  avg(last 20)= 118.6
# Episode 1160  return=  133  avg(last 20)= 123.8
# Episode 1180  return=  154  avg(last 20)= 141.3
# Episode 1200  return=   85  avg(last 20)= 113.6
# Episode 1220  return=   67  avg(last 20)=  65.9
# Episode 1240  return=   47  avg(last 20)=  53.3
# Episode 1260  return=   48  avg(last 20)=  48.7
# Episode 1280  return=   45  avg(last 20)=  45.2
# Episode 1300  return=   44  avg(last 20)=  42.3
# Episode 1320  return=   40  avg(last 20)=  41.7
# Episode 1340  return=   44  avg(last 20)=  43.7
# Episode 1360  return=   47  avg(last 20)=  46.8
# Episode 1380  return=   49  avg(last 20)=  49.5
# Episode 1400  return=   55  avg(last 20)=  51.8
# Episode 1420  return=   51  avg(last 20)=  51.9
# Episode 1440  return=   47  avg(last 20)=  48.7
# Episode 1460  return=   47  avg(last 20)=  47.9
# Episode 1480  return=   49  avg(last 20)=  47.7
# Episode 1500  return=   51  avg(last 20)=  52.1
# Episode 1520  return=   52  avg(last 20)=  52.8
# Episode 1540  return=   50  avg(last 20)=  51.8
# Episode 1560  return=   58  avg(last 20)=  53.1
# Episode 1580  return=   59  avg(last 20)=  59.4
# Episode 1600  return=  114  avg(last 20)=  95.0
# Episode 1620  return=  127  avg(last 20)= 131.1
# Episode 1640  return=  174  avg(last 20)= 164.3
# Episode 1660  return=  106  avg(last 20)= 128.3
# Episode 1680  return=  170  avg(last 20)= 153.3
# Episode 1700  return=  111  avg(last 20)= 157.4
# Episode 1720  return=  165  avg(last 20)= 155.3
# Episode 1740  return=   84  avg(last 20)= 128.9
# Episode 1760  return=  165  avg(last 20)= 132.9
# Episode 1780  return=   66  avg(last 20)=  87.5
# Episode 1800  return=   74  avg(last 20)=  65.1
# Episode 1820  return=   78  avg(last 20)=  76.9
# Episode 1840  return=  110  avg(last 20)=  86.9
# Episode 1860  return=  174  avg(last 20)= 155.1
# Episode 1880  return=  177  avg(last 20)= 179.5
# Episode 1900  return=  153  avg(last 20)= 166.7
# Episode 1920  return=  194  avg(last 20)= 181.5
# Episode 1940  return=  199  avg(last 20)= 197.8
# Episode 1960  return=  203  avg(last 20)= 201.9
# Episode 1980  return=  210  avg(last 20)= 206.1
# Episode 2000  return=  212  avg(last 20)= 210.7
# Episode 2020  return=  210  avg(last 20)= 211.2
# Episode 2040  return=  213  avg(last 20)= 210.6
# Episode 2060  return=  215  avg(last 20)= 204.5
# Episode 2080  return=  222  avg(last 20)= 217.7
# Episode 2100  return=  225  avg(last 20)= 226.4
# Episode 2120  return=  224  avg(last 20)= 225.8
# Episode 2140  return=  211  avg(last 20)= 225.8
# Episode 2160  return=  174  avg(last 20)= 192.7
# Episode 2180  return=  176  avg(last 20)= 171.4
# Episode 2200  return=  225  avg(last 20)= 188.9
# Episode 2220  return=  227  avg(last 20)= 225.2
# Episode 2240  return=  220  avg(last 20)= 223.9
# Episode 2260  return=  217  avg(last 20)= 219.6
# Episode 2280  return=  265  avg(last 20)= 232.9
# Episode 2300  return=  262  avg(last 20)= 258.6
# Episode 2320  return=  266  avg(last 20)= 268.2
# Episode 2340  return=  278  avg(last 20)= 267.4
# Episode 2360  return=  197  avg(last 20)= 227.4
# Episode 2380  return=  183  avg(last 20)= 176.7
# Episode 2400  return=  135  avg(last 20)= 147.9
# Episode 2420  return=  121  avg(last 20)= 135.1
# Episode 2440  return=  120  avg(last 20)= 140.8
# Episode 2460  return=  142  avg(last 20)= 146.1
# Episode 2480  return=  155  avg(last 20)= 154.6
# Episode 2500  return=  153  avg(last 20)= 151.7
# Episode 2520  return=  158  avg(last 20)= 147.6
# Episode 2540  return=  182  avg(last 20)= 184.2
# Episode 2560  return=  162  avg(last 20)= 187.2
# Episode 2580  return=  154  avg(last 20)= 168.8
# Episode 2600  return=  165  avg(last 20)= 160.0
# Episode 2620  return=  137  avg(last 20)= 153.0
# Episode 2640  return=  109  avg(last 20)= 122.1
# Episode 2660  return=  118  avg(last 20)= 150.8
# Episode 2680  return=  112  avg(last 20)= 121.8
# Episode 2700  return=  205  avg(last 20)= 143.3
# Episode 2720  return=  208  avg(last 20)= 205.3
# Episode 2740  return=  206  avg(last 20)= 204.7
# Episode 2760  return=  204  avg(last 20)= 205.8
# Episode 2780  return=  202  avg(last 20)= 206.6
# Episode 2800  return=  138  avg(last 20)= 178.4
# Episode 2820  return=  167  avg(last 20)= 159.9
# Episode 2840  return=  150  avg(last 20)= 163.2
# Episode 2860  return=  172  avg(last 20)= 154.2
# Episode 2880  return=  183  avg(last 20)= 167.8
# Episode 2900  return=  152  avg(last 20)= 173.8
# Episode 2920  return=  158  avg(last 20)= 140.8
# Episode 2940  return=  151  avg(last 20)= 161.1
# Episode 2960  return=  144  avg(last 20)= 129.0
# Episode 2980  return=  182  avg(last 20)= 148.6
# Saved model_cmp_reinforce_vanilla_seed4.pt and history_cmp_reinforce_vanilla_seed4.pkl and time_cmp_reinforce_vanilla_seed4.pkl
# running: cmp_reinforce_constant_seed0
# State space: Box(-inf, inf, (11,), float64)
# Action space: Box(-1.0, 1.0, (3,), float32)
# Episode    0  return=    5  avg(last 20)=   5.3
# Episode   20  return=  125  avg(last 20)=  43.6
# Episode   40  return=  172  avg(last 20)= 125.0
# Episode   60  return=  101  avg(last 20)= 114.0
# Episode   80  return=  114  avg(last 20)= 117.5
# Episode  100  return=  258  avg(last 20)= 169.0
# Episode  120  return=  306  avg(last 20)= 194.9
# Episode  140  return=  151  avg(last 20)= 223.9
# Episode  160  return=  117  avg(last 20)= 149.9
# Episode  180  return=  453  avg(last 20)= 192.7
# Episode  200  return=  247  avg(last 20)= 738.2
# Episode  220  return=  611  avg(last 20)= 819.7
# Episode  240  return=  756  avg(last 20)= 661.7
# Episode  260  return=  225  avg(last 20)= 466.5
# Episode  280  return=  145  avg(last 20)= 151.8
# Episode  300  return=  140  avg(last 20)= 142.0
# Episode  320  return=  205  avg(last 20)= 193.5
# Episode  340  return=  207  avg(last 20)= 204.7
# Episode  360  return=  193  avg(last 20)= 202.6
# Episode  380  return=  153  avg(last 20)= 171.5
# Episode  400  return=  162  avg(last 20)= 170.7
# Episode  420  return=   97  avg(last 20)= 104.0
# Episode  440  return=  155  avg(last 20)= 120.7
# Episode  460  return=  215  avg(last 20)= 271.6
# Episode  480  return=  152  avg(last 20)= 197.6
# Episode  500  return=  195  avg(last 20)= 174.9
# Episode  520  return=  240  avg(last 20)= 213.6
# Episode  540  return=   85  avg(last 20)= 200.7
# Episode  560  return=   47  avg(last 20)= 103.6
# Episode  580  return=  127  avg(last 20)=  83.5
# Episode  600  return=  449  avg(last 20)= 350.9
# Episode  620  return=  314  avg(last 20)= 384.8
# Episode  640  return=  243  avg(last 20)= 269.4
# Episode  660  return=  830  avg(last 20)= 498.4
# Episode  680  return=  513  avg(last 20)= 798.8
# Episode  700  return=  505  avg(last 20)= 613.2
# Episode  720  return=  218  avg(last 20)= 350.2
# Episode  740  return=  176  avg(last 20)= 188.9
# Episode  760  return=  238  avg(last 20)= 203.4
# Episode  780  return=   99  avg(last 20)= 153.9
# Episode  800  return=  113  avg(last 20)= 108.8
# Episode  820  return=   98  avg(last 20)= 104.3
# Episode  840  return=  101  avg(last 20)=  98.6
# Episode  860  return=  104  avg(last 20)= 107.8
# Episode  880  return=  115  avg(last 20)= 123.4
# Episode  900  return=   98  avg(last 20)= 109.0
# Episode  920  return=   85  avg(last 20)=  91.1
# Episode  940  return=  102  avg(last 20)=  90.3
# Episode  960  return=  168  avg(last 20)= 133.5
# Episode  980  return=  150  avg(last 20)= 155.6
# Episode 1000  return=  132  avg(last 20)= 140.2
# Episode 1020  return=  130  avg(last 20)= 138.9
# Episode 1040  return=  140  avg(last 20)= 147.7
# Episode 1060  return=  159  avg(last 20)= 152.1
# Episode 1080  return=  160  avg(last 20)= 159.9
# Episode 1100  return=  247  avg(last 20)= 188.8
# Episode 1120  return=  200  avg(last 20)= 189.2
# Episode 1140  return=  183  avg(last 20)= 181.8
# Episode 1160  return=  247  avg(last 20)= 206.1
# Episode 1180  return=  215  avg(last 20)= 217.7
# Episode 1200  return=  322  avg(last 20)= 239.0
# Episode 1220  return=  479  avg(last 20)= 563.1
# Episode 1240  return=  455  avg(last 20)= 575.5
# Episode 1260  return=  165  avg(last 20)= 563.0
# Episode 1280  return= 1060  avg(last 20)= 532.5
# Episode 1300  return=  143  avg(last 20)= 817.8
# Episode 1320  return=  113  avg(last 20)= 497.2
# Episode 1340  return=  391  avg(last 20)= 428.9
# Episode 1360  return=  369  avg(last 20)= 361.0
# Episode 1380  return=  236  avg(last 20)= 293.0
# Episode 1400  return=  384  avg(last 20)= 268.6
# Episode 1420  return=  431  avg(last 20)= 326.4
# Episode 1440  return=  210  avg(last 20)= 267.2
# Episode 1460  return=  119  avg(last 20)= 135.3
# Episode 1480  return=  157  avg(last 20)= 124.5
# Episode 1500  return=   62  avg(last 20)= 105.6
# Episode 1520  return=   67  avg(last 20)= 118.7
# Episode 1540  return=  110  avg(last 20)= 106.2
# Episode 1560  return=   78  avg(last 20)=  99.2
# Episode 1580  return=   69  avg(last 20)=  70.3
# Episode 1600  return=   58  avg(last 20)=  64.0
# Episode 1620  return=   62  avg(last 20)=  61.5
# Episode 1640  return=  102  avg(last 20)=  77.4
# Episode 1660  return=   64  avg(last 20)=  85.0
# Episode 1680  return=   92  avg(last 20)=  68.9
# Episode 1700  return=   83  avg(last 20)=  81.2
# Episode 1720  return=  108  avg(last 20)=  89.0
# Episode 1740  return=   77  avg(last 20)=  86.7
# Episode 1760  return=   89  avg(last 20)=  78.3
# Episode 1780  return=   76  avg(last 20)= 101.6
# Episode 1800  return=  270  avg(last 20)= 164.3
# Episode 1820  return=  860  avg(last 20)= 462.6
# Episode 1840  return=  456  avg(last 20)= 503.8
# Episode 1860  return=  480  avg(last 20)= 482.7
# Episode 1880  return=  448  avg(last 20)= 518.8
# Episode 1900  return=  243  avg(last 20)= 501.5
# Episode 1920  return=   89  avg(last 20)= 526.8
# Episode 1940  return= 1049  avg(last 20)= 401.6
# Episode 1960  return= 1009  avg(last 20)= 870.0
# Episode 1980  return= 1008  avg(last 20)= 675.0
# Episode 2000  return=  371  avg(last 20)= 406.8
# Episode 2020  return= 1039  avg(last 20)= 587.9
# Episode 2040  return=  178  avg(last 20)= 226.5
# Episode 2060  return=   63  avg(last 20)= 152.6
# Episode 2080  return=  245  avg(last 20)= 269.3
# Episode 2100  return=  286  avg(last 20)= 877.9
# Episode 2120  return=  702  avg(last 20)= 608.2
# Episode 2140  return=   58  avg(last 20)= 184.9
# Episode 2160  return=  515  avg(last 20)= 273.2
# Episode 2180  return=  522  avg(last 20)= 555.3
# Episode 2200  return=  484  avg(last 20)= 409.7
# Episode 2220  return=  505  avg(last 20)= 466.6
# Episode 2240  return=  645  avg(last 20)= 564.0
# Episode 2260  return=  436  avg(last 20)= 519.2
# Episode 2280  return=  837  avg(last 20)= 636.9
# Episode 2300  return= 1004  avg(last 20)=1020.8
# Episode 2320  return= 1008  avg(last 20)=1006.5
# Episode 2340  return= 1008  avg(last 20)=1006.3
# Episode 2360  return= 1001  avg(last 20)=1006.8
# Episode 2380  return= 1006  avg(last 20)=1008.2
# Episode 2400  return= 1029  avg(last 20)=1016.5
# Episode 2420  return=  330  avg(last 20)= 808.0
# Episode 2440  return=  303  avg(last 20)= 469.0
# Episode 2460  return=  394  avg(last 20)= 375.9
# Episode 2480  return= 1201  avg(last 20)= 558.9
# Episode 2500  return= 1243  avg(last 20)= 891.6
# Episode 2520  return= 1032  avg(last 20)= 917.2
# Episode 2540  return=  679  avg(last 20)= 778.3
# Episode 2560  return=  293  avg(last 20)= 460.6
# Episode 2580  return=  522  avg(last 20)= 455.8
# Episode 2600  return=  266  avg(last 20)= 276.4
# Episode 2620  return=  250  avg(last 20)= 388.7
# Episode 2640  return=  809  avg(last 20)= 407.9
# Episode 2660  return=  342  avg(last 20)= 379.4
# Episode 2680  return=  294  avg(last 20)= 319.3
# Episode 2700  return=  260  avg(last 20)= 299.5
# Episode 2720  return=  260  avg(last 20)= 309.7
# Episode 2740  return=  279  avg(last 20)= 297.5
# Episode 2760  return=  428  avg(last 20)= 325.5
# Episode 2780  return=  263  avg(last 20)= 336.7
# Episode 2800  return=  272  avg(last 20)= 290.0
# Episode 2820  return=  330  avg(last 20)= 342.0
# Episode 2840  return=  448  avg(last 20)= 407.3
# Episode 2860  return=  455  avg(last 20)= 428.4
# Episode 2880  return=  446  avg(last 20)= 435.5
# Episode 2900  return=  404  avg(last 20)= 482.3
# Episode 2920  return=  519  avg(last 20)= 471.8
# Episode 2940  return=  255  avg(last 20)= 378.9
# Episode 2960  return=  263  avg(last 20)= 275.5
# Episode 2980  return=  244  avg(last 20)= 247.9
# Saved model_cmp_reinforce_constant_seed0.pt and history_cmp_reinforce_constant_seed0.pkl and time_cmp_reinforce_constant_seed0.pkl
# running: cmp_reinforce_constant_seed1
# State space: Box(-inf, inf, (11,), float64)
# Action space: Box(-1.0, 1.0, (3,), float32)
# Episode    0  return=    8  avg(last 20)=   7.8
# Episode   20  return=   11  avg(last 20)=  10.6
# Episode   40  return=   42  avg(last 20)=  17.2
# Episode   60  return=  103  avg(last 20)=  65.0
# Episode   80  return=   86  avg(last 20)= 122.6
# Episode  100  return=  225  avg(last 20)= 192.4
# Episode  120  return=  229  avg(last 20)= 221.7
# Episode  140  return=  222  avg(last 20)= 219.0
# Episode  160  return=  214  avg(last 20)= 174.0
# Episode  180  return=  193  avg(last 20)= 194.2
# Episode  200  return=  174  avg(last 20)= 192.4
# Episode  220  return=  163  avg(last 20)= 179.3
# Episode  240  return=  180  avg(last 20)= 171.0
# Episode  260  return=  198  avg(last 20)= 164.9
# Episode  280  return=  186  avg(last 20)= 105.0
# Episode  300  return=  164  avg(last 20)= 140.2
# Episode  320  return=  152  avg(last 20)= 134.0
# Episode  340  return=  141  avg(last 20)= 126.7
# Episode  360  return=  102  avg(last 20)= 134.7
# Episode  380  return=  159  avg(last 20)= 146.7
# Episode  400  return=   99  avg(last 20)= 143.6
# Episode  420  return=  138  avg(last 20)= 112.2
# Episode  440  return=  149  avg(last 20)= 148.2
# Episode  460  return=   74  avg(last 20)=  80.3
# Episode  480  return=   88  avg(last 20)=  84.2
# Episode  500  return=  139  avg(last 20)= 120.9
# Episode  520  return=   93  avg(last 20)=  96.4
# Episode  540  return=   81  avg(last 20)=  60.2
# Episode  560  return=  166  avg(last 20)= 141.9
# Episode  580  return=  185  avg(last 20)= 175.0
# Episode  600  return=  193  avg(last 20)= 186.2
# Episode  620  return=  183  avg(last 20)= 190.4
# Episode  640  return=  204  avg(last 20)= 193.2
# Episode  660  return=  200  avg(last 20)= 191.4
# Episode  680  return=  173  avg(last 20)= 188.4
# Episode  700  return=  183  avg(last 20)= 187.1
# Episode  720  return=  211  avg(last 20)= 193.4
# Episode  740  return=  153  avg(last 20)= 185.1
# Episode  760  return=  185  avg(last 20)= 161.5
# Episode  780  return=  185  avg(last 20)= 167.6
# Episode  800  return=  156  avg(last 20)= 173.2
# Episode  820  return=  100  avg(last 20)= 128.2
# Episode  840  return=   88  avg(last 20)=  95.7
# Episode  860  return=   75  avg(last 20)=  82.4
# Episode  880  return=   79  avg(last 20)=  75.7
# Episode  900  return=   78  avg(last 20)=  77.6
# Episode  920  return=   87  avg(last 20)=  86.2
# Episode  940  return=   80  avg(last 20)=  81.3
# Episode  960  return=   70  avg(last 20)=  75.2
# Episode  980  return=   67  avg(last 20)=  61.1
# Episode 1000  return=   69  avg(last 20)=  64.4
# Episode 1020  return=   52  avg(last 20)=  60.6
# Episode 1040  return=   50  avg(last 20)=  56.1
# Episode 1060  return=   61  avg(last 20)=  57.1
# Episode 1080  return=   65  avg(last 20)=  62.1
# Episode 1100  return=   84  avg(last 20)=  76.5
# Episode 1120  return=   90  avg(last 20)=  91.3
# Episode 1140  return=   75  avg(last 20)=  82.2
# Episode 1160  return=  109  avg(last 20)=  92.0
# Episode 1180  return=  180  avg(last 20)= 148.6
# Episode 1200  return=  178  avg(last 20)= 180.1
# Episode 1220  return=  189  avg(last 20)= 185.0
# Episode 1240  return=  197  avg(last 20)= 189.7
# Episode 1260  return=  177  avg(last 20)= 190.1
# Episode 1280  return=  176  avg(last 20)= 176.8
# ...
# Episode 2680  return=  205  avg(last 20)= 214.4
# Episode 2700  return=  222  avg(last 20)= 210.4
# Episode 2720  return=  236  avg(last 20)= 210.0
# Episode 2740  return=  221  avg(last 20)= 215.8
# Episode 2760  return=  209  avg(last 20)= 215.9
# Episode 2780  return=  210  avg(last 20)= 211.6
# Episode 2800  return=  151  avg(last 20)= 199.5
# Episode 2820  return=  261  avg(last 20)= 205.1
# Episode 2840  return=  203  avg(last 20)= 210.7
# Episode 2860  return=  233  avg(last 20)= 204.7
# Episode 2880  return=  239  avg(last 20)= 228.9
# Episode 2900  return=  240  avg(last 20)= 225.8
# Episode 2920  return=  222  avg(last 20)= 218.1
# Episode 2940  return=  209  avg(last 20)= 202.3
# Episode 2960  return=  224  avg(last 20)= 222.6
# Episode 2980  return=  229  avg(last 20)= 217.6
# Saved model_cmp_actor-critic_refined_seed2.pt and history_cmp_actor-critic_refined_seed2.pkl and time_cmp_actor-critic_refined_seed2.pkl
# running: cmp_actor-critic_refined_seed3
# State space: Box(-inf, inf, (11,), float64)
# Action space: Box(-1.0, 1.0, (3,), float32)
# Episode    0  return=   40  avg(last 20)=  40.1
# Episode   20  return=   36  avg(last 20)=  17.2
# Episode   40  return=    7  avg(last 20)=  12.9
# Episode   60  return=   10  avg(last 20)=   9.1
# Episode   80  return=   12  avg(last 20)=   9.8
# Episode  100  return=   12  avg(last 20)=  24.1
# Episode  120  return=   23  avg(last 20)=  34.4
# Episode  140  return=   23  avg(last 20)=  84.4
# Episode  160  return=   39  avg(last 20)=  82.1
# Episode  180  return=   68  avg(last 20)= 104.9
# Episode  200  return=   27  avg(last 20)=  92.6
# Episode  220  return=  157  avg(last 20)= 107.2
# Episode  240  return=  125  avg(last 20)= 110.8
# Episode  260  return=   95  avg(last 20)= 106.0
# Episode  280  return=  122  avg(last 20)= 103.9
# Episode  300  return=   94  avg(last 20)= 105.5
# Episode  320  return=  133  avg(last 20)= 109.3
# Episode  340  return=   91  avg(last 20)= 110.8
# Episode  360  return=   80  avg(last 20)= 106.0
# Episode  380  return=  130  avg(last 20)=  95.4
# Episode  400  return=  120  avg(last 20)= 126.3
# Episode  420  return=  153  avg(last 20)= 120.8
# Episode  440  return=   44  avg(last 20)= 126.3
# Episode  460  return=  195  avg(last 20)= 125.8
# Episode  480  return=  190  avg(last 20)= 143.4
# Episode  500  return=  144  avg(last 20)= 148.8
# Episode  520  return=  176  avg(last 20)= 165.6
# Episode  540  return=  191  avg(last 20)= 147.8
# Episode  560  return=  113  avg(last 20)= 147.0
# Episode  580  return=   98  avg(last 20)= 152.4
# Episode  600  return=  126  avg(last 20)= 145.2
# Episode  620  return=  169  avg(last 20)= 179.8
# Episode  640  return=  139  avg(last 20)= 187.1
# Episode  660  return=  285  avg(last 20)= 158.0
# Episode  680  return=  205  avg(last 20)= 143.0
# Episode  700  return=  214  avg(last 20)= 177.6
# Episode  720  return=   30  avg(last 20)= 161.8
# Episode  740  return=  171  avg(last 20)= 176.1
# Episode  760  return=  206  avg(last 20)= 185.6
# Episode  780  return=  190  avg(last 20)= 187.2
# Episode  800  return=  268  avg(last 20)= 185.2
# Episode  820  return=  214  avg(last 20)= 174.8
# Episode  840  return=  186  avg(last 20)= 210.8
# Episode  860  return=  229  avg(last 20)= 198.0
# Episode  880  return=  117  avg(last 20)= 196.7
# Episode  900  return=  166  avg(last 20)= 179.6
# Episode  920  return=  160  avg(last 20)= 170.1
# Episode  940  return=  102  avg(last 20)= 171.1
# Episode  960  return=  137  avg(last 20)= 190.5
# Episode  980  return=   87  avg(last 20)= 161.4
# Episode 1000  return=  244  avg(last 20)= 176.9
# Episode 1020  return=  236  avg(last 20)= 197.5
# Episode 1040  return=  142  avg(last 20)= 204.0
# Episode 1060  return=  214  avg(last 20)= 165.5
# Episode 1080  return=  260  avg(last 20)= 197.1
# Episode 1100  return=  279  avg(last 20)= 231.6
# Episode 1120  return=  233  avg(last 20)= 244.9
# Episode 1140  return=  249  avg(last 20)= 229.9
# Episode 1160  return=  122  avg(last 20)= 223.6
# Episode 1180  return=  194  avg(last 20)= 232.4
# Episode 1200  return=  264  avg(last 20)= 235.0
# Episode 1220  return=  274  avg(last 20)= 241.0
# Episode 1240  return=  270  avg(last 20)= 260.9
# Episode 1260  return=  277  avg(last 20)= 215.3
# Episode 1280  return=  233  avg(last 20)= 257.9
# Episode 1300  return=  121  avg(last 20)= 193.6
# Episode 1320  return=  312  avg(last 20)= 240.9
# Episode 1340  return=  129  avg(last 20)= 228.9
# Episode 1360  return=  152  avg(last 20)= 270.6
# Episode 1380  return=  248  avg(last 20)= 238.2
# Episode 1400  return=  248  avg(last 20)= 236.5
# Episode 1420  return=  302  avg(last 20)= 239.7
# Episode 1440  return=  227  avg(last 20)= 216.4
# Episode 1460  return=  346  avg(last 20)= 260.7
# Episode 1480  return=  251  avg(last 20)= 273.4
# Episode 1500  return=  313  avg(last 20)= 229.8
# Episode 1520  return=  227  avg(last 20)= 229.6
# Episode 1540  return=  277  avg(last 20)= 252.6
# Episode 1560  return=  252  avg(last 20)= 192.3
# Episode 1580  return=  240  avg(last 20)= 190.5
# Episode 1600  return=  248  avg(last 20)= 233.5
# Episode 1620  return=  249  avg(last 20)= 224.0
# Episode 1640  return=  149  avg(last 20)= 192.9
# Episode 1660  return=  248  avg(last 20)= 218.8
# Episode 1680  return=  233  avg(last 20)= 227.9
# Episode 1700  return=  270  avg(last 20)= 246.0
# Episode 1720  return=  250  avg(last 20)= 234.0
# Episode 1740  return=  237  avg(last 20)= 235.3
# Episode 1760  return=  272  avg(last 20)= 223.1
# Episode 1780  return=  231  avg(last 20)= 210.0
# Episode 1800  return=  229  avg(last 20)= 233.0
# Episode 1820  return=  277  avg(last 20)= 254.5
# Episode 1840  return=  275  avg(last 20)= 275.9
# Episode 1860  return=  292  avg(last 20)= 276.1
# Episode 1880  return=  273  avg(last 20)= 260.4
# Episode 1900  return=  331  avg(last 20)= 247.4
# Episode 1920  return=  254  avg(last 20)= 250.2
# Episode 1940  return=  218  avg(last 20)= 231.7
# Episode 1960  return=  159  avg(last 20)= 243.3
# Episode 1980  return=  341  avg(last 20)= 260.1
# Episode 2000  return=  264  avg(last 20)= 262.8
# Episode 2020  return=  295  avg(last 20)= 270.8
# Episode 2040  return=  260  avg(last 20)= 272.2
# Episode 2060  return=  259  avg(last 20)= 257.7
# Episode 2080  return=  265  avg(last 20)= 256.8
# Episode 2100  return=  296  avg(last 20)= 245.4
# Episode 2120  return=  192  avg(last 20)= 282.5
# Episode 2140  return=  140  avg(last 20)= 285.8
# Episode 2160  return=  187  avg(last 20)= 274.5
# Episode 2180  return=  217  avg(last 20)= 256.2
# Episode 2200  return=  396  avg(last 20)= 151.5
# Episode 2220  return=  135  avg(last 20)= 192.8
# Episode 2240  return=   57  avg(last 20)= 140.8
# Episode 2260  return=  109  avg(last 20)= 127.3
# Episode 2280  return=   92  avg(last 20)= 171.3
# Episode 2300  return=   51  avg(last 20)= 166.4
# Episode 2320  return=  355  avg(last 20)= 193.8
# Episode 2340  return=  171  avg(last 20)= 224.4
# Episode 2360  return=  305  avg(last 20)= 193.3
# Episode 2380  return=  117  avg(last 20)= 255.9
# Episode 2400  return=  192  avg(last 20)= 251.3
# Episode 2420  return=  470  avg(last 20)= 271.7
# Episode 2440  return=  183  avg(last 20)= 264.5
# Episode 2460  return=  341  avg(last 20)= 303.3
# Episode 2480  return=  337  avg(last 20)= 277.7
# Episode 2500  return=  305  avg(last 20)= 327.8
# Episode 2520  return=  249  avg(last 20)= 395.6
# Episode 2540  return=  230  avg(last 20)= 342.0
# Episode 2560  return=  316  avg(last 20)= 375.2
# Episode 2580  return=  151  avg(last 20)= 439.5
# Episode 2600  return=  510  avg(last 20)= 409.9
# Episode 2620  return=  366  avg(last 20)= 378.0
# Episode 2640  return=  638  avg(last 20)= 546.8
# Episode 2660  return=  210  avg(last 20)= 451.3
# Episode 2680  return=  730  avg(last 20)= 535.9
# Episode 2700  return=  155  avg(last 20)= 565.2
# Episode 2720  return=  848  avg(last 20)= 492.5
# Episode 2740  return=  825  avg(last 20)= 597.5
# Episode 2760  return=  816  avg(last 20)= 578.3
# Episode 2780  return=  769  avg(last 20)= 754.7
# Episode 2800  return=  750  avg(last 20)= 732.8
# Episode 2820  return=  624  avg(last 20)= 631.4
# Episode 2840  return=  554  avg(last 20)= 692.5
# Episode 2860  return=  763  avg(last 20)= 758.5
# Episode 2880  return=  459  avg(last 20)= 800.4
# Episode 2900  return=  805  avg(last 20)= 870.5
# Episode 2920  return=  716  avg(last 20)= 669.6
# Episode 2940  return=  686  avg(last 20)= 724.4
# Episode 2960  return= 1059  avg(last 20)= 734.8
# Episode 2980  return=  877  avg(last 20)= 723.9
# Saved model_cmp_actor-critic_refined_seed3.pt and history_cmp_actor-critic_refined_seed3.pkl and time_cmp_actor-critic_refined_seed3.pkl
# running: cmp_actor-critic_refined_seed4
# State space: Box(-inf, inf, (11,), float64)
# Action space: Box(-1.0, 1.0, (3,), float32)
# Episode    0  return=    4  avg(last 20)=   3.5
# Episode   20  return=   10  avg(last 20)=  19.0
# Episode   40  return=    8  avg(last 20)=  17.4
# Episode   60  return=   10  avg(last 20)=   9.8
# Episode   80  return=   10  avg(last 20)=  11.5
# Episode  100  return=    6  avg(last 20)=  19.0
# Episode  120  return=   78  avg(last 20)=  40.2
# Episode  140  return=   12  avg(last 20)=  43.2
# Episode  160  return=   56  avg(last 20)=  49.7
# Episode  180  return=   26  avg(last 20)=  62.7
# Episode  200  return=   88  avg(last 20)=  84.7
# Episode  220  return=  173  avg(last 20)=  95.3
# Episode  240  return=  120  avg(last 20)= 111.9
# Episode  260  return=   78  avg(last 20)=  98.9
# Episode  280  return=   64  avg(last 20)=  85.4
# Episode  300  return=   32  avg(last 20)= 159.9
# Episode  320  return=   30  avg(last 20)= 136.4
# Episode  340  return=  185  avg(last 20)= 142.1
# Episode  360  return=  139  avg(last 20)= 128.0
# Episode  380  return=   95  avg(last 20)= 137.7
# Episode  400  return=  196  avg(last 20)= 154.9
# Episode  420  return=  110  avg(last 20)= 134.2
# Episode  440  return=   60  avg(last 20)= 145.7
# Episode  460  return=   87  avg(last 20)= 122.9
# Episode  480  return=  166  avg(last 20)= 128.1
# Episode  500  return=   68  avg(last 20)= 129.8
# Episode  520  return=  145  avg(last 20)= 136.8
# Episode  540  return=   65  avg(last 20)= 127.5
# Episode  560  return=  148  avg(last 20)= 126.3
# Episode  580  return=  101  avg(last 20)= 101.2
# Episode  600  return=  101  avg(last 20)= 124.9
# Episode  620  return=   45  avg(last 20)= 122.1
# Episode  640  return=  145  avg(last 20)= 147.5
# Episode  660  return=  189  avg(last 20)= 157.4
# Episode  680  return=  175  avg(last 20)= 152.5
# Episode  700  return=  182  avg(last 20)= 144.4
# Episode  720  return=  173  avg(last 20)= 150.1
# Episode  740  return=   55  avg(last 20)= 148.9
# Episode  760  return=   96  avg(last 20)= 158.8
# Episode  780  return=  156  avg(last 20)= 149.2
# Episode  800  return=  108  avg(last 20)= 153.7
# Episode  820  return=  171  avg(last 20)= 163.1
# Episode  840  return=  148  avg(last 20)= 162.7
# Episode  860  return=   95  avg(last 20)= 139.6
# Episode  880  return=   70  avg(last 20)= 154.5
# Episode  900  return=  130  avg(last 20)= 136.1
# Episode  920  return=  178  avg(last 20)= 148.7
# Episode  940  return=  177  avg(last 20)= 156.9
# Episode  960  return=  178  avg(last 20)= 177.8
# Episode  980  return=  179  avg(last 20)= 173.7
# Episode 1000  return=  151  avg(last 20)= 155.4
# Episode 1020  return=  173  avg(last 20)= 148.1
# Episode 1040  return=  106  avg(last 20)= 123.1
# Episode 1060  return=   75  avg(last 20)= 110.2
# Episode 1080  return=  119  avg(last 20)= 121.0
# Episode 1100  return=   97  avg(last 20)= 113.6
# Episode 1120  return=  106  avg(last 20)= 111.3
# Episode 1140  return=  169  avg(last 20)= 129.8
# Episode 1160  return=  179  avg(last 20)= 133.5
# Episode 1180  return=  174  avg(last 20)= 139.7
# Episode 1200  return=  124  avg(last 20)=  84.0
# Episode 1220  return=   38  avg(last 20)= 125.9
# Episode 1240  return=  187  avg(last 20)= 190.0
# Episode 1260  return=  135  avg(last 20)= 147.1
# Episode 1280  return=  164  avg(last 20)= 161.7
# Episode 1300  return=  166  avg(last 20)= 178.5
# Episode 1320  return=  107  avg(last 20)= 127.8
# Episode 1340  return=  174  avg(last 20)= 168.3
# Episode 1360  return=  147  avg(last 20)= 154.2
# Episode 1380  return=  203  avg(last 20)= 151.4
# Episode 1400  return=  209  avg(last 20)= 177.7
# Episode 1420  return=  170  avg(last 20)= 143.1
# Episode 1440  return=  177  avg(last 20)= 156.3
# Episode 1460  return=  175  avg(last 20)= 165.0
# Episode 1480  return=  121  avg(last 20)= 148.8
# Episode 1500  return=  206  avg(last 20)= 144.2
# Episode 1520  return=  133  avg(last 20)= 134.4
# Episode 1540  return=  206  avg(last 20)= 157.5
# Episode 1560  return=  187  avg(last 20)= 179.1
# Episode 1580  return=  172  avg(last 20)= 174.2
# Episode 1600  return=  191  avg(last 20)= 155.1
# Episode 1620  return=  176  avg(last 20)= 182.4
# Episode 1640  return=  204  avg(last 20)= 190.5
# Episode 1660  return=  142  avg(last 20)= 186.8
# Episode 1680  return=  145  avg(last 20)= 162.9
# Episode 1700  return=  213  avg(last 20)= 160.0
# Episode 1720  return=  178  avg(last 20)= 159.9
# Episode 1740  return=  191  avg(last 20)= 122.7
# Episode 1760  return=   71  avg(last 20)= 118.5
# Episode 1780  return=  138  avg(last 20)= 127.8
# Episode 1800  return=   79  avg(last 20)= 101.2
# Episode 1820  return=  125  avg(last 20)= 124.5
# Episode 1840  return=  119  avg(last 20)= 116.7
# Episode 1860  return=  112  avg(last 20)= 121.0
# Episode 1880  return=   75  avg(last 20)= 135.3
# Episode 1900  return=  131  avg(last 20)= 117.0
# Episode 1920  return=  163  avg(last 20)= 119.0
# Episode 1940  return=  152  avg(last 20)= 136.2
# Episode 1960  return=  127  avg(last 20)= 160.0
# Episode 1980  return=  203  avg(last 20)= 159.1
# Episode 2000  return=  115  avg(last 20)= 174.0
# Episode 2020  return=   71  avg(last 20)= 169.8
# Episode 2040  return=  197  avg(last 20)= 196.6
# Episode 2060  return=  204  avg(last 20)= 197.7
# Episode 2080  return=  200  avg(last 20)= 196.7
# Episode 2100  return=  202  avg(last 20)= 206.2
# Episode 2120  return=  202  avg(last 20)= 199.1
# Episode 2140  return=  205  avg(last 20)= 199.0
# Episode 2160  return=  229  avg(last 20)= 195.8
# Episode 2180  return=  206  avg(last 20)= 185.1
# Episode 2200  return=  220  avg(last 20)= 169.4
# Episode 2220  return=  199  avg(last 20)= 176.7
# Episode 2240  return=  193  avg(last 20)= 183.9
# Episode 2260  return=  190  avg(last 20)= 161.9
# Episode 2280  return=  184  avg(last 20)= 165.2
# Episode 2300  return=  208  avg(last 20)= 183.1
# Episode 2320  return=  202  avg(last 20)= 182.0
# Episode 2340  return=  206  avg(last 20)= 181.4
# Episode 2360  return=   28  avg(last 20)= 166.3
# Episode 2380  return=  173  avg(last 20)= 183.6
# Episode 2400  return=  191  avg(last 20)= 165.0
# Episode 2420  return=  211  avg(last 20)= 151.3
# Episode 2440  return=  189  avg(last 20)= 169.8
# Episode 2460  return=  166  avg(last 20)= 163.6
# Episode 2480  return=  187  avg(last 20)= 177.6
# Episode 2500  return=    6  avg(last 20)= 131.8
# Episode 2520  return=    2  avg(last 20)= 136.4
# Episode 2540  return=  111  avg(last 20)= 155.1
# Episode 2560  return=  215  avg(last 20)= 140.8
# Episode 2580  return=   20  avg(last 20)= 131.2
# Episode 2600  return=   26  avg(last 20)= 139.4
# Episode 2620  return=   41  avg(last 20)= 113.4
# Episode 2640  return=  224  avg(last 20)= 168.9
# Episode 2660  return=  110  avg(last 20)= 160.6
# Episode 2680  return=  121  avg(last 20)= 182.5
# Episode 2700  return=  228  avg(last 20)= 203.1
# Episode 2720  return=   53  avg(last 20)= 194.6
# Episode 2740  return=  231  avg(last 20)= 188.2
# Episode 2760  return=  208  avg(last 20)= 170.3
# Episode 2780  return=  212  avg(last 20)= 228.6
# Episode 2800  return=  211  avg(last 20)= 216.1
# Episode 2820  return=   22  avg(last 20)= 181.4
# Episode 2840  return=  137  avg(last 20)= 189.4
# Episode 2860  return=  215  avg(last 20)= 166.1
# Episode 2880  return=   97  avg(last 20)= 198.7
# Episode 2900  return=  215  avg(last 20)= 215.1
# Episode 2920  return=  217  avg(last 20)= 217.3
# Episode 2940  return=  220  avg(last 20)= 216.7
# Episode 2960  return=  224  avg(last 20)= 220.1
# Episode 2980  return=  227  avg(last 20)= 208.2
# Saved model_cmp_actor-critic_refined_seed4.pt and history_cmp_actor-critic_refined_seed4.pkl and time_cmp_actor-critic_refined_seed4.pkl
#
# Done. Methods: ['REINFORCE vanilla', 'REINFORCE constant', 'REINFORCE EMA', 'Actor-Critic tuned', 'Actor-Critic refined'] | seeds: [0, 1, 2, 3, 4]

# %%
def _peak_final(suffix, last_n=50):
    h = np.asarray(load_history(suffix))
    sm = smooth_50(h)
    return float(sm.max()), float(np.mean(h[-last_n:]))

agg = {}
print(f"{'method':24s}{'final-50 (mean +/- std)':>26s}{'peak (mean +/- std)':>24s}")
for m in cmp_methods:
    runs = [r for r in m["runs"]
            if os.path.exists(os.path.join(PREFIX, f"history_{r}.pkl"))]
    if not runs:
        continue
    peaks, finals = zip(*[_peak_final(r) for r in runs])
    peaks, finals = np.array(peaks), np.array(finals)
    agg[m["label"]] = {"finals": finals, "peaks": peaks, "runs": runs}
    print(f"{m['label']:24s}"
          f"{finals.mean():9.0f} +/- {finals.std():<10.0f}"
          f"{peaks.mean():11.0f} +/- {peaks.std():<8.0f}")

if "REINFORCE EMA" in agg:
    ema_f = agg["REINFORCE EMA"]["finals"]
    for ac_label in ("Actor-Critic refined", "Actor-Critic tuned"):
        if ac_label in agg:
            ac_f = agg[ac_label]["finals"]
            diff = ema_f.mean() - ac_f.mean()
            print(f"\nEMA vs {ac_label}: final-50 {ema_f.mean():.0f} vs {ac_f.mean():.0f} "
                  f"(diff {diff:+.0f}). EMA std {ema_f.std():.0f}, AC std {ac_f.std():.0f}.")
            overlap = (ema_f.mean() - ema_f.std()) < (ac_f.mean() + ac_f.std())
            print("  -> std bands OVERLAP: gap may be seed noise." if overlap
                  else "  -> std bands SEPARATE: EMA's edge is robust across seeds.")
            break

plt.figure(figsize=(11, 6))
for m in cmp_methods:
    if m["label"] not in agg:
        continue
    curves = [smooth_50(np.asarray(load_history(r))) for r in agg[m["label"]]["runs"]]
    L = min(len(c) for c in curves)
    arr = np.stack([c[:L] for c in curves])
    mean, std = arr.mean(0), arr.std(0)
    x = np.arange(50, 50 + L)
    line, = plt.plot(x, mean, label=f"{m['label']} (n={len(curves)})")
    plt.fill_between(x, mean - std, mean + std, alpha=0.15, color=line.get_color())

plt.xlabel("Episode")
plt.ylabel("Return (50-episode moving average)")
plt.title(f"Multi-seed comparison (seeds={CMP_SEEDS}): mean +/- std")
plt.legend(fontsize=8)
plt.grid(alpha=0.3)
plt.tight_layout()
plt.savefig(os.path.join(PREFIX, "multiseed_ema_vs_ac.png"), dpi=120, bbox_inches="tight")
plt.show()
print("Saved: multiseed_ema_vs_ac.png")
# Out:
# method                     final-50 (mean +/- std)     peak (mean +/- std)
# REINFORCE vanilla             101 +/- 67                598 +/- 365
# REINFORCE constant            107 +/- 76                536 +/- 376
# REINFORCE EMA                 333 +/- 117               732 +/- 327
# Actor-Critic tuned            358 +/- 328               399 +/- 319
# Actor-Critic refined          530 +/- 310               628 +/- 318
#
# EMA vs Actor-Critic refined: final-50 333 vs 530 (diff -196). EMA std 117, AC std 310.
#   -> std bands OVERLAP: gap may be seed noise.
# Saved: multiseed_ema_vs_ac.png

# %% [markdown]
# ## Does the truncation handling explain Actor-Critic's weakness?
#
# In `agent.py` the AC bootstrap target is `r + gamma * V(s') * (1 - done)` where the
# training loop sets `done = terminated or truncated`. Hopper-v4 **truncates at 1000 steps**
# (a time limit, not a real terminal). Treating that truncation as terminal zeroes the
# bootstrap on the final step of every long episode, so the value target is biased low
# *exactly once the agent gets good enough to survive to the time limit* — which is when AC
# starts to plateau/decay. REINFORCE+EMA uses full Monte-Carlo returns and is not hit by this.
#
# This is a **controlled test**: the *same* AC config is trained two ways across seeds, the
# only difference being whether we bootstrap through truncation. If the fixed variant closes
# the gap to EMA, the truncation handling was a real cause; if not, the gap is elsewhere.

# %%
import gymnasium as gym
import torch, random, pickle

from agent import Agent, Policy

def _ac_cfg():
    """Best AC config, normalized to hidden_size; prefer the refined one if present."""
    try:
        return dict(REFINED_BEST_CFG)
    except NameError:
        return dict(actor_lr=best_cfg["actor_lr"], critic_lr=best_cfg["critic_lr"],
                    critic_weight=best_cfg["critic_weight"], hidden_size=best_cfg["hidden"],
                    gamma=best_cfg["gamma"], grad_clip=best_cfg["grad_clip"],
                    entropy_weight=best_cfg["entropy_weight"],
                    normalize_advantage=best_cfg["normalize_advantage"])

def train_ac(bootstrap_truncation, cfg, seed, n_episodes=3000, run_name=None):
    torch.manual_seed(seed); np.random.seed(seed); random.seed(seed)
    env = gym.make("Hopper-v4")
    env.reset(seed=seed); env.action_space.seed(seed)
    policy = Policy(state_space=env.observation_space.shape[0],
                    action_space=env.action_space.shape[0], hidden=cfg["hidden_size"])
    agent = Agent(policy, algorithm="actor_critic",
                  actor_lr=cfg["actor_lr"], critic_lr=cfg["critic_lr"],
                  critic_weight=cfg["critic_weight"], gamma=cfg["gamma"],
                  grad_clip=cfg["grad_clip"], entropy_weight=cfg["entropy_weight"],
                  normalize_advantage=cfg["normalize_advantage"])
    history = []
    for ep in range(n_episodes):
        state, _ = env.reset(); done = False; ep_rew = []
        while not done:
            action, log_prob, entropy = agent.get_action(state)
            action = action.detach().cpu().numpy()
            next_state, reward, terminated, truncated, _ = env.step(action)
            done = terminated or truncated
            ep_rew.append(reward)

            store_done = terminated if bootstrap_truncation else (terminated or truncated)
            agent.store_outcome(state, next_state, log_prob, entropy, reward, store_done)
            state = next_state
        agent.update_policy()
        history.append(sum(ep_rew))
        if ep % 100 == 0:
            print(f"  ep {ep:4d}  return={sum(ep_rew):5.0f}")
    env.close()
    if run_name is not None:
        with open(os.path.join(PREFIX, f"history_{run_name}.pkl"), "wb") as f:
            pickle.dump(history, f)
    return history

try:
    TRUNC_SEEDS = CMP_SEEDS              
except NameError:
    TRUNC_SEEDS = [0, 1, 2]

trunc_variants = [
    ("ac_trunc_terminal",  False),      
    ("ac_trunc_bootstrap", True),        
]

ac_cfg = _ac_cfg()
print("AC config under test:", ac_cfg)
for prefix, boot in trunc_variants:
    for seed in TRUNC_SEEDS:
        run_name = f"{prefix}_seed{seed}"
        if os.path.exists(os.path.join(PREFIX, f"history_{run_name}.pkl")):
            print("skip (cached):", run_name); continue
        print(f"running: {run_name}  (bootstrap_truncation={boot})")
        train_ac(boot, ac_cfg, seed, run_name=run_name)

print("\nDone:", [f"{p}_seed*" for p, _ in trunc_variants], "| seeds:", TRUNC_SEEDS)
# Out:
# AC config under test: {'actor_lr': 3.5e-05, 'critic_lr': 0.0004, 'critic_weight': 1.0, 'hidden_size': 256, 'gamma': 0.995, 'grad_clip': 0.3, 'entropy_weight': 0.0001, 'normalize_advantage': True}
# running: ac_trunc_terminal_seed0  (bootstrap_truncation=False)
#   ep    0  return=    7
#   ep  100  return=   11
#   ep  200  return=   31
#   ep  300  return=  107
#   ep  400  return=  129
#   ep  500  return=   72
#   ep  600  return=  111
#   ep  700  return=  191
#   ep  800  return=  253
#   ep  900  return=  231
#   ep 1000  return=  144
#   ep 1100  return=   73
#   ep 1200  return=  462
#   ep 1300  return=  375
#   ep 1400  return=  476
#   ep 1500  return=  555
#   ep 1600  return=  491
#   ep 1700  return=  479
#   ep 1800  return=  241
#   ep 1900  return=  697
#   ep 2000  return=  460
#   ep 2100  return=  283
#   ep 2200  return=  246
#   ep 2300  return= 1009
#   ep 2400  return= 1016
#   ep 2500  return=  917
#   ep 2600  return=  286
#   ep 2700  return=  138
#   ep 2800  return= 1020
#   ep 2900  return= 1012
# running: ac_trunc_terminal_seed1  (bootstrap_truncation=False)
#   ep    0  return=    8
#   ep  100  return=   17
#   ep  200  return=  112
#   ep  300  return=  141
#   ep  400  return=  225
#   ep  500  return=  225
#   ep  600  return=  225
#   ep  700  return=  195
#   ep  800  return=  264
#   ep  900  return=  269
#   ep 1000  return=  294
#   ep 1100  return=  297
#   ep 1200  return=  249
#   ep 1300  return=  221
#   ep 1400  return=  201
#   ep 1500  return=  230
#   ep 1600  return=  264
#   ep 1700  return=  394
#   ep 1800  return=  323
#   ep 1900  return=  225
#   ep 2000  return=  483
#   ep 2100  return=   61
#   ep 2200  return=  544
#   ep 2300  return=  394
#   ep 2400  return=  115
#   ep 2500  return=  414
#   ep 2600  return=  538
#   ep 2700  return=  350
#   ep 2800  return=  595
#   ep 2900  return=  631
# running: ac_trunc_terminal_seed2  (bootstrap_truncation=False)
#   ep    0  return=    6
#   ep  100  return=   24
#   ep  200  return=  173
#   ep  300  return=  217
#   ep  400  return=  138
#   ep  500  return=  203
#   ep  600  return=  242
#   ep  700  return=  264
#   ep  800  return=  278
#   ep  900  return=  355
#   ep 1000  return=  287
#   ep 1100  return=  257
#   ep 1200  return=  265
#   ep 1300  return=  225
#   ep 1400  return=  217
#   ep 1500  return=  244
#   ep 1600  return=  208
#   ep 1700  return=  239
#   ep 1800  return=  255
#   ep 1900  return=  252
#   ep 2000  return=  215
#   ep 2100  return=  214
#   ep 2200  return=  235
#   ep 2300  return=  205
#   ep 2400  return=  178
#   ep 2500  return=  201
#   ep 2600  return=  214
#   ep 2700  return=  222
#   ep 2800  return=  151
#   ep 2900  return=  240
# running: ac_trunc_terminal_seed3  (bootstrap_truncation=False)
#   ep    0  return=   40
#   ep  100  return=   12
#   ep  200  return=   27
#   ep  300  return=   94
#   ep  400  return=  120
#   ep  500  return=  144
#   ep  600  return=  126
#   ep  700  return=  214
#   ep  800  return=  268
#   ep  900  return=  166
#   ep 1000  return=  244
#   ep 1100  return=  279
#   ep 1200  return=  264
#   ep 1300  return=  121
#   ep 1400  return=  248
#   ep 1500  return=  313
#   ep 1600  return=  248
#   ep 1700  return=  270
#   ep 1800  return=  229
#   ep 1900  return=  331
#   ep 2000  return=  264
#   ep 2100  return=  296
#   ep 2200  return=  396
#   ep 2300  return=   51
#   ep 2400  return=  192
#   ep 2500  return=  305
#   ep 2600  return=  510
#   ep 2700  return=  155
#   ep 2800  return=  750
#   ep 2900  return=  805
# running: ac_trunc_terminal_seed4  (bootstrap_truncation=False)
#   ep    0  return=    4
#   ep  100  return=    6
#   ep  200  return=   88
#   ep  300  return=   32
#   ep  400  return=  196
#   ep  500  return=   68
#   ep  600  return=  101
#   ep  700  return=  182
#   ep  800  return=  108
#   ep  900  return=  130
#   ep 1000  return=  151
#   ep 1100  return=   97
#   ep 1200  return=  124
#   ep 1300  return=  166
#   ep 1400  return=  209
#   ep 1500  return=  206
#   ep 1600  return=  191
#   ep 1700  return=  213
#   ep 1800  return=   79
#   ep 1900  return=  131
#   ep 2000  return=  115
#   ep 2100  return=  202
#   ep 2200  return=  220
#   ep 2300  return=  208
#   ep 2400  return=  191
#   ep 2500  return=    6
#   ep 2600  return=   26
#   ep 2700  return=  228
#   ep 2800  return=  211
#   ep 2900  return=  215
# running: ac_trunc_bootstrap_seed0  (bootstrap_truncation=True)
#   ep    0  return=    7
#   ep  100  return=   11
#   ep  200  return=   31
#   ep  300  return=  107
#   ep  400  return=  129
#   ep  500  return=   72
#   ep  600  return=  111
#   ep  700  return=  191
#   ep  800  return=  253
#   ep  900  return=  231
#   ep 1000  return=  144
#   ep 1100  return=   73
#   ep 1200  return=  462
#   ep 1300  return=  375
#   ep 1400  return=  476
#   ep 1500  return=  555
#   ep 1600  return=  491
#   ep 1700  return=  479
#   ep 1800  return=  241
#   ep 1900  return=  697
#   ep 2000  return=  488
#   ep 2100  return=  314
#   ep 2200  return=  577
#   ep 2300  return=  730
#   ep 2400  return=  494
#   ep 2500  return=  342
#   ep 2600  return=  585
#   ep 2700  return=  452
#   ep 2800  return=  295
#   ep 2900  return=  234
# running: ac_trunc_bootstrap_seed1  (bootstrap_truncation=True)
#   ep    0  return=    8
#   ep  100  return=   17
#   ep  200  return=  112
#   ep  300  return=  141
#   ep  400  return=  225
#   ep  500  return=  225
#   ep  600  return=  225
#   ep  700  return=  195
#   ep  800  return=  264
#   ep  900  return=  269
#   ep 1000  return=  294
#   ep 1100  return=  297
#   ep 1200  return=  249
#   ep 1300  return=  221
#   ep 1400  return=  201
#   ep 1500  return=  230
#   ep 1600  return=  264
#   ep 1700  return=  394
#   ep 1800  return=  323
#   ep 1900  return=  225
#   ep 2000  return=  483
#   ep 2100  return=   61
#   ep 2200  return=  544
#   ep 2300  return=  394
#   ep 2400  return=  115
#   ep 2500  return=  414
#   ep 2600  return=  538
#   ep 2700  return=  350
#   ep 2800  return=  429
#   ep 2900  return=  636
# running: ac_trunc_bootstrap_seed2  (bootstrap_truncation=True)
#   ep    0  return=    6
#   ep  100  return=   24
#   ep  200  return=  173
#   ep  300  return=  217
#   ep  400  return=  138
#   ep  500  return=  203
#   ep  600  return=  242
#   ep  700  return=  264
#   ep  800  return=  278
#   ep  900  return=  355
#   ep 1000  return=  287
#   ep 1100  return=  257
#   ep 1200  return=  265
#   ep 1300  return=  225
#   ep 1400  return=  217
#   ep 1500  return=  244
#   ep 1600  return=  208
#   ep 1700  return=  239
#   ep 1800  return=  255
#   ep 1900  return=  252
#   ep 2000  return=  215
#   ep 2100  return=  214
#   ep 2200  return=  235
#   ep 2300  return=  205
#   ep 2400  return=  178
#   ep 2500  return=  201
#   ep 2600  return=  214
#   ep 2700  return=  222
#   ep 2800  return=  151
#   ep 2900  return=  240
# running: ac_trunc_bootstrap_seed3  (bootstrap_truncation=True)
#   ep    0  return=   40
#   ep  100  return=   12
#   ep  200  return=   27
#   ep  300  return=   94
#   ep  400  return=  120
#   ep  500  return=  144
#   ep  600  return=  126
#   ep  700  return=  214
#   ep  800  return=  268
#   ep  900  return=  166
#   ep 1000  return=  244
#   ep 1100  return=  279
#   ep 1200  return=  264
#   ep 1300  return=  121
#   ep 1400  return=  248
#   ep 1500  return=  313
#   ep 1600  return=  248
#   ep 1700  return=  270
#   ep 1800  return=  229
#   ep 1900  return=  331
#   ep 2000  return=  264
#   ep 2100  return=  296
#   ep 2200  return=  396
#   ep 2300  return=   51
#   ep 2400  return=  192
#   ep 2500  return=  305
#   ep 2600  return=  510
#   ep 2700  return=  666
#   ep 2800  return=  205
#   ep 2900  return=  967
# running: ac_trunc_bootstrap_seed4  (bootstrap_truncation=True)
#   ep    0  return=    4
#   ep  100  return=    6
#   ep  200  return=   88
#   ep  300  return=   32
#   ep  400  return=  196
#   ep  500  return=   68
#   ep  600  return=  101
#   ep  700  return=  182
#   ep  800  return=  108
#   ep  900  return=  130
#   ep 1000  return=  151
#   ep 1100  return=   97
#   ep 1200  return=  124
#   ep 1300  return=  166
#   ep 1400  return=  209
#   ep 1500  return=  206
#   ep 1600  return=  191
#   ep 1700  return=  213
#   ep 1800  return=   79
#   ep 1900  return=  131
#   ep 2000  return=  115
#   ep 2100  return=  202
#   ep 2200  return=  220
#   ep 2300  return=  208
#   ep 2400  return=  191
#   ep 2500  return=    6
#   ep 2600  return=   26
#   ep 2700  return=  228
#   ep 2800  return=  211
#   ep 2900  return=  215
#
# Done: ['ac_trunc_terminal_seed*', 'ac_trunc_bootstrap_seed*'] | seeds: [0, 1, 2, 3, 4]

# %%
# ===== Compare truncation variants (and EMA reference) across seeds =====
def _peak_final(suffix, last_n=50):
    h = np.asarray(load_history(suffix))
    sm = smooth_50(h)
    return float(sm.max()), float(np.mean(h[-last_n:]))

trunc_series = [
    ("AC truncation=terminal (original)", "ac_trunc_terminal"),
    ("AC bootstrap-through-truncation",   "ac_trunc_bootstrap"),
]
if all(os.path.exists(os.path.join(PREFIX, f"history_cmp_reinforce_ema_seed{s}.pkl"))
       for s in TRUNC_SEEDS):
    trunc_series.append(("REINFORCE EMA (reference)", "cmp_reinforce_ema"))

agg = {}
print(f"{'variant':38s}{'final-50 (mean +/- std)':>26s}{'peak (mean +/- std)':>24s}")
for label, base in trunc_series:
    runs = [f"{base}_seed{s}" for s in TRUNC_SEEDS
            if os.path.exists(os.path.join(PREFIX, f"history_{base}_seed{s}.pkl"))]
    if not runs:
        continue
    peaks, finals = map(np.array, zip(*[_peak_final(r) for r in runs]))
    agg[label] = {"runs": runs, "finals": finals, "peaks": peaks}
    print(f"{label:38s}{finals.mean():9.0f} +/- {finals.std():<10.0f}"
          f"{peaks.mean():11.0f} +/- {peaks.std():<8.0f}")

orig = agg.get("AC truncation=terminal (original)")
fixed = agg.get("AC bootstrap-through-truncation")
ema = agg.get("REINFORCE EMA (reference)")
if orig and fixed:
    d = fixed["finals"].mean() - orig["finals"].mean()
    print(f"\nFix effect on final-50: {d:+.0f} "
          f"({orig['finals'].mean():.0f} -> {fixed['finals'].mean():.0f}).")
    if ema is not None:
        gap_before = ema["finals"].mean() - orig["finals"].mean()
        gap_after = ema["finals"].mean() - fixed["finals"].mean()
        print(f"Gap to EMA: {gap_before:.0f} (orig) -> {gap_after:.0f} (fixed). "
              + ("Truncation handling explains MOST of the gap." if gap_after < 0.4 * gap_before
                 else "Truncation handling is only PART of the gap - other causes remain."))

plt.figure(figsize=(11, 6))
for label, base in trunc_series:
    if label not in agg:
        continue
    curves = [smooth_50(np.asarray(load_history(r))) for r in agg[label]["runs"]]
    L = min(len(c) for c in curves)
    arr = np.stack([c[:L] for c in curves])
    mean, std = arr.mean(0), arr.std(0)
    x = np.arange(50, 50 + L)
    line, = plt.plot(x, mean, label=f"{label} (n={len(curves)})")
    plt.fill_between(x, mean - std, mean + std, alpha=0.15, color=line.get_color())

plt.xlabel("Episode")
plt.ylabel("Return (50-episode moving average)")
plt.title(f"Truncation bootstrap ablation (seeds={TRUNC_SEEDS})")
plt.legend(fontsize=8)
plt.grid(alpha=0.3)
plt.tight_layout()
plt.savefig(os.path.join(PREFIX, "truncation_bootstrap_ablation.png"),
            dpi=120, bbox_inches="tight")
plt.show()
print("Saved: truncation_bootstrap_ablation.png")
# Out:
# variant                                  final-50 (mean +/- std)     peak (mean +/- std)
# AC truncation=terminal (original)           530 +/- 310               628 +/- 318
# AC bootstrap-through-truncation             455 +/- 212               595 +/- 284
# REINFORCE EMA (reference)                   333 +/- 117               732 +/- 327
#
# Fix effect on final-50: -75 (530 -> 455).
# Gap to EMA: -196 (orig) -> -122 (fixed). Truncation handling explains MOST of the gap.
# Saved: truncation_bootstrap_ablation.png
